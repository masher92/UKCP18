# %%
import numpy as np

# %% [markdown]
# ### CEH-GEAR hourly
# Data is already just summer

# %%
cehgear_data_2001_2014 = []
cehgear_data_1990_2014 = []
resolution = "1km_reformatted"

print(resolution)
if resolution == '1km_reformatted':
    datadir = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/CEH-GEAR/{resolution}/'
else:
    datadir = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/CEH-GEAR/{resolution}/AreaWeighted/'        

for yr in range(1990, 2017):
    print(yr)
    print(len(cehgear_data_1990_2014))
    file_name = datadir + f"{yr}_compressed_GB_jja.npy"
    this_yr = np.load(file_name).astype('float32')
    
    print(np.nanmin(this_yr))
    this_yr = this_yr[this_yr >= 0.1]
    
    cehgear_data_1990_2014.extend(this_yr)  # Use extend() to add multiple elements
    if yr >= 2001:
        cehgear_data_2001_2014.extend(this_yr)

# Convert lists to NumPy arrays at the end
cehgear_data_1990_2014 = np.array(cehgear_data_1990_2014, dtype='float32')
cehgear_data_2001_2014 = np.array(cehgear_data_2001_2014, dtype='float32')

# Save the arrays
np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/CEH-GEAR/cehgear_2001-2014_{resolution}_GB_jja.npy', cehgear_data_2001_2014)
np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/CEH-GEAR/cehgear_1990-2014_{resolution}_GB_jja.npy', cehgear_data_1990_2014)
# Out:
# 1km_reformatted
# 1990
# 0.0
# 1991
# 0.0
# 1992
# 0.0
# 1993
# 0.0
# 1994
# 0.0
# 1995
# 0.0
# 1996
# 0.0
# 1997
# 0.0
# 1998
# 0.0
# 1999
# 0.0
# 2000
# 0.0
# 2001
# 0.0
# 2002
# 0.0
# 2003
# 0.0
# 2004
# 0.0
# 2005
# 0.0
# 2006
# 0.0
# 2007
# 0.0
# 2008
# 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5850/310631566.py in <module>
#      19     #print(len(this_yr))
#      20
# ---> 21     cehgear_data_1990_2014 =np.append(cehgear_data_1990_2014, this_yr)
#      22     if yr >=2001:
#      23          cehgear_data_2001_2014 =np.append(cehgear_data_2001_2014, this_yr)
#
# <__array_function__ internals> in append(*args, **kwargs)
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/numpy/lib/function_base.py in append(arr, values, axis)
#    4743         values = ravel(values)
#    4744         axis = arr.ndim-1
# ...

# %%
resolution = "2.2km_regridded" #"2.2km_regridded", "12km_regridded"
cehgear_data_2001_2014 = np.array([])
cehgear_data_1990_2014 = np.array([])

print(resolution)
if resolution =='1km_reformatted':
    datadir = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/CEH-GEAR/{resolution}/'
else:
    datadir = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/CEH-GEAR/{resolution}/AreaWeighted/'        

for yr in range(1990,2015):
    file_name = datadir + f"{yr}_compressed_GB_jja.npy"
    this_yr = np.load(file_name)
    this_yr = this_yr.astype('float32')
    print(len(this_yr))
    this_yr = this_yr[this_yr >= 0.1]
    print(len(this_yr))
    
    cehgear_data_1990_2014 =np.append(cehgear_data_1990_2014, this_yr)
    if yr >=2001:
         cehgear_data_2001_2014 =np.append(cehgear_data_2001_2014, this_yr)
            
np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/CEH-GEAR/cehgear_2001-2014_{resolution}_GB_jja.npy', cehgear_data_2001_2014)
np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/CEH-GEAR/cehgear_1990-2014_{resolution}_GB_jja.npy', cehgear_data_1990_2014)
# Out:
# 2.2km_regridded
# 102521856
# 8931886
# 102521856
# 10135215
# 102521856
# 10914942
# 102521856
# 9986105
# 102521856
# 8264869
# 102521856
# 5156294
# 102521856
# 7600617
# 102521856
# 11162002
# 102521856
# 12556629
# 102521856
# 9662324
# 102521856
# 8809947
# 102521856
# 10120805
# 102521856
# 11280053
# 102521856
# 7799091
# 102521856
# 12194363
# 102521856
# 9203358
# 102521856
# 7869443
# 102521856
# 14029651
# 102521856
# 13473675
# 102521856
# 12662968
# 102521856
# 10777142
# 102521856
# 11800884
# 102521856
# 16090569
# 102521856
# 8050301
# 102521856
# 10302584

# %% [markdown]
# ### UKCP18 hourly
# Data is already just summer

# %%
season='wholeyear'
ems = ['07', '08', '09', '10', '11', '12', '13', '15', '01','04', '05', '06', ]
resolutions = ["2.2km_bng_masked"] #"2.2km_bng_masked" "2.2km_bng_regridded_12km_masked" 
for resolution in resolutions:
    print(resolution)
    ukcp18_hrly_2001_2014 = np.array([])
    ukcp18_hrly_2001_2019 = np.array([])
    ukcp18_hrly_2006_2019 = np.array([])

    for em in ems:
        print(em)
        datadir = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/UKCP18_hourly/{resolution}/2002_2020/{em}_{season}/'
        for yr in range(2001,2020):
            # Read in data
            file_name = datadir + f"compressed_{yr}_GB_{season}.npy"
            this_yr = np.load(file_name)
            print(len(this_yr))
            this_yr = this_yr[this_yr >= 0.1]
            print(len(this_yr))

            # Full data
            ukcp18_hrly_2001_2019 = np.append(ukcp18_hrly_2001_2019, this_yr)

            # Just years overlapping with radar
            if yr >=2006:
                ukcp18_hrly_2006_2019 =np.append(ukcp18_hrly_2006_2019, this_yr)

            # Just years overlapping CEH-GEAR
            if yr <=2014:
                ukcp18_hrly_2001_2014 =np.append(ukcp18_hrly_2001_2014, this_yr)  
        print(yr, len(this_yr))
        
    np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/UKCP18_hourly/ukcp18_hrly_2001_2014_{resolution}_GB_{season}.npy', ukcp18_hrly_2001_2014)
    np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/UKCP18_hourly/ukcp18_hrly_2001_2019_{resolution}_GB_{season}.npy', ukcp18_hrly_2001_2019)
    np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/UKCP18_hourly/ukcp18_hrly_2006_2019_{resolution}_GB_{season}.npy', ukcp18_hrly_2006_2019)
# Out:
# 2.2km_bng_masked
# 07
# 382492800
# 53285527
# 382492800
# 56276883
# 382492800
# 50827211
# 382492800
# 46264115
# 382492800
# 47636475
# 382492800
# 45192335
# 382492800
# 50191321
# 382492800
# 40349552
# 382492800
# 47607087
# 382492800
# 47833152
# 382492800
# 45947632
# 382492800
# 51256298
# 382492800
# 50190035
# 382492800
# 48066210
# 382492800
# 48731680
# 382492800
# 51239232
# 382492800
# 60149915
# 382492800
# 50223859
# 382492800
# 57876355
# 2019 57876355
# 08
# 382492800
# 42054938
# 382492800
# 50807482
# 382492800
# 49548444
# 384049440
# 46947074
# 382492800
# 47800711
# 382492800
# 45518443
# 382492800
# 43355132
# 382492800
# 50166567
# 382492800
# 54417840
# 382492800
# 52373213
# 382492800
# 44262490
# 382492800
# 54627380
# 382492800
# 40300097
# 382492800
# 50261925
# 382492800
# 50179501
# 382492800
# 53554294
# 382492800
# 48857647
# 382492800
# 53054721
# 382492800
# 47577488
# 2019 47577488
# 09
# 382492800
# 49250557
# 382492800
# 45559348
# 382492800
# ...

# %%
ems = ['07', '08', '09', '10', '11', '12', '13', '15', '01','04', '05', '06', ]
resolutions = ['2.2km_bng_regridded_12km_masked'] #"2.2km_bng_masked",] # 
for resolution in resolutions:
    print(resolution)
    ukcp18_hrly_2001_2014 = np.array([])
    ukcp18_hrly_2001_2019 = np.array([])
    ukcp18_hrly_2006_2019 = np.array([])

    for em in ems:
        print(em)
        datadir = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/UKCP18_hourly/{resolution}/2002_2020/{em}/'
        for yr in range(2001,2020):
            # Read in data
            file_name = datadir + f"compressed_{yr}_GB_jja.npy"
            this_yr = np.load(file_name)
            print(len(this_yr))
            this_yr = this_yr[this_yr >= 0.1]
            print(len(this_yr))

            # Full data
            ukcp18_hrly_2001_2019 = np.append(ukcp18_hrly_2001_2019, this_yr)

            # Just years overlapping with radar
            if yr >=2006:
                ukcp18_hrly_2006_2019 =np.append(ukcp18_hrly_2006_2019, this_yr)

            # Just years overlapping CEH-GEAR
            if yr <=2014:
                ukcp18_hrly_2001_2014 =np.append(ukcp18_hrly_2001_2014, this_yr)  
        print(yr, len(this_yr))
        
    np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/UKCP18_hourly/ukcp18_hrly_2001_2014_{resolution}_GB_jja.npy', ukcp18_hrly_2001_2014)
    np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/UKCP18_hourly/ukcp18_hrly_2001_2019_{resolution}_GB_jja.npy', ukcp18_hrly_2001_2019)
    np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/UKCP18_hourly/ukcp18_hrly_2006_2019_{resolution}_GB_jja.npy', ukcp18_hrly_2006_2019)
# Out:
# 2.2km_bng_regridded_12km_masked
# 07
# 3464640
# 327083
# 3464640
# 290542
# 3464640
# 304243
# 3464640
# 379947
# 3464640
# 363198
# 3464640
# 300404
# 3464640
# 485990
# 3464640
# 303995
# 3464640
# 314403
# 3464640
# 459558
# 3464640
# 431354
# 3464640
# 391578
# 3464640
# 322852
# 3464640
# 270505
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5850/2674055422.py in <module>
#      19
#      20             # Full data
# ---> 21             ukcp18_hrly_2001_2019 = np.append(ukcp18_hrly_2001_2019, this_yr)
#      22
#      23             # Just years overlapping with radar
#
# KeyboardInterrupt:

# %% [markdown]
# ### UKCP18 30 mins

# %%
resolution = "2.2km_bng_regridded_12km_masked" #"2.2km_bng_masked"

ukcp18_30m_2001_2014 = []
ukcp18_30m_2001_2019 = []
ukcp18_30m_2006_2019 = []

ems= ['bc012', 'bc005', 'bc006', 'bc007', 'bc009', 'bc010', 'bc011', 'bc013',  'bc015',  'bc016', 'bc017', 'bc018']
for em in ems:
    print(em)
    datadir = f"/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/UKCP18_every30mins/{resolution}/2002_2020/{em}_wholeyear/"
    for yr in range(2001, 2020):
        file_name = datadir + f"compressed_{yr}_GB_jja.npy"
        this_yr = np.load(file_name)
        this_yr = this_yr.astype('float32')
        print(em, yr, len(this_yr))
        
        # Filter out values below 0.1
        this_yr = this_yr[this_yr >= 0.1]
        print(em, yr, len(this_yr))

        # Append to lists
        ukcp18_30m_2001_2019.append(this_yr)

        if yr >= 2006:
            ukcp18_30m_2006_2019.append(this_yr)

        if yr <= 2014:
            ukcp18_30m_2001_2014.append(this_yr)

# Concatenate lists into arrays
ukcp18_30m_2001_2014 = np.concatenate(ukcp18_30m_2001_2014)
ukcp18_30m_2001_2019 = np.concatenate(ukcp18_30m_2001_2019)
ukcp18_30m_2006_2019 = np.concatenate(ukcp18_30m_2006_2019)

np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/UKCP18_30mins/ukcp18_30m_2001_2014_{resolution}_jja_GB.npy', ukcp18_30m_2001_2014)
np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/UKCP18_30mins/UKCP18_30mins/ukcp18_30m_2001_2019_{resolution}_jja_GB.npy', ukcp18_30m_2001_2019)
np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/UKCP18_30mins/ukcp18_30m_2006_2019_{resolution}_jja_GB.npy', ukcp18_30m_2006_2019)
# Out:
# bc012
# bc012 2001 6929280
# bc012 2001 669709
# bc012 2002 6929280
# bc012 2002 434503
# bc012 2003 6929280
# bc012 2003 457083
# bc012 2004 6929280
# bc012 2004 667811
# bc012 2005 6929280
# bc012 2005 554541
# bc012 2006 6929280
# bc012 2006 622634
# bc012 2007 6929280
# bc012 2007 660352
# bc012 2008 6929280
# bc012 2008 649698
# bc012 2009 6929280
# bc012 2009 326838
# bc012 2010 6929280
# bc012 2010 542692
# bc012 2011 6929280
# bc012 2011 417884
# bc012 2012 6929280
# bc012 2012 576263
# bc012 2013 6929280
# bc012 2013 860529
# bc012 2014 6929280
# bc012 2014 666345
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5850/1689839243.py in <module>
#      11     for yr in range(2001, 2020):
#      12         file_name = datadir + f"compressed_{yr}_GB_jja.npy"
# ---> 13         this_yr = np.load(file_name)
#      14         this_yr = this_yr.astype('float32')
# ...

# %%
resolution = "2.2km_bng_masked"

ukcp18_30m_2001_2014 = []
ukcp18_30m_2001_2019 = []
ukcp18_30m_2006_2019 = []

ems= ['bc012', 'bc005', 'bc006', 'bc007', 'bc009', 'bc010', 'bc011', 'bc013',  'bc015',  'bc016', 'bc017', 'bc018']
for em in ems:
    print(em)
    datadir = f"/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/UKCP18_every30mins/{resolution}/2002_2020/{em}_wholeyear/"
    for yr in range(2001, 2020):
        file_name = datadir + f"compressed_{yr}_GB_jja.npy"
        this_yr = np.load(file_name)
        this_yr = this_yr.astype('float32')
        print(em, yr, len(this_yr))
        
        # Filter out values below 0.1
        this_yr = this_yr[this_yr >= 0.1]
        print(em, yr, len(this_yr))

        # Append to lists
        ukcp18_30m_2001_2019.append(this_yr)

        if yr >= 2006:
            ukcp18_30m_2006_2019.append(this_yr)

        if yr <= 2014:
            ukcp18_30m_2001_2014.append(this_yr)

# Concatenate lists into arrays
ukcp18_30m_2001_2014 = np.concatenate(ukcp18_30m_2001_2014)
ukcp18_30m_2001_2019 = np.concatenate(ukcp18_30m_2001_2019)
ukcp18_30m_2006_2019 = np.concatenate(ukcp18_30m_2006_2019)

np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/UKCP18_30mins/ukcp18_30m_2001_2014_{resolution}_jja_GB.npy', ukcp18_30m_2001_2014)
np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/UKCP18_30mins/UKCP18_30mins/ukcp18_30m_2001_2019_{resolution}_jja_GB.npy', ukcp18_30m_2001_2019)
np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/UKCP18_30mins/ukcp18_30m_2006_2019_{resolution}_jja_GB.npy', ukcp18_30m_2006_2019)
# Out:
# bc005
# bc005 2001 6929280
# bc005 2002 6929280
# bc005 2003 6929280
# bc005 2004 6929280
# bc005 2005 6929280
# bc005 2006 6929280
# bc005 2007 6929280
# bc005 2008 6929280
# bc005 2009 6929280
# bc005 2010 6929280
# bc005 2011 6929280
# bc005 2012 6929280
# bc005 2013 6929280
# bc005 2014 6929280
# bc005 2015 6929280
# bc005 2016 6929280
# bc005 2017 6929280
# bc005 2018 6929280
# bc005 2019 6929280
# bc006
# bc006 2001 6929280
# bc006 2002 6929280
# bc006 2003 6929280
# bc006 2004 6929280
# bc006 2005 6929280
# bc006 2006 6929280
# bc006 2007 6929280
# bc006 2008 6929280
# bc006 2009 6929280
# bc006 2010 6929280
# bc006 2011 6929280
# bc006 2012 6929280
# bc006 2013 6929280
# bc006 2014 6929280
# bc006 2015 6929280
# bc006 2016 6929280
# bc006 2017 6929280
# bc006 2018 6929280
# bc006 2019 6929280
# bc007
# bc007 2001 6929280
# bc007 2002 6929280
# bc007 2003 6929280
# bc007 2004 6929280
# bc007 2005 6929280
# bc007 2006 6929280
# bc007 2007 6929280
# bc007 2008 6929280
# ...

# %% [markdown]
# ### NIMROD

# %%
NIMROD_2006_2019 = np.array([])

datadir = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/NIMROD/30mins/NIMROD_regridded_12km/'

for yr in range(2006,2020):
    file_name = datadir + f"compressed_{yr}_filtered_100_GB_jja.npy"
    this_yr = np.load(file_name)
    this_yr = this_yr.astype('float32')
    print(len(this_yr))
    this_yr = this_yr[this_yr >= 0.1]
    print(len(this_yr))
    NIMROD_2006_2019 =np.append(NIMROD_2006_2019, this_yr)
np.save('/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/NIMROD/NIMROD_2006_2019_jja_GB_new.npy', NIMROD_2006_2019)
# Out:
# 10774071
# 974007
# 11193952
# 1709289
# 11206011
# 1796054
# 10192678
# 1496511
# 11664843
# 1430174
# 11884917
# 1773833
# 11910955
# 2371858
# 11930294
# 1375464
# 11796596
# 1558302
# 11582722
# 1816746
# 11895935
# 1778615
# 11804747
# 1940073
# 11527014
# 1090685
# 11465961
# 1972984

# %%
NIMROD_2006_2019 = []
resolution = "1km_reformatted"

datadir = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/NIMROD/30mins/NIMROD_regridded_12km/'        

for yr in range(1990, 2017):
    print(yr)
    print(len(cehgear_data_1990_2014))
    file_name = datadir + f"{yr}_compressed_GB_jja.npy"
    this_yr = np.load(file_name).astype('float32')
    
    print(np.nanmin(this_yr))
    this_yr = this_yr[this_yr >= 0.1]
    
    cehgear_data_1990_2014.extend(this_yr)  # Use extend() to add multiple elements
    if yr >= 2001:
        cehgear_data_2001_2014.extend(this_yr)

# Convert lists to NumPy arrays at the end
cehgear_data_1990_2014 = np.array(cehgear_data_1990_2014, dtype='float32')
cehgear_data_2001_2014 = np.array(cehgear_data_2001_2014, dtype='float32')

# Save the arrays
np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/CEH-GEAR/cehgear_2001-2014_{resolution}_GB_jja.npy', cehgear_data_2001_2014)
np.save(f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/CEH-GEAR/cehgear_1990-2014_{resolution}_GB_jja.npy', cehgear_data_1990_2014)
# Out:
# 180937794
# 15098394
# 189265232
# 26449735
# 186508625
# 27058744
# 169281118
# 22383462
# 196474210
# 22874076
# 197725751
# 26908808
# 197900914
# 34722425
# 197897328
# 20785875
# 195747211
# 22108458
# 192123823
# 27088956
# 197349833
# 26053160
# 196324750
# 28382133
# 191654937
# 15742208
# 191849604
# 30021447
