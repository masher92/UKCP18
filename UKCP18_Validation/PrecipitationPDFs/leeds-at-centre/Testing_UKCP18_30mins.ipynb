# %%
import numpy as np
import iris
import pandas as pd
import sys
import os
import datetime
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

resolution = '2.2km'
em ='bc005'

# %%
# ukcp_hourly_2_2km_fp = f"/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/UKCP18_hourly/{resolution}/{yrs_range}/leeds-at-centre/{em_H}/leeds-at-centre_jja.npy"

# %% [markdown]
# ### Check for 30 mins data the minimum value
# These are currently all negative because they still contain the 2000 and 2020 data

# %%
# ems= ['bc005',  'bc006',  'bc007', 'bc009',  'bc010', 
#        'bc011', 'bc013',  'bc015',  'bc016',  'bc017', 'bc018', 'bc012']
# for em in ems:
#     ukcp_30m_2_2km_fp = f"/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/UKCP18_every30mins/{resolution}/2002_2020/{em}/leeds-at-centre_jja.npy"
#     precip_data_30m = np.load(ukcp_30m_2_2km_fp)
#     print(np.nanmin(precip_data_30m))

# %%
# import matplotlib.pyplot as plt
# y_axis_scaling = 'log'
# hist, bins = np.histogram(precip_data_30m, bins=100)
# bin_centers = (bins[1:]+bins[:-1])*0.5
# plt.plot(bin_centers, hist)
# plt.yscale(y_axis_scaling)
# plt.xlabel('Precipitation (mm/hr')
# plt.ylabel('Probability density')

# %%
ems= ['01', '04', '05', '06', '07', '09', '10', '11', '12', '13', '15']
for em in ems:
    ukcp_30m_2_2km_fp = f"/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/UKCP18_every30mins/{resolution}/2002_2020/{em}/leeds-at-centre_jja.npy"
    precip_data_30m = np.load(ukcp_30m_2_2km_fp)
    print(np.nanmin(precip_data_30m))
# Out:
# Text(0, 0.5, 'Probability density')

# %%
# precip_data_all_ems = np.array([])
# ems = ['05', '06','07', '09', '11', '12', '13', '15', '17', '18']
# for em in ems:
#         print(em)
#         # Get data
#         precip_data = np.load(f"combined_data/ens{em}_leeds-at-centre_jjaonly.npy")  
#         # Convert units
#         precip_data_mm_hr =precip_data *8640 
#         # add to array containing data for all ensemble members
#         precip_data_all_ems = np.concatenate((precip_data_all_ems, precip_data_mm_hr))
