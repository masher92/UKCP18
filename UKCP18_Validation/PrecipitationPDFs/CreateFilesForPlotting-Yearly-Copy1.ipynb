# %%
import numpy as np
import os

season='wholeyear'

# %% [markdown]
# ### CEH-GEAR hourly
# Data is already just summer

# %%
cehgear = []
resolution = "2.2km_regridded"

output_file = f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/CEH-GEAR/cehgear_1990-2016_{resolution}_GB_{season}.npy'

print(resolution)
if resolution == '1km_reformatted':
    datadir = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/CEH-GEAR/{resolution}/'
else:
    datadir = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/CEH-GEAR/{resolution}/AreaWeighted/'        

    
for yr in range(1990,2017):
    file_name = os.path.join(datadir + f"{yr}_compressed_GB_jja.npy")

    if os.path.exists(file_name):
        # Load yearly data
        this_yr = np.load(file_name, mmap_mode='r')  # Memory-map for efficiency
        print(f"Processing: {yr} | Original size: {this_yr.size}")

        # Filter out values below 0.1
        this_yr = this_yr[this_yr >= 0.1]
        print(f"Filtered size: {this_yr.size}")

        # Append to the output file incrementally
        with open(output_file, 'ab') as f:
            np.save(f, this_yr)
# Out:
# 2.2km_regridded
# Processing: 1990 | Original size: 102521856
# Filtered size: 8931886
# Processing: 1991 | Original size: 102521856
# Filtered size: 10135215
# Processing: 1992 | Original size: 102521856
# Filtered size: 10914942
# Processing: 1993 | Original size: 102521856
# Filtered size: 9986105
# Processing: 1994 | Original size: 102521856
# Filtered size: 8264869
# Processing: 1995 | Original size: 102521856
# Filtered size: 5156294
# Processing: 1996 | Original size: 102521856
# Filtered size: 7600617
# Processing: 1997 | Original size: 102521856
# Filtered size: 11162002
# Processing: 1998 | Original size: 102521856
# Filtered size: 12556629
# Processing: 1999 | Original size: 102521856
# Filtered size: 9662324
# Processing: 2000 | Original size: 102521856
# Filtered size: 8809947
# Processing: 2001 | Original size: 102521856
# Filtered size: 10120805
# Processing: 2002 | Original size: 102521856
# Filtered size: 11280053
# Processing: 2003 | Original size: 102521856
# ...

# %% [markdown]
# ### UKCP18 hourly
# Data is already just summer

# %%
import os
ems = ['01','04', '05', '06', '07', '08', '09', '10', '11', '12', '13', '15', ]
season = 'wholeyear'
resolution = "2.2km_bng_masked"

output_file = f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/UKCP18_hourly/ukcp18_hrly_{resolution}_GB_{season}_allvals.npy'

# Ensure the output file does not exist before starting
if os.path.exists(output_file):
    os.remove(output_file)

for em in ems:
    datadir = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/UKCP18_hourly/{resolution}/2002_2020/{em}_{season}/'

    for yr in range(2001, 2020):
        file_name = os.path.join(datadir, f"compressed_{yr}_GB_{season}.npy")

        if os.path.exists(file_name):
            # Load yearly data
            this_yr = np.load(file_name, mmap_mode='r')  # Memory-map for efficiency
            print(f"Processing: {em} {yr} | Original size: {this_yr.size}")

            # Filter out values below 0.1
            # this_yr = this_yr[this_yr >= 0.05]
            print(f"Filtered size: {this_yr.size}")

            # Append to the output file incrementally
            with open(output_file, 'ab') as f:
                np.save(f, this_yr)

print(f"Data saved to: {output_file}")
# Out:
# Processing: 01 2001 | Original size: 382492800
# Filtered size: 382492800
# Processing: 01 2002 | Original size: 382492800
# Filtered size: 382492800
# Processing: 01 2003 | Original size: 382492800
# Filtered size: 382492800
# Processing: 01 2004 | Original size: 382492800
# Filtered size: 382492800
# Processing: 01 2005 | Original size: 382492800
# Filtered size: 382492800
# Processing: 01 2006 | Original size: 382492800
# Filtered size: 382492800
# Processing: 01 2007 | Original size: 382492800
# Filtered size: 382492800
# Processing: 01 2008 | Original size: 382492800
# Filtered size: 382492800
# Processing: 01 2009 | Original size: 382492800
# Filtered size: 382492800
# Processing: 01 2010 | Original size: 382492800
# Filtered size: 382492800
# Processing: 01 2011 | Original size: 382492800
# Filtered size: 382492800
# Processing: 01 2012 | Original size: 382492800
# Filtered size: 382492800
# Processing: 01 2013 | Original size: 382492800
# Filtered size: 382492800
# ...

# %% [markdown]
# ### UKCP18 30 mins

# %%
import os
ems = ['bc012', 'bc005', 'bc006', 'bc007', 'bc009', 'bc010', 'bc011', 'bc013', 'bc015', 'bc016', 'bc017', 'bc018']
season = 'wholeyear'
resolution = "2.2km_bng_masked"

output_file = f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/UKCP18_30mins/ukcp18_30m_{resolution}_GB_{season}.npy'

# Ensure the output file does not exist before starting
if os.path.exists(output_file):
    os.remove(output_file)

for em in ems:
    datadir = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/UKCP18_every30mins/{resolution}/2002_2020/{em}_{season}/'

    for yr in range(2001, 2020):
        file_name = os.path.join(datadir, f"compressed_{yr}_GB_{season}.npy")

        if os.path.exists(file_name):
            # Load yearly data
            this_yr = np.load(file_name, mmap_mode='r')  # Memory-map for efficiency
            print(f"Processing: {em} {yr} | Original size: {this_yr.size}")

            # Filter out values below 0.1
            this_yr = this_yr[this_yr >= 0.05]
            print(f"Filtered size: {this_yr.size}")

            # Append to the output file incrementally
            with open(output_file, 'ab') as f:
                np.save(f, this_yr)

print(f"Data saved to: {output_file}")
# Out:
# Processing: bc012 2001 | Original size: 764985600
# Filtered size: 89714907
# Processing: bc012 2002 | Original size: 764985600
# Filtered size: 88281121
# Processing: bc012 2003 | Original size: 764985600
# Filtered size: 83472975
# Processing: bc012 2004 | Original size: 764985600
# Filtered size: 100376395
# Processing: bc012 2005 | Original size: 764985600
# Filtered size: 107987241
# Processing: bc012 2006 | Original size: 764985600
# Filtered size: 107073410
# Processing: bc012 2007 | Original size: 764985600
# Filtered size: 106846944
# Processing: bc012 2008 | Original size: 764985600
# Filtered size: 99001053
# Processing: bc012 2009 | Original size: 764985600
# Filtered size: 75177100
# Processing: bc012 2010 | Original size: 764985600
# Filtered size: 98411649
# Processing: bc012 2011 | Original size: 764985600
# Filtered size: 88297637
# Processing: bc012 2012 | Original size: 764985600
# Filtered size: 88834275
# Processing: bc012 2013 | Original size: 764985600
# ...

# %% [markdown]
# ### NIMROD

# %%
season = 'wholeyear'
resolution = "2.2km_bng_masked"

output_file = f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/NIMROD/30mins/nimrod_{resolution}_2006_2019_GB_{season}.npy'

# Ensure the output file does not exist before starting
if os.path.exists(output_file):
    os.remove(output_file)

datadir = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/NIMROD/30mins/NIMROD_regridded_2.2km/'

for yr in range(2006, 2020):
    print(yr)
    file_name = os.path.join(datadir, f"compressed_{yr}_unfiltered_GB_{season}.npy")

    if os.path.exists(file_name):
        # Load yearly data
        this_yr = np.load(file_name, mmap_mode='r')  # Memory-map for efficiency
        print(f"Processing: {yr} | Original size: {this_yr.size}")

        # Filter out values below 0.1
        this_yr = this_yr[this_yr >= 0.05]
        print(f"Filtered size: {this_yr.size}")

        # Append to the output file incrementally
        with open(output_file, 'ab') as f:
            np.save(f, this_yr)

print(f"Data saved to: {output_file}")
# Out:
# 2006
# Processing: 2006 | Original size: 718352035
# Filtered size: 112611972
# 2007
# 2008
# Processing: 2008 | Original size: 488852719
# Filtered size: 97807578
# 2009
# Processing: 2009 | Original size: 479801305
# Filtered size: 86784186
# 2010
# Processing: 2010 | Original size: 464839638
# Filtered size: 78512923
# 2011
# Processing: 2011 | Original size: 500577432
# Filtered size: 94780974
# 2012
# Processing: 2012 | Original size: 510529401
# Filtered size: 106333662
# 2013
# Processing: 2013 | Original size: 512478606
# Filtered size: 91861634
# 2014
# Processing: 2014 | Original size: 508456389
# Filtered size: 93673879
# 2015
# Processing: 2015 | Original size: 496263801
# Filtered size: 96286986
# 2016
# Processing: 2016 | Original size: 506896035
# Filtered size: 88717505
# 2017
# Processing: 2017 | Original size: 503161590
# Filtered size: 90006530
# 2018
# Processing: 2018 | Original size: 501572063
# Filtered size: 82382097
# 2019
# ...

# %% [markdown]
# ### NIMROD hourly

# %%
season = 'wholeyear'
resolution = "2.2km_bng_masked"

output_file = f'/nfs/a319/gy17m2a/PhD/ProcessedData/PDF_Plotting/NIMROD/nimrod_1hr_{resolution}_GB_{season}_allvals.npy'

# Ensure the output file does not exist before starting
if os.path.exists(output_file):
    os.remove(output_file)

datadir = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/NIMROD/1hr/NIMROD_regridded_2.2km/'

for yr in range(2006, 2020):
    file_name = os.path.join(datadir, f"compressed_{yr}_unfiltered_GB_{season}.npy")

    if os.path.exists(file_name):
        # Load yearly data
        this_yr = np.load(file_name, mmap_mode='r')  # Memory-map for efficiency
        print(f"Processing: {yr} | Original size: {this_yr.size}")

        # Filter out values below 0.1
        # this_yr = this_yr[this_yr >= 0.1]
        print(f"Filtered size: {this_yr.size}")

        # Append to the output file incrementally
        with open(output_file, 'ab') as f:
            np.save(f, this_yr)

print(f"Data saved to: {output_file}")
# Out:
# Processing: 2006 | Original size: 362893349
# Filtered size: 362893349
# Processing: 2007 | Original size: 373108670
# Filtered size: 373108670
# Processing: 2008 | Original size: 373819569
# Filtered size: 373819569
# Processing: 2009 | Original size: 373416011
# Filtered size: 373416011
# Processing: 2010 | Original size: 343063282
# Filtered size: 343063282
# Processing: 2012 | Original size: 390547390
# Filtered size: 390547390
# Processing: 2013 | Original size: 391621458
# Filtered size: 391621458
# Processing: 2014 | Original size: 389515695
# Filtered size: 389515695
# Processing: 2016 | Original size: 386364370
# Filtered size: 386364370
# Processing: 2017 | Original size: 383034018
# Filtered size: 383034018
# Processing: 2018 | Original size: 384215253
# Filtered size: 384215253
# Processing: 2019 | Original size: 383483801
# Filtered size: 383483801
# ...
