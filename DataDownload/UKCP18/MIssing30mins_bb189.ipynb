# %%
# bc018, bc016, bc015, bc011, bc010,

import iris
import os
import glob as glob
import datetime as datetime
import iris.coord_categorisation as cat
import sys
import iris.plot as iplt

# Set up path to root directory
root_fp = "/nfs/a319/gy17m2a/PhD/"
os.chdir(root_fp)

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

# Create path to files containing functions
sys.path.insert(0, root_fp + 'Scripts/GlobalFunctions')
from Spatial_plotting_functions import *
from Spatial_geometry_functions import *

# ### Load necessary spatial data
# This is a square area surrounding Leeds
leeds_at_centre_gdf = create_leeds_at_centre_outline({'init' :'epsg:3857'})

# ### Establish the corresponding ensemble member numbers
em_matching_dict = {'01':'bc005', '04': 'bc006', '05': 'bc007', '06':'bc009',  '07':'bc010', 
                    '08': 'bc011', '09':'bc013', '10': 'bc015', '11': 'bc016', '12': 'bc017', '13':'bc018', '15':'bc012'}
em_matching_dict = {'01':'bb189', '06':'bb198'}

resolution = '2.2km_original'
yrs_range = "2060_2081"

for em_1hr in ['01']:
    em_30mins = em_matching_dict[em_1hr]

    for yr in range(2061,2081):
        for month_num in ['01', '02', '03', '04', '05', '06','07','08','09', '10','11','12']:
            print(f"em{em_1hr}, yr {yr}, month {month_num}")
            if (os.path.isfile(f"/nfs/a319/gy17m2a/PhD/datadir/UKCP18_every30mins/{resolution}/{yrs_range}/{em_30mins}/{em_30mins}a.pr{yr}{month_num}.nc")):
                print("already exists")
            else:
                print(f"Running for month {month_num} in {yr}, for {em_1hr} (which equatees to {em_30mins})")
                try:
                    ####################################################### 
                    #######################################################
                    ## Get one month of data - HOURLY
                    ####################################################### 
                    #######################################################
                    ### Get a list of filenames for hourly data
                    general_filename_1hr = f'/nfs/a319/gy17m2a/PhD/datadir/UKCP18_hourly/2.2km_original/{em_1hr}/{yrs_range}/pr_rcp85_land-cpm_uk_2.2km_{em_1hr}_1hr_{yr}{month_num}*'
                    filenames_1hr = []
                    for filename in glob.glob(general_filename_1hr):
                            filenames_1hr.append(filename)

                    # ### Load in the data and remove the ensemble member dimension
                    monthly_cubes_list_1hr = iris.load(filenames_1hr)
                    cube_1hr = monthly_cubes_list_1hr[0]
                    cube_1hr = cube_1hr[0,:,:,:]

                    # ### Trim to Leeds
                    # cube_1hr = trim_to_bbox_of_region(cube_1hr, leeds_at_centre_gdf)

                    #######################################################
                    #######################################################
                    ## Get one month of data - 30mins
                    #######################################################
                    #######################################################
                    # ### Get all files for this ensemble member
                    general_filename_30mins = f'/nfs/a319/gy17m2a/PhD/datadir/UKCP18_first30mins/{yrs_range}/{em_30mins}/{em_30mins}a.pr{yr}{month_num}*'
                    filenames_first30mins = []
                    for filename_30mins in glob.glob(general_filename_30mins):
                        filenames_first30mins.append(filename_30mins)
                    filenames_first30mins.sort()

                    # ### Load in the data 
                    monthly_cubes_list_30mins = iris.load(filenames_first30mins)

                    # Equalise
                    for cube in monthly_cubes_list_30mins:
                        for attr in ['forecast_period', 'forecast_reference_time']:
                            if attr in cube.attributes:
                                del cube.attributes[attr]


                    monthly_cube_30mins = monthly_cubes_list_30mins.concatenate_cube()      

                    # ### Trim to be the same shape as the hourly data
                    # monthly_cube_30mins_1st = trim_to_bbox_of_region_30mins(monthly_cube_30mins, leeds_at_centre_gdf)
                    monthly_cube_30mins_1st = monthly_cube_30mins[:,24:-24,24:-24]

                    # ### Convert units of 30 mins data
                    # Check current units
                    # print(monthly_cube_30mins_1st.units)
                    # Set the units to those of the 1 hr cube
                    monthly_cube_30mins_1st.units = cube_1hr.units
                    # print(monthly_cube_30mins_1st.units)

                    # Convert the data to also be this unit
                    monthly_cube_30mins_1st_data = monthly_cube_30mins_1st.data
                    monthly_cube_30mins_1st_data = monthly_cube_30mins_1st_data*3600

                    monthly_cube_30mins_1st.data = monthly_cube_30mins_1st_data


                    #######################################################
                    #######################################################
                    ## Find the second half of the hour, using the first half of hour and hourly values
                    #######################################################
                    #######################################################
                    # get the hourly data
                    cube_1hr_data = cube_1hr.data
                    # calculate value for second half of hour
                    second_half_of_the_hour_mean_hourly_rainfall_rate_data = 2*cube_1hr_data-monthly_cube_30mins_1st_data
                    # Create a new cube for the second half of the hour (start by copying the first half of hour cube)
                    monthly_cube_30mins_2nd = monthly_cube_30mins_1st.copy()
                    # Set values as calculated
                    monthly_cube_30mins_2nd.data = second_half_of_the_hour_mean_hourly_rainfall_rate_data


                    # ### Edit the times to be 30 mins later
                    # get the times from the first half hour
                    first_half_hour_times = monthly_cube_30mins_1st.coord('time').copy()
                    # add 30 mins
                    second_half_hour_times = first_half_hour_times + 0.5
                    # for the second hald hour cube, remove the time dimension and then re-add the edited one
                    monthly_cube_30mins_2nd.remove_coord('time')
                    monthly_cube_30mins_2nd.add_dim_coord(second_half_hour_times, 0)

                    #######################################################
                    #######################################################
                    ## Join first half hour and second half hour into one cube
                    #######################################################
                    #######################################################
                    # ### Get a list of all the cubes in each of the monthly cubes
                    list_30mins_1st = iris.cube.CubeList(monthly_cube_30mins_1st.slices_over('time'))
                    list_30mins_2nd = iris.cube.CubeList(monthly_cube_30mins_2nd.slices_over('time'))
                    list_30mins = list_30mins_1st +  list_30mins_2nd

                    ### Merge back into one cube
                    monthly_cube_30mins = list_30mins.merge_cube()

                    #######################################################
                    #######################################################
                    ## Save
                    #######################################################
                    #######################################################
                    dir_to_save = f"datadir/UKCP18_every30mins/{resolution}/{yrs_range}/{em_30mins}/"

                    if os.path.isdir(dir_to_save):
                        print("Exists")
                    else:
                        print("Doesn't exist")
                        os.makedirs(dir_to_save)
                    fp_to_save = f"datadir/UKCP18_every30mins/{resolution}/{yrs_range}/{em_30mins}/{em_30mins}a.pr{yr}{month_num}.nc" 
                    print(fp_to_save)
                    iris.save(monthly_cube_30mins, fp_to_save)
                except Exception as e:
                    # Print the error message for any other exceptions
                    print(f"An error occurred: {e}")
# Out:
# em01, yr 2061, month 01
# already exists
# em01, yr 2061, month 02
# already exists
# em01, yr 2061, month 03
# already exists
# em01, yr 2061, month 04
# already exists
# em01, yr 2061, month 05
# already exists
# em01, yr 2061, month 06
# already exists
# em01, yr 2061, month 07
# already exists
# em01, yr 2061, month 08
# already exists
# em01, yr 2061, month 09
# already exists
# em01, yr 2061, month 10
# already exists
# em01, yr 2061, month 11
# already exists
# em01, yr 2061, month 12
# already exists
# em01, yr 2062, month 01
# already exists
# em01, yr 2062, month 02
# already exists
# em01, yr 2062, month 03
# already exists
# em01, yr 2062, month 04
# already exists
# em01, yr 2062, month 05
# already exists
# em01, yr 2062, month 06
# already exists
# em01, yr 2062, month 07
# already exists
# em01, yr 2062, month 08
# already exists
# em01, yr 2062, month 09
# already exists
# em01, yr 2062, month 10
# already exists
# em01, yr 2062, month 11
# Running for month 11 in 2062, for 01 (which equatees to bb189)
# An error occurred: operands could not be broadcast together with shapes (720,606,484) (696,606,484)
# em01, yr 2062, month 12
# already exists
# em01, yr 2063, month 01
# already exists
# em01, yr 2063, month 02
# already exists
# em01, yr 2063, month 03
# already exists
# em01, yr 2063, month 04
# already exists
# em01, yr 2063, month 05
# already exists
# em01, yr 2063, month 06
# Running for month 06 in 2063, for 01 (which equatees to bb189)
# An error occurred: operands could not be broadcast together with shapes (720,606,484) (696,606,484)
# em01, yr 2063, month 07
# Running for month 07 in 2063, for 01 (which equatees to bb189)
# An error occurred: operands could not be broadcast together with shapes (720,606,484) (696,606,484)
# em01, yr 2063, month 08
# already exists
# em01, yr 2063, month 09
# already exists
# em01, yr 2063, month 10
# Running for month 10 in 2063, for 01 (which equatees to bb189)
# An error occurred: operands could not be broadcast together with shapes (720,606,484) (696,606,484)
# em01, yr 2063, month 11
# already exists
# em01, yr 2063, month 12
# already exists
# em01, yr 2064, month 01
# already exists
# em01, yr 2064, month 02
# already exists
# em01, yr 2064, month 03
# already exists
# em01, yr 2064, month 04
# already exists
# em01, yr 2064, month 05
# already exists
# em01, yr 2064, month 06
# already exists
# em01, yr 2064, month 07
# already exists
# em01, yr 2064, month 08
# already exists
# em01, yr 2064, month 09
# already exists
# em01, yr 2064, month 10
# already exists
# em01, yr 2064, month 11
# already exists
# em01, yr 2064, month 12
# already exists
# em01, yr 2065, month 01
# already exists
# em01, yr 2065, month 02
# already exists
# em01, yr 2065, month 03
# already exists
# em01, yr 2065, month 04
# already exists
# em01, yr 2065, month 05
# already exists
# em01, yr 2065, month 06
# already exists
# em01, yr 2065, month 07
# already exists
# em01, yr 2065, month 08
# already exists
# em01, yr 2065, month 09
# already exists
# em01, yr 2065, month 10
# already exists
# em01, yr 2065, month 11
# already exists
# em01, yr 2065, month 12
# already exists
# em01, yr 2066, month 01
# already exists
# em01, yr 2066, month 02
# already exists
# em01, yr 2066, month 03
# already exists
# em01, yr 2066, month 04
# already exists
# em01, yr 2066, month 05
# already exists
# em01, yr 2066, month 06
# already exists
# em01, yr 2066, month 07
# already exists
# em01, yr 2066, month 08
# already exists
# em01, yr 2066, month 09
# already exists
# em01, yr 2066, month 10
# already exists
# em01, yr 2066, month 11
# already exists
# em01, yr 2066, month 12
# already exists
# em01, yr 2067, month 01
# already exists
# em01, yr 2067, month 02
# already exists
# em01, yr 2067, month 03
# already exists
# em01, yr 2067, month 04
# already exists
# em01, yr 2067, month 05
# already exists
# em01, yr 2067, month 06
# already exists
# em01, yr 2067, month 07
# already exists
# em01, yr 2067, month 08
# already exists
# em01, yr 2067, month 09
# already exists
# em01, yr 2067, month 10
# already exists
# em01, yr 2067, month 11
# already exists
# em01, yr 2067, month 12
# already exists
# em01, yr 2068, month 01
# already exists
# em01, yr 2068, month 02
# already exists
# em01, yr 2068, month 03
# already exists
# em01, yr 2068, month 04
# already exists
# em01, yr 2068, month 05
# already exists
# em01, yr 2068, month 06
# already exists
# em01, yr 2068, month 07
# already exists
# em01, yr 2068, month 08
# already exists
# em01, yr 2068, month 09
# already exists
# em01, yr 2068, month 10
# already exists
# em01, yr 2068, month 11
# already exists
# em01, yr 2068, month 12
# already exists
# em01, yr 2069, month 01
# already exists
# em01, yr 2069, month 02
# already exists
# em01, yr 2069, month 03
# already exists
# em01, yr 2069, month 04
# already exists
# em01, yr 2069, month 05
# already exists
# em01, yr 2069, month 06
# already exists
# em01, yr 2069, month 07
# already exists
# em01, yr 2069, month 08
# already exists
# em01, yr 2069, month 09
# already exists
# em01, yr 2069, month 10
# already exists
# em01, yr 2069, month 11
# already exists
# em01, yr 2069, month 12
# already exists
# em01, yr 2070, month 01
# already exists
# em01, yr 2070, month 02
# already exists
# em01, yr 2070, month 03
# already exists
# em01, yr 2070, month 04
# already exists
# em01, yr 2070, month 05
# already exists
# em01, yr 2070, month 06
# already exists
# em01, yr 2070, month 07
# already exists
# em01, yr 2070, month 08
# already exists
# em01, yr 2070, month 09
# already exists
# em01, yr 2070, month 10
# already exists
# em01, yr 2070, month 11
# already exists
# em01, yr 2070, month 12
# already exists
# em01, yr 2071, month 01
# already exists
# em01, yr 2071, month 02
# already exists
# em01, yr 2071, month 03
# already exists
# em01, yr 2071, month 04
# already exists
# em01, yr 2071, month 05
# already exists
# em01, yr 2071, month 06
# already exists
# em01, yr 2071, month 07
# already exists
# em01, yr 2071, month 08
# already exists
# em01, yr 2071, month 09
# already exists
# em01, yr 2071, month 10
# already exists
# em01, yr 2071, month 11
# already exists
# em01, yr 2071, month 12
# already exists
# em01, yr 2072, month 01
# already exists
# em01, yr 2072, month 02
# already exists
# em01, yr 2072, month 03
# already exists
# em01, yr 2072, month 04
# already exists
# em01, yr 2072, month 05
# already exists
# em01, yr 2072, month 06
# already exists
# em01, yr 2072, month 07
# already exists
# em01, yr 2072, month 08
# already exists
# em01, yr 2072, month 09
# already exists
# em01, yr 2072, month 10
# already exists
# em01, yr 2072, month 11
# already exists
# em01, yr 2072, month 12
# already exists
# em01, yr 2073, month 01
# already exists
# em01, yr 2073, month 02
# already exists
# em01, yr 2073, month 03
# already exists
# em01, yr 2073, month 04
# already exists
# em01, yr 2073, month 05
# already exists
# em01, yr 2073, month 06
# Running for month 06 in 2073, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207306.nc
# em01, yr 2073, month 07
# Running for month 07 in 2073, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207307.nc
# em01, yr 2073, month 08
# Running for month 08 in 2073, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207308.nc
# em01, yr 2073, month 09
# Running for month 09 in 2073, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207309.nc
# em01, yr 2073, month 10
# Running for month 10 in 2073, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207310.nc
# em01, yr 2073, month 11
# Running for month 11 in 2073, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207311.nc
# em01, yr 2073, month 12
# Running for month 12 in 2073, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207312.nc
# em01, yr 2074, month 01
# Running for month 01 in 2074, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207401.nc
# em01, yr 2074, month 02
# Running for month 02 in 2074, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207402.nc
# em01, yr 2074, month 03
# Running for month 03 in 2074, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207403.nc
# em01, yr 2074, month 04
# Running for month 04 in 2074, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207404.nc
# em01, yr 2074, month 05
# Running for month 05 in 2074, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207405.nc
# em01, yr 2074, month 06
# Running for month 06 in 2074, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207406.nc
# em01, yr 2074, month 07
# Running for month 07 in 2074, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207407.nc
# em01, yr 2074, month 08
# Running for month 08 in 2074, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207408.nc
# em01, yr 2074, month 09
# Running for month 09 in 2074, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207409.nc
# em01, yr 2074, month 10
# Running for month 10 in 2074, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207410.nc
# em01, yr 2074, month 11
# Running for month 11 in 2074, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207411.nc
# em01, yr 2074, month 12
# Running for month 12 in 2074, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207412.nc
# em01, yr 2075, month 01
# Running for month 01 in 2075, for 01 (which equatees to bb189)
# An error occurred: operands could not be broadcast together with shapes (720,606,484) (696,606,484)
# em01, yr 2075, month 02
# Running for month 02 in 2075, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207502.nc
# em01, yr 2075, month 03
# Running for month 03 in 2075, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207503.nc
# em01, yr 2075, month 04
# Running for month 04 in 2075, for 01 (which equatees to bb189)
# An error occurred: operands could not be broadcast together with shapes (720,606,484) (696,606,484)
# em01, yr 2075, month 05
# Running for month 05 in 2075, for 01 (which equatees to bb189)
# An error occurred: operands could not be broadcast together with shapes (720,606,484) (696,606,484)
# em01, yr 2075, month 06
# Running for month 06 in 2075, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207506.nc
# em01, yr 2075, month 07
# Running for month 07 in 2075, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207507.nc
# em01, yr 2075, month 08
# Running for month 08 in 2075, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207508.nc
# em01, yr 2075, month 09
# Running for month 09 in 2075, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207509.nc
# em01, yr 2075, month 10
# Running for month 10 in 2075, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207510.nc
# em01, yr 2075, month 11
# Running for month 11 in 2075, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207511.nc
# em01, yr 2075, month 12
# Running for month 12 in 2075, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207512.nc
# em01, yr 2076, month 01
# Running for month 01 in 2076, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207601.nc
# em01, yr 2076, month 02
# Running for month 02 in 2076, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207602.nc
# em01, yr 2076, month 03
# Running for month 03 in 2076, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207603.nc
# em01, yr 2076, month 04
# Running for month 04 in 2076, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207604.nc
# em01, yr 2076, month 05
# Running for month 05 in 2076, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207605.nc
# em01, yr 2076, month 06
# Running for month 06 in 2076, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207606.nc
# em01, yr 2076, month 07
# Running for month 07 in 2076, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207607.nc
# em01, yr 2076, month 08
# Running for month 08 in 2076, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207608.nc
# em01, yr 2076, month 09
# Running for month 09 in 2076, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207609.nc
# em01, yr 2076, month 10
# Running for month 10 in 2076, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207610.nc
# em01, yr 2076, month 11
# Running for month 11 in 2076, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207611.nc
# em01, yr 2076, month 12
# Running for month 12 in 2076, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207612.nc
# em01, yr 2077, month 01
# Running for month 01 in 2077, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207701.nc
# em01, yr 2077, month 02
# Running for month 02 in 2077, for 01 (which equatees to bb189)
# An error occurred: operands could not be broadcast together with shapes (720,606,484) (696,606,484)
# em01, yr 2077, month 03
# Running for month 03 in 2077, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207703.nc
# em01, yr 2077, month 04
# Running for month 04 in 2077, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207704.nc
# em01, yr 2077, month 05
# Running for month 05 in 2077, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207705.nc
# em01, yr 2077, month 06
# Running for month 06 in 2077, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207706.nc
# em01, yr 2077, month 07
# Running for month 07 in 2077, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207707.nc
# em01, yr 2077, month 08
# Running for month 08 in 2077, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207708.nc
# em01, yr 2077, month 09
# Running for month 09 in 2077, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207709.nc
# em01, yr 2077, month 10
# Running for month 10 in 2077, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207710.nc
# em01, yr 2077, month 11
# Running for month 11 in 2077, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207711.nc
# em01, yr 2077, month 12
# Running for month 12 in 2077, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207712.nc
# em01, yr 2078, month 01
# Running for month 01 in 2078, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207801.nc
# em01, yr 2078, month 02
# Running for month 02 in 2078, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207802.nc
# em01, yr 2078, month 03
# Running for month 03 in 2078, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207803.nc
# em01, yr 2078, month 04
# Running for month 04 in 2078, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207804.nc
# em01, yr 2078, month 05
# Running for month 05 in 2078, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207805.nc
# em01, yr 2078, month 06
# Running for month 06 in 2078, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207806.nc
# em01, yr 2078, month 07
# Running for month 07 in 2078, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207807.nc
# em01, yr 2078, month 08
# Running for month 08 in 2078, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207808.nc
# em01, yr 2078, month 09
# Running for month 09 in 2078, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207809.nc
# em01, yr 2078, month 10
# Running for month 10 in 2078, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207810.nc
# em01, yr 2078, month 11
# Running for month 11 in 2078, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207811.nc
# em01, yr 2078, month 12
# Running for month 12 in 2078, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207812.nc
# em01, yr 2079, month 01
# Running for month 01 in 2079, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207901.nc
# em01, yr 2079, month 02
# Running for month 02 in 2079, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207902.nc
# em01, yr 2079, month 03
# Running for month 03 in 2079, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207903.nc
# em01, yr 2079, month 04
# Running for month 04 in 2079, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207904.nc
# em01, yr 2079, month 05
# Running for month 05 in 2079, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207905.nc
# em01, yr 2079, month 06
# Running for month 06 in 2079, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207906.nc
# em01, yr 2079, month 07
# Running for month 07 in 2079, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207907.nc
# em01, yr 2079, month 08
# Running for month 08 in 2079, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207908.nc
# em01, yr 2079, month 09
# Running for month 09 in 2079, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207909.nc
# em01, yr 2079, month 10
# Running for month 10 in 2079, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207910.nc
# em01, yr 2079, month 11
# Running for month 11 in 2079, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207911.nc
# em01, yr 2079, month 12
# Running for month 12 in 2079, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr207912.nc
# em01, yr 2080, month 01
# Running for month 01 in 2080, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr208001.nc
# em01, yr 2080, month 02
# Running for month 02 in 2080, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr208002.nc
# em01, yr 2080, month 03
# Running for month 03 in 2080, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr208003.nc
# em01, yr 2080, month 04
# Running for month 04 in 2080, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr208004.nc
# em01, yr 2080, month 05
# Running for month 05 in 2080, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr208005.nc
# em01, yr 2080, month 06
# Running for month 06 in 2080, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr208006.nc
# em01, yr 2080, month 07
# Running for month 07 in 2080, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr208007.nc
# em01, yr 2080, month 08
# Running for month 08 in 2080, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr208008.nc
# em01, yr 2080, month 09
# Running for month 09 in 2080, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr208009.nc
# em01, yr 2080, month 10
# Running for month 10 in 2080, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr208010.nc
# em01, yr 2080, month 11
# Running for month 11 in 2080, for 01 (which equatees to bb189)
# Exists
# datadir/UKCP18_every30mins/2.2km_original/2060_2081/bb189/bb189a.pr208011.nc
# em01, yr 2080, month 12
# Running for month 12 in 2080, for 01 (which equatees to bb189)
# An error occurred: list index out of range
