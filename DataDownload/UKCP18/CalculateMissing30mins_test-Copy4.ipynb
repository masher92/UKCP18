# %%
import iris
import os
import glob as glob
import datetime as datetime
import iris.coord_categorisation as cat
import sys
import iris.plot as iplt

# Set up path to root directory
root_fp = "/nfs/a319/gy17m2a/PhD/"
os.chdir(root_fp)

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)


# Create path to files containing functions
sys.path.insert(0, root_fp + 'Scripts/GlobalFunctions')
from Spatial_plotting_functions import *
from Spatial_geometry_functions import *


# ### Load necessary spatial data
# This is a square area surrounding Leeds
leeds_at_centre_gdf = create_leeds_at_centre_outline({'init' :'epsg:3857'})


# ### Establish the corresponding ensemble member numbers
em_matching_dict = {'01':'bc005', '04': 'bc006', '05': 'bc007', '06':'bc009',  '07':'bc010', 
                    '08': 'bc011', '09':'bc013', '10': 'bc015', '11': 'bc016', '12': 'bc017', '13':'bc018', '15':'bc012'}

resolution = '2.2km'
yrs_range = "2002_2020"
# em_1hr = '05'
# yr = 2012
# month_num = '06'

# %%
# for em_1hr in ['01', '04', '05', '06', '07', '08', '09', '10', '11', '12', '13', '15']:
for em_1hr in ['09']:
    em_30mins = em_matching_dict[em_1hr]
    for yr in range(2001,2020):
        for month_num in ['01', '02', '03','04', '05', '06', '07', '08', '09', '10','11','12']:
            print(f"em{em_1hr},{em_30mins}, yr {yr}, month {month_num}")
            if (os.path.isfile(f"/nfs/a319/gy17m2a/PhD/datadir/UKCP18_every30mins/{resolution}/{em_30mins}/{yrs_range}/{em_30mins}a.pr{yr}{month_num}.nc")):
                print("already exists")
            else:
                print(f"Running for month {month_num} in {yr}, for {em_1hr} (which equatees to {em_30mins})")

                ####################################################### 
                #######################################################
                ## Get one month of data - HOURLY
                ####################################################### 
                #######################################################
                ### Get a list of filenames for hourly data
                general_filename_1hr = f'/nfs/a319/gy17m2a/PhD/datadir/UKCP18_hourly/2.2km/{em_1hr}/{yrs_range}/pr_rcp85_land-cpm_uk_2.2km_{em_1hr}_1hr_{yr}{month_num}*'
                filenames_1hr = []
                for filename in glob.glob(general_filename_1hr):
                        filenames_1hr.append(filename)
                # If don't find any files matching this string in the 2001_2020 folder, then check the 1980_2001
                if len(filenames_1hr) == 0:
                    general_filename_1hr = f'/nfs/a319/gy17m2a/PhD/datadir/UKCP18_hourly/2.2km/{em_1hr}/1980_2001/pr_rcp85_land-cpm_uk_2.2km_{em_1hr}_1hr_{yr}{month_num}*'
                    for filename in glob.glob(general_filename_1hr):
                            filenames_1hr.append(filename)
                    print(len(filenames_1hr))

                # ### Load in the data and remove the ensemble member dimension
                monthly_cubes_list_1hr = iris.load(filenames_1hr)
                cube_1hr = monthly_cubes_list_1hr[0]
                cube_1hr = cube_1hr[0,:,:,:]

                # ### Trim to Leeds
                # cube_1hr = trim_to_bbox_of_region(cube_1hr, leeds_at_centre_gdf)

                #######################################################
                #######################################################
                ## Get one month of data - 30mins
                #######################################################
                #######################################################
                # ### Get all files for this ensemble member
                general_filename_30mins = f'/nfs/a319/gy17m2a/PhD/datadir/UKCP18_first30mins/{yrs_range}/{em_30mins}/{em_30mins}a.pr{yr}{month_num}*'
                filenames_first30mins = []
                for filename_30mins in glob.glob(general_filename_30mins):
                    filenames_first30mins.append(filename_30mins)
                filenames_first30mins.sort()

                # ### Load in the data 
                monthly_cubes_list_30mins = iris.load(filenames_first30mins)

                # Equalise
                for cube in monthly_cubes_list_30mins:
                    for attr in ['forecast_period', 'forecast_reference_time']:
                        if attr in cube.attributes:
                            del cube.attributes[attr]


                monthly_cube_30mins = monthly_cubes_list_30mins.concatenate_cube()      

                # ### Trim to be the same shape as the hourly data
                # monthly_cube_30mins_1st = trim_to_bbox_of_region_30mins(monthly_cube_30mins, leeds_at_centre_gdf)
                monthly_cube_30mins_1st = monthly_cube_30mins[:,24:-24,24:-24]

                # ### Convert units of 30 mins data
                # Check current units
                # print(monthly_cube_30mins_1st.units)
                # Set the units to those of the 1 hr cube
                monthly_cube_30mins_1st.units = cube_1hr.units
                # print(monthly_cube_30mins_1st.units)

                # Convert the data to also be this unit
                monthly_cube_30mins_1st_data = monthly_cube_30mins_1st.data
                monthly_cube_30mins_1st_data = monthly_cube_30mins_1st_data*3600

                monthly_cube_30mins_1st.data = monthly_cube_30mins_1st_data


                #######################################################
                #######################################################
                ## Find the second half of the hour, using the first half of hour and hourly values
                #######################################################
                #######################################################
                # get the hourly data
                cube_1hr_data = cube_1hr.data
                # calculate value for second half of hour
                second_half_of_the_hour_mean_hourly_rainfall_rate_data = 2*cube_1hr_data-monthly_cube_30mins_1st_data
                # Create a new cube for the second half of the hour (start by copying the first half of hour cube)
                monthly_cube_30mins_2nd = monthly_cube_30mins_1st.copy()
                # Set values as calculated
                monthly_cube_30mins_2nd.data = second_half_of_the_hour_mean_hourly_rainfall_rate_data


                # ### Edit the times to be 30 mins later
                # get the times from the first half hour
                first_half_hour_times = monthly_cube_30mins_1st.coord('time').copy()
                # add 30 mins
                second_half_hour_times = first_half_hour_times + 0.5
                # for the second hald hour cube, remove the time dimension and then re-add the edited one
                monthly_cube_30mins_2nd.remove_coord('time')
                monthly_cube_30mins_2nd.add_dim_coord(second_half_hour_times, 0)

                #######################################################
                #######################################################
                ## Join first half hour and second half hour into one cube
                #######################################################
                #######################################################
                # ### Get a list of all the cubes in each of the monthly cubes
                list_30mins_1st = iris.cube.CubeList(monthly_cube_30mins_1st.slices_over('time'))
                list_30mins_2nd = iris.cube.CubeList(monthly_cube_30mins_2nd.slices_over('time'))
                list_30mins = list_30mins_1st +  list_30mins_2nd

                ### Merge back into one cube
                monthly_cube_30mins = list_30mins.merge_cube()

                #######################################################
                #######################################################
                ## Save
                #######################################################
                #######################################################
                dir_to_save = f"datadir/UKCP18_every30mins/{resolution}/{em_30mins}/{yrs_range}/"

                if os.path.isdir(dir_to_save):
                    print("Exists")
                else:
                    print("Doesn't exist")
                    os.makedirs(dir_to_save)
                fp_to_save = f"datadir/UKCP18_every30mins/{resolution}/{em_30mins}/{yrs_range}/{em_30mins}a.pr{yr}{month_num}.nc" 
                print(fp_to_save)
                iris.save(monthly_cube_30mins, fp_to_save)
# Out:
# em09,bc013, yr 2001, month 01
# already exists
# em09,bc013, yr 2001, month 02
# already exists
# em09,bc013, yr 2001, month 03
# already exists
# em09,bc013, yr 2001, month 04
# already exists
# em09,bc013, yr 2001, month 05
# already exists
# em09,bc013, yr 2001, month 06
# already exists
# em09,bc013, yr 2001, month 07
# already exists
# em09,bc013, yr 2001, month 08
# already exists
# em09,bc013, yr 2001, month 09
# already exists
# em09,bc013, yr 2001, month 10
# already exists
# em09,bc013, yr 2001, month 11
# already exists
# em09,bc013, yr 2001, month 12
# already exists
# em09,bc013, yr 2002, month 01
# already exists
# em09,bc013, yr 2002, month 02
# already exists
# em09,bc013, yr 2002, month 03
# already exists
# em09,bc013, yr 2002, month 04
# already exists
# em09,bc013, yr 2002, month 05
# already exists
# em09,bc013, yr 2002, month 06
# already exists
# em09,bc013, yr 2002, month 07
# already exists
# em09,bc013, yr 2002, month 08
# already exists
# em09,bc013, yr 2002, month 09
# already exists
# em09,bc013, yr 2002, month 10
# already exists
# em09,bc013, yr 2002, month 11
# already exists
# em09,bc013, yr 2002, month 12
# already exists
# em09,bc013, yr 2003, month 01
# already exists
# em09,bc013, yr 2003, month 02
# already exists
# em09,bc013, yr 2003, month 03
# already exists
# em09,bc013, yr 2003, month 04
# already exists
# em09,bc013, yr 2003, month 05
# already exists
# em09,bc013, yr 2003, month 06
# already exists
# em09,bc013, yr 2003, month 07
# already exists
# em09,bc013, yr 2003, month 08
# already exists
# em09,bc013, yr 2003, month 09
# already exists
# em09,bc013, yr 2003, month 10
# already exists
# em09,bc013, yr 2003, month 11
# already exists
# em09,bc013, yr 2003, month 12
# already exists
# em09,bc013, yr 2004, month 01
# already exists
# em09,bc013, yr 2004, month 02
# already exists
# em09,bc013, yr 2004, month 03
# already exists
# em09,bc013, yr 2004, month 04
# already exists
# em09,bc013, yr 2004, month 05
# already exists
# em09,bc013, yr 2004, month 06
# already exists
# em09,bc013, yr 2004, month 07
# already exists
# em09,bc013, yr 2004, month 08
# already exists
# em09,bc013, yr 2004, month 09
# already exists
# em09,bc013, yr 2004, month 10
# already exists
# em09,bc013, yr 2004, month 11
# already exists
# em09,bc013, yr 2004, month 12
# already exists
# em09,bc013, yr 2005, month 01
# already exists
# em09,bc013, yr 2005, month 02
# already exists
# em09,bc013, yr 2005, month 03
# already exists
# em09,bc013, yr 2005, month 04
# already exists
# em09,bc013, yr 2005, month 05
# already exists
# em09,bc013, yr 2005, month 06
# already exists
# em09,bc013, yr 2005, month 07
# already exists
# em09,bc013, yr 2005, month 08
# already exists
# em09,bc013, yr 2005, month 09
# already exists
# em09,bc013, yr 2005, month 10
# already exists
# em09,bc013, yr 2005, month 11
# already exists
# em09,bc013, yr 2005, month 12
# already exists
# em09,bc013, yr 2006, month 01
# already exists
# em09,bc013, yr 2006, month 02
# already exists
# em09,bc013, yr 2006, month 03
# already exists
# em09,bc013, yr 2006, month 04
# already exists
# em09,bc013, yr 2006, month 05
# already exists
# em09,bc013, yr 2006, month 06
# already exists
# em09,bc013, yr 2006, month 07
# already exists
# em09,bc013, yr 2006, month 08
# already exists
# em09,bc013, yr 2006, month 09
# already exists
# em09,bc013, yr 2006, month 10
# already exists
# em09,bc013, yr 2006, month 11
# already exists
# em09,bc013, yr 2006, month 12
# already exists
# em09,bc013, yr 2007, month 01
# already exists
# em09,bc013, yr 2007, month 02
# already exists
# em09,bc013, yr 2007, month 03
# already exists
# em09,bc013, yr 2007, month 04
# already exists
# em09,bc013, yr 2007, month 05
# already exists
# em09,bc013, yr 2007, month 06
# already exists
# em09,bc013, yr 2007, month 07
# already exists
# em09,bc013, yr 2007, month 08
# already exists
# em09,bc013, yr 2007, month 09
# already exists
# em09,bc013, yr 2007, month 10
# already exists
# em09,bc013, yr 2007, month 11
# already exists
# em09,bc013, yr 2007, month 12
# already exists
# em09,bc013, yr 2008, month 01
# already exists
# em09,bc013, yr 2008, month 02
# already exists
# em09,bc013, yr 2008, month 03
# already exists
# em09,bc013, yr 2008, month 04
# already exists
# em09,bc013, yr 2008, month 05
# already exists
# em09,bc013, yr 2008, month 06
# already exists
# em09,bc013, yr 2008, month 07
# already exists
# em09,bc013, yr 2008, month 08
# already exists
# em09,bc013, yr 2008, month 09
# already exists
# em09,bc013, yr 2008, month 10
# already exists
# em09,bc013, yr 2008, month 11
# already exists
# em09,bc013, yr 2008, month 12
# already exists
# em09,bc013, yr 2009, month 01
# already exists
# em09,bc013, yr 2009, month 02
# already exists
# em09,bc013, yr 2009, month 03
# already exists
# em09,bc013, yr 2009, month 04
# already exists
# em09,bc013, yr 2009, month 05
# already exists
# em09,bc013, yr 2009, month 06
# already exists
# em09,bc013, yr 2009, month 07
# already exists
# em09,bc013, yr 2009, month 08
# already exists
# em09,bc013, yr 2009, month 09
# already exists
# em09,bc013, yr 2009, month 10
# already exists
# em09,bc013, yr 2009, month 11
# already exists
# em09,bc013, yr 2009, month 12
# already exists
# em09,bc013, yr 2010, month 01
# already exists
# em09,bc013, yr 2010, month 02
# already exists
# em09,bc013, yr 2010, month 03
# already exists
# em09,bc013, yr 2010, month 04
# already exists
# em09,bc013, yr 2010, month 05
# already exists
# em09,bc013, yr 2010, month 06
# already exists
# em09,bc013, yr 2010, month 07
# already exists
# em09,bc013, yr 2010, month 08
# already exists
# em09,bc013, yr 2010, month 09
# already exists
# em09,bc013, yr 2010, month 10
# already exists
# em09,bc013, yr 2010, month 11
# already exists
# em09,bc013, yr 2010, month 12
# already exists
# em09,bc013, yr 2011, month 01
# already exists
# em09,bc013, yr 2011, month 02
# already exists
# em09,bc013, yr 2011, month 03
# already exists
# em09,bc013, yr 2011, month 04
# already exists
# em09,bc013, yr 2011, month 05
# already exists
# em09,bc013, yr 2011, month 06
# already exists
# em09,bc013, yr 2011, month 07
# already exists
# em09,bc013, yr 2011, month 08
# already exists
# em09,bc013, yr 2011, month 09
# already exists
# em09,bc013, yr 2011, month 10
# already exists
# em09,bc013, yr 2011, month 11
# already exists
# em09,bc013, yr 2011, month 12
# already exists
# em09,bc013, yr 2012, month 01
# already exists
# em09,bc013, yr 2012, month 02
# already exists
# em09,bc013, yr 2012, month 03
# already exists
# em09,bc013, yr 2012, month 04
# already exists
# em09,bc013, yr 2012, month 05
# already exists
# em09,bc013, yr 2012, month 06
# already exists
# em09,bc013, yr 2012, month 07
# already exists
# em09,bc013, yr 2012, month 08
# already exists
# em09,bc013, yr 2012, month 09
# already exists
# em09,bc013, yr 2012, month 10
# already exists
# em09,bc013, yr 2012, month 11
# already exists
# em09,bc013, yr 2012, month 12
# already exists
# em09,bc013, yr 2013, month 01
# already exists
# em09,bc013, yr 2013, month 02
# Running for month 02 in 2013, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201302.nc
# em09,bc013, yr 2013, month 03
# Running for month 03 in 2013, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201303.nc
# em09,bc013, yr 2013, month 04
# Running for month 04 in 2013, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201304.nc
# em09,bc013, yr 2013, month 05
# Running for month 05 in 2013, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201305.nc
# em09,bc013, yr 2013, month 06
# already exists
# em09,bc013, yr 2013, month 07
# already exists
# em09,bc013, yr 2013, month 08
# already exists
# em09,bc013, yr 2013, month 09
# Running for month 09 in 2013, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201309.nc
# em09,bc013, yr 2013, month 10
# Running for month 10 in 2013, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201310.nc
# em09,bc013, yr 2013, month 11
# Running for month 11 in 2013, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201311.nc
# em09,bc013, yr 2013, month 12
# Running for month 12 in 2013, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201312.nc
# em09,bc013, yr 2014, month 01
# Running for month 01 in 2014, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201401.nc
# em09,bc013, yr 2014, month 02
# Running for month 02 in 2014, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201402.nc
# em09,bc013, yr 2014, month 03
# Running for month 03 in 2014, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201403.nc
# em09,bc013, yr 2014, month 04
# Running for month 04 in 2014, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201404.nc
# em09,bc013, yr 2014, month 05
# Running for month 05 in 2014, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201405.nc
# em09,bc013, yr 2014, month 06
# already exists
# em09,bc013, yr 2014, month 07
# already exists
# em09,bc013, yr 2014, month 08
# already exists
# em09,bc013, yr 2014, month 09
# Running for month 09 in 2014, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201409.nc
# em09,bc013, yr 2014, month 10
# Running for month 10 in 2014, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201410.nc
# em09,bc013, yr 2014, month 11
# Running for month 11 in 2014, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201411.nc
# em09,bc013, yr 2014, month 12
# Running for month 12 in 2014, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201412.nc
# em09,bc013, yr 2015, month 01
# Running for month 01 in 2015, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201501.nc
# em09,bc013, yr 2015, month 02
# Running for month 02 in 2015, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201502.nc
# em09,bc013, yr 2015, month 03
# Running for month 03 in 2015, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201503.nc
# em09,bc013, yr 2015, month 04
# Running for month 04 in 2015, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201504.nc
# em09,bc013, yr 2015, month 05
# Running for month 05 in 2015, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201505.nc
# em09,bc013, yr 2015, month 06
# already exists
# em09,bc013, yr 2015, month 07
# already exists
# em09,bc013, yr 2015, month 08
# already exists
# em09,bc013, yr 2015, month 09
# Running for month 09 in 2015, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201509.nc
# em09,bc013, yr 2015, month 10
# Running for month 10 in 2015, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201510.nc
# em09,bc013, yr 2015, month 11
# Running for month 11 in 2015, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201511.nc
# em09,bc013, yr 2015, month 12
# Running for month 12 in 2015, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201512.nc
# em09,bc013, yr 2016, month 01
# Running for month 01 in 2016, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201601.nc
# em09,bc013, yr 2016, month 02
# Running for month 02 in 2016, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201602.nc
# em09,bc013, yr 2016, month 03
# Running for month 03 in 2016, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201603.nc
# em09,bc013, yr 2016, month 04
# Running for month 04 in 2016, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201604.nc
# em09,bc013, yr 2016, month 05
# Running for month 05 in 2016, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201605.nc
# em09,bc013, yr 2016, month 06
# already exists
# em09,bc013, yr 2016, month 07
# already exists
# em09,bc013, yr 2016, month 08
# already exists
# em09,bc013, yr 2016, month 09
# Running for month 09 in 2016, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201609.nc
# em09,bc013, yr 2016, month 10
# Running for month 10 in 2016, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201610.nc
# em09,bc013, yr 2016, month 11
# Running for month 11 in 2016, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201611.nc
# em09,bc013, yr 2016, month 12
# Running for month 12 in 2016, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201612.nc
# em09,bc013, yr 2017, month 01
# Running for month 01 in 2017, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201701.nc
# em09,bc013, yr 2017, month 02
# Running for month 02 in 2017, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201702.nc
# em09,bc013, yr 2017, month 03
# Running for month 03 in 2017, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201703.nc
# em09,bc013, yr 2017, month 04
# Running for month 04 in 2017, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201704.nc
# em09,bc013, yr 2017, month 05
# Running for month 05 in 2017, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201705.nc
# em09,bc013, yr 2017, month 06
# already exists
# em09,bc013, yr 2017, month 07
# already exists
# em09,bc013, yr 2017, month 08
# already exists
# em09,bc013, yr 2017, month 09
# Running for month 09 in 2017, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201709.nc
# em09,bc013, yr 2017, month 10
# Running for month 10 in 2017, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201710.nc
# em09,bc013, yr 2017, month 11
# Running for month 11 in 2017, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201711.nc
# em09,bc013, yr 2017, month 12
# Running for month 12 in 2017, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201712.nc
# em09,bc013, yr 2018, month 01
# Running for month 01 in 2018, for 09 (which equatees to bc013)
# Exists
# datadir/UKCP18_every30mins/2.2km/bc013/2002_2020/bc013a.pr201801.nc
# em09,bc013, yr 2018, month 02
# Running for month 02 in 2018, for 09 (which equatees to bc013)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_19950/3482224112.py in <module>
#      48
#      49                 # ### Load in the data
# ---> 50                 monthly_cubes_list_30mins = iris.load(filenames_first30mins)
#      51
#      52                 # Equalise
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/iris/__init__.py in load(uris, constraints, callback)
#     301
#     302     """
# --> 303     return _load_collection(uris, constraints, callback).merged().cubes()
#     304
#     305
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/iris/__init__.py in _load_collection(uris, constraints, callback)
#     268     try:
#     269         cubes = _generate_cubes(uris, callback, constraints)
# --> 270         result = _CubeFilterCollection.from_cubes(cubes, constraints)
#     271     except EOFError as e:
#     272         raise iris.exceptions.TranslationError(
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/iris/cube.py in from_cubes(cubes, constraints)
#     113         pairs = [_CubeFilter(constraint) for constraint in constraints]
#     114         collection = _CubeFilterCollection(pairs)
# --> 115         for cube in cubes:
#     116             collection.add_cube(cube)
#     117         return collection
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/iris/__init__.py in _generate_cubes(uris, callback, constraints)
#     253         if scheme == "file":
#     254             part_names = [x[1] for x in groups]
# --> 255             for cube in iris.io.load_files(part_names, callback, constraints):
#     256                 yield cube
#     257         elif scheme in ["http", "https"]:
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/iris/io/__init__.py in load_files(filenames, callback, constraints)
#     194         with open(fn, "rb") as fh:
#     195             handling_format_spec = FORMAT_AGENT.get_spec(
# --> 196                 os.path.basename(fn), fh
#     197             )
#     198             handler_map[handling_format_spec].append(fn)
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/iris/io/format_picker.py in get_spec(self, basename, buffer_obj)
#     138             " File element cache:\n {}".format(printable_values)
#     139         )
# --> 140         raise ValueError(msg)
#     141
#     142
#
# ValueError: No format specification could be found for the given buffer. File element cache:
#  {'UriProtocol()': 'file', 'LeadingLine()': 'b"\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00...', 'MagicNumber(4, None)': '0', 'MagicNumber(8, None)': '0', 'FileExtension()': '.pp', 'MagicNumber(100, None)': "b'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00..."}
