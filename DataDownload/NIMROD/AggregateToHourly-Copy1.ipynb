# %%
import iris
import glob
import iris.plot as iplt
import iris.quickplot as qplt
import datetime as datetime
import iris.coord_categorisation as cat
import numpy as np
import os
import sys

# surrogate = iris.load("/nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2019/metoffice-c-band-rain-radar_uk_20190307.nc")
# surrogate = surrogate[0]

# if 'projection_y_coordinate' not in surrogate.coords():
#     # Copy projection_y_coordinate from the first cube
#     day_cube.add_dim_coord(surrogate.coord('projection_y_coordinate'), 1)

# if 'projection_x_coordinate' not in surrogate.coords():
#     # Copy projection_x_coordinate from the first cube
#     day_cube.add_dim_coord(surrogate.coord('projection_x_coordinate'), 2)

# if 'time' not in surrogate.coords():
#     # Copy projection_x_coordinate from the first cube
#     day_cube.add_dim_coord(surrogate.coord('time'), 0)    


def concatenate_with_error_handling(cube_list):
    """Handle errors during cube concatenation by identifying problematic cubes."""
    problematic_cube_index = None
    start = 0

    for i, cube in enumerate(cube_list):
        try:
            cube_list[start:i + 1].concatenate_cube()
        except Exception as e:
            print(f"Error concatenating cube {i}: {str(e)}")
            problematic_cube_index = i
            start = i

    if 0 <= problematic_cube_index < len(cube_list):
        del cube_list[problematic_cube_index]
        print(f"Cube at index {problematic_cube_index} removed from CubeList.")
    else:
        print(f"Index {problematic_cube_index} is out of range for CubeList.")

    return cube_list.concatenate_cube()


def process_half_hour(cube, label):
    """Process half-hourly data, apply filters, and calculate statistics."""
    
    if cube is None:
        print(f"No values in {label}.")
        return None

    if len(cube.shape) == 2:
        print(f"Only 1 value in {label}.")
        return None

    if cube.shape[0] < 4:
        print(f"Only {cube.shape[0]} values in {label}.")
        return None

    # Append unfiltered data
    mean_cube = cube.copy().aggregated_by(['hour'], iris.analysis.MEAN)
    return mean_cube


def process_hour(cube):
    """Process half-hourly data, apply filters, and calculate statistics."""
    
    if cube is None:
        print(f"No values.")
        return None

    if len(cube.shape) == 2:
        print(f"Only 1 value.")
        return None

    if cube.shape[0] < 8:
        print(f"Only {cube.shape[0]} values in cube.")
        return None

    # Append unfiltered data
    mean_cube = cube.copy().aggregated_by(['hour'], iris.analysis.MEAN)
    return mean_cube


def create_year_directory(base_path, year):
    """Create directories for each year in the range if they don't exist."""
    for label in ['unfiltered']:
        year_path = os.path.join(base_path.format(label), str(year))
        os.makedirs(year_path, exist_ok=True)
        print(f"Directory created: {year_path}")


def process_and_save_cubes(cube_list, label, base_fp, year, iteration):
    """Concatenate cubes, filter data, and save to disk."""
    # Check if the cube list is empty
    if not cube_list:
        print(f"No cubes to process for {label}, year {year}, iteration {iteration}.")
        return

    # Ensure data in each cube is in the correct format
    for halfhour_i in range(len(cube_list)):
        cube_list[halfhour_i].data = cube_list[halfhour_i].data.astype('float64')

    try:
        # Attempt to concatenate cubes
        full_day_cube = cube_list.concatenate_cube()
    except Exception as e:
        print(f"Concatenation failed: {e}. Attempting error-handling concatenation.")
        full_day_cube = concatenate_with_error_handling(cube_list)

    # Print the maximum value in the cube's data
    print(f"Max value before saving: {np.nanmax(full_day_cube.data)}")
    print(full_day_cube.shape)

    # Save the concatenated cube to the specified file path
    save_path = base_fp.replace('unfiltered', label)
    iris.save(full_day_cube, save_path)

    # Print statistics for the cube
    print(f"Saved {label} cube for {year}, iteration {iteration}")
    print(f"Min: {np.nanmin(full_day_cube.data)}, Max: {np.nanmax(full_day_cube.data)}, Mean: {np.nanmean(full_day_cube.data)}")
    print(full_day_cube.shape)

def process_year(year):
    print(f"Processing year: {year}")

    radardir = f'/nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/{year}/'
    sorted_files = sorted(glob.glob(radardir + "*.nc"))

    for i, file_path in enumerate(sorted_files):
        print(f"Processing file {i + 1}/{len(sorted_files)}: {file_path}")

        new_fp_base = file_path.replace('OriginalFormat_1km/', 'OriginalFormat_1km/unfiltered/')
        new_fp_base = new_fp_base.replace('5mins', '1hr')[:-3] + '_1h.nc'
        new_fp_base = new_fp_base.replace('/2006/', f'/{year}/')

        if all(os.path.exists(new_fp_base.replace('unfiltered', label)) for label in ['unfiltered']):
            print("All files exist, skipping.")
            continue

        day_cube = iris.load_cube(file_path)
        if len(day_cube.shape)==2:
            day_cube = iris.util.new_axis(day_cube, "time")
        day_cube = day_cube[:,620:1800,210:1075]
        try:
            cat.add_hour(day_cube, 'time', name='hour')
        except:
            continue
        unfiltered_ls = iris.cube.CubeList()

        hours = set(day_cube.coord('hour').points)

        for hour in hours:
            hour_constraint = iris.Constraint(time=lambda cell: cell.point.hour == hour)
            hour_cube = day_cube.extract(hour_constraint)

            ##### SET negative values to NAN
            if np.nanmin(hour_cube.data) < 0:
                print(f"{hour}, min b4 correction", np.nanmin(hour_cube.data))
                # Ensure hour_cube.data is a MaskedArray
                hour_cube.data = np.ma.masked_where(hour_cube.data.mask, hour_cube.data)  # Safeguard if not already masked

                # Apply the condition only where the mask is False
                hour_cube.data = np.ma.masked_where(hour_cube.data.mask, np.where((hour_cube.data < 0) & (~hour_cube.data.mask), np.nan, hour_cube.data))
                print(f"{hour}, min after correction", np.nanmin(hour_cube.data))

            ########### Unfiltered version
            # Split the 5 minute cube into the first half hour and second half hour
            hour_cube_unfiltered = hour_cube.copy()

            # Get a first half and second half of hour aggregated to 30 mins
            hour_cube = process_hour(hour_cube_unfiltered)

            #  Add both to the lsit
            if hour_cube is not None:
                #  Add both to the lsit
                unfiltered_ls.append(hour_cube)


        for label, cube_list in [('unfiltered', unfiltered_ls)]:
            print(len(cube_list))
            process_and_save_cubes(cube_list, label, new_fp_base, year, i)  

for year in range(2011, 2013):
    base_path = '/nfs/a161/gy17m2a/PhD/datadir/NIMROD/1hr/OriginalFormat_1km/{}'
    create_year_directory(base_path, year)
    process_year(year)
# Out:
# Directory created: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/1hr/OriginalFormat_1km/unfiltered/2011
# Processing year: 2011
# Processing file 1/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110104.nc
# All files exist, skipping.
# Processing file 2/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110105.nc
# All files exist, skipping.
# Processing file 3/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110106.nc
# All files exist, skipping.
# Processing file 4/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110107.nc
# All files exist, skipping.
# Processing file 5/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110108.nc
# All files exist, skipping.
# Processing file 6/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110109.nc
# All files exist, skipping.
# Processing file 7/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110110.nc
# All files exist, skipping.
# Processing file 8/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110111.nc
# All files exist, skipping.
# Processing file 9/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110112.nc
# All files exist, skipping.
# Processing file 10/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110113.nc
# All files exist, skipping.
# Processing file 11/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110114.nc
# All files exist, skipping.
# Processing file 12/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110115.nc
# All files exist, skipping.
# Processing file 13/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110116.nc
# All files exist, skipping.
# Processing file 14/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110117.nc
# All files exist, skipping.
# Processing file 15/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110118.nc
# All files exist, skipping.
# Processing file 16/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110119.nc
# All files exist, skipping.
# Processing file 17/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110120.nc
# All files exist, skipping.
# Processing file 18/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110121.nc
# All files exist, skipping.
# Processing file 19/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110122.nc
# All files exist, skipping.
# Processing file 20/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110123.nc
# All files exist, skipping.
# Processing file 21/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110124.nc
# All files exist, skipping.
# Processing file 22/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110125.nc
# All files exist, skipping.
# Processing file 23/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110126.nc
# All files exist, skipping.
# Processing file 24/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110127.nc
# All files exist, skipping.
# Processing file 25/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110128.nc
# All files exist, skipping.
# Processing file 26/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110129.nc
# All files exist, skipping.
# Processing file 27/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110130.nc
# All files exist, skipping.
# Processing file 28/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110131.nc
# All files exist, skipping.
# Processing file 29/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110201.nc
# All files exist, skipping.
# Processing file 30/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110202.nc
# All files exist, skipping.
# Processing file 31/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110203.nc
# All files exist, skipping.
# Processing file 32/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110204.nc
# All files exist, skipping.
# Processing file 33/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110205.nc
# All files exist, skipping.
# Processing file 34/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110206.nc
# All files exist, skipping.
# Processing file 35/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110207.nc
# All files exist, skipping.
# Processing file 36/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110208.nc
# All files exist, skipping.
# Processing file 37/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110209.nc
# All files exist, skipping.
# Processing file 38/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110210.nc
# All files exist, skipping.
# Processing file 39/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110211.nc
# All files exist, skipping.
# Processing file 40/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110212.nc
# All files exist, skipping.
# Processing file 41/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110213.nc
# All files exist, skipping.
# Processing file 42/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110214.nc
# All files exist, skipping.
# Processing file 43/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110215.nc
# All files exist, skipping.
# Processing file 44/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110216.nc
# All files exist, skipping.
# Processing file 45/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110217.nc
# All files exist, skipping.
# Processing file 46/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110218.nc
# All files exist, skipping.
# Processing file 47/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110219.nc
# All files exist, skipping.
# Processing file 48/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110220.nc
# All files exist, skipping.
# Processing file 49/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110221.nc
# All files exist, skipping.
# Processing file 50/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110222.nc
# All files exist, skipping.
# Processing file 51/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110223.nc
# All files exist, skipping.
# Processing file 52/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110224.nc
# All files exist, skipping.
# Processing file 53/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110225.nc
# All files exist, skipping.
# Processing file 54/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110227.nc
# All files exist, skipping.
# Processing file 55/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110228.nc
# All files exist, skipping.
# Processing file 56/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110301.nc
# All files exist, skipping.
# Processing file 57/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110302.nc
# All files exist, skipping.
# Processing file 58/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110303.nc
# All files exist, skipping.
# Processing file 59/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110304.nc
# All files exist, skipping.
# Processing file 60/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110305.nc
# All files exist, skipping.
# Processing file 61/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110306.nc
# All files exist, skipping.
# Processing file 62/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110307.nc
# All files exist, skipping.
# Processing file 63/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110309.nc
# All files exist, skipping.
# Processing file 64/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110310.nc
# All files exist, skipping.
# Processing file 65/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110311.nc
# All files exist, skipping.
# Processing file 66/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110312.nc
# All files exist, skipping.
# Processing file 67/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110313.nc
# All files exist, skipping.
# Processing file 68/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110314.nc
# All files exist, skipping.
# Processing file 69/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110315.nc
# All files exist, skipping.
# Processing file 70/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110316.nc
# All files exist, skipping.
# Processing file 71/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110317.nc
# All files exist, skipping.
# Processing file 72/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110318.nc
# All files exist, skipping.
# Processing file 73/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110319.nc
# All files exist, skipping.
# Processing file 74/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110320.nc
# All files exist, skipping.
# Processing file 75/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110321.nc
# All files exist, skipping.
# Processing file 76/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110322.nc
# All files exist, skipping.
# Processing file 77/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110323.nc
# All files exist, skipping.
# Processing file 78/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110324.nc
# All files exist, skipping.
# Processing file 79/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110325.nc
# All files exist, skipping.
# Processing file 80/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110326.nc
# All files exist, skipping.
# Processing file 81/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110327.nc
# All files exist, skipping.
# Processing file 82/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110328.nc
# All files exist, skipping.
# Processing file 83/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110329.nc
# All files exist, skipping.
# Processing file 84/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110330.nc
# All files exist, skipping.
# Processing file 85/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110331.nc
# All files exist, skipping.
# Processing file 86/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110401.nc
# All files exist, skipping.
# Processing file 87/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110402.nc
# All files exist, skipping.
# Processing file 88/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110403.nc
# All files exist, skipping.
# Processing file 89/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110404.nc
# All files exist, skipping.
# Processing file 90/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110405.nc
# All files exist, skipping.
# Processing file 91/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110406.nc
# All files exist, skipping.
# Processing file 92/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110407.nc
# All files exist, skipping.
# Processing file 93/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110408.nc
# All files exist, skipping.
# Processing file 94/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110409.nc
# All files exist, skipping.
# Processing file 95/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110410.nc
# All files exist, skipping.
# Processing file 96/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110411.nc
# All files exist, skipping.
# Processing file 97/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110412.nc
# All files exist, skipping.
# Processing file 98/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110413.nc
# All files exist, skipping.
# Processing file 99/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110414.nc
# All files exist, skipping.
# Processing file 100/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110415.nc
# All files exist, skipping.
# Processing file 101/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110416.nc
# All files exist, skipping.
# Processing file 102/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110417.nc
# All files exist, skipping.
# Processing file 103/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110418.nc
# All files exist, skipping.
# Processing file 104/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110419.nc
# All files exist, skipping.
# Processing file 105/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110420.nc
# All files exist, skipping.
# Processing file 106/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110421.nc
# All files exist, skipping.
# Processing file 107/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110422.nc
# All files exist, skipping.
# Processing file 108/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110423.nc
# All files exist, skipping.
# Processing file 109/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110424.nc
# All files exist, skipping.
# Processing file 110/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110425.nc
# All files exist, skipping.
# Processing file 111/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110426.nc
# All files exist, skipping.
# Processing file 112/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110427.nc
# All files exist, skipping.
# Processing file 113/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110428.nc
# All files exist, skipping.
# Processing file 114/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110429.nc
# All files exist, skipping.
# Processing file 115/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110430.nc
# All files exist, skipping.
# Processing file 116/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110501.nc
# All files exist, skipping.
# Processing file 117/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110502.nc
# All files exist, skipping.
# Processing file 118/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110503.nc
# All files exist, skipping.
# Processing file 119/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110504.nc
# All files exist, skipping.
# Processing file 120/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110505.nc
# All files exist, skipping.
# Processing file 121/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110506.nc
# All files exist, skipping.
# Processing file 122/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110507.nc
# All files exist, skipping.
# Processing file 123/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110508.nc
# All files exist, skipping.
# Processing file 124/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110509.nc
# All files exist, skipping.
# Processing file 125/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110510.nc
# All files exist, skipping.
# Processing file 126/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110511.nc
# All files exist, skipping.
# Processing file 127/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110512.nc
# All files exist, skipping.
# Processing file 128/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110513.nc
# All files exist, skipping.
# Processing file 129/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110514.nc
# All files exist, skipping.
# Processing file 130/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110515.nc
# 24
# Max value before saving: 239.125
# (24, 1180, 865)
# Saved unfiltered cube for 2011, iteration 129
# Min: 0.0, Max: 239.125, Mean: 0.07647564445008158
# (24, 1180, 865)
# Processing file 131/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110516.nc
# All files exist, skipping.
# Processing file 132/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110517.nc
# All files exist, skipping.
# Processing file 133/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110518.nc
# 24
# Max value before saving: 162.44791666666666
# (24, 1180, 865)
# Saved unfiltered cube for 2011, iteration 132
# Min: 0.0, Max: 162.44791666666666, Mean: 0.05721091400359937
# (24, 1180, 865)
# Processing file 134/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110519.nc
# All files exist, skipping.
# Processing file 135/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110520.nc
# All files exist, skipping.
# Processing file 136/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110521.nc
# All files exist, skipping.
# Processing file 137/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110522.nc
# All files exist, skipping.
# Processing file 138/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110523.nc
# All files exist, skipping.
# Processing file 139/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110524.nc
# All files exist, skipping.
# Processing file 140/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110525.nc
# All files exist, skipping.
# Processing file 141/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110526.nc
# All files exist, skipping.
# Processing file 142/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110527.nc
# All files exist, skipping.
# Processing file 143/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110528.nc
# All files exist, skipping.
# Processing file 144/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110529.nc
# 24
# Max value before saving: 30.84375
# (24, 1180, 865)
# Saved unfiltered cube for 2011, iteration 143
# Min: 0.0, Max: 30.84375, Mean: 0.07675409529546934
# (24, 1180, 865)
# Processing file 145/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110530.nc
# All files exist, skipping.
# Processing file 146/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110531.nc
# All files exist, skipping.
# Processing file 147/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110601.nc
# All files exist, skipping.
# Processing file 148/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110602.nc
# All files exist, skipping.
# Processing file 149/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110603.nc
# All files exist, skipping.
# Processing file 150/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110604.nc
# All files exist, skipping.
# Processing file 151/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110605.nc
# All files exist, skipping.
# Processing file 152/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110606.nc
# All files exist, skipping.
# Processing file 153/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110607.nc
# All files exist, skipping.
# Processing file 154/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110608.nc
# All files exist, skipping.
# Processing file 155/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110609.nc
# All files exist, skipping.
# Processing file 156/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110610.nc
# All files exist, skipping.
# Processing file 157/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110611.nc
# All files exist, skipping.
# Processing file 158/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110612.nc
# All files exist, skipping.
# Processing file 159/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110613.nc
# All files exist, skipping.
# Processing file 160/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110614.nc
# All files exist, skipping.
# Processing file 161/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110615.nc
# 24
# Max value before saving: 85.79947916666667
# (24, 1180, 865)
# Saved unfiltered cube for 2011, iteration 160
# Min: 0.0, Max: 85.79947916666667, Mean: 0.04493225300201085
# (24, 1180, 865)
# Processing file 162/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110616.nc
# All files exist, skipping.
# Processing file 163/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110617.nc
# All files exist, skipping.
# Processing file 164/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110618.nc
# All files exist, skipping.
# Processing file 165/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110619.nc
# All files exist, skipping.
# Processing file 166/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110620.nc
# 24
# Max value before saving: 128.80729166666666
# (24, 1180, 865)
# Saved unfiltered cube for 2011, iteration 165
# Min: 0.0, Max: 128.80729166666666, Mean: 0.06394515628460543
# (24, 1180, 865)
# Processing file 167/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110621.nc
# All files exist, skipping.
# Processing file 168/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110622.nc
# All files exist, skipping.
# Processing file 169/358: /nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2011/metoffice-c-band-rain-radar_uk_20110623.nc
