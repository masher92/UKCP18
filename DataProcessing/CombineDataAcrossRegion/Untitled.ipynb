# %%
import os
import numpy as np

# %%
em='bc005'
resolution = "2.2km_bng_masked"
season='wholeyear'
datadir = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/UKCP18_every30mins/{resolution}/2002_2020/{em}_{season}/'
yr=2006
file_name = os.path.join(datadir, f"compressed_{yr}_GB_{season}.npy")

# Load yearly data
this_yr_30mins = np.load(file_name, mmap_mode='r')  # Memory-map for efficiency

# %%
averaged_arr = [(this_yr_30mins[i] + this_yr_30mins[i+1]) / 2 for i in range(len(this_yr_30mins) - 1)]

print(averaged_arr)  # Output: [1.5, 2.5, 3.5, 4.5, 5.5]

# %%
em='01'
resolution = "2.2km_bng_masked"
season='wholeyear'
datadir = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/UKCP18_hourly/{resolution}/2002_2020/{em}_{season}/'
yr=2006
file_name = os.path.join(datadir, f"compressed_{yr}_GB_{season}.npy")

# Load yearly data
this_yr_hrly = np.load(file_name, mmap_mode='r')  # Memory-map for efficiency

# %%
ddir = "/nfs/a161/gy17m2a/PhD/datadir/UKCP18_hourly/2.2km_original/01/2002_2020/"
import iris
test2=iris.load(ddir+'pr_rcp85_land-cpm_uk_2.2km_01_1hr_20011201-20011230.nc')

# %%
test2
# Out:
# [<iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>]

# %%
ddir = "/nfs/a161/gy17m2a/PhD/datadir/UKCP18_hourly/2.2km_original/01/2002_2020/"
import iris
test=iris.load(ddir+'bng_pr_rcp85_land-cpm_uk_2.2km_01_1hr_20011201-20011230.nc')

# %%
print(test[0].coord('time'))
# Out:
# DimCoord([2001-12-01 00:30:00, 2001-12-01 01:30:00, 2001-12-01 02:30:00,
#        2001-12-01 03:30:00, 2001-12-01 04:30:00, 2001-12-01 05:30:00,
#        2001-12-01 06:30:00, 2001-12-01 07:30:00, 2001-12-01 08:30:00,
#        2001-12-01 09:30:00, 2001-12-01 10:30:00, 2001-12-01 11:30:00,
#        2001-12-01 12:30:00, 2001-12-01 13:30:00, 2001-12-01 14:30:00,
#        2001-12-01 15:30:00, 2001-12-01 16:30:00, 2001-12-01 17:30:00,
#        2001-12-01 18:30:00, 2001-12-01 19:30:00, 2001-12-01 20:30:00,
#        2001-12-01 21:30:00, 2001-12-01 22:30:00, 2001-12-01 23:30:00,
#        2001-12-02 00:30:00, 2001-12-02 01:30:00, 2001-12-02 02:30:00,
#        2001-12-02 03:30:00, 2001-12-02 04:30:00, 2001-12-02 05:30:00,
#        2001-12-02 06:30:00, 2001-12-02 07:30:00, 2001-12-02 08:30:00,
#        2001-12-02 09:30:00, 2001-12-02 10:30:00, 2001-12-02 11:30:00,
#        2001-12-02 12:30:00, 2001-12-02 13:30:00, 2001-12-02 14:30:00,
# ...

# %%
ddir_30mins = "/nfs/a321/gy17m2a/PhD/datadir/UKCP18_every30mins/2.2km_bng_masked/2002_2020/bc005/"
test_30mins = iris.load(ddir_30mins+ 'bng_bc005a.pr200209.nc')

# %%
print(test_30mins[0].coord('time'))
# Out:
# DimCoord([2002-09-01 00:15:00, 2002-09-01 00:45:00, 2002-09-01 01:15:00, ...,
#        2002-09-30 22:45:00, 2002-09-30 23:15:00, 2002-09-30 23:45:00], bounds=[[2002-09-01 00:00:00, 2002-09-01 00:30:00],
#        [2002-09-01 00:30:00, 2002-09-01 01:00:00],
#        [2002-09-01 01:00:00, 2002-09-01 01:30:00],
#        ...,
#        [2002-09-30 22:30:00, 2002-09-30 23:00:00],
#        [2002-09-30 23:00:00, 2002-09-30 23:30:00],
#        [2002-09-30 23:30:00, 2002-10-01 00:00:00]], standard_name='time', calendar='360_day', var_name='time')
