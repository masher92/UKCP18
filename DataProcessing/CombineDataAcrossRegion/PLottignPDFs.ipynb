# %%
import numpy as np

# %%
precip_data_30m = np.load("/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/NIMROD/30mins/NIMROD_regridded_2.2km/2006_compressed.npy")

# %%
# all_precip =  np.array([])
# for year in range(2006,2021):
#     if year not in [2008, 2009]:
#         one_yr_precip = np.load(f"/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/NIMROD/30mins/NIMROD_regridded_2.2km/{year}_compressed.npy")
#         all_precip = np.append(all_precip, one_yr_precip)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_27686/1171251283.py in <module>
#       2 for year in range(2006,2021):
#       3     if year not in [2008, 2009]:
# ----> 4         one_yr_precip = np.load(f"/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/NIMROD/30mins/NIMROD_regridded_2.2km/{year}_compressed.npy")
#       5         all_precip = np.append(all_precip, one_yr_precip)
#       6
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# ...

# %%
np.nanmin(all_precip)
# Out:
# 0.1198827111562499

# %%
all_precip= all_precip[np.isfinite(all_precip)]

# %%
# from collections import Counter
# b = Counter(all_precip)
print(b.most_common(1))
# Out:
# [(0.0, 1996159736)]

# %%
import matplotlib.pyplot as plt
y_axis_scaling = 'log'
hist, bins = np.histogram(all_precip, bins=100)
bin_centers = (bins[1:]+bins[:-1])*0.5
plt.plot(bin_centers, hist)
plt.yscale(y_axis_scaling)
plt.xlabel('Precipitation (mm/hr')
plt.ylabel('Probability density')
# Out:
# Text(0,0.5,'Probability density')

# %%
import matplotlib.pyplot as plt
y_axis_scaling = 'log'
hist, bins = np.histogram(all_precip, bins=100)
bin_centers = (bins[1:]+bins[:-1])*0.5
plt.plot(bin_centers, hist)
plt.yscale('log')
plt.xlabel('Precipitation (mm/hr')
plt.ylabel('Probability density')
# Out:
# Text(0,0.5,'Probability density')
