# %%
import iris
import os
import glob as sir_globington_the_file_gatherer
import datetime as datetime
import iris.coord_categorisation as cat

# Set up path to root directory
root_fp = "/nfs/a319/gy17m2a/PhD/"
os.chdir(root_fp)

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Establish the ensemble member

# %%
em = '01'
yrs_range = "1980_2001"

# %% [markdown]
# ### Get a list of filenames for this ensemble member, for just JJA

# %%
general_filename = f'datadir/UKCP18/2.2km/{em}/{yrs_range}/pr_rcp85_land-cpm_uk_2.2km_{em}_1hr_*'
filenames = []
for filename in sir_globington_the_file_gatherer.glob(general_filename):
    #print(filename)
    filenames.append(filename)
print(len(filenames))
# Out:
# 253

# %% [markdown]
# ### Load in the data

# %%
monthly_cubes_list = iris.load(filenames,'lwe_precipitation_rate')

# %%
monthly_cubes_list
# Out:
# [<iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>,
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (ensemble_member: 1; time: 720; grid_latitude: 606; grid_longitude: 484)>]

# %%
for cube in monthly_cubes_list:
     for attr in ['creation_date', 'tracking_id', 'history', 'Conventions']:
            if attr in cube.attributes:
                del cube.attributes[attr]

# %% [markdown]
# ### Concatenate cubes into one

# %%
# Concatenate the cubes into one
model_cube = monthly_cubes_list.concatenate_cube()
# Out:
# ---------------------------------------------------------------------------
# ConcatenateError                          Traceback (most recent call last)
# Cell In [19], line 2
#       1 # Concatenate the cubes into one
# ----> 2 model_cube = monthly_cubes_list.concatenate_cube()
#
# File /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/iris/cube.py:548, in CubeList.concatenate_cube(self, check_aux_coords, check_cell_measures, check_ancils)
#     546 unique_names = list(OrderedDict.fromkeys(names))
#     547 if len(unique_names) == 1:
# --> 548     res = concatenate(
#     549         self,
#     550         error_on_mismatch=True,
#     551         check_aux_coords=check_aux_coords,
#     552         check_cell_measures=check_cell_measures,
#     553         check_ancils=check_ancils,
#     554     )
#     555     n_res_cubes = len(res)
#     556     if n_res_cubes == 1:
#
# File /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/iris/_concatenate.py:317, in concatenate(cubes, error_on_mismatch, check_aux_coords, check_cell_measures, check_ancils)
#     315 # Register cube with an existing proto-cube.
#     316 for proto_cube in proto_cubes:
# --> 317     registered = proto_cube.register(
#     318         cube,
#     319         axis,
#     320         error_on_mismatch,
#     321         check_aux_coords,
#     322         check_cell_measures,
#     323         check_ancils,
#     324     )
#     325     if registered:
#     326         axis = proto_cube.axis
#
# File /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/iris/_concatenate.py:838, in _ProtoCube.register(self, cube, axis, error_on_mismatch, check_aux_coords, check_cell_measures, check_ancils)
#     836 # Check for compatible cube signatures.
#     837 cube_signature = _CubeSignature(cube)
# --> 838 match = self._cube_signature.match(cube_signature, error_on_mismatch)
#     840 # Check for compatible coordinate signatures.
#     841 if match:
#
# File /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/pygeospatial/lib/python3.9/site-packages/iris/_concatenate.py:566, in _CubeSignature.match(self, other, error_on_mismatch)
#     564 match = not bool(msgs)
#     565 if error_on_mismatch and not match:
# --> 566     raise iris.exceptions.ConcatenateError(msgs)
#     567 return match
#
# ConcatenateError: failed to concatenate into a single cube.
#   Cube metadata differs for phenomenon: lwe_precipitation_rate

# %% [markdown]
# ### Remove ensemble member dimension

# %%
model_cube = model_cube[0,:,:,:]

# %% [markdown]
# ### Cut to just JJA

# %%
## Add season variables
iris.coord_categorisation.add_season(model_cube,'time', name = "clim_season")
# Keep only JJA
jja = model_cube.extract(iris.Constraint(clim_season = 'jja'))

# %%
jja
# Out:
# <iris 'Cube' of lwe_precipitation_rate / (mm/hour) (time: 45360; grid_latitude: 606; grid_longitude: 484)>
