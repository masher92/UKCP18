# %%
import iris
import iris.plot as iplt
import numpy as np
from iris.coords import DimCoord
from iris.coord_systems import TransverseMercator,GeogCS
from iris.cube import Cube
from cf_units import Unit
import cf_units
import os
import glob
from pyproj import Proj, transform
import sys
import warnings
import multiprocessing as mp
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

root_fp = "/nfs/a319/gy17m2a/"
# Create path to files containing functions
sys.path.insert(0, root_fp + 'PhD/Scripts/DataProcessing/Regridding')
from Regridding_functions import *
sys.path.insert(0, root_fp + 'Scripts/GlobalFunctions')
from Spatial_plotting_functions import *
from Spatial_geometry_functions import *

##########################################
# Define dataset and years to work on
##########################################
yrs_range = '2002_2020'

uk_gdf = create_uk_outline({'init' :'epsg:3857'})

##########################################
# Load UKCP18 2km model data to use in regriddding
##########################################
file_model_2_2km_bng ='/nfs/a161/gy17m2a/PhD/datadir/UKCP18_hourly/2.2km_bng_masked/01/1980_2001/bng_pr_rcp85_land-cpm_uk_2.2km_01_1hr_19910601-19910630.nc'
cube_2km_bng =iris.load_cube(file_model_2_2km_bng)

##########################################
# Load LSM and use a NIMROD file to regrid it to 1km
##########################################
file_nimrod_1km = "/nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/OriginalFormat_1km/filtered_100/2007/metoffice-c-band-rain-radar_uk_20070614_30mins.nc"
nimrod_1km =iris.load_cube(file_nimrod_1km)
nimrod_1km= trim_to_bbox_of_region_obs(nimrod_1km, uk_gdf, 'projection_y_coordinate', 'projection_x_coordinate')

lsm = iris.load("/nfs/a319/gy17m2a/PhD/datadir/Masks/lsm_land-cpm_BI_5km.nc")[0]
lsm_1km = lsm.regrid(nimrod_1km, iris.analysis.Nearest()) 

###################
# Load UKCP18 12km model data to use in regriddding
###################
file_model_12km=f'/nfs/a161/gy17m2a/PhD/datadir/UKCP18_hourly/2.2km_bng_regridded_12km_masked/01/AreaWeighted/1980_2001/bng_rg_pr_rcp85_land-cpm_uk_2.2km_01_1hr_19810601-19810630.nc'
cube_12km_bng=iris.load_cube(file_model_12km)

in_jja=iris.Constraint(time=lambda cell: 8 <= cell.point.month <= 8)
season='wholeyear'

##############
### Loop through all years of data
##############
year=2010

for filtering_name in ["unfiltered"]:
    print(year)
    # Change directory to be for correct year
    os.chdir(f"/nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/OriginalFormat_1km/{filtering_name}/{year}")
    # Define filepaths to save files to
    output_dir_2km = f"/nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/{filtering_name}/AreaWeighted/{year}/"
    output_dir_12km = f"/nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_12km/{filtering_name}/AreaWeighted/{year}/"

    if not os.path.isdir(output_dir_12km):
        os.makedirs(output_dir_12km)
    # Create these directories if they don't exist already
    if not os.path.isdir(output_dir_2km):
        os.makedirs(output_dir_2km)

    # Loop through all the diles in the 1km folder    
    for filename in sorted(glob.glob("*")):

        # Create version of filename specifying it is regridded
        filename_to_save_to = f"rg_{filename}"
        if not os.path.isfile(output_dir_2km + filename_to_save_to):
            cube = iris.load(filename)[0] 
            print(f"{filename} doesn't exist: Creating now")

             # Fill in missing bounds
            cube.coord('projection_y_coordinate').guess_bounds()
            cube.coord('projection_x_coordinate').guess_bounds()
            # Align small rounding error in coordinates
            cube.coord('projection_x_coordinate').coord_system = cube_2km_bng.coord('projection_x_coordinate').coord_system
            cube.coord('projection_y_coordinate').coord_system = cube_2km_bng.coord('projection_y_coordinate').coord_system

            cube = trim_to_bbox_of_region_obs(cube, uk_gdf, 'projection_y_coordinate', 'projection_x_coordinate')

            broadcasted_lsm_1km_data = np.broadcast_to(lsm_1km.data.data, cube.shape)
            broadcasted_lsm_1km_data_reversed = ~broadcasted_lsm_1km_data.astype(bool)

            # Apply mask
            cube_masked = iris.util.mask_cube(cube.copy(), broadcasted_lsm_1km_data_reversed)

            # Area Weighted
            reg_cube_masked_2km =cube_masked.regrid(cube_2km_bng,iris.analysis.AreaWeighted())    
            print("Regridded")
            reg_cube_masked_12km =cube_masked.regrid(cube_12km_bng,iris.analysis.AreaWeighted())    
            print("Regridded")     

            print(cube_masked.shape)    
            print(reg_cube_masked_2km.shape)
            print(reg_cube_masked_12km.shape)

            # Save 
            print(output_dir_2km + filename_to_save_to)
            iris.save(reg_cube_masked_2km, output_dir_2km + filename_to_save_to)    
            iris.save(reg_cube_masked_12km, output_dir_12km + filename_to_save_to) 
            
        else:
            print(f"{output_dir_2km + filename_to_save_to} exists")
# Out:
# 2010
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100101_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100102_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100103_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100104_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100105_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100106_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100107_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100108_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100109_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100110_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100111_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100112_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100113_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100115_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100116_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100117_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100118_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100119_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100120_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100121_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100122_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100123_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100124_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100125_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100126_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100127_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100128_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100129_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100130_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100131_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100201_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100202_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100203_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100204_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100205_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100206_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100207_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100208_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100209_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100210_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100211_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100212_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100213_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100214_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100215_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100216_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100217_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100218_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100219_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100220_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100221_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100222_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100223_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100224_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100225_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100226_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100227_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100228_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100301_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100302_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100303_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100304_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100305_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100306_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100307_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100308_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100309_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100310_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100311_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100312_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100313_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100314_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100315_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100316_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100317_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100318_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100319_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100320_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100321_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100322_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100323_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100324_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100325_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100326_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100327_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100328_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100329_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100330_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100331_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100401_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100402_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100403_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100404_30mins.nc exists
# metoffice-c-band-rain-radar_uk_20100405_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100405_30mins.nc
# metoffice-c-band-rain-radar_uk_20100406_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100406_30mins.nc
# metoffice-c-band-rain-radar_uk_20100407_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100407_30mins.nc
# metoffice-c-band-rain-radar_uk_20100408_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100408_30mins.nc
# metoffice-c-band-rain-radar_uk_20100409_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (20, 1179, 865)
# (20, 519, 423)
# (20, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100409_30mins.nc
# metoffice-c-band-rain-radar_uk_20100411_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (33, 1179, 865)
# (33, 519, 423)
# (33, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100411_30mins.nc
# metoffice-c-band-rain-radar_uk_20100412_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (46, 1179, 865)
# (46, 519, 423)
# (46, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100412_30mins.nc
# metoffice-c-band-rain-radar_uk_20100413_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100413_30mins.nc
# metoffice-c-band-rain-radar_uk_20100414_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100414_30mins.nc
# metoffice-c-band-rain-radar_uk_20100415_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100415_30mins.nc
# metoffice-c-band-rain-radar_uk_20100416_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100416_30mins.nc
# metoffice-c-band-rain-radar_uk_20100417_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100417_30mins.nc
# metoffice-c-band-rain-radar_uk_20100418_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100418_30mins.nc
# metoffice-c-band-rain-radar_uk_20100419_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100419_30mins.nc
# metoffice-c-band-rain-radar_uk_20100420_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (31, 1179, 865)
# (31, 519, 423)
# (31, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100420_30mins.nc
# metoffice-c-band-rain-radar_uk_20100421_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (7, 1179, 865)
# (7, 519, 423)
# (7, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100421_30mins.nc
# metoffice-c-band-rain-radar_uk_20100425_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (26, 1179, 865)
# (26, 519, 423)
# (26, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100425_30mins.nc
# metoffice-c-band-rain-radar_uk_20100426_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100426_30mins.nc
# metoffice-c-band-rain-radar_uk_20100427_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100427_30mins.nc
# metoffice-c-band-rain-radar_uk_20100428_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100428_30mins.nc
# metoffice-c-band-rain-radar_uk_20100429_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100429_30mins.nc
# metoffice-c-band-rain-radar_uk_20100430_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100430_30mins.nc
# metoffice-c-band-rain-radar_uk_20100501_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100501_30mins.nc
# metoffice-c-band-rain-radar_uk_20100502_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100502_30mins.nc
# metoffice-c-band-rain-radar_uk_20100503_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100503_30mins.nc
# metoffice-c-band-rain-radar_uk_20100504_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100504_30mins.nc
# metoffice-c-band-rain-radar_uk_20100505_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100505_30mins.nc
# metoffice-c-band-rain-radar_uk_20100506_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100506_30mins.nc
# metoffice-c-band-rain-radar_uk_20100507_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100507_30mins.nc
# metoffice-c-band-rain-radar_uk_20100508_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100508_30mins.nc
# metoffice-c-band-rain-radar_uk_20100509_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100509_30mins.nc
# metoffice-c-band-rain-radar_uk_20100510_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100510_30mins.nc
# metoffice-c-band-rain-radar_uk_20100511_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (48, 1179, 865)
# (48, 519, 423)
# (48, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2010/rg_metoffice-c-band-rain-radar_uk_20100511_30mins.nc
# metoffice-c-band-rain-radar_uk_20100512_30mins.nc doesn't exist: Creating now
