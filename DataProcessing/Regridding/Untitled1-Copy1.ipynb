# %%
import iris
import iris.plot as iplt
import numpy as np
from iris.coords import DimCoord
from iris.coord_systems import TransverseMercator,GeogCS
from iris.cube import Cube
from cf_units import Unit
import cf_units
import os
import glob
from pyproj import Proj, transform
import sys
import warnings
import multiprocessing as mp
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

root_fp = "/nfs/a319/gy17m2a/"
# Create path to files containing functions
sys.path.insert(0, root_fp + 'PhD/Scripts/DataProcessing/Regridding')
from Regridding_functions import *
sys.path.insert(0, root_fp + 'Scripts/GlobalFunctions')
from Spatial_plotting_functions import *
from Spatial_geometry_functions import *

##########################################
# Define dataset and years to work on
##########################################
yrs_range = '2002_2020'

uk_gdf = create_uk_outline({'init' :'epsg:3857'})

##########################################
# Load UKCP18 2km model data to use in regriddding
##########################################
file_model_2_2km_bng ='/nfs/a161/gy17m2a/PhD/datadir/UKCP18_hourly/2.2km_bng_masked/01/1980_2001/bng_pr_rcp85_land-cpm_uk_2.2km_01_1hr_19910601-19910630.nc'
cube_2km_bng =iris.load_cube(file_model_2_2km_bng)

##########################################
# Load LSM and use a NIMROD file to regrid it to 1km
##########################################
file_nimrod_1km = "/nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/OriginalFormat_1km/filtered_100/2007/metoffice-c-band-rain-radar_uk_20070614_30mins.nc"
nimrod_1km =iris.load_cube(file_nimrod_1km)
nimrod_1km= trim_to_bbox_of_region_obs(nimrod_1km, uk_gdf, 'projection_y_coordinate', 'projection_x_coordinate')

lsm = iris.load("/nfs/a319/gy17m2a/PhD/datadir/Masks/lsm_land-cpm_BI_5km.nc")[0]
lsm_1km = lsm.regrid(nimrod_1km, iris.analysis.Nearest()) 

###################
# Load UKCP18 12km model data to use in regriddding
###################
file_model_12km=f'/nfs/a161/gy17m2a/PhD/datadir/UKCP18_hourly/2.2km_bng_regridded_12km_masked/01/AreaWeighted/1980_2001/bng_rg_pr_rcp85_land-cpm_uk_2.2km_01_1hr_19810601-19810630.nc'
cube_12km_bng=iris.load_cube(file_model_12km)

in_jja=iris.Constraint(time=lambda cell: 8 <= cell.point.month <= 8)
season='wholeyear'

##############
### Loop through all years of data
##############
year=2006

for filtering_name in ["unfiltered"]:
    print(year)
    # Change directory to be for correct year
    os.chdir(f"/nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/OriginalFormat_1km/{filtering_name}/{year}")
    # Define filepaths to save files to
    output_dir_2km = f"/nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/{filtering_name}/AreaWeighted/{year}/"
    output_dir_12km = f"/nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_12km/{filtering_name}/AreaWeighted/{year}/"

    if not os.path.isdir(output_dir_12km):
        os.makedirs(output_dir_12km)
    # Create these directories if they don't exist already
    if not os.path.isdir(output_dir_2km):
        os.makedirs(output_dir_2km)

    # Loop through all the diles in the 1km folder    
    for filename in sorted(glob.glob("*")):

        # Create version of filename specifying it is regridded
        filename_to_save_to = f"rg_{filename}"
        if not os.path.isfile(output_dir_2km + filename_to_save_to):
            cube = iris.load(filename)[0] 
            print(f"{filename} doesn't exist: Creating now")

             # Fill in missing bounds
            cube.coord('projection_y_coordinate').guess_bounds()
            cube.coord('projection_x_coordinate').guess_bounds()
            # Align small rounding error in coordinates
            cube.coord('projection_x_coordinate').coord_system = cube_2km_bng.coord('projection_x_coordinate').coord_system
            cube.coord('projection_y_coordinate').coord_system = cube_2km_bng.coord('projection_y_coordinate').coord_system

            cube = trim_to_bbox_of_region_obs(cube, uk_gdf, 'projection_y_coordinate', 'projection_x_coordinate')

            broadcasted_lsm_1km_data = np.broadcast_to(lsm_1km.data.data, cube.shape)
            broadcasted_lsm_1km_data_reversed = ~broadcasted_lsm_1km_data.astype(bool)

            # Apply mask
            cube_masked = iris.util.mask_cube(cube.copy(), broadcasted_lsm_1km_data_reversed)

            # Area Weighted
            reg_cube_masked_2km =cube_masked.regrid(cube_2km_bng,iris.analysis.AreaWeighted())    
            print("Regridded")
            reg_cube_masked_12km =cube_masked.regrid(cube_12km_bng,iris.analysis.AreaWeighted())    
            print("Regridded")     

            print(cube_masked.shape)    
            print(reg_cube_masked_2km.shape)
            print(reg_cube_masked_12km.shape)

            # Save 
            print(output_dir_2km + filename_to_save_to)
            iris.save(reg_cube_masked_2km, output_dir_2km + filename_to_save_to)    
            iris.save(reg_cube_masked_12km, output_dir_12km + filename_to_save_to) 
            
        else:
            print(f"{output_dir_2km + filename_to_save_to} exists")
# Out:
# ERROR:fiona._env:PROJ: proj_identify: /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/share/proj/proj.db lacks DATABASE.LAYOUT.VERSION.MAJOR / DATABASE.LAYOUT.VERSION.MINOR metadata. It comes from another PROJ installation.
# ERROR:fiona._env:PROJ: proj_identify: /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/share/proj/proj.db lacks DATABASE.LAYOUT.VERSION.MAJOR / DATABASE.LAYOUT.VERSION.MINOR metadata. It comes from another PROJ installation.
# 2006
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060101_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060102_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060103_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060104_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060105_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060106_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060107_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060108_30mins.nc exists
# metoffice-c-band-rain-radar_uk_20060109_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (47, 1179, 865)
# (47, 519, 423)
# (47, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060109_30mins.nc
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060110_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060111_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060112_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060113_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060114_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060115_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060116_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060117_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060118_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060119_30mins.nc exists
# metoffice-c-band-rain-radar_uk_20060120_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (45, 1179, 865)
# (45, 519, 423)
# (45, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060120_30mins.nc
# metoffice-c-band-rain-radar_uk_20060121_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (44, 1179, 865)
# (44, 519, 423)
# (44, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060121_30mins.nc
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060122_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060123_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060124_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060125_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060126_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060127_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060128_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060129_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060130_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060131_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060201_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060202_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060203_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060204_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060205_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060206_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060207_30mins.nc exists
# metoffice-c-band-rain-radar_uk_20060208_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (47, 1179, 865)
# (47, 519, 423)
# (47, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060208_30mins.nc
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060209_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060210_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060211_30mins.nc exists
# metoffice-c-band-rain-radar_uk_20060212_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (8, 1179, 865)
# (8, 519, 423)
# (8, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060212_30mins.nc
# metoffice-c-band-rain-radar_uk_20060214_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (25, 1179, 865)
# (25, 519, 423)
# (25, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060214_30mins.nc
# metoffice-c-band-rain-radar_uk_20060215_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (35, 1179, 865)
# (35, 519, 423)
# (35, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060215_30mins.nc
# metoffice-c-band-rain-radar_uk_20060216_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (25, 1179, 865)
# (25, 519, 423)
# (25, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060216_30mins.nc
# metoffice-c-band-rain-radar_uk_20060217_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (16, 1179, 865)
# (16, 519, 423)
# (16, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060217_30mins.nc
# metoffice-c-band-rain-radar_uk_20060220_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (3, 1179, 865)
# (3, 519, 423)
# (3, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060220_30mins.nc
# metoffice-c-band-rain-radar_uk_20060223_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (16, 1179, 865)
# (16, 519, 423)
# (16, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060223_30mins.nc
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060224_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060225_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060226_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060227_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060228_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060301_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060302_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060303_30mins.nc exists
# metoffice-c-band-rain-radar_uk_20060304_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (46, 1179, 865)
# (46, 519, 423)
# (46, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060304_30mins.nc
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060305_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060306_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060307_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060308_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060309_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060310_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060311_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060312_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060313_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060314_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060315_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060316_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060317_30mins.nc exists
# metoffice-c-band-rain-radar_uk_20060318_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (47, 1179, 865)
# (47, 519, 423)
# (47, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060318_30mins.nc
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060319_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060320_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060321_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060322_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060323_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060324_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060325_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060326_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060327_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060328_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060329_30mins.nc exists
# metoffice-c-band-rain-radar_uk_20060330_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (20, 1179, 865)
# (20, 519, 423)
# (20, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060330_30mins.nc
# metoffice-c-band-rain-radar_uk_20060403_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (29, 1179, 865)
# (29, 519, 423)
# (29, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060403_30mins.nc
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060404_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060405_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060406_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060407_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060408_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060409_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060410_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060411_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060412_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060413_30mins.nc exists
# metoffice-c-band-rain-radar_uk_20060414_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (47, 1179, 865)
# (47, 519, 423)
# (47, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060414_30mins.nc
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060415_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060416_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060417_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060418_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060419_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060420_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060421_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060422_30mins.nc exists
# metoffice-c-band-rain-radar_uk_20060423_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (47, 1179, 865)
# (47, 519, 423)
# (47, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060423_30mins.nc
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060424_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060425_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060426_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060427_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060428_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060429_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060430_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060501_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060502_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060503_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060504_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060505_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060506_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060507_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060508_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060509_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060510_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060511_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060512_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060513_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060514_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060515_30mins.nc exists
# metoffice-c-band-rain-radar_uk_20060516_30mins.nc doesn't exist: Creating now
# Regridded
# Regridded
# (47, 1179, 865)
# (47, 519, 423)
# (47, 112, 82)
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060516_30mins.nc
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060517_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060518_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060519_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060520_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060521_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060522_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060523_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060524_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060525_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060526_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060527_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060528_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060529_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060530_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060531_30mins.nc exists
# /nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/unfiltered/AreaWeighted/2006/rg_metoffice-c-band-rain-radar_uk_20060601_30mins.nc exists
