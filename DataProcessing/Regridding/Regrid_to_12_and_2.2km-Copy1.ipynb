# %%
import iris
import numpy as np
from iris.coords import DimCoord
from iris.coord_systems import TransverseMercator,GeogCS
from iris.cube import Cube
from cf_units import Unit
import cf_units
import os
import glob
from pyproj import Proj, transform
import sys
import warnings
import multiprocessing as mp
import cartopy.crs as ccrs

warnings.filterwarnings("ignore")

ems_hourly = ['01', '04', '06', '07', '08', '09', '10', '11', '12', '13', '15']
ems_30mins = ['bc005', 'bc006', 'bc007', 'bc009', 'bc010', 'bc011', 'bc013',  'bc015',  'bc016', 'bc017', 'bc018', 'bc012']
yrs_range = '1980_2001'

# %%
##########################################################################################
#########################################################################################
# Define variables and set up environment
##########################################################################################
##########################################################################################
root_fp = "/nfs/a319/gy17m2a/"
os.chdir(root_fp)

# Create path to files containing functions
sys.path.insert(0, root_fp + 'PhD/Scripts/DataProcessing/Regridding')
from Regridding_functions import *
# Create path to files containing functions
sys.path.insert(0, root_fp + 'Scripts/GlobalFunctions')
from Spatial_plotting_functions import *
from Spatial_geometry_functions import *

gb_gdf = create_gb_outline({'init' :'epsg:3857'})

# Load UKCP18 12km model data to use in regriddding
file_model_12km=f'/nfs/a319/gy17m2a/PhD/datadir/UKCP18_hourly/12km/01/{yrs_range}/pr_rcp85_land-rcm_uk_12km_01_day_19801201-19901130.nc'
cube_12km=iris.load_cube(file_model_12km)

file_model_2_2km ='/nfs/a319/gy17m2a/PhD/datadir/UKCP18_hourly/2.2km/01/1980_2001/pr_rcp85_land-cpm_uk_2.2km_01_1hr_19910601-19910630.nc'
cube_2km =iris.load_cube(file_model_2_2km)

file_model_12km_wgs84 ='/nfs/a319/gy17m2a/PhD/datadir/UKCP18_hourly/12km_wgs84/01/1980_2001/wgs84_pr_rcp85_land-rcm_uk_12km_01_day_20701201-20801130.nc'
cube_12km_wgs84 =iris.load_cube(file_model_12km_wgs84)

# remove ensemble member dimension
cube_2km = cube_2km[0,:,:,:]
cube_12km = cube_12km[0,:,:,:]

# %%
##################################################################
# This is a square area surrounding Leeds
leeds_at_centre_gdf = create_leeds_at_centre_outline({'init' :'epsg:3857'})
cube_12km_trimmed_to_leeds =  trim_to_bbox_of_region_obs(cube_12km, leeds_at_centre_gdf)

# %%
yrs_range = '1980_2001'
# ems_hourly = ['04', '06', '07', '08', '09', '10', ]

# %% [markdown]
# ### Trim so the same size

# %%
# cube_2km = trim_to_bbox_of_region_regriddedobs(cube_2km, gb_gdf)
# cube_12km = trim_to_bbox_of_region_obs(cube_12km, gb_gdf)

iplt.contourf(cube_12km[1,:,:])
plt.gca().coastlines(resolution='10m', color='black', linewidth=0.5);

# %% [markdown]
# ### Inspect coordinates

# %%
### 2km cube has grid_latitude and grid_longitude as 1D dimension coordinates (rotated geodesic)
### 2km cube has projection_y_coordinate and projection_x_coordinate as 1D dimension coordinates (BNG)

# %%
# cube_2km_test = cube_2km[0,1:5,:,:]
# cube_12km_test = cube_12km[0,1:5,:,:]
# iris.save(cube_12km_test,"mytest2km.nc")
# iris.save(cube_2km_test,"myest12km.nc")

# %%
# print(cube_2km.coord('grid_latitude').shape)
# print(cube_2km.coord('grid_longitude').shape)
# print(cube_12km.coord('projection_y_coordinate').shape)
# print(cube_12km.coord('projection_x_coordinate').shape)

# %%
### 2km cube has latitude and longitude as 2D dimension coordinates (rotated geodesic)
### 12km cube has grid_latitude and grid_longitude as 2D dimension coordinates (BNG)

# %%
# print(cube_2km.coord('latitude').shape)
# print(cube_2km.coord('longitude').shape)
# print(cube_12km.coord('grid_latitude').shape)
# print(cube_12km.coord('grid_longitude').shape)

# %%
### But are the grid_latitude and grid_longitude coordinates the same?
### Don't think so
### 2km is in rotated pole
### But 12km is in WGS84 still

# %%
# cube_12km.coord('grid_latitude').coord_system

# print(cube_2km.coord('grid_longitude').coord_system)
# print(cube_2km.coord('longitude').coord_system)

# print(cube_12km.coord('projection_y_coordinate').coord_system)
# print(cube_12km.coord('grid_longitude').coord_system)

# %% [markdown]
# ## Transform cube 12km to WGS84

# %%
# this is the crs that we want to transform to
source_crs_12km = ccrs.OSGB(approx=False)
source_crs_2km = ccrs.RotatedGeodetic(pole_latitude=37.5,
                                        pole_longitude=177.5,
                                        central_rotated_longitude=0)

# these are the crs we are transforming from
target_crs = ccrs.Geodetic()

# %%
def convert_to_wgs84(source_crs, cube, x_coord_name, y_coord_name):
    # Extract the 2D meshgrid of X (eastings) and Y (northings) coordinates from the cube
    x = cube.coord(x_coord_name).points
    y = cube.coord(y_coord_name).points
    xx, yy = np.meshgrid(x, y)

    # Also get time for the new cube
    time_coord = cube.coord('time')

    # Use transform_points to project your coordinates
    transformed_points = target_crs.transform_points(source_crs, xx.flatten(), yy.flatten())

    # transformed_points now has a shape (n*m, 3), where the last dimension contains (lon, lat, z)
    # Reshape the array back to your original grid shape and separate the components
    lons, lats = transformed_points[..., 0].reshape(xx.shape), transformed_points[..., 1].reshape(yy.shape)

    # Now, you should create a new cube with these lons and lats as coordinates.
    # Note: This step requires careful handling to ensure the new cube's data aligns correctly with the transformed coordinates.
    # You might need to create new latitude and longitude DimCoords, ensuring they have bounds set if performing area-weighted regridding later.

    # Here's a simplified way to create a new cube with the transformed coordinates,
    # assuming your original data is 2-dimensional and compatible with the new grid.
    new_cube_data = cube.data  # This might require adjustment if the data needs to be interpolated onto the new grid.
    latitude_coord = iris.coords.DimCoord(lats[:, 0], standard_name='latitude', units='degrees')
    longitude_coord = iris.coords.DimCoord(lons[0, :], standard_name='longitude', units='degrees')

    # Guess bounds
    latitude_coord.guess_bounds()
    longitude_coord.guess_bounds()

    cube_wgs84 = iris.cube.Cube(new_cube_data,
                              dim_coords_and_dims=[(time_coord, 0), (latitude_coord, 1), (longitude_coord, 2)],
                              standard_name=cube.standard_name,
                              units=cube.units)
    
    return cube_wgs84

# %%
for em in ['01']:
    print(em)
    os.chdir(f"/nfs/a319/gy17m2a/PhD/datadir/UKCP18_hourly/2.2km/{em}/{yrs_range}/")
    output_fp_wgs84 = f"/nfs/a319/gy17m2a/PhD/datadir/UKCP18_hourly/2.2km_wgs84/{em}/{yrs_range}/"
    output_fp_regridded = f"/nfs/a319/gy17m2a/PhD/datadir/UKCP18_hourly/2.2km_regridded_12km/{em}/AreaWeighted/{yrs_range}/"
    if not os.path.isdir(output_fp_wgs84):
        os.makedirs(output_fp_wgs84)
    if not os.path.isdir(output_fp_regridded):
        os.makedirs(output_fp_regridded)        
    for filename in glob.glob("*"):     
            if filename[47:49] in ['06', '07', '08']:
                if not os.path.isfile(output_fp +  f"wgs84_{filename}"):
                    print("already exist")
                else:
                    print(filename)
                    cube = iris.load(filename)[0]
                    # transform to wgs84
                    cube_2km_wgs84 = convert_to_wgs84 (source_crs_2km, cube_2km, "grid_longitude", "grid_latitude")
                    # regrid to 12km
                    cube_2km_regridded_12km_wgs84 = cube_2km_wgs84.regrid(cube_12km_wgs84, iris.analysis.AreaWeighted()) 
                    # Save 
                    iris.save(cube_2km_wgs84, output_fp_wgs84 +  f"wgs84_{filename}")
                    iris.save(cube_2km_regridded_12km_wgs84, output_fp_regridded +  f"wgs84_rg_{filename}")
# Out:
# 01
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19930701-19930730.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19900801-19900830.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19960601-19960630.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19820601-19820630.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19840801-19840830.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19890701-19890730.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19810801-19810830.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19870601-19870630.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19910801-19910830.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19990801-19990830.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19960701-19960730.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19950801-19950830.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19880601-19880630.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19900701-19900730.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19820701-19820730.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19980801-19980830.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19830701-19830730.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19940601-19940630.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19940801-19940830.nc
# pr_rcp85_land-cpm_uk_2.2km_01_1hr_19810601-19810630.nc

# %%
# iplt.contourf(transformed_cube_2km[1,:,:])
# plt.gca().coastlines(resolution='10m', color='black', linewidth=0.5);

# %% [markdown]
# ## Regrid 30 mins UKCP18 data to 12km - DONE
# For this need to use version of the regridding cube which is trimmed to the leeds-at-centre region, as the 30 mins data is already clipped to this extent

# %%
ems_30mins =  ['bc005',  'bc006',  'bc007', 'bc009',  'bc010', 
       'bc011', 'bc013',  'bc015',  'bc016',  'bc017', 'bc018', 'bc012']

# %%
for em in ems_30mins:
    print(em)
    os.chdir(f"/nfs/a319/gy17m2a/PhD/datadir/UKCP18_every30mins/2.2km/{em}/2002_2020/")
    output_fp = f"/nfs/a319/gy17m2a/PhD/datadir/UKCP18_every30mins/2.2km_regridded_12km/{em}/NearestNeighbour/2002_2020/"
    if not os.path.isdir(output_fp):
        os.makedirs(output_fp)
    for filename in np.sort(glob.glob("*")):   
        print(filename)
        if not os.path.isfile(output_fp +  f"rg_{filename}"):
            print("creating")
            # print(filename)
            cube = iris.load(filename)[0]
            # Linear interpolation
            #reg_cube_lin =cube.regrid(cube_model,iris.analysis.Linear())      
            # Nearest neighbour
            try:
                reg_cube_nn =cube.regrid(cube_12km_trimmed_to_leeds,iris.analysis.Nearest())   
            except:
                print("Didnt work")
                pass
            # print(reg_cube_nn.shape)
            # Save 
            iris.save(reg_cube_nn, output_fp +  f"rg_{filename}") 
        else:
            print("already exists")
# Out:
# bc005
# bc005a.pr200006.nc
# already exists
# bc005a.pr200007.nc
# already exists
# bc005a.pr200008.nc
# already exists
# bc005a.pr200106.nc
# already exists
# bc005a.pr200107.nc
# already exists
# bc005a.pr200108.nc
# already exists
# bc005a.pr200206.nc
# already exists
# bc005a.pr200207.nc
# already exists
# bc005a.pr200208.nc
# already exists
# bc005a.pr200306.nc
# already exists
# bc005a.pr200307.nc
# already exists
# bc005a.pr200308.nc
# already exists
# bc005a.pr200406.nc
# already exists
# bc005a.pr200407.nc
# already exists
# bc005a.pr200408.nc
# already exists
# bc005a.pr200506.nc
# already exists
# bc005a.pr200507.nc
# already exists
# bc005a.pr200508.nc
# already exists
# bc005a.pr200606.nc
# already exists
# bc005a.pr200607.nc
# already exists
# bc005a.pr200608.nc
# already exists
# bc005a.pr200706.nc
# already exists
# bc005a.pr200707.nc
# already exists
# bc005a.pr200708.nc
# already exists
# bc005a.pr200806.nc
# already exists
# bc005a.pr200807.nc
# already exists
# bc005a.pr200808.nc
# already exists
# bc005a.pr200906.nc
# already exists
# bc005a.pr200907.nc
# already exists
# bc005a.pr200908.nc
# already exists
# bc005a.pr201006.nc
# already exists
# bc005a.pr201007.nc
# already exists
# bc005a.pr201008.nc
# already exists
# bc005a.pr201106.nc
# already exists
# bc005a.pr201107.nc
# already exists
# bc005a.pr201108.nc
# already exists
# bc005a.pr201206.nc
# already exists
# bc005a.pr201207.nc
# already exists
# bc005a.pr201208.nc
# already exists
# bc005a.pr201306.nc
# already exists
# bc005a.pr201307.nc
# already exists
# bc005a.pr201308.nc
# already exists
# bc005a.pr201406.nc
# already exists
# bc005a.pr201407.nc
# already exists
# bc005a.pr201408.nc
# already exists
# bc005a.pr201506.nc
# already exists
# bc005a.pr201507.nc
# already exists
# bc005a.pr201508.nc
# already exists
# bc005a.pr201606.nc
# already exists
# bc005a.pr201607.nc
# already exists
# bc005a.pr201608.nc
# already exists
# bc005a.pr201706.nc
# already exists
# bc005a.pr201707.nc
# already exists
# bc005a.pr201708.nc
# already exists
# bc005a.pr201806.nc
# already exists
# bc005a.pr201807.nc
# already exists
# bc005a.pr201808.nc
# already exists
# bc005a.pr201906.nc
# already exists
# bc005a.pr201907.nc
# already exists
# bc005a.pr201908.nc
# already exists
# bc005a.pr202006.nc
# already exists
# bc005a.pr202007.nc
# already exists
# bc005a.pr202008.nc
# already exists
# bc006
# bc006a.pr200006.nc
# already exists
# bc006a.pr200007.nc
# already exists
# bc006a.pr200008.nc
# already exists
# bc006a.pr200106.nc
# already exists
# bc006a.pr200107.nc
# already exists
# bc006a.pr200108.nc
# already exists
# bc006a.pr200206.nc
# already exists
# bc006a.pr200207.nc
# already exists
# bc006a.pr200208.nc
# already exists
# bc006a.pr200306.nc
# already exists
# bc006a.pr200307.nc
# already exists
# bc006a.pr200308.nc
# already exists
# bc006a.pr200406.nc
# already exists
# bc006a.pr200407.nc
# already exists
# bc006a.pr200408.nc
# already exists
# bc006a.pr200506.nc
# already exists
# bc006a.pr200507.nc
# already exists
# bc006a.pr200508.nc
# already exists
# bc006a.pr200606.nc
# already exists
# bc006a.pr200607.nc
# already exists
# bc006a.pr200608.nc
# already exists
# bc006a.pr200706.nc
# already exists
# bc006a.pr200707.nc
# already exists
# bc006a.pr200708.nc
# already exists
# bc006a.pr200806.nc
# already exists
# bc006a.pr200807.nc
# already exists
# bc006a.pr200808.nc
# already exists
# bc006a.pr200906.nc
# already exists
# bc006a.pr200907.nc
# already exists
# bc006a.pr200908.nc
# already exists
# bc006a.pr201006.nc
# already exists
# bc006a.pr201007.nc
# already exists
# bc006a.pr201008.nc
# already exists
# bc006a.pr201106.nc
# already exists
# bc006a.pr201107.nc
# already exists
# bc006a.pr201108.nc
# already exists
# bc006a.pr201206.nc
# already exists
# bc006a.pr201207.nc
# already exists
# bc006a.pr201208.nc
# already exists
# bc006a.pr201306.nc
# already exists
# bc006a.pr201307.nc
# already exists
# bc006a.pr201308.nc
# already exists
# bc006a.pr201406.nc
# already exists
# bc006a.pr201407.nc
# already exists
# bc006a.pr201408.nc
# already exists
# bc006a.pr201506.nc
# already exists
# bc006a.pr201507.nc
# already exists
# bc006a.pr201508.nc
# already exists
# bc006a.pr201606.nc
# already exists
# bc006a.pr201607.nc
# already exists
# bc006a.pr201608.nc
# already exists
# bc006a.pr201706.nc
# already exists
# bc006a.pr201707.nc
# already exists
# bc006a.pr201708.nc
# already exists
# bc006a.pr201806.nc
# already exists
# bc006a.pr201807.nc
# already exists
# bc006a.pr201808.nc
# already exists
# bc006a.pr201906.nc
# already exists
# bc006a.pr201907.nc
# already exists
# bc006a.pr201908.nc
# already exists
# bc006a.pr202006.nc
# already exists
# bc006a.pr202007.nc
# already exists
# bc006a.pr202008.nc
# already exists
# bc007
# bc007a.pr200006.nc
# already exists
# bc007a.pr200007.nc
# already exists
# bc007a.pr200008.nc
# already exists
# bc007a.pr200106.nc
# already exists
# bc007a.pr200107.nc
# already exists
# bc007a.pr200108.nc
# already exists
# bc007a.pr200206.nc
# already exists
# bc007a.pr200207.nc
# already exists
# bc007a.pr200208.nc
# already exists
# bc007a.pr200306.nc
# already exists
# bc007a.pr200307.nc
# already exists
# bc007a.pr200308.nc
# already exists
# bc007a.pr200406.nc
# already exists
# bc007a.pr200407.nc
# already exists
# bc007a.pr200408.nc
# already exists
# bc007a.pr200506.nc
# already exists
# bc007a.pr200507.nc
# already exists
# bc007a.pr200508.nc
# already exists
# bc007a.pr200606.nc
# already exists
# bc007a.pr200607.nc
# already exists
# bc007a.pr200608.nc
# already exists
# bc007a.pr200706.nc
# already exists
# bc007a.pr200707.nc
# already exists
# bc007a.pr200708.nc
# already exists
# bc007a.pr200806.nc
# already exists
# bc007a.pr200807.nc
# already exists
# bc007a.pr200808.nc
# already exists
# bc007a.pr200906.nc
# already exists
# bc007a.pr200907.nc
# already exists
# bc007a.pr200908.nc
# already exists
# bc007a.pr201006.nc
# already exists
# bc007a.pr201007.nc
# already exists
# bc007a.pr201008.nc
# already exists
# bc007a.pr201106.nc
# already exists
# bc007a.pr201107.nc
# already exists
# bc007a.pr201108.nc
# already exists
# bc007a.pr201206.nc
# already exists
# bc007a.pr201207.nc
# already exists
# bc007a.pr201208.nc
# already exists
# bc007a.pr201306.nc
# already exists
# bc007a.pr201307.nc
# already exists
# bc007a.pr201308.nc
# already exists
# bc007a.pr201406.nc
# already exists
# bc007a.pr201407.nc
# already exists
# bc007a.pr201408.nc
# already exists
# bc007a.pr201506.nc
# already exists
# bc007a.pr201507.nc
# already exists
# bc007a.pr201508.nc
# already exists
# bc007a.pr201606.nc
# already exists
# bc007a.pr201607.nc
# already exists
# bc007a.pr201608.nc
# already exists
# bc007a.pr201706.nc
# already exists
# bc007a.pr201707.nc
# already exists
# bc007a.pr201708.nc
# already exists
# bc007a.pr201806.nc
# already exists
# bc007a.pr201807.nc
# already exists
# bc007a.pr201808.nc
# already exists
# bc007a.pr201906.nc
# already exists
# bc007a.pr201907.nc
# already exists
# bc007a.pr201908.nc
# already exists
# bc007a.pr202006.nc
# already exists
# bc007a.pr202007.nc
# already exists
# bc007a.pr202008.nc
# already exists
# bc009
# bc009a.pr200006.nc
# already exists
# bc009a.pr200007.nc
# already exists
# bc009a.pr200008.nc
# already exists
# bc009a.pr200106.nc
# already exists
# bc009a.pr200107.nc
# already exists
# bc009a.pr200108.nc
# already exists
# bc009a.pr200206.nc
# already exists
# bc009a.pr200207.nc
# already exists
# bc009a.pr200208.nc
# already exists
# bc009a.pr200306.nc
# already exists
# bc009a.pr200307.nc
# already exists
# bc009a.pr200308.nc
# already exists
# bc009a.pr200406.nc
# already exists
# bc009a.pr200407.nc
# already exists
# bc009a.pr200408.nc
# already exists
# bc009a.pr200506.nc
# already exists
# bc009a.pr200507.nc
# already exists
# bc009a.pr200508.nc
# already exists
# bc009a.pr200606.nc
# already exists
# bc009a.pr200607.nc
# already exists
# bc009a.pr200608.nc
# already exists
# bc009a.pr200706.nc
# already exists
# bc009a.pr200707.nc
# already exists
# bc009a.pr200708.nc
# already exists
# bc009a.pr200806.nc
# already exists
# bc009a.pr200807.nc
# already exists
# bc009a.pr200808.nc
# already exists
# bc009a.pr200906.nc
# already exists
# bc009a.pr200907.nc
# already exists
# bc009a.pr200908.nc
# already exists
# bc009a.pr201006.nc
# already exists
# bc009a.pr201007.nc
# already exists
# bc009a.pr201008.nc
# already exists
# bc009a.pr201106.nc
# already exists
# bc009a.pr201107.nc
# already exists
# bc009a.pr201108.nc
# already exists
# bc009a.pr201206.nc
# already exists
# bc009a.pr201207.nc
# already exists
# bc009a.pr201208.nc
# already exists
# bc009a.pr201306.nc
# already exists
# bc009a.pr201307.nc
# already exists
# bc009a.pr201308.nc
# already exists
# bc009a.pr201406.nc
# already exists
# bc009a.pr201407.nc
# already exists
# bc009a.pr201408.nc
# already exists
# bc009a.pr201506.nc
# already exists
# bc009a.pr201507.nc
# already exists
# bc009a.pr201508.nc
# already exists
# bc009a.pr201606.nc
# already exists
# bc009a.pr201607.nc
# already exists
# bc009a.pr201608.nc
# already exists
# bc009a.pr201706.nc
# already exists
# bc009a.pr201707.nc
# already exists
# bc009a.pr201708.nc
# already exists
# bc009a.pr201806.nc
# already exists
# bc009a.pr201807.nc
# already exists
# bc009a.pr201808.nc
# already exists
# bc009a.pr201906.nc
# already exists
# bc009a.pr201907.nc
# already exists
# bc009a.pr201908.nc
# already exists
# bc009a.pr202006.nc
# already exists
# bc009a.pr202007.nc
# already exists
# bc009a.pr202008.nc
# already exists
# bc010
# bc010a.pr200006.nc
# already exists
# bc010a.pr200007.nc
# already exists
# bc010a.pr200008.nc
# already exists
# bc010a.pr200106.nc
# already exists
# bc010a.pr200107.nc
# already exists
# bc010a.pr200108.nc
# already exists
# bc010a.pr200206.nc
# already exists
# bc010a.pr200207.nc
# already exists
# bc010a.pr200208.nc
# already exists
# bc010a.pr200306.nc
# already exists
# bc010a.pr200307.nc
# already exists
# bc010a.pr200308.nc
# already exists
# bc010a.pr200406.nc
# already exists
# bc010a.pr200407.nc
# already exists
# bc010a.pr200408.nc
# already exists
# bc010a.pr200506.nc
# already exists
# bc010a.pr200507.nc
# already exists
# bc010a.pr200508.nc
# already exists
# bc010a.pr200606.nc
# already exists
# bc010a.pr200607.nc
# already exists
# bc010a.pr200608.nc
# already exists
# bc010a.pr200706.nc
# already exists
# bc010a.pr200707.nc
# already exists
# bc010a.pr200708.nc
# already exists
# bc010a.pr200806.nc
# already exists
# bc010a.pr200807.nc
# already exists
# bc010a.pr200808.nc
# already exists
# bc010a.pr200906.nc
# already exists
# bc010a.pr200907.nc
# already exists
# bc010a.pr200908.nc
# already exists
# bc010a.pr201006.nc
# already exists
# bc010a.pr201007.nc
# already exists
# bc010a.pr201008.nc
# already exists
# bc010a.pr201106.nc
# already exists
# bc010a.pr201107.nc
# already exists
# bc010a.pr201108.nc
# already exists
# bc010a.pr201206.nc
# already exists
# bc010a.pr201207.nc
# already exists
# bc010a.pr201208.nc
# already exists
# bc010a.pr201306.nc
# already exists
# bc010a.pr201307.nc
# already exists
# bc010a.pr201308.nc
# already exists
# bc010a.pr201406.nc
# already exists
# bc010a.pr201407.nc
# already exists
# bc010a.pr201408.nc
# already exists
# bc010a.pr201506.nc
# already exists
# bc010a.pr201507.nc
# already exists
# bc010a.pr201508.nc
# already exists
# bc010a.pr201606.nc
# already exists
# bc010a.pr201607.nc
# already exists
# bc010a.pr201608.nc
# already exists
# bc010a.pr201706.nc
# already exists
# bc010a.pr201707.nc
# already exists
# bc010a.pr201708.nc
# already exists
# bc010a.pr201806.nc
# already exists
# bc010a.pr201807.nc
# already exists
# bc010a.pr201808.nc
# already exists
# bc010a.pr201906.nc
# already exists
# bc010a.pr201907.nc
# already exists
# bc010a.pr201908.nc
# already exists
# bc010a.pr202006.nc
# already exists
# bc010a.pr202007.nc
# already exists
# bc010a.pr202008.nc
# already exists
# bc011
# bc011a.pr200006.nc
# already exists
# bc011a.pr200007.nc
# already exists
# bc011a.pr200008.nc
# already exists
# bc011a.pr200106.nc
# already exists
# bc011a.pr200107.nc
# already exists
# bc011a.pr200108.nc
# already exists
# bc011a.pr200206.nc
# already exists
# bc011a.pr200207.nc
# already exists
# bc011a.pr200208.nc
# already exists
# bc011a.pr200306.nc
# already exists
# bc011a.pr200307.nc
# already exists
# bc011a.pr200308.nc
# already exists
# bc011a.pr200406.nc
# already exists
# bc011a.pr200407.nc
# already exists
# bc011a.pr200408.nc
# already exists
# bc011a.pr200506.nc
# already exists
# bc011a.pr200507.nc
# already exists
# bc011a.pr200508.nc
# already exists
# bc011a.pr200606.nc
# already exists
# bc011a.pr200607.nc
# already exists
# bc011a.pr200608.nc
# already exists
# bc011a.pr200706.nc
# already exists
# bc011a.pr200707.nc
# already exists
# bc011a.pr200708.nc
# already exists
# bc011a.pr200806.nc
# already exists
# bc011a.pr200807.nc
# already exists
# bc011a.pr200808.nc
# already exists
# bc011a.pr200906.nc
# already exists
# bc011a.pr200907.nc
# already exists
# bc011a.pr200908.nc
# already exists
# bc011a.pr201006.nc
# already exists
# bc011a.pr201007.nc
# already exists
# bc011a.pr201008.nc
# already exists
# bc011a.pr201106.nc
# already exists
# bc011a.pr201107.nc
# already exists
# bc011a.pr201108.nc
# already exists
# bc011a.pr201206.nc
# already exists
# bc011a.pr201207.nc
# already exists
# bc011a.pr201208.nc
# already exists
# bc011a.pr201306.nc
# already exists
# bc011a.pr201307.nc
# already exists
# bc011a.pr201308.nc
# already exists
# bc011a.pr201406.nc
# already exists
# bc011a.pr201407.nc
# already exists
# bc011a.pr201408.nc
# already exists
# bc011a.pr201506.nc
# already exists
# bc011a.pr201507.nc
# already exists
# bc011a.pr201508.nc
# already exists
# bc011a.pr201606.nc
# already exists
# bc011a.pr201607.nc
# already exists
# bc011a.pr201608.nc
# already exists
# bc011a.pr201706.nc
# already exists
# bc011a.pr201707.nc
# already exists
# bc011a.pr201708.nc
# already exists
# bc011a.pr201806.nc
# already exists
# bc011a.pr201807.nc
# already exists
# bc011a.pr201808.nc
# already exists
# bc011a.pr201906.nc
# already exists
# bc011a.pr201907.nc
# already exists
# bc011a.pr201908.nc
# already exists
# bc011a.pr202006.nc
# already exists
# bc011a.pr202007.nc
# already exists
# bc011a.pr202008.nc
# already exists
# bc013
# bc013a.pr200006.nc
# already exists
# bc013a.pr200007.nc
# already exists
# bc013a.pr200008.nc
# already exists
# bc013a.pr200106.nc
# already exists
# bc013a.pr200107.nc
# already exists
# bc013a.pr200108.nc
# already exists
# bc013a.pr200206.nc
# already exists
# bc013a.pr200207.nc
# already exists
# bc013a.pr200208.nc
# already exists
# bc013a.pr200306.nc
# already exists
# bc013a.pr200307.nc
# already exists
# bc013a.pr200308.nc
# already exists
# bc013a.pr200406.nc
# already exists
# bc013a.pr200407.nc
# already exists
# bc013a.pr200408.nc
# already exists
# bc013a.pr200506.nc
# already exists
# bc013a.pr200507.nc
# already exists
# bc013a.pr200508.nc
# already exists
# bc013a.pr200606.nc
# already exists
# bc013a.pr200607.nc
# already exists
# bc013a.pr200608.nc
# already exists
# bc013a.pr200706.nc
# already exists
# bc013a.pr200707.nc
# already exists
# bc013a.pr200708.nc
# already exists
# bc013a.pr200806.nc
# already exists
# bc013a.pr200807.nc
# already exists
# bc013a.pr200808.nc
# already exists
# bc013a.pr200906.nc
# already exists
# bc013a.pr200907.nc
# already exists
# bc013a.pr200908.nc
# already exists
# bc013a.pr201006.nc
# already exists
# bc013a.pr201007.nc
# already exists
# bc013a.pr201008.nc
# already exists
# bc013a.pr201106.nc
# creating
# bc013a.pr201107.nc
# creating
# bc013a.pr201108.nc
# creating
# bc013a.pr201206.nc
# creating
# bc013a.pr201207.nc
# creating
# bc013a.pr201208.nc
# creating
# bc013a.pr201306.nc
# creating
# bc013a.pr201307.nc
# creating
# bc013a.pr201308.nc
# creating
# bc013a.pr201406.nc
# creating
# bc013a.pr201407.nc
# creating
# bc013a.pr201408.nc
# creating
# bc013a.pr201506.nc
# creating
# bc013a.pr201507.nc
# creating
# bc013a.pr201508.nc
# creating
# bc013a.pr201606.nc
# creating
# bc013a.pr201607.nc
# creating
# bc013a.pr201608.nc
# creating
# bc013a.pr201706.nc
# creating
# bc013a.pr201707.nc
# creating
# bc013a.pr201708.nc
# creating
# bc013a.pr201806.nc
# creating
# bc013a.pr201807.nc
# creating
# bc013a.pr201808.nc
# creating
# bc013a.pr201906.nc
# creating
# bc013a.pr201907.nc
# creating
# bc013a.pr201908.nc
# creating
# bc013a.pr202006.nc
# creating
# bc013a.pr202007.nc
# creating
# bc013a.pr202008.nc
# creating
# bc015
# bc015a.pr200006.nc
# already exists
# bc015a.pr200007.nc
# already exists
# bc015a.pr200008.nc
# already exists
# bc015a.pr200106.nc
# already exists
# bc015a.pr200107.nc
# already exists
# bc015a.pr200108.nc
# already exists
# bc015a.pr200206.nc
# already exists
# bc015a.pr200207.nc
# already exists
# bc015a.pr200208.nc
# already exists
# bc015a.pr200306.nc
# already exists
# bc015a.pr200307.nc
# already exists
# bc015a.pr200308.nc
# already exists
# bc015a.pr200406.nc
# already exists
# bc015a.pr200407.nc
# already exists
# bc015a.pr200408.nc
# already exists
# bc015a.pr200506.nc
# already exists
# bc015a.pr200507.nc
# already exists
# bc015a.pr200508.nc
# already exists
# bc015a.pr200606.nc
# already exists
# bc015a.pr200607.nc
# already exists
# bc015a.pr200608.nc
# already exists
# bc015a.pr200706.nc
# already exists
# bc015a.pr200707.nc
# already exists
# bc015a.pr200708.nc
# already exists
# bc015a.pr200806.nc
# already exists
# bc015a.pr200807.nc
# already exists
# bc015a.pr200808.nc
# already exists
# bc015a.pr200906.nc
# already exists
# bc015a.pr200907.nc
# already exists
# bc015a.pr200908.nc
# already exists
# bc015a.pr201006.nc
# already exists
# bc015a.pr201007.nc
# already exists
# bc015a.pr201008.nc
# already exists
# bc015a.pr201106.nc
# already exists
# bc015a.pr201107.nc
# already exists
# bc015a.pr201108.nc
# already exists
# bc015a.pr201206.nc
# already exists
# bc015a.pr201207.nc
# already exists
# bc015a.pr201208.nc
# already exists
# bc015a.pr201306.nc
# already exists
# bc015a.pr201307.nc
# already exists
# bc015a.pr201308.nc
# already exists
# bc015a.pr201406.nc
# already exists
# bc015a.pr201407.nc
# already exists
# bc015a.pr201408.nc
# already exists
# bc015a.pr201506.nc
# already exists
# bc015a.pr201507.nc
# already exists
# bc015a.pr201508.nc
# already exists
# bc015a.pr201606.nc
# already exists
# bc015a.pr201607.nc
# already exists
# bc015a.pr201608.nc
# already exists
# bc015a.pr201706.nc
# already exists
# bc015a.pr201707.nc
# already exists
# bc015a.pr201708.nc
# already exists
# bc015a.pr201806.nc
# already exists
# bc015a.pr201807.nc
# already exists
# bc015a.pr201808.nc
# already exists
# bc015a.pr201906.nc
# already exists
# bc015a.pr201907.nc
# already exists
# bc015a.pr201908.nc
# already exists
# bc015a.pr202006.nc
# already exists
# bc015a.pr202007.nc
# already exists
# bc015a.pr202008.nc
# already exists
# bc016
# bc016a.pr200006.nc
# already exists
# bc016a.pr200007.nc
# already exists
# bc016a.pr200008.nc
# already exists
# bc016a.pr200106.nc
# already exists
# bc016a.pr200107.nc
# already exists
# bc016a.pr200108.nc
# already exists
# bc016a.pr200206.nc
# already exists
# bc016a.pr200207.nc
# already exists
# bc016a.pr200208.nc
# already exists
# bc016a.pr200306.nc
# already exists
# bc016a.pr200307.nc
# already exists
# bc016a.pr200308.nc
# already exists
# bc016a.pr200406.nc
# already exists
# bc016a.pr200407.nc
# already exists
# bc016a.pr200408.nc
# already exists
# bc016a.pr200506.nc
# already exists
# bc016a.pr200507.nc
# already exists
# bc016a.pr200508.nc
# already exists
# bc016a.pr200606.nc
# already exists
# bc016a.pr200607.nc
# already exists
# bc016a.pr200608.nc
# already exists
# bc016a.pr200706.nc
# already exists
# bc016a.pr200707.nc
# already exists
# bc016a.pr200708.nc
# already exists
# bc016a.pr200806.nc
# already exists
# bc016a.pr200807.nc
# already exists
# bc016a.pr200808.nc
# already exists
# bc016a.pr200906.nc
# already exists
# bc016a.pr200907.nc
# already exists
# bc016a.pr200908.nc
# already exists
# bc016a.pr201006.nc
# already exists
# bc016a.pr201007.nc
# already exists
# bc016a.pr201008.nc
# already exists
# bc016a.pr201106.nc
# already exists
# bc016a.pr201107.nc
# already exists
# bc016a.pr201108.nc
# already exists
# bc016a.pr201206.nc
# already exists
# bc016a.pr201207.nc
# already exists
# bc016a.pr201208.nc
# already exists
# bc016a.pr201306.nc
# already exists
# bc016a.pr201307.nc
# already exists
# bc016a.pr201308.nc
# already exists
# bc016a.pr201406.nc
# already exists
# bc016a.pr201407.nc
# already exists
# bc016a.pr201408.nc
# already exists
# bc016a.pr201506.nc
# already exists
# bc016a.pr201507.nc
# already exists
# bc016a.pr201508.nc
# already exists
# bc016a.pr201606.nc
# already exists
# bc016a.pr201607.nc
# already exists
# bc016a.pr201608.nc
# already exists
# bc016a.pr201706.nc
# already exists
# bc016a.pr201707.nc
# already exists
# bc016a.pr201708.nc
# already exists
# bc016a.pr201806.nc
# already exists
# bc016a.pr201807.nc
# already exists
# bc016a.pr201808.nc
# already exists
# bc016a.pr201906.nc
# already exists
# bc016a.pr201907.nc
# already exists
# bc016a.pr201908.nc
# already exists
# bc016a.pr202006.nc
# already exists
# bc016a.pr202007.nc
# already exists
# bc016a.pr202008.nc
# already exists
# bc017
# bc017a.pr200006.nc
# already exists
# bc017a.pr200007.nc
# already exists
# bc017a.pr200008.nc
# already exists
# bc017a.pr200106.nc
# already exists
# bc017a.pr200107.nc
# already exists
# bc017a.pr200108.nc
# already exists
# bc017a.pr200206.nc
# already exists
# bc017a.pr200207.nc
# already exists
# bc017a.pr200208.nc
# already exists
# bc017a.pr200306.nc
# already exists
# bc017a.pr200307.nc
# already exists
# bc017a.pr200308.nc
# already exists
# bc017a.pr200406.nc
# already exists
# bc017a.pr200407.nc
# already exists
# bc017a.pr200408.nc
# already exists
# bc017a.pr200506.nc
# already exists
# bc017a.pr200507.nc
# already exists
# bc017a.pr200508.nc
# already exists
# bc017a.pr200606.nc
# already exists
# bc017a.pr200607.nc
# already exists
# bc017a.pr200608.nc
# already exists
# bc017a.pr200706.nc
# already exists
# bc017a.pr200707.nc
# already exists
# bc017a.pr200708.nc
# already exists
# bc017a.pr200806.nc
# already exists
# bc017a.pr200807.nc
# already exists
# bc017a.pr200808.nc
# already exists
# bc017a.pr200906.nc
# already exists
# bc017a.pr200907.nc
# already exists
# bc017a.pr200908.nc
# already exists
# bc017a.pr201006.nc
# already exists
# bc017a.pr201007.nc
# already exists
# bc017a.pr201008.nc
# already exists
# bc017a.pr201106.nc
# already exists
# bc017a.pr201107.nc
# already exists
# bc017a.pr201108.nc
# already exists
# bc017a.pr201206.nc
# already exists
# bc017a.pr201207.nc
# already exists
# bc017a.pr201208.nc
# already exists
# bc017a.pr201306.nc
# already exists
# bc017a.pr201307.nc
# already exists
# bc017a.pr201308.nc
# already exists
# bc017a.pr201406.nc
# already exists
# bc017a.pr201407.nc
# already exists
# bc017a.pr201408.nc
# already exists
# bc017a.pr201506.nc
# already exists
# bc017a.pr201507.nc
# already exists
# bc017a.pr201508.nc
# already exists
# bc017a.pr201606.nc
# already exists
# bc017a.pr201607.nc
# already exists
# bc017a.pr201608.nc
# already exists
# bc017a.pr201706.nc
# already exists
# bc017a.pr201707.nc
# already exists
# bc017a.pr201708.nc
# already exists
# bc017a.pr201806.nc
# already exists
# bc017a.pr201807.nc
# already exists
# bc017a.pr201808.nc
# already exists
# bc017a.pr201906.nc
# already exists
# bc017a.pr201907.nc
# already exists
# bc017a.pr201908.nc
# already exists
# bc017a.pr202006.nc
# already exists
# bc017a.pr202007.nc
# already exists
# bc017a.pr202008.nc
# already exists
# bc018
# bc018a.pr200006.nc
# already exists
# bc018a.pr200007.nc
# already exists
# bc018a.pr200008.nc
# already exists
# bc018a.pr200106.nc
# already exists
# bc018a.pr200107.nc
# already exists
# bc018a.pr200108.nc
# already exists
# bc018a.pr200206.nc
# already exists
# bc018a.pr200207.nc
# already exists
# bc018a.pr200208.nc
# already exists
# bc018a.pr200306.nc
# already exists
# bc018a.pr200307.nc
# already exists
# bc018a.pr200308.nc
# already exists
# bc018a.pr200406.nc
# already exists
# bc018a.pr200407.nc
# already exists
# bc018a.pr200408.nc
# already exists
# bc018a.pr200506.nc
# already exists
# bc018a.pr200507.nc
# already exists
# bc018a.pr200508.nc
# already exists
# bc018a.pr200606.nc
# already exists
# bc018a.pr200607.nc
# already exists
# bc018a.pr200608.nc
# already exists
# bc018a.pr200706.nc
# already exists
# bc018a.pr200707.nc
# already exists
# bc018a.pr200708.nc
# already exists
# bc018a.pr200806.nc
# already exists
# bc018a.pr200807.nc
# already exists
# bc018a.pr200808.nc
# already exists
# bc018a.pr200906.nc
# already exists
# bc018a.pr200907.nc
# already exists
# bc018a.pr200908.nc
# already exists
# bc018a.pr201006.nc
# already exists
# bc018a.pr201007.nc
# already exists
# bc018a.pr201008.nc
# already exists
# bc018a.pr201106.nc
# already exists
# bc018a.pr201107.nc
# already exists
# bc018a.pr201108.nc
# already exists
# bc018a.pr201206.nc
# already exists
# bc018a.pr201207.nc
# already exists
# bc018a.pr201208.nc
# already exists
# bc018a.pr201306.nc
# already exists
# bc018a.pr201307.nc
# already exists
# bc018a.pr201308.nc
# already exists
# bc018a.pr201406.nc
# already exists
# bc018a.pr201407.nc
# already exists
# bc018a.pr201408.nc
# already exists
# bc018a.pr201506.nc
# already exists
# bc018a.pr201507.nc
# already exists
# bc018a.pr201508.nc
# already exists
# bc018a.pr201606.nc
# already exists
# bc018a.pr201607.nc
# already exists
# bc018a.pr201608.nc
# already exists
# bc018a.pr201706.nc
# already exists
# bc018a.pr201707.nc
# already exists
# bc018a.pr201708.nc
# already exists
# bc018a.pr201806.nc
# already exists
# bc018a.pr201807.nc
# already exists
# bc018a.pr201808.nc
# already exists
# bc018a.pr201906.nc
# already exists
# bc018a.pr201907.nc
# already exists
# bc018a.pr201908.nc
# already exists
# bc018a.pr202006.nc
# already exists
# bc018a.pr202007.nc
# already exists
# bc018a.pr202008.nc
# already exists
# bc012
# bc012a.pr200006.nc
# already exists
# bc012a.pr200007.nc
# already exists
# bc012a.pr200008.nc
# already exists
# bc012a.pr200106.nc
# already exists
# bc012a.pr200107.nc
# already exists
# bc012a.pr200108.nc
# already exists
# bc012a.pr200206.nc
# already exists
# bc012a.pr200207.nc
# already exists
# bc012a.pr200208.nc
# already exists
# bc012a.pr200306.nc
# already exists
# bc012a.pr200307.nc
# already exists
# bc012a.pr200308.nc
# already exists
# bc012a.pr200406.nc
# already exists
# bc012a.pr200407.nc
# already exists
# bc012a.pr200408.nc
# already exists
# bc012a.pr200506.nc
# already exists
# bc012a.pr200507.nc
# already exists
# bc012a.pr200508.nc
# already exists
# bc012a.pr200606.nc
# already exists
# bc012a.pr200607.nc
# already exists
# bc012a.pr200608.nc
# already exists
# bc012a.pr200706.nc
# already exists
# bc012a.pr200707.nc
# already exists
# bc012a.pr200708.nc
# already exists
# bc012a.pr200806.nc
# already exists
# bc012a.pr200807.nc
# already exists
# bc012a.pr200808.nc
# already exists
# bc012a.pr200906.nc
# already exists
# bc012a.pr200907.nc
# already exists
# bc012a.pr200908.nc
# already exists
# bc012a.pr201006.nc
# already exists
# bc012a.pr201007.nc
# already exists
# bc012a.pr201008.nc
# already exists
# bc012a.pr201106.nc
# already exists
# bc012a.pr201107.nc
# already exists
# bc012a.pr201108.nc
# already exists
# bc012a.pr201206.nc
# already exists
# bc012a.pr201207.nc
# already exists
# bc012a.pr201208.nc
# already exists
# bc012a.pr201306.nc
# already exists
# bc012a.pr201307.nc
# already exists
# bc012a.pr201308.nc
# already exists
# bc012a.pr201406.nc
# already exists
# bc012a.pr201407.nc
# already exists
# bc012a.pr201408.nc
# already exists
# bc012a.pr201506.nc
# already exists
# bc012a.pr201507.nc
# already exists
# bc012a.pr201508.nc
# already exists
# bc012a.pr201606.nc
# already exists
# bc012a.pr201607.nc
# already exists
# bc012a.pr201608.nc
# already exists
# bc012a.pr201706.nc
# already exists
# bc012a.pr201707.nc
# already exists
# bc012a.pr201708.nc
# already exists
# bc012a.pr201806.nc
# already exists
# bc012a.pr201807.nc
# already exists
# bc012a.pr201808.nc
# already exists
# bc012a.pr201906.nc
# already exists
# bc012a.pr201907.nc
# already exists
# bc012a.pr201908.nc
# already exists
# bc012a.pr202006.nc
# already exists
# bc012a.pr202007.nc
# already exists
# bc012a.pr202008.nc
# already exists

# %% [markdown]
# ## Regrid NIMROD - DONE

# %%
for year in range(2012,2013):
    print(year)
    # Change directory to be for correct year
    os.chdir(f"/nfs/a319/gy17m2a/PhD/datadir/NIMROD/30mins/OriginalFormat_1km/{year}")
    # Define filepaths to save files to
    output_dir_12km = f"/nfs/a319/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_12km/NearestNeighbour/{year}/"
    output_dir_2_2km = f"/nfs/a319/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/NearestNeighbour/{year}/"
    # Create these directories if they don't exist already
    if not os.path.isdir(output_dir_12km):
        os.makedirs(output_dir_12km)
    if not os.path.isdir(output_dir_2_2km):
        os.makedirs(output_dir_2_2km)
    # Loop through all the diles in the 1km folder    
    for filename in sorted(glob.glob("*")):
        if filename != 'metoffice-c-band-rain-radar_uk_20090728_30mins.nc':
            print(filename)
            # Create version of filename specifying it is regridded
            filename_to_save_to = f"rg_{filename}"

            # Check if this regridded file exists, and if not create it
            # Don't want to load the cube twice unnecessarily, so if we load it for 12km, then make a flag to tell us it's
            # already loaded and then use this for 2.2km

            # 12km regridding
            if os.path.isfile(output_dir_12km + filename_to_save_to):
                print("File already exists")
            if not os.path.isfile(output_dir_12km + filename_to_save_to):
                print('Making file 12km')
                cube = iris.load(filename)[0]
                loaded_cube=True
                # Nearest neighbour
                reg_cube_nn =cube.regrid(cube_12km,iris.analysis.Nearest())    
                # Save 
                iris.save(reg_cube_nn, output_dir_12km + filename_to_save_to)

            # 2.2km regridding
            if os.path.isfile(output_dir_2_2km + filename_to_save_to):
                print("File already exists")
            if not os.path.isfile(output_dir_2_2km + filename_to_save_to):
                print('Making 2.2km file')
                if loaded_cube == False:
                    cube = iris.load(filename)[0]
                # Nearest neighbour
                reg_cube_nn =cube.regrid(cube_model_2_2km,iris.analysis.Nearest())    
                print("Regridded")
                # Save 
                iris.save(reg_cube_nn, output_dir_2_2km + filename_to_save_to)    

            loaded_cube=False
# Out:
# 2012
# metoffice-c-band-rain-radar_uk_20120601_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120602_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120603_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120604_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120605_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120606_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120607_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120608_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120609_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120610_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120611_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120612_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120613_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120614_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120615_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120616_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120617_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120618_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120619_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120620_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120621_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120622_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120623_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120624_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120625_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120626_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120627_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120628_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120629_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120630_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120701_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120702_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120703_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120704_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120705_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120706_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120707_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120708_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120709_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120710_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120711_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120712_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120713_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120714_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120715_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120716_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120717_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120718_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120719_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120720_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120721_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120722_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120723_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120724_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120725_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120726_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120727_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120728_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120729_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120730_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120731_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120801_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120802_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120803_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120804_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120805_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120806_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120807_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120808_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120809_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120810_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120811_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120812_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120813_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120814_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120815_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120816_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120817_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120818_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120819_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120820_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120821_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120822_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120823_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120824_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120825_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120826_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120827_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120828_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120829_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120830_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded
# metoffice-c-band-rain-radar_uk_20120831_30mins.nc
# Making file 12km
# Making 2.2km file
# Regridded

# %% [markdown]
# ## Regrid CEH-GEAR

# %%
# os.chdir("/nfs/a319/gy17m2a/PhD/datadir/CEH-GEAR/OriginalFormat/")
# filenames =[ ]
# for filename in glob.glob("*"):
#     filenames.append(filename)
# len(filenames)

# %%
os.chdir("/nfs/a319/gy17m2a/PhD/datadir/CEH-GEAR/OriginalFormat/")
for filename in glob.glob("*")
    print(filename)
    cube = iris.load(filename)[0]
    
    # Filename to save reformatted cube to
    filename_to_save_to_reformat = f"/nfs/a319/gy17m2a/PhD/datadir/CEH-GEAR/CEH-GEAR_reformatted/rf_{filename}"
    # Filename to save 2.2km regridded cube to -- linear
    filename_to_save_to_lin_2_2km = f"/nfs/a319/gy17m2a/PhD/datadir/CEH-GEAR/CEH-GEAR_regridded_2.2km/LinearRegridding/rg_{filename}"
    # Filename to save 2.2km regridded cube to -- nearest neighbour
    filename_to_save_to_nn_2_2km = f"/nfs/a319/gy17m2a/PhD/datadir/CEH-GEAR/CEH-GEAR_regridded_2.2km/NearestNeighbour/rg_{filename}"
      # Filename to save 12km regridded cube to -- nearest neihgoubt
    #filename_to_save_to_lin_12km = f"/nfs/a319/gy17m2a/datadir/CEH-GEAR/CEH-GEAR_regridded_12km/LinearRegrdding/rg_{filename}"
    filename_to_save_to_nn_12km = f"/nfs/a319/gy17m2a/PhD/datadir/CEH-GEAR/CEH-GEAR_regridded_12km/NearestNeighbour/rg_{filename}"
    
    ###### Open dataset with Xarry and reformat
    xr_ds=xr.open_dataset(filename)
    # Convert to cube in the correct format and save
    cube=make_bng_cube(xr_ds,'rainfall_amount')
    iris.save(cube, filename_to_save_to_reformat)
    
    #### Regrid observations onto 2.2km model grid
    # Lienar interpolation
    reg_cube_lin_2_2km =cube.regrid(cube_model_2_2km,iris.analysis.Linear())      
    # nearest neighbour
    reg_cube_nn_2_2km =cube.regrid(cube_model_2_2km,iris.analysis.Nearest()) 
    # Save 
    iris.save(reg_cube_lin_2_2km, filename_to_save_to_lin_2_2km)
    iris.save(reg_cube_nn_2_2km, filename_to_save_to_nn_2_2km)
    
    #### Regrid observations onto 12km model grid
    # Linear interpolation
    #reg_cube_lin_12km =cube.regrid(cube_12km,iris.analysis.Linear())      
    # nearest neighbour
    reg_cube_nn_12km =cube.regrid(cube_12km,iris.analysis.Nearest()) 
    # Save 
    #iris.save(reg_cube_lin_12km, filename_to_save_to_lin_12km)
    iris.save(reg_cube_nn_12km, filename_to_save_to_nn_12km)
