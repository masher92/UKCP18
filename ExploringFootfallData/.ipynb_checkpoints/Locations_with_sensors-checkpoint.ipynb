# %%
import folium
import pandas as pd
import os
import requests
import json
os.chdir("C:/Users/gy17m2a/OneDrive - University of Leeds/Project/Footfall")

def export_to_csv(base_url):
    print("Exporting report results to JSON file...")

    csv_file = open('report_results.csv', "w", encoding="utf8")
    csv_file.write("Id, Employee_Name"+"\n") #manually modify this CSV file header
    csv_file.close()

    #there are 3 attributes in my example; add/remove levels according to the number of attributes in your case
    r = get_report(base_url)
    report_parsed = json.loads(r)
    print(report_parsed)
    a1_list = report_parsed['data']
    print(a1_list)
    for a1 in a1_list:
        a1_id = a1['id']
        a2_employee_name=a1['employee_name']
        csv_file = open('report_results.csv', "a", encoding="utf8")
        csv_file.write("'"+a1_id + "','" + a2_employee_name +"\n")
        csv_file.close()
  
def get_report(base_url):
    print("Getting report results...")
    header_gs = {'Accept': 'application/json'}
    r = requests.get(base_url)
    if r.ok:
        print("Report results received...")
        print("HTTP %i - %s" % (r.status_code, r.reason))
        return r.text
    else:
        print("HTTP %i - %s" % (r.status_code, r.reason))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2153/3543830484.py in <module>
#       4 import requests
#       5 import json
# ----> 6 os.chdir("C:/Users/gy17m2a/OneDrive - University of Leeds/Project/Footfall")
#       7
#       8 def export_to_csv(base_url):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/gy17m2a/OneDrive - University of Leeds/Project/Footfall'

# %% [markdown]
# ## Leeds - 10 sensors with locations

# %%
# Locations defined manually using https://open-innovations.github.io/traffic-growth/ and google maps
leeds_sensors = pd.DataFrame({"Latitude":[53.7975, 53.7973, 53.797291, 53.797, 53.7967, 53.798042, 53.7990, 53.7993, 53.7994,
                                         53.801],
                              "Longitude":[-1.5451, -1.5451, -1.54430, -1.5436, -1.5426, -1.547109, -1.54189, -1.5441,
                                        -1.5440, -1.5448], 
                              "Name":["Albion Street North", "Albion Street South", "Commercial Street at Sharps",
                                      "Commercial Street at Barratts","Briggate", "Park row", "Briggate at McDonalds",
                                      "Headrow", "Headrow at Dortmund Square", "Albion Street at Mcdonalds"]})

# %%
leeds_map = folium.Map(location=[leeds_sensors.Latitude.mean(),
                           leeds_sensors.Longitude.mean()], zoom_start=16, control_scale=True, min_zoom = 16)
for index, location_info in leeds_sensors.iterrows():
    folium.Marker([location_info["Latitude"], location_info["Longitude"]], popup=location_info["Name"]).add_to(leeds_map)
leeds_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9d73ad51103e07aae46d584cc408e45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9d73ad51103e07aae46d584cc408e45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c9d73ad51103e07aae46d584cc408e45 = L.map(
#                 &quot;map_c9d73ad51103e07aae46d584cc408e45&quot;,
#                 {
#                     center: [53.7982533, -1.5442599000000004],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c9d73ad51103e07aae46d584cc408e45);
#
#
#
#
#
#             var tile_layer_5762f672e30a255dd485063210233522 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 16, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c9d73ad51103e07aae46d584cc408e45);
#
#
#             var marker_b897ada9e26258de35f93fcecefbf551 = L.marker(
#                 [53.7975, -1.5451],
#                 {}
#             ).addTo(map_c9d73ad51103e07aae46d584cc408e45);
#
#
#         var popup_35377e79fc3f843048ddd3e437ec8110 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_388a74bae03f21d5a866e5b5aea3f6b0 = $(`&lt;div id=&quot;html_388a74bae03f21d5a866e5b5aea3f6b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Albion Street North&lt;/div&gt;`)[0];
#             popup_35377e79fc3f843048ddd3e437ec8110.setContent(html_388a74bae03f21d5a866e5b5aea3f6b0);
#
#
#         marker_b897ada9e26258de35f93fcecefbf551.bindPopup(popup_35377e79fc3f843048ddd3e437ec8110)
#         ;
#
#
#
#
#             var marker_1d8ab3ef7ed1321cbf6ee0d09342351b = L.marker(
#                 [53.7973, -1.5451],
#                 {}
#             ).addTo(map_c9d73ad51103e07aae46d584cc408e45);
#
#
#         var popup_ba7004d592bafecc8834505d73e42954 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b72356fc4e0eb77e6d3c1e81ad8b3162 = $(`&lt;div id=&quot;html_b72356fc4e0eb77e6d3c1e81ad8b3162&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Albion Street South&lt;/div&gt;`)[0];
#             popup_ba7004d592bafecc8834505d73e42954.setContent(html_b72356fc4e0eb77e6d3c1e81ad8b3162);
#
#
#         marker_1d8ab3ef7ed1321cbf6ee0d09342351b.bindPopup(popup_ba7004d592bafecc8834505d73e42954)
#         ;
#
#
#
#
#             var marker_d8453d62ac515278b904fba23b8df7fb = L.marker(
#                 [53.797291, -1.5443],
#                 {}
#             ).addTo(map_c9d73ad51103e07aae46d584cc408e45);
#
#
#         var popup_f2042663fb85dda060574d283d5805d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0b7dc0a8bd4fd013efae89fe1439b9d1 = $(`&lt;div id=&quot;html_0b7dc0a8bd4fd013efae89fe1439b9d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Commercial Street at Sharps&lt;/div&gt;`)[0];
#             popup_f2042663fb85dda060574d283d5805d6.setContent(html_0b7dc0a8bd4fd013efae89fe1439b9d1);
#
#
#         marker_d8453d62ac515278b904fba23b8df7fb.bindPopup(popup_f2042663fb85dda060574d283d5805d6)
#         ;
#
#
#
#
#             var marker_a5236bd5f69f9d75e1d6eeaa9c293938 = L.marker(
#                 [53.797, -1.5436],
#                 {}
#             ).addTo(map_c9d73ad51103e07aae46d584cc408e45);
#
#
#         var popup_f21960d49bc19b8630cfcd644f4f48d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_931e19967e0f9f765ab5efcaa9bfe87d = $(`&lt;div id=&quot;html_931e19967e0f9f765ab5efcaa9bfe87d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Commercial Street at Barratts&lt;/div&gt;`)[0];
#             popup_f21960d49bc19b8630cfcd644f4f48d0.setContent(html_931e19967e0f9f765ab5efcaa9bfe87d);
#
#
#         marker_a5236bd5f69f9d75e1d6eeaa9c293938.bindPopup(popup_f21960d49bc19b8630cfcd644f4f48d0)
#         ;
#
#
#
#
#             var marker_2908c5fcbe2f32ee991bf9500bb0d4d9 = L.marker(
#                 [53.7967, -1.5426],
#                 {}
#             ).addTo(map_c9d73ad51103e07aae46d584cc408e45);
#
#
#         var popup_eae57822532823a1fe61d16e15e7ae55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bc44f7164c953ae667585efe1bd2941c = $(`&lt;div id=&quot;html_bc44f7164c953ae667585efe1bd2941c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Briggate&lt;/div&gt;`)[0];
#             popup_eae57822532823a1fe61d16e15e7ae55.setContent(html_bc44f7164c953ae667585efe1bd2941c);
#
#
#         marker_2908c5fcbe2f32ee991bf9500bb0d4d9.bindPopup(popup_eae57822532823a1fe61d16e15e7ae55)
#         ;
#
#
#
#
#             var marker_d04d928b7fef7cbb38d6fb1f6143baec = L.marker(
#                 [53.798042, -1.547109],
#                 {}
#             ).addTo(map_c9d73ad51103e07aae46d584cc408e45);
#
#
#         var popup_01166dd21d962330a11e7715b312619d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             v

# %% [markdown]
# ## Bologna - 10 sensors with locations

# %%
# Locations defined manually using names from csv and google maps
bologna_sensors = pd.DataFrame({"Latitude" : [ 44.498459,44.497270, 44.496760, 44.49711, 44.4966, 44.49709, 44.496354, 44.49562,
                                     44.495472, 44.494406],
                                       "Longitude":[11.356230, 11.353520, 11.354510, 11.352338, 11.3524, 11.3507, 
                                                    11.3507, 11.35503, 11.3491, 11.3467], 
                                       "Name":["Porta San Donato", "Piazza Puntoni", "Via San Giacomo", "Piazza Scaravelli",
                                              "Palazzo Poggi", "Via del Guasto", "Piazza Verdi", "Facolta di Giurisprudenza",
                                              "Piazza Rossini", "Due torri"]})

# %%
bologna_map = folium.Map(location=[bologna_sensors.Latitude.mean(),
                           bologna_sensors.Longitude.mean()], zoom_start=17, control_scale=True, min_zoom = 16)
for index, location_info in bologna_sensors.iterrows():
    folium.Marker([location_info["Latitude"], location_info["Longitude"]], popup=location_info["Name"]).add_to(bologna_map)
bologna_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5253519ad3c53d6df688e1692f32df3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5253519ad3c53d6df688e1692f32df3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d5253519ad3c53d6df688e1692f32df3 = L.map(
#                 &quot;map_d5253519ad3c53d6df688e1692f32df3&quot;,
#                 {
#                     center: [44.4965141, 11.3521228],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d5253519ad3c53d6df688e1692f32df3);
#
#
#
#
#
#             var tile_layer_9e8797df80fb20df2c2c1e89a40feaaa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 16, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d5253519ad3c53d6df688e1692f32df3);
#
#
#             var marker_3d89563d22772c1ead845ea746796c44 = L.marker(
#                 [44.498459, 11.35623],
#                 {}
#             ).addTo(map_d5253519ad3c53d6df688e1692f32df3);
#
#
#         var popup_5734a305698475f0d11abfec76fbc9ca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8a256bb9f408ca0ad19b40464f6da05e = $(`&lt;div id=&quot;html_8a256bb9f408ca0ad19b40464f6da05e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Porta San Donato&lt;/div&gt;`)[0];
#             popup_5734a305698475f0d11abfec76fbc9ca.setContent(html_8a256bb9f408ca0ad19b40464f6da05e);
#
#
#         marker_3d89563d22772c1ead845ea746796c44.bindPopup(popup_5734a305698475f0d11abfec76fbc9ca)
#         ;
#
#
#
#
#             var marker_ab4f93ede3c178a3b25794be9e0e8838 = L.marker(
#                 [44.49727, 11.35352],
#                 {}
#             ).addTo(map_d5253519ad3c53d6df688e1692f32df3);
#
#
#         var popup_d23c905f49e0554a9b05113091e5b5ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_62c15f2225b208d4d277b616b100d69a = $(`&lt;div id=&quot;html_62c15f2225b208d4d277b616b100d69a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Piazza Puntoni&lt;/div&gt;`)[0];
#             popup_d23c905f49e0554a9b05113091e5b5ba.setContent(html_62c15f2225b208d4d277b616b100d69a);
#
#
#         marker_ab4f93ede3c178a3b25794be9e0e8838.bindPopup(popup_d23c905f49e0554a9b05113091e5b5ba)
#         ;
#
#
#
#
#             var marker_70843167a800bba19a07459584dfe921 = L.marker(
#                 [44.49676, 11.35451],
#                 {}
#             ).addTo(map_d5253519ad3c53d6df688e1692f32df3);
#
#
#         var popup_86d2ec7134ae28924b7e3f0d3d7fb3ce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0844cf7ef67fa0ba57979dbc9cfda54a = $(`&lt;div id=&quot;html_0844cf7ef67fa0ba57979dbc9cfda54a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Via San Giacomo&lt;/div&gt;`)[0];
#             popup_86d2ec7134ae28924b7e3f0d3d7fb3ce.setContent(html_0844cf7ef67fa0ba57979dbc9cfda54a);
#
#
#         marker_70843167a800bba19a07459584dfe921.bindPopup(popup_86d2ec7134ae28924b7e3f0d3d7fb3ce)
#         ;
#
#
#
#
#             var marker_e0388da34e7a97ac8d1d1dfa18b9f006 = L.marker(
#                 [44.49711, 11.352338],
#                 {}
#             ).addTo(map_d5253519ad3c53d6df688e1692f32df3);
#
#
#         var popup_ef60574bce349e8707017c79180189fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e01097550f56d9802134a6793ed7b910 = $(`&lt;div id=&quot;html_e01097550f56d9802134a6793ed7b910&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Piazza Scaravelli&lt;/div&gt;`)[0];
#             popup_ef60574bce349e8707017c79180189fa.setContent(html_e01097550f56d9802134a6793ed7b910);
#
#
#         marker_e0388da34e7a97ac8d1d1dfa18b9f006.bindPopup(popup_ef60574bce349e8707017c79180189fa)
#         ;
#
#
#
#
#             var marker_24bb3037b52e7cf22f3dfe55173d23d9 = L.marker(
#                 [44.4966, 11.3524],
#                 {}
#             ).addTo(map_d5253519ad3c53d6df688e1692f32df3);
#
#
#         var popup_b9dfd05d4f2aa68c106c1fabc365f361 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6eef4bc407d00fe480baf8f832d0ed2b = $(`&lt;div id=&quot;html_6eef4bc407d00fe480baf8f832d0ed2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Palazzo Poggi&lt;/div&gt;`)[0];
#             popup_b9dfd05d4f2aa68c106c1fabc365f361.setContent(html_6eef4bc407d00fe480baf8f832d0ed2b);
#
#
#         marker_24bb3037b52e7cf22f3dfe55173d23d9.bindPopup(popup_b9dfd05d4f2aa68c106c1fabc365f361)
#         ;
#
#
#
#
#             var marker_b661ac8791295c4f880685c4f82ad113 = L.marker(
#                 [44.49709, 11.3507],
#                 {}
#             ).addTo(map_d5253519ad3c53d6df688e1692f32df3);
#
#
#         var popup_2b3c5ae5989f908e01c162579c4fc85d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ddf378dd99e5bf9f3a04b4

# %% [markdown]
# ## Turin - 8 sensors with locations

# %%
# Locations defined manually using names from csv and google maps
torino_sensors = pd.DataFrame({"Latitude":[45.07520, 45.0651, 45.04931, 45.07105, 45.06899, 45.072951, 45.07247,
                                          45.0692],
                                       "Longitude":[7.68022, 7.6692, 7.68529, 7.68598, 7.68608, 7.6863, 7.68952,
                                                   7.6856], 
                                       "Name":["Museo di Arte Orientale", "Gam Galleria Arte Moderna", 
                                 "Borgo Medievale Parco Del Valentino", "Palazzo Madama", "Museo Del Risorgimento",
                                "Palazzo Reale", "Giardini Reali di Torino", "Palazzo Carignano - Cortile"]})
# Also Office test 1 and 2. Not sure of location

# %%
torino_map = folium.Map(location=[torino_sensors.Latitude.mean(),
                           torino_sensors.Longitude.mean()], zoom_start=14, control_scale=True, min_zoom = 13)
for index, location_info in torino_sensors.iterrows():
    folium.Marker([location_info["Latitude"], location_info["Longitude"]], popup=location_info["Name"]).add_to(torino_map)
torino_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a69ec84dd7b2d822bff66a3e3b484d23 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a69ec84dd7b2d822bff66a3e3b484d23&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a69ec84dd7b2d822bff66a3e3b484d23 = L.map(
#                 &quot;map_a69ec84dd7b2d822bff66a3e3b484d23&quot;,
#                 {
#                     center: [45.068033875, 7.683523749999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_a69ec84dd7b2d822bff66a3e3b484d23);
#
#
#
#
#
#             var tile_layer_945ac940f5f1e0316efc60e859f72dfc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 13, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a69ec84dd7b2d822bff66a3e3b484d23);
#
#
#             var marker_1b6d868c33af8202eddf38223b2a7a55 = L.marker(
#                 [45.0752, 7.68022],
#                 {}
#             ).addTo(map_a69ec84dd7b2d822bff66a3e3b484d23);
#
#
#         var popup_f3434922b11cf9f80f4d89c2931e2327 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d756a90a44fbd394ba906f49bab69a32 = $(`&lt;div id=&quot;html_d756a90a44fbd394ba906f49bab69a32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Museo di Arte Orientale&lt;/div&gt;`)[0];
#             popup_f3434922b11cf9f80f4d89c2931e2327.setContent(html_d756a90a44fbd394ba906f49bab69a32);
#
#
#         marker_1b6d868c33af8202eddf38223b2a7a55.bindPopup(popup_f3434922b11cf9f80f4d89c2931e2327)
#         ;
#
#
#
#
#             var marker_2162564131af5c3afebe5b5c69dbb0ec = L.marker(
#                 [45.0651, 7.6692],
#                 {}
#             ).addTo(map_a69ec84dd7b2d822bff66a3e3b484d23);
#
#
#         var popup_fd0be88c702c8b8210ba786543cab71a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_11350d339de436e03c5b4458f1120058 = $(`&lt;div id=&quot;html_11350d339de436e03c5b4458f1120058&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gam Galleria Arte Moderna&lt;/div&gt;`)[0];
#             popup_fd0be88c702c8b8210ba786543cab71a.setContent(html_11350d339de436e03c5b4458f1120058);
#
#
#         marker_2162564131af5c3afebe5b5c69dbb0ec.bindPopup(popup_fd0be88c702c8b8210ba786543cab71a)
#         ;
#
#
#
#
#             var marker_6a352eec3cf2495e140f451c978eecb5 = L.marker(
#                 [45.04931, 7.68529],
#                 {}
#             ).addTo(map_a69ec84dd7b2d822bff66a3e3b484d23);
#
#
#         var popup_df16304f8c0a51f0dbed889f0ef487a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_26ccf6aac99887d29db19aef1a52205a = $(`&lt;div id=&quot;html_26ccf6aac99887d29db19aef1a52205a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Borgo Medievale Parco Del Valentino&lt;/div&gt;`)[0];
#             popup_df16304f8c0a51f0dbed889f0ef487a0.setContent(html_26ccf6aac99887d29db19aef1a52205a);
#
#
#         marker_6a352eec3cf2495e140f451c978eecb5.bindPopup(popup_df16304f8c0a51f0dbed889f0ef487a0)
#         ;
#
#
#
#
#             var marker_c250368d29ee720e7317ae67f8886b4e = L.marker(
#                 [45.07105, 7.68598],
#                 {}
#             ).addTo(map_a69ec84dd7b2d822bff66a3e3b484d23);
#
#
#         var popup_55e0df25a9c213986ea20bb746bf54fe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fd3f5c4e95057e095cc542b469dd6978 = $(`&lt;div id=&quot;html_fd3f5c4e95057e095cc542b469dd6978&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Palazzo Madama&lt;/div&gt;`)[0];
#             popup_55e0df25a9c213986ea20bb746bf54fe.setContent(html_fd3f5c4e95057e095cc542b469dd6978);
#
#
#         marker_c250368d29ee720e7317ae67f8886b4e.bindPopup(popup_55e0df25a9c213986ea20bb746bf54fe)
#         ;
#
#
#
#
#             var marker_f6914463fd42bed79acd1946a035682e = L.marker(
#                 [45.06899, 7.68608],
#                 {}
#             ).addTo(map_a69ec84dd7b2d822bff66a3e3b484d23);
#
#
#         var popup_770de537a38335fea66f20d1229219bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c9731e880224a1a4e34d7f8ec03ff069 = $(`&lt;div id=&quot;html_c9731e880224a1a4e34d7f8ec03ff069&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Museo Del Risorgimento&lt;/div&gt;`)[0];
#             popup_770de537a38335fea66f20d1229219bc.setContent(html_c9731e880224a1a4e34d7f8ec03ff069);
#
#
#         marker_f6914463fd42bed79acd1946a035682e.bindPopup(popup_770de537a38335fea66f20d1229219bc)
#         ;
#
#
#
#
#             var marker_2a51a2254102c3f4d715c567c57732cb = L.marker(
#                 [45.072951, 7.6863],
#                 {}
#             ).addTo(map_a69ec84dd7b2d822bff66a3e3b484d23);
#
#
#         var popup_3e8903f9e3fa9026a03e912ab82485c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});

# %% [markdown]
# ## Cluj-Napoca, Romania - 6 sensors with locations

# %%
# Locations defined manually using names from csv and google maps
cluj_sensors = pd.DataFrame({"Latitude":[46.7688, 46.7686, 46.7670, 46.766246, 46.7725, 46.7695],
                                       "Longitude":[23.574, 23.5724, 23.569600, 23.570204, 23.58417, 23.590], 
                                       "Name":["Parcul Stadion", "Cluj Arena 1St Floor Balcony", "Sala Polivalenta", 
                                              "Sala Polivalenta Corner Aleea Stadionului", "Magyar Opera House",
                                              "Unirii Square"]})

# Missing "Casino Roof"
cluj_map = folium.Map(location=[cluj_sensors.Latitude.mean(),
                           cluj_sensors.Longitude.mean()], zoom_start=15, control_scale=True, min_zoom = 13)
for index, location_info in cluj_sensors.iterrows():
    folium.Marker([location_info["Latitude"], location_info["Longitude"]], popup=location_info["Name"]).add_to(cluj_map)
cluj_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97f1585e17e594f92a66eef946317806 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97f1585e17e594f92a66eef946317806&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_97f1585e17e594f92a66eef946317806 = L.map(
#                 &quot;map_97f1585e17e594f92a66eef946317806&quot;,
#                 {
#                     center: [46.76877433333333, 23.576729],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_97f1585e17e594f92a66eef946317806);
#
#
#
#
#
#             var tile_layer_1af3f4ee6cd06eeb1df03f30f5438ce8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 13, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_97f1585e17e594f92a66eef946317806);
#
#
#             var marker_ca2ec839200d049e27d7717a49cd8bd0 = L.marker(
#                 [46.7688, 23.574],
#                 {}
#             ).addTo(map_97f1585e17e594f92a66eef946317806);
#
#
#         var popup_dd3b9d518b1070dc660a179e663df10b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5ae17c4a3027992bd93bd973fa8cde22 = $(`&lt;div id=&quot;html_5ae17c4a3027992bd93bd973fa8cde22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Parcul Stadion&lt;/div&gt;`)[0];
#             popup_dd3b9d518b1070dc660a179e663df10b.setContent(html_5ae17c4a3027992bd93bd973fa8cde22);
#
#
#         marker_ca2ec839200d049e27d7717a49cd8bd0.bindPopup(popup_dd3b9d518b1070dc660a179e663df10b)
#         ;
#
#
#
#
#             var marker_4593cf4586c378d16396a64db0d2b8e6 = L.marker(
#                 [46.7686, 23.5724],
#                 {}
#             ).addTo(map_97f1585e17e594f92a66eef946317806);
#
#
#         var popup_7cf5122aedac2a2587325b6809896233 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1895df84be03b63a3ee3b9090e69cf1c = $(`&lt;div id=&quot;html_1895df84be03b63a3ee3b9090e69cf1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluj Arena 1St Floor Balcony&lt;/div&gt;`)[0];
#             popup_7cf5122aedac2a2587325b6809896233.setContent(html_1895df84be03b63a3ee3b9090e69cf1c);
#
#
#         marker_4593cf4586c378d16396a64db0d2b8e6.bindPopup(popup_7cf5122aedac2a2587325b6809896233)
#         ;
#
#
#
#
#             var marker_7ccce7ee8797b7486b55f8d8b8fe23f4 = L.marker(
#                 [46.767, 23.5696],
#                 {}
#             ).addTo(map_97f1585e17e594f92a66eef946317806);
#
#
#         var popup_92977a3d85a5b7b49fe10a150758cdb7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b3c89073dfe20fca302e8f9c36873b58 = $(`&lt;div id=&quot;html_b3c89073dfe20fca302e8f9c36873b58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sala Polivalenta&lt;/div&gt;`)[0];
#             popup_92977a3d85a5b7b49fe10a150758cdb7.setContent(html_b3c89073dfe20fca302e8f9c36873b58);
#
#
#         marker_7ccce7ee8797b7486b55f8d8b8fe23f4.bindPopup(popup_92977a3d85a5b7b49fe10a150758cdb7)
#         ;
#
#
#
#
#             var marker_109a67bcead5a1c4aff2a90e76504d6c = L.marker(
#                 [46.766246, 23.570204],
#                 {}
#             ).addTo(map_97f1585e17e594f92a66eef946317806);
#
#
#         var popup_a9c2a16006863fc0fb4b576e578002eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e808b853b6ef944dda338e79e846f64b = $(`&lt;div id=&quot;html_e808b853b6ef944dda338e79e846f64b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sala Polivalenta Corner Aleea Stadionului&lt;/div&gt;`)[0];
#             popup_a9c2a16006863fc0fb4b576e578002eb.setContent(html_e808b853b6ef944dda338e79e846f64b);
#
#
#         marker_109a67bcead5a1c4aff2a90e76504d6c.bindPopup(popup_a9c2a16006863fc0fb4b576e578002eb)
#         ;
#
#
#
#
#             var marker_d9e9e44fd07367dcec9f41d9fe6fee57 = L.marker(
#                 [46.7725, 23.58417],
#                 {}
#             ).addTo(map_97f1585e17e594f92a66eef946317806);
#
#
#         var popup_93677f50f84ae11c520b39d6f6ebf00a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e89dbe54ccfe89e54076d8979c5d70c5 = $(`&lt;div id=&quot;html_e89dbe54ccfe89e54076d8979c5d70c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Magyar Opera House&lt;/div&gt;`)[0];
#             popup_93677f50f84ae11c520b39d6f6ebf00a.setContent(html_e89dbe54ccfe89e54076d8979c5d70c5);
#
#
#         marker_d9e9e44fd07367dcec9f41d9fe6fee57.bindPopup(popup_93677f50f84ae11c520b39d6f6ebf00a)
#         ;
#
#
#
#
#             var marker_d5cafa2793cd90a5de56179b673c2ad4 = L.marker(
#                 [46.7695, 23.59],
#                 {}
#             ).addTo(map_97f1585e17e594f92a66eef946317806);
#
#
#         var popup_0fb93abcd5a3b8db296d4d4495219319 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});

# %% [markdown]
# ## Dublin

# %%
dublin_sensors = pd.read_csv("Footfall Data/SensorLocations/dublin_locations.csv")
dublin_sensors.rename(columns={'Counter Locations': 'Name'}, inplace = True)

dublin_map = folium.Map(location=[dublin_sensors.Latitude.mean(),
                           dublin_sensors.Longitude.mean()], zoom_start=15, control_scale=True, min_zoom = 13)
for index, location_info in dublin_sensors.iterrows():
    folium.Marker([location_info["Latitude"], location_info["Longitude"]], popup=location_info["Name"]).add_to(dublin_map)
dublin_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fee1e9af7ce4bdf1aa8b67ac16e1dc7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fee1e9af7ce4bdf1aa8b67ac16e1dc7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1fee1e9af7ce4bdf1aa8b67ac16e1dc7 = L.map(
#                 &quot;map_1fee1e9af7ce4bdf1aa8b67ac16e1dc7&quot;,
#                 {
#                     center: [53.34635353652174, -6.2603441584782615],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_1fee1e9af7ce4bdf1aa8b67ac16e1dc7);
#
#
#
#
#
#             var tile_layer_306830a979cf0d94d516bb4ea502aa15 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 13, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1fee1e9af7ce4bdf1aa8b67ac16e1dc7);
#
#
#             var marker_b4fde05b014764ed1c1546cb312095ae = L.marker(
#                 [53.34973, -6.2609],
#                 {}
#             ).addTo(map_1fee1e9af7ce4bdf1aa8b67ac16e1dc7);
#
#
#         var popup_e404ef09c5638c60361cdc52e390e2bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7d2715e9e3380ee6c030024ec11556ac = $(`&lt;div id=&quot;html_7d2715e9e3380ee6c030024ec11556ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Henry Street&lt;/div&gt;`)[0];
#             popup_e404ef09c5638c60361cdc52e390e2bd.setContent(html_7d2715e9e3380ee6c030024ec11556ac);
#
#
#         marker_b4fde05b014764ed1c1546cb312095ae.bindPopup(popup_e404ef09c5638c60361cdc52e390e2bd)
#         ;
#
#
#
#
#             var marker_b923ab74be0c94700805696b0d94cf59 = L.marker(
#                 [53.34902, -6.26005],
#                 {}
#             ).addTo(map_1fee1e9af7ce4bdf1aa8b67ac16e1dc7);
#
#
#         var popup_8141ca67b38be9bc39f73e6ede640973 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1a302f851a8c76973de1cdba9256d1eb = $(`&lt;div id=&quot;html_1a302f851a8c76973de1cdba9256d1eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;O&#x27;Connell St Outside Clerys&lt;/div&gt;`)[0];
#             popup_8141ca67b38be9bc39f73e6ede640973.setContent(html_1a302f851a8c76973de1cdba9256d1eb);
#
#
#         marker_b923ab74be0c94700805696b0d94cf59.bindPopup(popup_8141ca67b38be9bc39f73e6ede640973)
#         ;
#
#
#
#
#             var marker_592ec9f8427fc6be9f329653fe966b7a = L.marker(
#                 [53.34877, -6.26674],
#                 {}
#             ).addTo(map_1fee1e9af7ce4bdf1aa8b67ac16e1dc7);
#
#
#         var popup_1fefd7a12732f9761d28f575981f74cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f355754721531f8f341370bbc90a3db0 = $(`&lt;div id=&quot;html_f355754721531f8f341370bbc90a3db0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mary Street&lt;/div&gt;`)[0];
#             popup_1fefd7a12732f9761d28f575981f74cb.setContent(html_f355754721531f8f341370bbc90a3db0);
#
#
#         marker_592ec9f8427fc6be9f329653fe966b7a.bindPopup(popup_1fefd7a12732f9761d28f575981f74cb)
#         ;
#
#
#
#
#             var marker_47349f76dfbc6c8f0e626c19204f8385 = L.marker(
#                 [53.34842, -6.26918],
#                 {}
#             ).addTo(map_1fee1e9af7ce4bdf1aa8b67ac16e1dc7);
#
#
#         var popup_950f9db0952a14dc081c882dfa3cf8a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3f4056fe75cc9cf6b56a012c75136428 = $(`&lt;div id=&quot;html_3f4056fe75cc9cf6b56a012c75136428&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capel Street&lt;/div&gt;`)[0];
#             popup_950f9db0952a14dc081c882dfa3cf8a9.setContent(html_3f4056fe75cc9cf6b56a012c75136428);
#
#
#         marker_47349f76dfbc6c8f0e626c19204f8385.bindPopup(popup_950f9db0952a14dc081c882dfa3cf8a9)
#         ;
#
#
#
#
#             var marker_1e24516c4418b55ba7eb7f052eb8a274 = L.marker(
#                 [53.34662, -6.25982],
#                 {}
#             ).addTo(map_1fee1e9af7ce4bdf1aa8b67ac16e1dc7);
#
#
#         var popup_0280c2b1591bf35c0269de3828b7e1f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c564fa4885cd5e522228057636532c8f = $(`&lt;div id=&quot;html_c564fa4885cd5e522228057636532c8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aston Quay&lt;/div&gt;`)[0];
#             popup_0280c2b1591bf35c0269de3828b7e1f1.setContent(html_c564fa4885cd5e522228057636532c8f);
#
#
#         marker_1e24516c4418b55ba7eb7f052eb8a274.bindPopup(popup_0280c2b1591bf35c0269de3828b7e1f1)
#         ;
#
#
#
#
#             var marker_0f702d52babba25757714caff3f74c38 = L.marker(
#                 [53.34337, -6.25898],
#                 {}
#             ).addTo(map_1fee1e9af7ce4bdf1aa8b67ac16e1dc7);
#
#
#         var popup_2511af21cc8e84940156c916989154c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fa72

# %% [markdown]
# ## Melbourne

# %%
# melbourne_sensors = pd.read_csv("Footfall Data/SensorLocations/melbourne_locations.csv")
# melbourne_sensors.rename(columns={'sensor_description': 'Name'}, inplace = True)
# len(melbourne_sensors)

# # Plot
# melbourne_map = folium.Map(location=[melbourne_sensors.Latitude.mean(),
#                            melbourne_sensors.Longitude.mean()], zoom_start=14, control_scale=True, min_zoom = 13)
# for index, location_info in melbourne_sensors.iterrows():
#     folium.Marker([location_info["Latitude"], location_info["Longitude"]], popup=location_info["Name"]).add_to(melbourne_map)
# melbourne_map
os.getcwd()
# Out:
# '/nfs/a319/gy17m2a/Project/Footfall/Scripts/ExploringFootfallData'

# %% [markdown]
# ## Glasgow - CCTV

# %%
if os.path.exists("glasgow_cctv.csv"):
    glasgow_cctv = pd.read_csv("glasgow_cctv.csv")
else:
    r = get_report("https://api.glasgow.gov.uk/cctv/v1/get_detection_summaries?startDate=2015-01-01&endDate=2022-09-16")
    report_parsed = json.loads(r)
    a1_list = report_parsed['data']
    glasgow_cctv = pd.DataFrame()
    for a1 in a1_list:
        this_line = pd.concat([pd.DataFrame({'Timestamp':a1['timestamp']}, index = [0])
                                    , pd.DataFrame(a1['camera'], index=[0]), 
                                    pd.DataFrame(a1['objects'], index=[0])], axis =1)    
        glasgow_cctv = pd.concat([glasgow_cctv, this_line], axis = 0)
    
    glasgow_cctv.to_csv("glasgow_cctv.csv")

# %%
# Remove cameras which don't have location information for some reason
glasgow_cctv = glasgow_cctv[(glasgow_cctv['cameraName'] != 'A83') & (glasgow_cctv['cameraName'] != 'A65')]
glasgow_cctv = glasgow_cctv.drop_duplicates('cameraName', keep='last')

# Plot
glasgow_cctv_map = folium.Map(location=[glasgow_cctv.latitude.mean(),
                           glasgow_cctv.longitude.mean()], zoom_start=12, control_scale=True, min_zoom = 12)
for index, location_info in glasgow_cctv.iterrows():
    folium.Marker([location_info["latitude"], location_info["longitude"]], popup=location_info["cameraName"]).add_to(glasgow_cctv_map)
glasgow_cctv_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_948cecc78a39c666d7a3e808035e30d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_948cecc78a39c666d7a3e808035e30d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_948cecc78a39c666d7a3e808035e30d5 = L.map(
#                 &quot;map_948cecc78a39c666d7a3e808035e30d5&quot;,
#                 {
#                     center: [55.859315769230776, -4.2602900256410265],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_948cecc78a39c666d7a3e808035e30d5);
#
#
#
#
#
#             var tile_layer_96be065b0e9e8a2aef04bd8a9d01575a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 12, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_948cecc78a39c666d7a3e808035e30d5);
#
#
#             var marker_819eeaeb71d4ded7cb474000dcdb5076 = L.marker(
#                 [55.858442, -4.2591331],
#                 {}
#             ).addTo(map_948cecc78a39c666d7a3e808035e30d5);
#
#
#         var popup_e147c999541db2b13f59a9c7373cc17a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_583da3d16355eb4d0140493327e30ee4 = $(`&lt;div id=&quot;html_583da3d16355eb4d0140493327e30ee4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A47static&lt;/div&gt;`)[0];
#             popup_e147c999541db2b13f59a9c7373cc17a.setContent(html_583da3d16355eb4d0140493327e30ee4);
#
#
#         marker_819eeaeb71d4ded7cb474000dcdb5076.bindPopup(popup_e147c999541db2b13f59a9c7373cc17a)
#         ;
#
#
#
#
#             var marker_911690fdefdc8a823a7eeac0053cad65 = L.marker(
#                 [55.856152, -4.2580733],
#                 {}
#             ).addTo(map_948cecc78a39c666d7a3e808035e30d5);
#
#
#         var popup_0f883c65212ccc543797986718c57031 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d95a423f388b109be84a596db385e651 = $(`&lt;div id=&quot;html_d95a423f388b109be84a596db385e651&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A32&lt;/div&gt;`)[0];
#             popup_0f883c65212ccc543797986718c57031.setContent(html_d95a423f388b109be84a596db385e651);
#
#
#         marker_911690fdefdc8a823a7eeac0053cad65.bindPopup(popup_0f883c65212ccc543797986718c57031)
#         ;
#
#
#
#
#             var marker_e7b06a513347f9eb0817ed7ae97a58e8 = L.marker(
#                 [55.85583, -4.2565047],
#                 {}
#             ).addTo(map_948cecc78a39c666d7a3e808035e30d5);
#
#
#         var popup_c67430f48f8cd83570478e853c5af07c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4dc08c1850d3545788f9af8bad4eb6d5 = $(`&lt;div id=&quot;html_4dc08c1850d3545788f9af8bad4eb6d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A31&lt;/div&gt;`)[0];
#             popup_c67430f48f8cd83570478e853c5af07c.setContent(html_4dc08c1850d3545788f9af8bad4eb6d5);
#
#
#         marker_e7b06a513347f9eb0817ed7ae97a58e8.bindPopup(popup_c67430f48f8cd83570478e853c5af07c)
#         ;
#
#
#
#
#             var marker_8ea334e2a6a19afaa239aa3be839d2a5 = L.marker(
#                 [55.854334, -4.2508098],
#                 {}
#             ).addTo(map_948cecc78a39c666d7a3e808035e30d5);
#
#
#         var popup_ddcbe1935b9b31355cfbefb54515c4dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a6994338855f71799c0df620ca5b2f96 = $(`&lt;div id=&quot;html_a6994338855f71799c0df620ca5b2f96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A33&lt;/div&gt;`)[0];
#             popup_ddcbe1935b9b31355cfbefb54515c4dd.setContent(html_a6994338855f71799c0df620ca5b2f96);
#
#
#         marker_8ea334e2a6a19afaa239aa3be839d2a5.bindPopup(popup_ddcbe1935b9b31355cfbefb54515c4dd)
#         ;
#
#
#
#
#             var marker_0a90a596fe334427e37f1ba8b05ab3cf = L.marker(
#                 [55.860038, -4.2588262],
#                 {}
#             ).addTo(map_948cecc78a39c666d7a3e808035e30d5);
#
#
#         var popup_c25bbc7ff0f14b808105b5bf6e333d4f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cd146c953d7a50c3a9d836ae525b7efe = $(`&lt;div id=&quot;html_cd146c953d7a50c3a9d836ae525b7efe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A92&lt;/div&gt;`)[0];
#             popup_c25bbc7ff0f14b808105b5bf6e333d4f.setContent(html_cd146c953d7a50c3a9d836ae525b7efe);
#
#
#         marker_0a90a596fe334427e37f1ba8b05ab3cf.bindPopup(popup_c25bbc7ff0f14b808105b5bf6e333d4f)
#         ;
#
#
#
#
#             var marker_b1328572ea16de54f39fee20a9fc6c41 = L.marker(
#                 [55.852468, -4.2447742],
#                 {}
#             ).addTo(map_948cecc78a39c666d7a3e808035e30d5);
#
#
#         var popup_66c277b95d67fe7a33e322cc03a0f4f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a21a25484f0c4b6654f96c5e22d37b39 = $(`&lt

# %% [markdown]
# ## Glasgow - Springboard sensors

# %%
if os.path.exists("Footfall Data/glasgow_springboard.csv"):
    glasgow_springboard = pd.read_csv("Footfall Data/glasgow_springboard.csv")
else:
    r = get_report("https://api.glasgow.gov.uk/mobility/v1/footfall/historical?format=json&startDate=2010-01-01&endDate=2022-01-01")
    report_parsed = json.loads(r)
    glasgow_springboard = pd.DataFrame()
    for i in report_parsed:
        this_line = pd.DataFrame({'Timestamp':i['processDate'], 'Count': i['pedestrianCount'],
                           'latitude': i['location']['latitude'], 'longitude': i['location']['longitude'],
                            'name': i['location']['description']},index = [0])
        glasgow_springboard = pd.concat([glasgow_springboard, this_line], axis = 0)
    glasgow_springboard.to_csv("glasgow_springboard.csv")
# Out:
# Getting report results...
# Report results received...
# HTTP 200 - OK

# %%
glasgow_springboard.columns
# Out:
# Index(['Timestamp', 'Count', 'latitude', 'longitude', 'name'], dtype='object')

# %%
# # Approximate locations from sensor names and google maps
# # Sensors at boundaries of streets should be relatively accurate, but some others (e.g. those in parks with no clear
# # landmarks are likely to be further off)
# glasgow_springboard_locs = pd.DataFrame({"Name" : glasgow_springboard['location'].unique()})
# glasgow_springboard_locs['latitude'] = [55.860568,55.858596,55.853101,"?", 55.856074,55.854316, 55.858339,55.874644,55.874644,55.856714, 55.855950, 
#                   55.858596,55.865555, 55.859067, 55.860634, 55.860249, 55.864936, 55.8444,55.844358,55.868056, 55.867868,55.869048,
#                   55.869062,55.850121, 55.851680, 55.851407, 55.849166, 55.851616, 55.836606, 55.860742,55.860311, 55.858247, 
#                     55.886736, 55.848342, 55.848342, 55.865027, 55.884886,55.856764, 55.856500, 55.856923,55.856923,
#                     55.856567, 55.857750, 55.859592, 55.856714]
# glasgow_springboard_locs['longitude'] = [-4.256939,-4.259565,-4.307439,"?",-4.257325,-4.250451,-4.256757, -4.294458, -4.294458, -4.243537,-4.256211,
#                    -4.259565,-4.264677,-4.264956, -4.258714, -4.258880, -4.252564, -4.3216, -4.321818,-4.283760,  -4.280626, -4.287004,
#                     -4.283544, -4.237647, -4.237611, -4.240697, -4.237947, -4.236305, -4.264721,  -4.250324, -4.239860,-4.224189,
#                     -4.284584, -4.180028, -4.180028,-4.260333, -4.279044,-4.268601,-4.267267, -4.264092,  -4.264092,
#                     -4.260588, -4.281615, -4.269382,-4.243537]
# # remove row which it wasnt possible to get a location for "zebratest"
# glasgow_springboard_locs = glasgow_springboard_locs.drop(3)

# %%
# Plot
glasgow_springboard_map = folium.Map(location=[glasgow_springboard.latitude.mean(),
                           glasgow_springboard.longitude.mean()], zoom_start=12, control_scale=True, min_zoom = 12)
for index, location_info in glasgow_springboard.iterrows():
    folium.Marker([location_info["latitude"], location_info["longitude"]], popup=location_info["name"]).add_to(glasgow_springboard_map)
glasgow_springboard_map

# %% [markdown]
# ## Glasgow - combined sensors

# %%
# Plot
glasgow_combined_map = folium.Map(location=[glasgow_springboard_locs.latitude.mean(),
                           glasgow_springboard_locs.longitude.mean()], zoom_start=12, control_scale=True, min_zoom = 12)
# Springboard
for index, location_info in glasgow_springboard_locs.iterrows():
    icon=folium.Icon(color="red")
    folium.Marker([location_info["latitude"], location_info["longitude"]], 
                  popup=location_info["Name"], icon=icon).add_to(glasgow_combined_map)
# CCTV
for index, location_info in glasgow_cctv.iterrows():
    icon=folium.Icon(color="blue")
    folium.Marker([location_info["latitude"], location_info["longitude"]], 
                  popup=location_info["cameraName"], icon=icon).add_to(glasgow_combined_map)
glasgow_combined_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0266da44f19b3aea65bf510c59b8df07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0266da44f19b3aea65bf510c59b8df07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0266da44f19b3aea65bf510c59b8df07 = L.map(
#                 &quot;map_0266da44f19b3aea65bf510c59b8df07&quot;,
#                 {
#                     center: [55.85899402272725, -4.261075909090909],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0266da44f19b3aea65bf510c59b8df07);
#
#
#
#
#
#             var tile_layer_597fa86f09a69ce99d969a4158d4008a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 12, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0266da44f19b3aea65bf510c59b8df07);
#
#
#             var marker_2736e608bb2937874a05bf0e8ae980f0 = L.marker(
#                 [55.860568, -4.256939],
#                 {}
#             ).addTo(map_0266da44f19b3aea65bf510c59b8df07);
#
#
#             var icon_7ad1585517dc0694e2e2b92a6e64c7fb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2736e608bb2937874a05bf0e8ae980f0.setIcon(icon_7ad1585517dc0694e2e2b92a6e64c7fb);
#
#
#         var popup_ef311b7dca192430707cd1f0aa65b564 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6164db10957ede31cec09a6da7749923 = $(`&lt;div id=&quot;html_6164db10957ede31cec09a6da7749923&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gordon_St_@_Renfield_St&lt;/div&gt;`)[0];
#             popup_ef311b7dca192430707cd1f0aa65b564.setContent(html_6164db10957ede31cec09a6da7749923);
#
#
#         marker_2736e608bb2937874a05bf0e8ae980f0.bindPopup(popup_ef311b7dca192430707cd1f0aa65b564)
#         ;
#
#
#
#
#             var marker_8308df801d8a261ec8c58d10319ef5dc = L.marker(
#                 [55.858596, -4.259565],
#                 {}
#             ).addTo(map_0266da44f19b3aea65bf510c59b8df07);
#
#
#             var icon_9524157867544a218ab31f30e713f060 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8308df801d8a261ec8c58d10319ef5dc.setIcon(icon_9524157867544a218ab31f30e713f060);
#
#
#         var popup_98ea0854ceab256c686e4d730f795e4a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_021ff3ec4f533946df5c3c0e9167cfe7 = $(`&lt;div id=&quot;html_021ff3ec4f533946df5c3c0e9167cfe7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Argyle_St_@_Oswald_St&lt;/div&gt;`)[0];
#             popup_98ea0854ceab256c686e4d730f795e4a.setContent(html_021ff3ec4f533946df5c3c0e9167cfe7);
#
#
#         marker_8308df801d8a261ec8c58d10319ef5dc.bindPopup(popup_98ea0854ceab256c686e4d730f795e4a)
#         ;
#
#
#
#
#             var marker_1dbda7b1a8786fc52ac8e92f18252509 = L.marker(
#                 [55.853101, -4.307439],
#                 {}
#             ).addTo(map_0266da44f19b3aea65bf510c59b8df07);
#
#
#             var icon_c545f13caf35bbdfcee3959bb41ac091 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1dbda7b1a8786fc52ac8e92f18252509.setIcon(icon_c545f13caf35bbdfcee3959bb41ac091);
#
#
#         var popup_9f9a8dc5aa976538e878ca7b6e95ceae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e26d9ad16c482a337d57e0247e3f627b = $(`&lt;div id=&quot;html_e26d9ad16c482a337d57e0247e3f627b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ibrox&lt;/div&gt;`)[0];
#             popup_9f9a8dc5aa976538e878ca7b6e95ceae.setContent(html_e26d9ad16c482a337d57e0247e3f627b);
#
#
#         marker_1dbda7b1a8786fc52ac8e92f18252509.bindPopup(popup_9f9a8dc5aa976538e878ca7b6e95ceae)
#         ;
#
#
#
#
#             var marker_ace6def02614e624dbd87cd4ab5fa9ff = L.marker(
#                 [55.856074, -4.257325],
#                 {}
#             ).addTo(map_0266da44f19b3aea65bf510c59b8df07);
#
#
#             var icon_309a868856bc2c697938a8699c0095c3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;

# %% [markdown]
# ## Testing plotting

# %%
# glasgow_data2['location'].unique()
# one_camera = glasgow_data2[glasgow_data2['location'] == "Argyle_St_@_Brown_St"]


# def make_ticks (file):
#     t = file.iloc[:,0]
#     ticks = list(t.values.flatten())
#     if len(t) <= 10: 
#            ticks = ticks
#            tick_locations =  [i for i in range(0,len(t))]
#     else: 
#            ticks = [ticks[i] for i in range(0,len(t),int(len(t)/10))]
#            tick_locations =  [i for i in range(0,len(t),int(len(t)/10))]
#     return (ticks, tick_locations)        

# ticks = make_ticks(one_camera)[0]
# tick_locations = make_ticks(one_camera)[1]

# fig, ax = plt.subplots()
# ax.plot(one_camera['Timestamp'], one_camera['person'])
# ax.set_xticks(tick_locations)
# ax.set_xticklabels(ticks, rotation=70);

# %% [markdown]
# ## Testing finding BBOX

# %%
# def bounding_box(points):
#     x_coordinates, y_coordinates = zip(*points)

#     return [(min(x_coordinates), min(y_coordinates)), (max(x_coordinates), max(y_coordinates))]

# points = [[1, 3], [2, 4], [4, 1], [3, 3], [1, 6]]
