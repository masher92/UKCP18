# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from warnings import simplefilter
warnings.filterwarnings("ignore", category =UserWarning,)

import numpy as np
import pandas as pd
import iris
import glob
import sys
import os
import cartopy.crs as ccrs
import itertools
from scipy import spatial
import numpy.ma as ma
import tilemapbase
import iris.plot as iplt
from math import cos, radians
import geopandas as gpd
from shapely.geometry import Polygon
import matplotlib.pyplot as plt
import time
from pyproj import Proj, transform
import warnings
import gc
import pickle
from collections import OrderedDict

from Identify_Events_Functions import *

pd.set_option('display.float_format', '{:.3f}'.format)

# %%
def load_and_cache_cube(year, cache, filenames_pattern):
    if year in cache:
        print(f"Using cached data for year {year}")
        return cache[year]

    print(f"Loading data for year {year}")
    filenames = [filename for filename in glob.glob(filenames_pattern) if '.nc' in filename]

    if not filenames:
        raise FileNotFoundError(f"No files found for the year {year} with pattern {filenames_pattern}")

    cubes = iris.load(filenames)
    cubes = [cube for cube in cubes if len(cube.shape) != 2]
    cubes = iris.cube.CubeList(cubes)
    for cube in cubes:
        cube.rename(cubes[0].name())
    iris.util.equalise_attributes(cubes) 
    cube = cubes.concatenate_cube()
    cache[year] = cube

    return cube

def save_cube_to_disk(cube, filepath):
    with open(filepath, 'wb') as f:
        pickle.dump(cube, f)

def load_cube_from_disk(filepath):
    with open(filepath, 'rb') as f:
        return pickle.load(f)

def find_gauge_Tb0_and_location_in_grid(gauge_num, sample_cube):
    # Get data just for this gauge
    gauge1 = tbo_vals.iloc[gauge_num]
    # Find the interevent arrival time (Tb0)
    Tb0 = int(gauge1['Critical_interarrival_time'])
    # Find the coordinates of the cell containing this gauge
    closest_point, idx_2d = find_position_obs(sample_cube, gauge1['Lat'], gauge1['Lon'], plot_radius=30, plot=False)
    
    return Tb0, idx_2d

def find_amax_indy_events_v2(df, duration, Tb0):
    rainfall_cores = find_rainfall_core(df, duration=duration, Tb0=Tb0)
    rainfall_events_expanded = []

    for rainfall_core in rainfall_cores:
        rainfall_core_after_search1 = search1(df, rainfall_core)
        rainfall_core_after_search2 = search2(df, rainfall_core_after_search1)
        rainfall_core_after_search3 = search3(df, rainfall_core_after_search2, Tb0=Tb0)
        # If the event is not entirely dry 
        if len(rainfall_core_after_search3[rainfall_core_after_search3['precipitation (mm/hr)'] > 0.1]) > 0:
            rainfall_events_expanded.append(rainfall_core_after_search3)
    
    return rainfall_events_expanded

# %%
# Get tb0 values at each gauge
tbo_vals = pd.read_csv('/nfs/a319/gy17m2a/PhD/datadir/RainGauge/interarrival_thresholds_CDD_noMissing.txt')


# Dataset paths and patterns
datasets = {
    'unfiltered': '/nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/Unfiltered/AreaWeighted/{year}/*',}
#     'filtered_100': '/nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/Filtered_100/AreaWeighted/{year}/*',
#     'filtered_300': '/nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/Filtered_300/AreaWeighted/{year}/*'}

# Custom limited-size cache
class LimitedSizeDict(OrderedDict):
    def __init__(self, *args, max_size=100, **kwargs):
        self.max_size = max_size
        super().__init__(*args, **kwargs)

    def __setitem__(self, key, value):
        if len(self) >= self.max_size:
            self.popitem(last=False)
        OrderedDict.__setitem__(self, key, value)

# Initialize a limited-size cache
cubes_cache = {
    'unfiltered': LimitedSizeDict(max_size=10),
    'filtered_100': LimitedSizeDict(max_size=10),
    'filtered_300': LimitedSizeDict(max_size=10)
}        
        
# Loop through years
for gauge_num in range(1187, 1300):
    if gauge_num not in [423, 444, 827, 888]:
        print(f"Processing gauge {gauge_num}")

        # Read in a sample cube for finding the location of gauge in grid
        sample_cube = iris.load(f'/nfs/a161/gy17m2a/PhD/datadir/NIMROD/30mins/NIMROD_regridded_2.2km/Unfiltered/AreaWeighted/2012/rg_metoffice-c-band-rain-radar_uk_20120602_30mins.nc')[0][1,:,:]

        # Find the Tb0 and index of this gauge
        Tb0, idx_2d = find_gauge_Tb0_and_location_in_grid(gauge_num, sample_cube)

        # Loop through gauges
        for yr in range(2006, 2021):
            print(f"Processing year {yr}")

            # Ensure directories for unfiltered, filtered_100, and filtered_300 exist
            for dataset_name in datasets.keys():
                base_dir = f"../../ProcessedData/IndependentEvents/NIMROD/NIMROD_2.2km_{dataset_name}/{gauge_num}"
                if not os.path.isdir(base_dir):
                    os.makedirs(base_dir)

            # Check if any files are missing for this year across all datasets
            missing_files = False
            for dataset_name in datasets.keys():
                base_dir = f"../../ProcessedData/IndependentEvents/NIMROD/NIMROD_2.2km_{dataset_name}/{gauge_num}"
                if not any(os.path.exists(f"{base_dir}/{duration}hrs_{yr}_v2_part0.csv") for duration in [0.5, 1, 2, 3, 6, 12, 24]):
                    missing_files = True
                    break

            if missing_files:
                for dataset_name, dataset_path_pattern in datasets.items():
                    print(f"Processing dataset: {dataset_name}")

                    # Load data for this year
                    general_filename = dataset_path_pattern.format(year=yr)
                    cache_filepath = f"/nfs/a319/gy17m2a/PhD/datadir/cache/nimrod_2.2km/cube_{yr}.pkl"

                    try:
                        if yr not in cubes_cache[dataset_name]:
                            if os.path.exists(cache_filepath):
                                cube = load_cube_from_disk(cache_filepath)
                            else:
                                cube = load_and_cache_cube(yr, cubes_cache[dataset_name], general_filename)
                                save_cube_to_disk(cube, cache_filepath)
                        else:
                            cube = cubes_cache[dataset_name][yr]
                    except (EOFError, FileNotFoundError) as e:
                        print(f"Error loading cube for year {yr}: {e}")
                        continue

                    # Extract data for the specified indices
                    data = cube[:, idx_2d[0], idx_2d[1]].data

                    # Create a DataFrame from the data
                    df = pd.DataFrame({
                        'times': cube[:, idx_2d[0], idx_2d[1]].coord('time').units.num2date(cube.coord('time').points),
                        'precipitation (mm/hr)': data,
                        'precipitation (mm)': data / 2})

                    # Loop through durations
                    for duration in [0.5, 1, 2, 3, 6, 12, 24]:
                        base_dir = f"../../ProcessedData/IndependentEvents/NIMROD/NIMROD_2.2km_{dataset_name}/{gauge_num}"
                        if not os.path.exists(f"{base_dir}/{duration}hrs_{yr}_v2_part0.csv"):
                            print(f"Finding the AMAX for {duration}hr events for gauge {gauge_num} in year {yr} for {dataset_name}")

                            # Find events
                            events_v2 = find_amax_indy_events_v2(df, duration=duration, Tb0=Tb0)

                            # Save events to CSV
                            for num, event in enumerate(events_v2):
                                if len(event) > 1:
                                    event.to_csv(f"{base_dir}/{duration}hrs_{yr}_v2_part{num}.csv")
            else:
                print(f"All files already exist for gauge {gauge_num} and year {yr}")

        # Clear the cache at the end of processing each year
        for cache in cubes_cache.values():
            cache.clear()

        # Collect garbage to free up memory
        gc.collect()
# Out:
# Processing gauge 1187
# (303, 255)
# Processing year 2006
# All files already exist for gauge 1187 and year 2006
# Processing year 2007
# All files already exist for gauge 1187 and year 2007
# Processing year 2008
# All files already exist for gauge 1187 and year 2008
# Processing year 2009
# All files already exist for gauge 1187 and year 2009
# Processing year 2010
# All files already exist for gauge 1187 and year 2010
# Processing year 2011
# All files already exist for gauge 1187 and year 2011
# Processing year 2012
# All files already exist for gauge 1187 and year 2012
# Processing year 2013
# All files already exist for gauge 1187 and year 2013
# Processing year 2014
# All files already exist for gauge 1187 and year 2014
# Processing year 2015
# All files already exist for gauge 1187 and year 2015
# Processing year 2016
# All files already exist for gauge 1187 and year 2016
# Processing year 2017
# All files already exist for gauge 1187 and year 2017
# Processing year 2018
# All files already exist for gauge 1187 and year 2018
# Processing year 2019
# All files already exist for gauge 1187 and year 2019
# Processing year 2020
# All files already exist for gauge 1187 and year 2020
# Processing gauge 1188
# (298, 268)
# Processing year 2006
# All files already exist for gauge 1188 and year 2006
# Processing year 2007
# All files already exist for gauge 1188 and year 2007
# Processing year 2008
# All files already exist for gauge 1188 and year 2008
# Processing year 2009
# All files already exist for gauge 1188 and year 2009
# Processing year 2010
# All files already exist for gauge 1188 and year 2010
# Processing year 2011
# All files already exist for gauge 1188 and year 2011
# Processing year 2012
# All files already exist for gauge 1188 and year 2012
# Processing year 2013
# All files already exist for gauge 1188 and year 2013
# Processing year 2014
# All files already exist for gauge 1188 and year 2014
# Processing year 2015
# All files already exist for gauge 1188 and year 2015
# Processing year 2016
# All files already exist for gauge 1188 and year 2016
# Processing year 2017
# All files already exist for gauge 1188 and year 2017
# Processing year 2018
# All files already exist for gauge 1188 and year 2018
# Processing year 2019
# All files already exist for gauge 1188 and year 2019
# Processing year 2020
# All files already exist for gauge 1188 and year 2020
# Processing gauge 1189
# (298, 266)
# Processing year 2006
# All files already exist for gauge 1189 and year 2006
# Processing year 2007
# All files already exist for gauge 1189 and year 2007
# Processing year 2008
# All files already exist for gauge 1189 and year 2008
# Processing year 2009
# All files already exist for gauge 1189 and year 2009
# Processing year 2010
# All files already exist for gauge 1189 and year 2010
# Processing year 2011
# All files already exist for gauge 1189 and year 2011
# Processing year 2012
# All files already exist for gauge 1189 and year 2012
# Processing year 2013
# All files already exist for gauge 1189 and year 2013
# Processing year 2014
# All files already exist for gauge 1189 and year 2014
# Processing year 2015
# All files already exist for gauge 1189 and year 2015
# Processing year 2016
# All files already exist for gauge 1189 and year 2016
# Processing year 2017
# All files already exist for gauge 1189 and year 2017
# Processing year 2018
# All files already exist for gauge 1189 and year 2018
# Processing year 2019
# All files already exist for gauge 1189 and year 2019
# Processing year 2020
# All files already exist for gauge 1189 and year 2020
# Processing gauge 1190
# (300, 264)
# Processing year 2006
# All files already exist for gauge 1190 and year 2006
# Processing year 2007
# All files already exist for gauge 1190 and year 2007
# Processing year 2008
# All files already exist for gauge 1190 and year 2008
# Processing year 2009
# All files already exist for gauge 1190 and year 2009
# Processing year 2010
# All files already exist for gauge 1190 and year 2010
# Processing year 2011
# All files already exist for gauge 1190 and year 2011
# Processing year 2012
# All files already exist for gauge 1190 and year 2012
# Processing year 2013
# All files already exist for gauge 1190 and year 2013
# Processing year 2014
# All files already exist for gauge 1190 and year 2014
# Processing year 2015
# All files already exist for gauge 1190 and year 2015
# Processing year 2016
# All files already exist for gauge 1190 and year 2016
# Processing year 2017
# All files already exist for gauge 1190 and year 2017
# Processing year 2018
# All files already exist for gauge 1190 and year 2018
# Processing year 2019
# All files already exist for gauge 1190 and year 2019
# Processing year 2020
# All files already exist for gauge 1190 and year 2020
# Processing gauge 1191
# (306, 263)
# Processing year 2006
# All files already exist for gauge 1191 and year 2006
# Processing year 2007
# All files already exist for gauge 1191 and year 2007
# Processing year 2008
# All files already exist for gauge 1191 and year 2008
# Processing year 2009
# All files already exist for gauge 1191 and year 2009
# Processing year 2010
# All files already exist for gauge 1191 and year 2010
# Processing year 2011
# All files already exist for gauge 1191 and year 2011
# Processing year 2012
# All files already exist for gauge 1191 and year 2012
# Processing year 2013
# All files already exist for gauge 1191 and year 2013
# Processing year 2014
# All files already exist for gauge 1191 and year 2014
# Processing year 2015
# All files already exist for gauge 1191 and year 2015
# Processing year 2016
# All files already exist for gauge 1191 and year 2016
# Processing year 2017
# All files already exist for gauge 1191 and year 2017
# Processing year 2018
# All files already exist for gauge 1191 and year 2018
# Processing year 2019
# All files already exist for gauge 1191 and year 2019
# Processing year 2020
# All files already exist for gauge 1191 and year 2020
# Processing gauge 1192
# (295, 261)
# Processing year 2006
# All files already exist for gauge 1192 and year 2006
# Processing year 2007
# All files already exist for gauge 1192 and year 2007
# Processing year 2008
# All files already exist for gauge 1192 and year 2008
# Processing year 2009
# All files already exist for gauge 1192 and year 2009
# Processing year 2010
# All files already exist for gauge 1192 and year 2010
# Processing year 2011
# All files already exist for gauge 1192 and year 2011
# Processing year 2012
# All files already exist for gauge 1192 and year 2012
# Processing year 2013
# All files already exist for gauge 1192 and year 2013
# Processing year 2014
# All files already exist for gauge 1192 and year 2014
# Processing year 2015
# All files already exist for gauge 1192 and year 2015
# Processing year 2016
# All files already exist for gauge 1192 and year 2016
# Processing year 2017
# All files already exist for gauge 1192 and year 2017
# Processing year 2018
# All files already exist for gauge 1192 and year 2018
# Processing year 2019
# All files already exist for gauge 1192 and year 2019
# Processing year 2020
# All files already exist for gauge 1192 and year 2020
# Processing gauge 1193
# (301, 268)
# Processing year 2006
# All files already exist for gauge 1193 and year 2006
# Processing year 2007
# All files already exist for gauge 1193 and year 2007
# Processing year 2008
# All files already exist for gauge 1193 and year 2008
# Processing year 2009
# All files already exist for gauge 1193 and year 2009
# Processing year 2010
# All files already exist for gauge 1193 and year 2010
# Processing year 2011
# All files already exist for gauge 1193 and year 2011
# Processing year 2012
# All files already exist for gauge 1193 and year 2012
# Processing year 2013
# All files already exist for gauge 1193 and year 2013
# Processing year 2014
# All files already exist for gauge 1193 and year 2014
# Processing year 2015
# All files already exist for gauge 1193 and year 2015
# Processing year 2016
# All files already exist for gauge 1193 and year 2016
# Processing year 2017
# All files already exist for gauge 1193 and year 2017
# Processing year 2018
# All files already exist for gauge 1193 and year 2018
# Processing year 2019
# All files already exist for gauge 1193 and year 2019
# Processing year 2020
# All files already exist for gauge 1193 and year 2020
# Processing gauge 1194
# (292, 270)
# Processing year 2006
# All files already exist for gauge 1194 and year 2006
# Processing year 2007
# All files already exist for gauge 1194 and year 2007
# Processing year 2008
# All files already exist for gauge 1194 and year 2008
# Processing year 2009
# All files already exist for gauge 1194 and year 2009
# Processing year 2010
# All files already exist for gauge 1194 and year 2010
# Processing year 2011
# All files already exist for gauge 1194 and year 2011
# Processing year 2012
# All files already exist for gauge 1194 and year 2012
# Processing year 2013
# All files already exist for gauge 1194 and year 2013
# Processing year 2014
# All files already exist for gauge 1194 and year 2014
# Processing year 2015
# All files already exist for gauge 1194 and year 2015
# Processing year 2016
# All files already exist for gauge 1194 and year 2016
# Processing year 2017
# All files already exist for gauge 1194 and year 2017
# Processing year 2018
# All files already exist for gauge 1194 and year 2018
# Processing year 2019
# All files already exist for gauge 1194 and year 2019
# Processing year 2020
# All files already exist for gauge 1194 and year 2020
# Processing gauge 1195
# (299, 283)
# Processing year 2006
# All files already exist for gauge 1195 and year 2006
# Processing year 2007
# All files already exist for gauge 1195 and year 2007
# Processing year 2008
# All files already exist for gauge 1195 and year 2008
# Processing year 2009
# All files already exist for gauge 1195 and year 2009
# Processing year 2010
# All files already exist for gauge 1195 and year 2010
# Processing year 2011
# All files already exist for gauge 1195 and year 2011
# Processing year 2012
# All files already exist for gauge 1195 and year 2012
# Processing year 2013
# All files already exist for gauge 1195 and year 2013
# Processing year 2014
# All files already exist for gauge 1195 and year 2014
# Processing year 2015
# All files already exist for gauge 1195 and year 2015
# Processing year 2016
# All files already exist for gauge 1195 and year 2016
# Processing year 2017
# All files already exist for gauge 1195 and year 2017
# Processing year 2018
# All files already exist for gauge 1195 and year 2018
# Processing year 2019
# All files already exist for gauge 1195 and year 2019
# Processing year 2020
# All files already exist for gauge 1195 and year 2020
# Processing gauge 1196
# (303, 287)
# Processing year 2006
# All files already exist for gauge 1196 and year 2006
# Processing year 2007
# All files already exist for gauge 1196 and year 2007
# Processing year 2008
# All files already exist for gauge 1196 and year 2008
# Processing year 2009
# All files already exist for gauge 1196 and year 2009
# Processing year 2010
# All files already exist for gauge 1196 and year 2010
# Processing year 2011
# All files already exist for gauge 1196 and year 2011
# Processing year 2012
# All files already exist for gauge 1196 and year 2012
# Processing year 2013
# All files already exist for gauge 1196 and year 2013
# Processing year 2014
# All files already exist for gauge 1196 and year 2014
# Processing year 2015
# All files already exist for gauge 1196 and year 2015
# Processing year 2016
# All files already exist for gauge 1196 and year 2016
# Processing year 2017
# All files already exist for gauge 1196 and year 2017
# Processing year 2018
# All files already exist for gauge 1196 and year 2018
# Processing year 2019
# All files already exist for gauge 1196 and year 2019
# Processing year 2020
# All files already exist for gauge 1196 and year 2020
# Processing gauge 1197
# (295, 274)
# Processing year 2006
# All files already exist for gauge 1197 and year 2006
# Processing year 2007
# All files already exist for gauge 1197 and year 2007
# Processing year 2008
# All files already exist for gauge 1197 and year 2008
# Processing year 2009
# All files already exist for gauge 1197 and year 2009
# Processing year 2010
# All files already exist for gauge 1197 and year 2010
# Processing year 2011
# All files already exist for gauge 1197 and year 2011
# Processing year 2012
# All files already exist for gauge 1197 and year 2012
# Processing year 2013
# All files already exist for gauge 1197 and year 2013
# Processing year 2014
# All files already exist for gauge 1197 and year 2014
# Processing year 2015
# All files already exist for gauge 1197 and year 2015
# Processing year 2016
# All files already exist for gauge 1197 and year 2016
# Processing year 2017
# All files already exist for gauge 1197 and year 2017
# Processing year 2018
# All files already exist for gauge 1197 and year 2018
# Processing year 2019
# All files already exist for gauge 1197 and year 2019
# Processing year 2020
# All files already exist for gauge 1197 and year 2020
# Processing gauge 1198
# (301, 281)
# Processing year 2006
# All files already exist for gauge 1198 and year 2006
# Processing year 2007
# All files already exist for gauge 1198 and year 2007
# Processing year 2008
# All files already exist for gauge 1198 and year 2008
# Processing year 2009
# All files already exist for gauge 1198 and year 2009
# Processing year 2010
# All files already exist for gauge 1198 and year 2010
# Processing year 2011
# All files already exist for gauge 1198 and year 2011
# Processing year 2012
# All files already exist for gauge 1198 and year 2012
# Processing year 2013
# All files already exist for gauge 1198 and year 2013
# Processing year 2014
# All files already exist for gauge 1198 and year 2014
# Processing year 2015
# All files already exist for gauge 1198 and year 2015
# Processing year 2016
# All files already exist for gauge 1198 and year 2016
# Processing year 2017
# All files already exist for gauge 1198 and year 2017
# Processing year 2018
# All files already exist for gauge 1198 and year 2018
# Processing year 2019
# All files already exist for gauge 1198 and year 2019
# Processing year 2020
# All files already exist for gauge 1198 and year 2020
# Processing gauge 1199
# (386, 273)
# Processing year 2006
# All files already exist for gauge 1199 and year 2006
# Processing year 2007
# All files already exist for gauge 1199 and year 2007
# Processing year 2008
# All files already exist for gauge 1199 and year 2008
# Processing year 2009
# All files already exist for gauge 1199 and year 2009
# Processing year 2010
# All files already exist for gauge 1199 and year 2010
# Processing year 2011
# All files already exist for gauge 1199 and year 2011
# Processing year 2012
# All files already exist for gauge 1199 and year 2012
# Processing year 2013
# All files already exist for gauge 1199 and year 2013
# Processing year 2014
# All files already exist for gauge 1199 and year 2014
# Processing year 2015
# All files already exist for gauge 1199 and year 2015
# Processing year 2016
# All files already exist for gauge 1199 and year 2016
# Processing year 2017
# All files already exist for gauge 1199 and year 2017
# Processing year 2018
# All files already exist for gauge 1199 and year 2018
# Processing year 2019
# All files already exist for gauge 1199 and year 2019
# Processing year 2020
# All files already exist for gauge 1199 and year 2020
# Processing gauge 1200
# (377, 269)
# Processing year 2006
# All files already exist for gauge 1200 and year 2006
# Processing year 2007
# All files already exist for gauge 1200 and year 2007
# Processing year 2008
# All files already exist for gauge 1200 and year 2008
# Processing year 2009
# All files already exist for gauge 1200 and year 2009
# Processing year 2010
# All files already exist for gauge 1200 and year 2010
# Processing year 2011
# All files already exist for gauge 1200 and year 2011
# Processing year 2012
# All files already exist for gauge 1200 and year 2012
# Processing year 2013
# All files already exist for gauge 1200 and year 2013
# Processing year 2014
# All files already exist for gauge 1200 and year 2014
# Processing year 2015
# All files already exist for gauge 1200 and year 2015
# Processing year 2016
# All files already exist for gauge 1200 and year 2016
# Processing year 2017
# All files already exist for gauge 1200 and year 2017
# Processing year 2018
# All files already exist for gauge 1200 and year 2018
# Processing year 2019
# All files already exist for gauge 1200 and year 2019
# Processing year 2020
# All files already exist for gauge 1200 and year 2020
# Processing gauge 1201
# (421, 232)
# Processing year 2006
# All files already exist for gauge 1201 and year 2006
# Processing year 2007
# All files already exist for gauge 1201 and year 2007
# Processing year 2008
# All files already exist for gauge 1201 and year 2008
# Processing year 2009
# All files already exist for gauge 1201 and year 2009
# Processing year 2010
# All files already exist for gauge 1201 and year 2010
# Processing year 2011
# All files already exist for gauge 1201 and year 2011
# Processing year 2012
# All files already exist for gauge 1201 and year 2012
# Processing year 2013
# All files already exist for gauge 1201 and year 2013
# Processing year 2014
# All files already exist for gauge 1201 and year 2014
# Processing year 2015
# All files already exist for gauge 1201 and year 2015
# Processing year 2016
# All files already exist for gauge 1201 and year 2016
# Processing year 2017
# All files already exist for gauge 1201 and year 2017
# Processing year 2018
# All files already exist for gauge 1201 and year 2018
# Processing year 2019
# All files already exist for gauge 1201 and year 2019
# Processing year 2020
# All files already exist for gauge 1201 and year 2020
# Processing gauge 1202
# (378, 281)
# Processing year 2006
# All files already exist for gauge 1202 and year 2006
# Processing year 2007
# All files already exist for gauge 1202 and year 2007
# Processing year 2008
# All files already exist for gauge 1202 and year 2008
# Processing year 2009
# All files already exist for gauge 1202 and year 2009
# Processing year 2010
# All files already exist for gauge 1202 and year 2010
# Processing year 2011
# All files already exist for gauge 1202 and year 2011
# Processing year 2012
# All files already exist for gauge 1202 and year 2012
# Processing year 2013
# All files already exist for gauge 1202 and year 2013
# Processing year 2014
# All files already exist for gauge 1202 and year 2014
# Processing year 2015
# All files already exist for gauge 1202 and year 2015
# Processing year 2016
# All files already exist for gauge 1202 and year 2016
# Processing year 2017
# All files already exist for gauge 1202 and year 2017
# Processing year 2018
# All files already exist for gauge 1202 and year 2018
# Processing year 2019
# All files already exist for gauge 1202 and year 2019
# Processing year 2020
# All files already exist for gauge 1202 and year 2020
# Processing gauge 1203
# (365, 282)
# Processing year 2006
# All files already exist for gauge 1203 and year 2006
# Processing year 2007
# All files already exist for gauge 1203 and year 2007
# Processing year 2008
# All files already exist for gauge 1203 and year 2008
# Processing year 2009
# All files already exist for gauge 1203 and year 2009
# Processing year 2010
# All files already exist for gauge 1203 and year 2010
# Processing year 2011
# All files already exist for gauge 1203 and year 2011
# Processing year 2012
# All files already exist for gauge 1203 and year 2012
# Processing year 2013
# All files already exist for gauge 1203 and year 2013
# Processing year 2014
# All files already exist for gauge 1203 and year 2014
# Processing year 2015
# All files already exist for gauge 1203 and year 2015
# Processing year 2016
# All files already exist for gauge 1203 and year 2016
# Processing year 2017
# All files already exist for gauge 1203 and year 2017
# Processing year 2018
# All files already exist for gauge 1203 and year 2018
# Processing year 2019
# All files already exist for gauge 1203 and year 2019
# Processing year 2020
# All files already exist for gauge 1203 and year 2020
# Processing gauge 1204
# (370, 274)
# Processing year 2006
# All files already exist for gauge 1204 and year 2006
# Processing year 2007
# All files already exist for gauge 1204 and year 2007
# Processing year 2008
# All files already exist for gauge 1204 and year 2008
# Processing year 2009
# All files already exist for gauge 1204 and year 2009
# Processing year 2010
# All files already exist for gauge 1204 and year 2010
# Processing year 2011
# All files already exist for gauge 1204 and year 2011
# Processing year 2012
# All files already exist for gauge 1204 and year 2012
# Processing year 2013
# All files already exist for gauge 1204 and year 2013
# Processing year 2014
# All files already exist for gauge 1204 and year 2014
# Processing year 2015
# All files already exist for gauge 1204 and year 2015
# Processing year 2016
# All files already exist for gauge 1204 and year 2016
# Processing year 2017
# All files already exist for gauge 1204 and year 2017
# Processing year 2018
# All files already exist for gauge 1204 and year 2018
# Processing year 2019
# All files already exist for gauge 1204 and year 2019
# Processing year 2020
# All files already exist for gauge 1204 and year 2020
# Processing gauge 1205
# (349, 284)
# Processing year 2006
# All files already exist for gauge 1205 and year 2006
# Processing year 2007
# All files already exist for gauge 1205 and year 2007
# Processing year 2008
# All files already exist for gauge 1205 and year 2008
# Processing year 2009
# All files already exist for gauge 1205 and year 2009
# Processing year 2010
# All files already exist for gauge 1205 and year 2010
# Processing year 2011
# All files already exist for gauge 1205 and year 2011
# Processing year 2012
# All files already exist for gauge 1205 and year 2012
# Processing year 2013
# All files already exist for gauge 1205 and year 2013
# Processing year 2014
# All files already exist for gauge 1205 and year 2014
# Processing year 2015
# All files already exist for gauge 1205 and year 2015
# Processing year 2016
# All files already exist for gauge 1205 and year 2016
# Processing year 2017
# All files already exist for gauge 1205 and year 2017
# Processing year 2018
# All files already exist for gauge 1205 and year 2018
# Processing year 2019
# All files already exist for gauge 1205 and year 2019
# Processing year 2020
# All files already exist for gauge 1205 and year 2020
# Processing gauge 1206
# (416, 185)
# Processing year 2006
# All files already exist for gauge 1206 and year 2006
# Processing year 2007
# All files already exist for gauge 1206 and year 2007
# Processing year 2008
# All files already exist for gauge 1206 and year 2008
# Processing year 2009
# All files already exist for gauge 1206 and year 2009
# Processing year 2010
# All files already exist for gauge 1206 and year 2010
# Processing year 2011
# All files already exist for gauge 1206 and year 2011
# Processing year 2012
# All files already exist for gauge 1206 and year 2012
# Processing year 2013
# All files already exist for gauge 1206 and year 2013
# Processing year 2014
# All files already exist for gauge 1206 and year 2014
# Processing year 2015
# All files already exist for gauge 1206 and year 2015
# Processing year 2016
# All files already exist for gauge 1206 and year 2016
# Processing year 2017
# Processing dataset: unfiltered
# Finding the AMAX for 0.5hr events for gauge 1206 in year 2017 for unfiltered
# Finding the AMAX for 1hr events for gauge 1206 in year 2017 for unfiltered
# Finding the AMAX for 2hr events for gauge 1206 in year 2017 for unfiltered
# Finding the AMAX for 3hr events for gauge 1206 in year 2017 for unfiltered
# Finding the AMAX for 6hr events for gauge 1206 in year 2017 for unfiltered
# 2 events
# Finding the AMAX for 12hr events for gauge 1206 in year 2017 for unfiltered
# 2 events
# Finding the AMAX for 24hr events for gauge 1206 in year 2017 for unfiltered
# 2 events
# Processing year 2018
# All files already exist for gauge 1206 and year 2018
# Processing year 2019
# All files already exist for gauge 1206 and year 2019
# Processing year 2020
# All files already exist for gauge 1206 and year 2020
# Processing gauge 1207
# (387, 279)
# Processing year 2006
# All files already exist for gauge 1207 and year 2006
# Processing year 2007
# All files already exist for gauge 1207 and year 2007
# Processing year 2008
# All files already exist for gauge 1207 and year 2008
# Processing year 2009
# All files already exist for gauge 1207 and year 2009
# Processing year 2010
# All files already exist for gauge 1207 and year 2010
# Processing year 2011
# All files already exist for gauge 1207 and year 2011
# Processing year 2012
# All files already exist for gauge 1207 and year 2012
# Processing year 2013
# All files already exist for gauge 1207 and year 2013
# Processing year 2014
# All files already exist for gauge 1207 and year 2014
# Processing year 2015
# All files already exist for gauge 1207 and year 2015
# Processing year 2016
# All files already exist for gauge 1207 and year 2016
# Processing year 2017
# All files already exist for gauge 1207 and year 2017
# Processing year 2018
# All files already exist for gauge 1207 and year 2018
# Processing year 2019
# All files already exist for gauge 1207 and year 2019
# Processing year 2020
# All files already exist for gauge 1207 and year 2020
# Processing gauge 1208
# (373, 265)
# Processing year 2006
# All files already exist for gauge 1208 and year 2006
# Processing year 2007
# All files already exist for gauge 1208 and year 2007
# Processing year 2008
# All files already exist for gauge 1208 and year 2008
# Processing year 2009
# All files already exist for gauge 1208 and year 2009
# Processing year 2010
# All files already exist for gauge 1208 and year 2010
# Processing year 2011
# All files already exist for gauge 1208 and year 2011
# Processing year 2012
# All files already exist for gauge 1208 and year 2012
# Processing year 2013
# All files already exist for gauge 1208 and year 2013
# Processing year 2014
# All files already exist for gauge 1208 and year 2014
# Processing year 2015
# All files already exist for gauge 1208 and year 2015
# Processing year 2016
# All files already exist for gauge 1208 and year 2016
# Processing year 2017
# All files already exist for gauge 1208 and year 2017
# Processing year 2018
# All files already exist for gauge 1208 and year 2018
# Processing year 2019
# All files already exist for gauge 1208 and year 2019
# Processing year 2020
# All files already exist for gauge 1208 and year 2020
# Processing gauge 1209
# (384, 221)
# Processing year 2006
# All files already exist for gauge 1209 and year 2006
# Processing year 2007
# All files already exist for gauge 1209 and year 2007
# Processing year 2008
# All files already exist for gauge 1209 and year 2008
# Processing year 2009
# All files already exist for gauge 1209 and year 2009
# Processing year 2010
# All files already exist for gauge 1209 and year 2010
# Processing year 2011
# All files already exist for gauge 1209 and year 2011
# Processing year 2012
# All files already exist for gauge 1209 and year 2012
# Processing year 2013
# All files already exist for gauge 1209 and year 2013
# Processing year 2014
# All files already exist for gauge 1209 and year 2014
# Processing year 2015
# All files already exist for gauge 1209 and year 2015
# Processing year 2016
# All files already exist for gauge 1209 and year 2016
# Processing year 2017
# All files already exist for gauge 1209 and year 2017
# Processing year 2018
# All files already exist for gauge 1209 and year 2018
# Processing year 2019
# All files already exist for gauge 1209 and year 2019
# Processing year 2020
# All files already exist for gauge 1209 and year 2020
# Processing gauge 1210
# (458, 270)
# Processing year 2006
# All files already exist for gauge 1210 and year 2006
# Processing year 2007
# All files already exist for gauge 1210 and year 2007
# Processing year 2008
# All files already exist for gauge 1210 and year 2008
# Processing year 2009
# All files already exist for gauge 1210 and year 2009
# Processing year 2010
# All files already exist for gauge 1210 and year 2010
# Processing year 2011
# All files already exist for gauge 1210 and year 2011
# Processing year 2012
# All files already exist for gauge 1210 and year 2012
# Processing year 2013
# All files already exist for gauge 1210 and year 2013
# Processing year 2014
# All files already exist for gauge 1210 and year 2014
# Processing year 2015
# All files already exist for gauge 1210 and year 2015
# Processing year 2016
# All files already exist for gauge 1210 and year 2016
# Processing year 2017
# All files already exist for gauge 1210 and year 2017
# Processing year 2018
# All files already exist for gauge 1210 and year 2018
# Processing year 2019
# All files already exist for gauge 1210 and year 2019
# Processing year 2020
# All files already exist for gauge 1210 and year 2020
# Processing gauge 1211
# (364, 258)
# Processing year 2006
# All files already exist for gauge 1211 and year 2006
# Processing year 2007
# All files already exist for gauge 1211 and year 2007
# Processing year 2008
# All files already exist for gauge 1211 and year 2008
# Processing year 2009
# All files already exist for gauge 1211 and year 2009
# Processing year 2010
# All files already exist for gauge 1211 and year 2010
# Processing year 2011
# All files already exist for gauge 1211 and year 2011
# Processing year 2012
# All files already exist for gauge 1211 and year 2012
# Processing year 2013
# All files already exist for gauge 1211 and year 2013
# Processing year 2014
# All files already exist for gauge 1211 and year 2014
# Processing year 2015
# All files already exist for gauge 1211 and year 2015
# Processing year 2016
# All files already exist for gauge 1211 and year 2016
# Processing year 2017
# All files already exist for gauge 1211 and year 2017
# Processing year 2018
# All files already exist for gauge 1211 and year 2018
# Processing year 2019
# All files already exist for gauge 1211 and year 2019
# Processing year 2020
# All files already exist for gauge 1211 and year 2020
# Processing gauge 1212
# (428, 263)
# Processing year 2006
# All files already exist for gauge 1212 and year 2006
# Processing year 2007
# All files already exist for gauge 1212 and year 2007
# Processing year 2008
# All files already exist for gauge 1212 and year 2008
# Processing year 2009
# All files already exist for gauge 1212 and year 2009
# Processing year 2010
# All files already exist for gauge 1212 and year 2010
# Processing year 2011
# All files already exist for gauge 1212 and year 2011
# Processing year 2012
# All files already exist for gauge 1212 and year 2012
# Processing year 2013
# All files already exist for gauge 1212 and year 2013
# Processing year 2014
# All files already exist for gauge 1212 and year 2014
# Processing year 2015
# All files already exist for gauge 1212 and year 2015
# Processing year 2016
# All files already exist for gauge 1212 and year 2016
# Processing year 2017
# All files already exist for gauge 1212 and year 2017
# Processing year 2018
# All files already exist for gauge 1212 and year 2018
# Processing year 2019
# All files already exist for gauge 1212 and year 2019
# Processing year 2020
# All files already exist for gauge 1212 and year 2020
# Processing gauge 1213
# (371, 209)
# Processing year 2006
# All files already exist for gauge 1213 and year 2006
# Processing year 2007
# All files already exist for gauge 1213 and year 2007
# Processing year 2008
# All files already exist for gauge 1213 and year 2008
# Processing year 2009
# All files already exist for gauge 1213 and year 2009
# Processing year 2010
# All files already exist for gauge 1213 and year 2010
# Processing year 2011
# All files already exist for gauge 1213 and year 2011
# Processing year 2012
# All files already exist for gauge 1213 and year 2012
# Processing year 2013
# All files already exist for gauge 1213 and year 2013
# Processing year 2014
# All files already exist for gauge 1213 and year 2014
# Processing year 2015
# All files already exist for gauge 1213 and year 2015
# Processing year 2016
# All files already exist for gauge 1213 and year 2016
# Processing year 2017
# All files already exist for gauge 1213 and year 2017
# Processing year 2018
# All files already exist for gauge 1213 and year 2018
# Processing year 2019
# All files already exist for gauge 1213 and year 2019
# Processing year 2020
# All files already exist for gauge 1213 and year 2020
# Processing gauge 1214
# (410, 257)
# Processing year 2006
# All files already exist for gauge 1214 and year 2006
# Processing year 2007
# All files already exist for gauge 1214 and year 2007
# Processing year 2008
# All files already exist for gauge 1214 and year 2008
# Processing year 2009
# All files already exist for gauge 1214 and year 2009
# Processing year 2010
# All files already exist for gauge 1214 and year 2010
# Processing year 2011
# All files already exist for gauge 1214 and year 2011
# Processing year 2012
# All files already exist for gauge 1214 and year 2012
# Processing year 2013
# All files already exist for gauge 1214 and year 2013
# Processing year 2014
# All files already exist for gauge 1214 and year 2014
# Processing year 2015
# All files already exist for gauge 1214 and year 2015
# Processing year 2016
# All files already exist for gauge 1214 and year 2016
# Processing year 2017
# All files already exist for gauge 1214 and year 2017
# Processing year 2018
# All files already exist for gauge 1214 and year 2018
# Processing year 2019
# All files already exist for gauge 1214 and year 2019
# Processing year 2020
# All files already exist for gauge 1214 and year 2020
# Processing gauge 1215
# (413, 218)
# Processing year 2006
# All files already exist for gauge 1215 and year 2006
# Processing year 2007
# All files already exist for gauge 1215 and year 2007
# Processing year 2008
# All files already exist for gauge 1215 and year 2008
# Processing year 2009
# All files already exist for gauge 1215 and year 2009
# Processing year 2010
# All files already exist for gauge 1215 and year 2010
# Processing year 2011
# All files already exist for gauge 1215 and year 2011
# Processing year 2012
# All files already exist for gauge 1215 and year 2012
# Processing year 2013
# All files already exist for gauge 1215 and year 2013
# Processing year 2014
# All files already exist for gauge 1215 and year 2014
# Processing year 2015
# All files already exist for gauge 1215 and year 2015
# Processing year 2016
# All files already exist for gauge 1215 and year 2016
# Processing year 2017
# All files already exist for gauge 1215 and year 2017
# Processing year 2018
# All files already exist for gauge 1215 and year 2018
# Processing year 2019
# All files already exist for gauge 1215 and year 2019
# Processing year 2020
# All files already exist for gauge 1215 and year 2020
# Processing gauge 1216
# (383, 264)
# Processing year 2006
# All files already exist for gauge 1216 and year 2006
# Processing year 2007
# All files already exist for gauge 1216 and year 2007
# Processing year 2008
# All files already exist for gauge 1216 and year 2008
# Processing year 2009
# All files already exist for gauge 1216 and year 2009
# Processing year 2010
# All files already exist for gauge 1216 and year 2010
# Processing year 2011
# All files already exist for gauge 1216 and year 2011
# Processing year 2012
# All files already exist for gauge 1216 and year 2012
# Processing year 2013
# All files already exist for gauge 1216 and year 2013
# Processing year 2014
# All files already exist for gauge 1216 and year 2014
# Processing year 2015
# All files already exist for gauge 1216 and year 2015
# Processing year 2016
# All files already exist for gauge 1216 and year 2016
# Processing year 2017
# All files already exist for gauge 1216 and year 2017
# Processing year 2018
# All files already exist for gauge 1216 and year 2018
# Processing year 2019
# All files already exist for gauge 1216 and year 2019
# Processing year 2020
# All files already exist for gauge 1216 and year 2020
# Processing gauge 1217
# (376, 209)
# Processing year 2006
# All files already exist for gauge 1217 and year 2006
# Processing year 2007
# All files already exist for gauge 1217 and year 2007
# Processing year 2008
# All files already exist for gauge 1217 and year 2008
# Processing year 2009
# All files already exist for gauge 1217 and year 2009
# Processing year 2010
# All files already exist for gauge 1217 and year 2010
# Processing year 2011
# All files already exist for gauge 1217 and year 2011
# Processing year 2012
# All files already exist for gauge 1217 and year 2012
# Processing year 2013
# All files already exist for gauge 1217 and year 2013
# Processing year 2014
# All files already exist for gauge 1217 and year 2014
# Processing year 2015
# All files already exist for gauge 1217 and year 2015
# Processing year 2016
# All files already exist for gauge 1217 and year 2016
# Processing year 2017
# All files already exist for gauge 1217 and year 2017
# Processing year 2018
# All files already exist for gauge 1217 and year 2018
# Processing year 2019
# All files already exist for gauge 1217 and year 2019
# Processing year 2020
# All files already exist for gauge 1217 and year 2020
# Processing gauge 1218
# (355, 272)
# Processing year 2006
# All files already exist for gauge 1218 and year 2006
# Processing year 2007
# All files already exist for gauge 1218 and year 2007
# Processing year 2008
# All files already exist for gauge 1218 and year 2008
# Processing year 2009
# All files already exist for gauge 1218 and year 2009
# Processing year 2010
# All files already exist for gauge 1218 and year 2010
# Processing year 2011
# All files already exist for gauge 1218 and year 2011
# Processing year 2012
# All files already exist for gauge 1218 and year 2012
# Processing year 2013
# All files already exist for gauge 1218 and year 2013
# Processing year 2014
# All files already exist for gauge 1218 and year 2014
# Processing year 2015
# All files already exist for gauge 1218 and year 2015
# Processing year 2016
# All files already exist for gauge 1218 and year 2016
# Processing year 2017
# All files already exist for gauge 1218 and year 2017
# Processing year 2018
# All files already exist for gauge 1218 and year 2018
# Processing year 2019
# All files already exist for gauge 1218 and year 2019
# Processing year 2020
# All files already exist for gauge 1218 and year 2020
# Processing gauge 1219
# (343, 202)
# Processing year 2006
# All files already exist for gauge 1219 and year 2006
# Processing year 2007
# All files already exist for gauge 1219 and year 2007
# Processing year 2008
# All files already exist for gauge 1219 and year 2008
# Processing year 2009
# All files already exist for gauge 1219 and year 2009
# Processing year 2010
# All files already exist for gauge 1219 and year 2010
# Processing year 2011
# All files already exist for gauge 1219 and year 2011
# Processing year 2012
# All files already exist for gauge 1219 and year 2012
# Processing year 2013
# All files already exist for gauge 1219 and year 2013
# Processing year 2014
# All files already exist for gauge 1219 and year 2014
# Processing year 2015
# All files already exist for gauge 1219 and year 2015
# Processing year 2016
# All files already exist for gauge 1219 and year 2016
# Processing year 2017
# All files already exist for gauge 1219 and year 2017
# Processing year 2018
# All files already exist for gauge 1219 and year 2018
# Processing year 2019
# All files already exist for gauge 1219 and year 2019
# Processing year 2020
# All files already exist for gauge 1219 and year 2020
# Processing gauge 1220
# (398, 234)
# Processing year 2006
# All files already exist for gauge 1220 and year 2006
# Processing year 2007
# All files already exist for gauge 1220 and year 2007
# Processing year 2008
# All files already exist for gauge 1220 and year 2008
# Processing year 2009
# All files already exist for gauge 1220 and year 2009
# Processing year 2010
# All files already exist for gauge 1220 and year 2010
# Processing year 2011
# All files already exist for gauge 1220 and year 2011
# Processing year 2012
# All files already exist for gauge 1220 and year 2012
# Processing year 2013
# All files already exist for gauge 1220 and year 2013
# Processing year 2014
# All files already exist for gauge 1220 and year 2014
# Processing year 2015
# All files already exist for gauge 1220 and year 2015
# Processing year 2016
# All files already exist for gauge 1220 and year 2016
# Processing year 2017
# All files already exist for gauge 1220 and year 2017
# Processing year 2018
# All files already exist for gauge 1220 and year 2018
# Processing year 2019
# All files already exist for gauge 1220 and year 2019
# Processing year 2020
# All files already exist for gauge 1220 and year 2020
# Processing gauge 1221
# (367, 251)
# Processing year 2006
# All files already exist for gauge 1221 and year 2006
# Processing year 2007
# All files already exist for gauge 1221 and year 2007
# Processing year 2008
# All files already exist for gauge 1221 and year 2008
# Processing year 2009
# All files already exist for gauge 1221 and year 2009
# Processing year 2010
# All files already exist for gauge 1221 and year 2010
# Processing year 2011
# All files already exist for gauge 1221 and year 2011
# Processing year 2012
# All files already exist for gauge 1221 and year 2012
# Processing year 2013
# All files already exist for gauge 1221 and year 2013
# Processing year 2014
# All files already exist for gauge 1221 and year 2014
# Processing year 2015
# All files already exist for gauge 1221 and year 2015
# Processing year 2016
# All files already exist for gauge 1221 and year 2016
# Processing year 2017
# All files already exist for gauge 1221 and year 2017
# Processing year 2018
# All files already exist for gauge 1221 and year 2018
# Processing year 2019
# All files already exist for gauge 1221 and year 2019
# Processing year 2020
# All files already exist for gauge 1221 and year 2020
# Processing gauge 1222
# (354, 238)
# Processing year 2006
# All files already exist for gauge 1222 and year 2006
# Processing year 2007
# All files already exist for gauge 1222 and year 2007
# Processing year 2008
# All files already exist for gauge 1222 and year 2008
# Processing year 2009
# All files already exist for gauge 1222 and year 2009
# Processing year 2010
# All files already exist for gauge 1222 and year 2010
# Processing year 2011
# All files already exist for gauge 1222 and year 2011
# Processing year 2012
# All files already exist for gauge 1222 and year 2012
# Processing year 2013
# All files already exist for gauge 1222 and year 2013
# Processing year 2014
# All files already exist for gauge 1222 and year 2014
# Processing year 2015
# All files already exist for gauge 1222 and year 2015
# Processing year 2016
# All files already exist for gauge 1222 and year 2016
# Processing year 2017
# All files already exist for gauge 1222 and year 2017
# Processing year 2018
# All files already exist for gauge 1222 and year 2018
# Processing year 2019
# All files already exist for gauge 1222 and year 2019
# Processing year 2020
# All files already exist for gauge 1222 and year 2020
# Processing gauge 1223
# (431, 249)
# Processing year 2006
# All files already exist for gauge 1223 and year 2006
# Processing year 2007
# All files already exist for gauge 1223 and year 2007
# Processing year 2008
# All files already exist for gauge 1223 and year 2008
# Processing year 2009
# All files already exist for gauge 1223 and year 2009
# Processing year 2010
# All files already exist for gauge 1223 and year 2010
# Processing year 2011
# All files already exist for gauge 1223 and year 2011
# Processing year 2012
# All files already exist for gauge 1223 and year 2012
# Processing year 2013
# All files already exist for gauge 1223 and year 2013
# Processing year 2014
# All files already exist for gauge 1223 and year 2014
# Processing year 2015
# All files already exist for gauge 1223 and year 2015
# Processing year 2016
# All files already exist for gauge 1223 and year 2016
# Processing year 2017
# All files already exist for gauge 1223 and year 2017
# Processing year 2018
# All files already exist for gauge 1223 and year 2018
# Processing year 2019
# All files already exist for gauge 1223 and year 2019
# Processing year 2020
# All files already exist for gauge 1223 and year 2020
# Processing gauge 1224
# (379, 263)
# Processing year 2006
# All files already exist for gauge 1224 and year 2006
# Processing year 2007
# All files already exist for gauge 1224 and year 2007
# Processing year 2008
# All files already exist for gauge 1224 and year 2008
# Processing year 2009
# All files already exist for gauge 1224 and year 2009
# Processing year 2010
# All files already exist for gauge 1224 and year 2010
# Processing year 2011
# All files already exist for gauge 1224 and year 2011
# Processing year 2012
# All files already exist for gauge 1224 and year 2012
# Processing year 2013
# All files already exist for gauge 1224 and year 2013
# Processing year 2014
# All files already exist for gauge 1224 and year 2014
# Processing year 2015
# All files already exist for gauge 1224 and year 2015
# Processing year 2016
# All files already exist for gauge 1224 and year 2016
# Processing year 2017
# All files already exist for gauge 1224 and year 2017
# Processing year 2018
# All files already exist for gauge 1224 and year 2018
# Processing year 2019
# All files already exist for gauge 1224 and year 2019
# Processing year 2020
# All files already exist for gauge 1224 and year 2020
# Processing gauge 1225
# (357, 247)
# Processing year 2006
# All files already exist for gauge 1225 and year 2006
# Processing year 2007
# All files already exist for gauge 1225 and year 2007
# Processing year 2008
# All files already exist for gauge 1225 and year 2008
# Processing year 2009
# All files already exist for gauge 1225 and year 2009
# Processing year 2010
# All files already exist for gauge 1225 and year 2010
# Processing year 2011
# All files already exist for gauge 1225 and year 2011
# Processing year 2012
# All files already exist for gauge 1225 and year 2012
# Processing year 2013
# All files already exist for gauge 1225 and year 2013
# Processing year 2014
# All files already exist for gauge 1225 and year 2014
# Processing year 2015
# All files already exist for gauge 1225 and year 2015
# Processing year 2016
# All files already exist for gauge 1225 and year 2016
# Processing year 2017
# All files already exist for gauge 1225 and year 2017
# Processing year 2018
# All files already exist for gauge 1225 and year 2018
# Processing year 2019
# All files already exist for gauge 1225 and year 2019
# Processing year 2020
# All files already exist for gauge 1225 and year 2020
# Processing gauge 1226
# (382, 258)
# Processing year 2006
# All files already exist for gauge 1226 and year 2006
# Processing year 2007
# All files already exist for gauge 1226 and year 2007
# Processing year 2008
# All files already exist for gauge 1226 and year 2008
# Processing year 2009
# All files already exist for gauge 1226 and year 2009
# Processing year 2010
# All files already exist for gauge 1226 and year 2010
# Processing year 2011
# All files already exist for gauge 1226 and year 2011
# Processing year 2012
# All files already exist for gauge 1226 and year 2012
# Processing year 2013
# All files already exist for gauge 1226 and year 2013
# Processing year 2014
# All files already exist for gauge 1226 and year 2014
# Processing year 2015
# All files already exist for gauge 1226 and year 2015
# Processing year 2016
# All files already exist for gauge 1226 and year 2016
# Processing year 2017
# All files already exist for gauge 1226 and year 2017
# Processing year 2018
# All files already exist for gauge 1226 and year 2018
# Processing year 2019
# All files already exist for gauge 1226 and year 2019
# Processing year 2020
# All files already exist for gauge 1226 and year 2020
# Processing gauge 1227
# (301, 241)
# Processing year 2006
# All files already exist for gauge 1227 and year 2006
# Processing year 2007
# All files already exist for gauge 1227 and year 2007
# Processing year 2008
# All files already exist for gauge 1227 and year 2008
# Processing year 2009
# All files already exist for gauge 1227 and year 2009
# Processing year 2010
# All files already exist for gauge 1227 and year 2010
# Processing year 2011
# All files already exist for gauge 1227 and year 2011
# Processing year 2012
# All files already exist for gauge 1227 and year 2012
# Processing year 2013
# All files already exist for gauge 1227 and year 2013
# Processing year 2014
# All files already exist for gauge 1227 and year 2014
# Processing year 2015
# All files already exist for gauge 1227 and year 2015
# Processing year 2016
# All files already exist for gauge 1227 and year 2016
# Processing year 2017
# All files already exist for gauge 1227 and year 2017
# Processing year 2018
# All files already exist for gauge 1227 and year 2018
# Processing year 2019
# All files already exist for gauge 1227 and year 2019
# Processing year 2020
# All files already exist for gauge 1227 and year 2020
# Processing gauge 1228
# (272, 256)
# Processing year 2006
# All files already exist for gauge 1228 and year 2006
# Processing year 2007
# All files already exist for gauge 1228 and year 2007
# Processing year 2008
# All files already exist for gauge 1228 and year 2008
# Processing year 2009
# All files already exist for gauge 1228 and year 2009
# Processing year 2010
# All files already exist for gauge 1228 and year 2010
# Processing year 2011
# All files already exist for gauge 1228 and year 2011
# Processing year 2012
# All files already exist for gauge 1228 and year 2012
# Processing year 2013
# ...
# Processing year 2017
# All files already exist for gauge 1281 and year 2017
# Processing year 2018
# All files already exist for gauge 1281 and year 2018
# Processing year 2019
# All files already exist for gauge 1281 and year 2019
# Processing year 2020
# All files already exist for gauge 1281 and year 2020
# Processing gauge 1282
# (291, 229)
# Processing year 2006
# All files already exist for gauge 1282 and year 2006
# Processing year 2007
# All files already exist for gauge 1282 and year 2007
# Processing year 2008
# All files already exist for gauge 1282 and year 2008
# Processing year 2009
# All files already exist for gauge 1282 and year 2009
# Processing year 2010
# All files already exist for gauge 1282 and year 2010
# Processing year 2011
# All files already exist for gauge 1282 and year 2011
# Processing year 2012
# All files already exist for gauge 1282 and year 2012
# Processing year 2013
# All files already exist for gauge 1282 and year 2013
# Processing year 2014
# All files already exist for gauge 1282 and year 2014
# Processing year 2015
# All files already exist for gauge 1282 and year 2015
# Processing year 2016
# All files already exist for gauge 1282 and year 2016
# Processing year 2017
# All files already exist for gauge 1282 and year 2017
# Processing year 2018
# All files already exist for gauge 1282 and year 2018
# Processing year 2019
# All files already exist for gauge 1282 and year 2019
# Processing year 2020
# All files already exist for gauge 1282 and year 2020
# Processing gauge 1283
# (297, 225)
# Processing year 2006
# All files already exist for gauge 1283 and year 2006
# Processing year 2007
# All files already exist for gauge 1283 and year 2007
# Processing year 2008
# All files already exist for gauge 1283 and year 2008
# Processing year 2009
# All files already exist for gauge 1283 and year 2009
# Processing year 2010
# All files already exist for gauge 1283 and year 2010
# Processing year 2011
# All files already exist for gauge 1283 and year 2011
# Processing year 2012
# All files already exist for gauge 1283 and year 2012
# Processing year 2013
# All files already exist for gauge 1283 and year 2013
# Processing year 2014
# All files already exist for gauge 1283 and year 2014
# Processing year 2015
# All files already exist for gauge 1283 and year 2015
# Processing year 2016
# All files already exist for gauge 1283 and year 2016
# Processing year 2017
# All files already exist for gauge 1283 and year 2017
# Processing year 2018
# All files already exist for gauge 1283 and year 2018
# Processing year 2019
# All files already exist for gauge 1283 and year 2019
# Processing year 2020
# All files already exist for gauge 1283 and year 2020
# Processing gauge 1284
# (401, 228)
# Processing year 2006
# All files already exist for gauge 1284 and year 2006
# Processing year 2007
# All files already exist for gauge 1284 and year 2007
# Processing year 2008
# All files already exist for gauge 1284 and year 2008
# Processing year 2009
# All files already exist for gauge 1284 and year 2009
# Processing year 2010
# All files already exist for gauge 1284 and year 2010
# Processing year 2011
# All files already exist for gauge 1284 and year 2011
# Processing year 2012
# All files already exist for gauge 1284 and year 2012
# Processing year 2013
# All files already exist for gauge 1284 and year 2013
# Processing year 2014
# All files already exist for gauge 1284 and year 2014
# Processing year 2015
# All files already exist for gauge 1284 and year 2015
# Processing year 2016
# All files already exist for gauge 1284 and year 2016
# Processing year 2017
# All files already exist for gauge 1284 and year 2017
# Processing year 2018
# All files already exist for gauge 1284 and year 2018
# Processing year 2019
# All files already exist for gauge 1284 and year 2019
# Processing year 2020
# All files already exist for gauge 1284 and year 2020
# Processing gauge 1285
# (294, 251)
# Processing year 2006
# All files already exist for gauge 1285 and year 2006
# Processing year 2007
# All files already exist for gauge 1285 and year 2007
# Processing year 2008
# All files already exist for gauge 1285 and year 2008
# Processing year 2009
# All files already exist for gauge 1285 and year 2009
# Processing year 2010
# All files already exist for gauge 1285 and year 2010
# Processing year 2011
# All files already exist for gauge 1285 and year 2011
# Processing year 2012
# All files already exist for gauge 1285 and year 2012
# Processing year 2013
# All files already exist for gauge 1285 and year 2013
# Processing year 2014
# All files already exist for gauge 1285 and year 2014
# Processing year 2015
# All files already exist for gauge 1285 and year 2015
# Processing year 2016
# All files already exist for gauge 1285 and year 2016
# Processing year 2017
# All files already exist for gauge 1285 and year 2017
# Processing year 2018
# All files already exist for gauge 1285 and year 2018
# Processing year 2019
# All files already exist for gauge 1285 and year 2019
# Processing year 2020
# All files already exist for gauge 1285 and year 2020
# Processing gauge 1286
# (377, 245)
# Processing year 2006
# All files already exist for gauge 1286 and year 2006
# Processing year 2007
# All files already exist for gauge 1286 and year 2007
# Processing year 2008
# All files already exist for gauge 1286 and year 2008
# Processing year 2009
# All files already exist for gauge 1286 and year 2009
# Processing year 2010
# All files already exist for gauge 1286 and year 2010
# Processing year 2011
# All files already exist for gauge 1286 and year 2011
# Processing year 2012
# All files already exist for gauge 1286 and year 2012
# Processing year 2013
# All files already exist for gauge 1286 and year 2013
# Processing year 2014
# All files already exist for gauge 1286 and year 2014
# Processing year 2015
# All files already exist for gauge 1286 and year 2015
# Processing year 2016
# All files already exist for gauge 1286 and year 2016
# Processing year 2017
# All files already exist for gauge 1286 and year 2017
# Processing year 2018
# All files already exist for gauge 1286 and year 2018
# Processing year 2019
# All files already exist for gauge 1286 and year 2019
# Processing year 2020
# All files already exist for gauge 1286 and year 2020
# Processing gauge 1287
# (314, 273)
# Processing year 2006
# All files already exist for gauge 1287 and year 2006
# Processing year 2007
# All files already exist for gauge 1287 and year 2007
# Processing year 2008
# All files already exist for gauge 1287 and year 2008
# Processing year 2009
# All files already exist for gauge 1287 and year 2009
# Processing year 2010
# All files already exist for gauge 1287 and year 2010
# Processing year 2011
# All files already exist for gauge 1287 and year 2011
# Processing year 2012
# All files already exist for gauge 1287 and year 2012
# Processing year 2013
# All files already exist for gauge 1287 and year 2013
# Processing year 2014
# All files already exist for gauge 1287 and year 2014
# Processing year 2015
# All files already exist for gauge 1287 and year 2015
# Processing year 2016
# All files already exist for gauge 1287 and year 2016
# Processing year 2017
# All files already exist for gauge 1287 and year 2017
# Processing year 2018
# All files already exist for gauge 1287 and year 2018
# Processing year 2019
# All files already exist for gauge 1287 and year 2019
# Processing year 2020
# All files already exist for gauge 1287 and year 2020
# Processing gauge 1288
# (261, 225)
# Processing year 2006
# All files already exist for gauge 1288 and year 2006
# Processing year 2007
# All files already exist for gauge 1288 and year 2007
# Processing year 2008
# All files already exist for gauge 1288 and year 2008
# Processing year 2009
# All files already exist for gauge 1288 and year 2009
# Processing year 2010
# All files already exist for gauge 1288 and year 2010
# Processing year 2011
# All files already exist for gauge 1288 and year 2011
# Processing year 2012
# All files already exist for gauge 1288 and year 2012
# Processing year 2013
# All files already exist for gauge 1288 and year 2013
# Processing year 2014
# All files already exist for gauge 1288 and year 2014
# Processing year 2015
# All files already exist for gauge 1288 and year 2015
# Processing year 2016
# All files already exist for gauge 1288 and year 2016
# Processing year 2017
# All files already exist for gauge 1288 and year 2017
# Processing year 2018
# All files already exist for gauge 1288 and year 2018
# Processing year 2019
# All files already exist for gauge 1288 and year 2019
# Processing year 2020
# All files already exist for gauge 1288 and year 2020
# Processing gauge 1289
# (246, 243)
# Processing year 2006
# All files already exist for gauge 1289 and year 2006
# Processing year 2007
# All files already exist for gauge 1289 and year 2007
# Processing year 2008
# All files already exist for gauge 1289 and year 2008
# Processing year 2009
# All files already exist for gauge 1289 and year 2009
# Processing year 2010
# All files already exist for gauge 1289 and year 2010
# Processing year 2011
# All files already exist for gauge 1289 and year 2011
# Processing year 2012
# All files already exist for gauge 1289 and year 2012
# Processing year 2013
# All files already exist for gauge 1289 and year 2013
# Processing year 2014
# All files already exist for gauge 1289 and year 2014
# Processing year 2015
# All files already exist for gauge 1289 and year 2015
# Processing year 2016
# All files already exist for gauge 1289 and year 2016
# Processing year 2017
# All files already exist for gauge 1289 and year 2017
# Processing year 2018
# All files already exist for gauge 1289 and year 2018
# Processing year 2019
# All files already exist for gauge 1289 and year 2019
# Processing year 2020
# All files already exist for gauge 1289 and year 2020
# Processing gauge 1290
# (265, 274)
# Processing year 2006
# All files already exist for gauge 1290 and year 2006
# Processing year 2007
# All files already exist for gauge 1290 and year 2007
# Processing year 2008
# All files already exist for gauge 1290 and year 2008
# Processing year 2009
# All files already exist for gauge 1290 and year 2009
# Processing year 2010
# All files already exist for gauge 1290 and year 2010
# Processing year 2011
# All files already exist for gauge 1290 and year 2011
# Processing year 2012
# All files already exist for gauge 1290 and year 2012
# Processing year 2013
# All files already exist for gauge 1290 and year 2013
# Processing year 2014
# All files already exist for gauge 1290 and year 2014
# Processing year 2015
# All files already exist for gauge 1290 and year 2015
# Processing year 2016
# All files already exist for gauge 1290 and year 2016
# Processing year 2017
# All files already exist for gauge 1290 and year 2017
# Processing year 2018
# All files already exist for gauge 1290 and year 2018
# Processing year 2019
# All files already exist for gauge 1290 and year 2019
# Processing year 2020
# All files already exist for gauge 1290 and year 2020
# Processing gauge 1291
# (450, 278)
# Processing year 2006
# All files already exist for gauge 1291 and year 2006
# Processing year 2007
# All files already exist for gauge 1291 and year 2007
# Processing year 2008
# All files already exist for gauge 1291 and year 2008
# Processing year 2009
# All files already exist for gauge 1291 and year 2009
# Processing year 2010
# All files already exist for gauge 1291 and year 2010
# Processing year 2011
# All files already exist for gauge 1291 and year 2011
# Processing year 2012
# All files already exist for gauge 1291 and year 2012
# Processing year 2013
# All files already exist for gauge 1291 and year 2013
# Processing year 2014
# All files already exist for gauge 1291 and year 2014
# Processing year 2015
# All files already exist for gauge 1291 and year 2015
# Processing year 2016
# All files already exist for gauge 1291 and year 2016
# Processing year 2017
# All files already exist for gauge 1291 and year 2017
# Processing year 2018
# All files already exist for gauge 1291 and year 2018
# Processing year 2019
# All files already exist for gauge 1291 and year 2019
# Processing year 2020
# All files already exist for gauge 1291 and year 2020
# Processing gauge 1292
# (307, 236)
# Processing year 2006
# All files already exist for gauge 1292 and year 2006
# Processing year 2007
# All files already exist for gauge 1292 and year 2007
# Processing year 2008
# All files already exist for gauge 1292 and year 2008
# Processing year 2009
# All files already exist for gauge 1292 and year 2009
# Processing year 2010
# All files already exist for gauge 1292 and year 2010
# Processing year 2011
# All files already exist for gauge 1292 and year 2011
# Processing year 2012
# All files already exist for gauge 1292 and year 2012
# Processing year 2013
# All files already exist for gauge 1292 and year 2013
# Processing year 2014
# All files already exist for gauge 1292 and year 2014
# Processing year 2015
# All files already exist for gauge 1292 and year 2015
# Processing year 2016
# All files already exist for gauge 1292 and year 2016
# Processing year 2017
# All files already exist for gauge 1292 and year 2017
# Processing year 2018
# All files already exist for gauge 1292 and year 2018
# Processing year 2019
# All files already exist for gauge 1292 and year 2019
# Processing year 2020
# All files already exist for gauge 1292 and year 2020
# Processing gauge 1293
# (299, 268)
# Processing year 2006
# All files already exist for gauge 1293 and year 2006
# Processing year 2007
# All files already exist for gauge 1293 and year 2007
# Processing year 2008
# All files already exist for gauge 1293 and year 2008
# Processing year 2009
# All files already exist for gauge 1293 and year 2009
# Processing year 2010
# All files already exist for gauge 1293 and year 2010
# Processing year 2011
# All files already exist for gauge 1293 and year 2011
# Processing year 2012
# All files already exist for gauge 1293 and year 2012
# Processing year 2013
# All files already exist for gauge 1293 and year 2013
# Processing year 2014
# All files already exist for gauge 1293 and year 2014
# Processing year 2015
# All files already exist for gauge 1293 and year 2015
# Processing year 2016
# All files already exist for gauge 1293 and year 2016
# Processing year 2017
# All files already exist for gauge 1293 and year 2017
# Processing year 2018
# All files already exist for gauge 1293 and year 2018
# Processing year 2019
# All files already exist for gauge 1293 and year 2019
# Processing year 2020
# All files already exist for gauge 1293 and year 2020
# Processing gauge 1294
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_76109/253865722.py in <module>
#      36
#      37         # Find the Tb0 and index of this gauge
# ---> 38         Tb0, idx_2d = find_gauge_Tb0_and_location_in_grid(gauge_num, sample_cube)
#      39
#      40         # Loop through gauges
#
# /tmp/ipykernel_76109/1921568155.py in find_gauge_Tb0_and_location_in_grid(gauge_num, sample_cube)
#      31 def find_gauge_Tb0_and_location_in_grid(gauge_num, sample_cube):
#      32     # Get data just for this gauge
# ---> 33     gauge1 = tbo_vals.iloc[gauge_num]
#      34     # Find the interevent arrival time (Tb0)
#      35     Tb0 = int(gauge1['Critical_interarrival_time'])
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds
