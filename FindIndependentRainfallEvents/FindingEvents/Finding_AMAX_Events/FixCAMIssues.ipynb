# %%
import os
from collections import defaultdict
import pandas as pd

# %%
em = 'bb189'
time_period = 'Future'

# %%
home_dir = '/nfs/a319/gy17m2a/PhD/'
home_dir2 = '/nfs/a161/gy17m2a/PhD/'

# %%
ems_present = ['bc005', 'bc006', 'bc007', 'bc009', 'bc010', 'bc011', 'bc012', 'bc013', 'bc015', 'bc016', 'bc017', 'bc018']
ems_present = ['bc006']

# %%
for em in [em]:
    for gauge_num in range(0,1294):
        if gauge_num not in [444, 827, 888]:
            # Directory containing the files
            directory_path = home_dir2 + f'ProcessedData/IndependentEvents/UKCP18_30mins/{time_period}/{em}/{gauge_num}/WholeYear/EventSet/'

            # Dictionary to group files with similar names (excluding the 'part' identifier)
            file_groups = defaultdict(list)

            # Loop through all the files in the directory
            for filename in os.listdir(directory_path):
                if filename.endswith('.csv'):
                    # Remove the part of the filename that specifies 'partX'
                    base_name = filename.rsplit('_part', 1)[0]

                    # Add the file to its corresponding group in the dictionary
                    file_groups[base_name].append(filename)

            # Extract and check pairs where we have both part0 and part1
            for base_name, files in file_groups.items():
                
                if len(files) == 2 and any('part0' in f for f in files) and any('part1' in f for f in files):
                    # Sort files so that 'part0' comes first, 'part1' comes second
                    sorted_files = sorted(files, key=lambda x: 'part0' not in x) # 'part0' comes first
                    # print(sorted_files)
                    
                    # Print sorted files to confirm the order
                    print(f"Found pair: {sorted_files[0]}, {sorted_files[1]}")

                    part0 = pd.read_csv(directory_path + sorted_files[0])
                    part1 = pd.read_csv(directory_path + sorted_files[1])

                    col_part0 = part0['Unnamed: 0']
                    col_part1 = part1['Unnamed: 0']
                    
                    if 'part0' in sorted_files[1]:
                        print("'part0' is in the second file")
                        break
                        
                    # Find the overlapping values between the two columns
                    overlapping_values = set(col_part0).intersection(set(col_part1))
                    if len(overlapping_values) == 0:
                        print(f"No values are overlapping {gauge_num}")
                        
                    else:
                        # Check if part1 contains only overlapping values
                        if set(col_part1).issubset(overlapping_values):
                            print(f"-- All values are overlapping. Deleting {sorted_files[1]}")
                            os.remove(directory_path + sorted_files[1])
                        else:
                            print(f"-- Non-overlapping values exist; after filtering:")
                            # Filter part1 to exclude overlapping rows
                            part1_filtered = part1[~part1['Unnamed: 0'].isin(overlapping_values)]
                            # print(f"Filtered part1 (non-overlapping rows):\n{part1_filtered}")

                            # Print the first and last index of part0 and part1_filtered for verification
                            print(f"---- part0: First index = {part0['Unnamed: 0'].iloc[0]}, Last index = {part0['Unnamed: 0'].iloc[-1]}")
                            print(f"---- part1_filtered: First index = {part1_filtered['Unnamed: 0'].iloc[0]}, Last index = {part1_filtered['Unnamed: 0'].iloc[-1]}")

                            ## Check if filtered still has any non zero values
                            count_over_005 = part1_filtered[part1_filtered['precipitation (mm)'] > 0.05].shape[0]
                            if count_over_005 >0:
                                print(f"----- Saving {gauge_num}")
                                part1_filtered.to_csv(directory_path + sorted_files[1], index=False)
                            else:
                                print("----- All 0 values, deleting sorted_files[1]")
                                os.remove(directory_path + sorted_files[1])
# Out:
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10924, Last index = 10953
# ---- part1_filtered: First index = 10954, Last index = 10973
# ----- Saving 0
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7556, Last index = 7587
# ---- part1_filtered: First index = 7588, Last index = 7603
# ----- Saving 0
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2062_v2_part1.csv
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13751, Last index = 13807
# ---- part1_filtered: First index = 13808, Last index = 13827
# ----- Saving 1
# Found pair: 12hrs_2069_v2_part0.csv, 12hrs_2069_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 6165, Last index = 6187
# ---- part1_filtered: First index = 6188, Last index = 6188
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 6124, Last index = 6169
# ---- part1_filtered: First index = 6170, Last index = 6171
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2078_v2_part1.csv
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8147, Last index = 8191
# ---- part1_filtered: First index = 8192, Last index = 8194
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13499, Last index = 13538
# ---- part1_filtered: First index = 13539, Last index = 13546
# ----- Saving 2
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 16237, Last index = 16277
# ---- part1_filtered: First index = 16278, Last index = 16284
# ----- Saving 2
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9772, Last index = 9810
# ---- part1_filtered: First index = 9811, Last index = 9843
# ----- Saving 2
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9034, Last index = 9075
# ---- part1_filtered: First index = 9076, Last index = 9081
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 12hrs_2078_v2_part0.csv, 12hrs_2078_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9854, Last index = 9877
# ---- part1_filtered: First index = 9878, Last index = 9878
# ----- Saving 2
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 6501, Last index = 6531
# ---- part1_filtered: First index = 6532, Last index = 6548
# ----- Saving 3
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2069_v2_part1.csv
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7742, Last index = 7812
# ---- part1_filtered: First index = 7813, Last index = 7813
# ----- Saving 3
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2061_v2_part1.csv
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7985, Last index = 8021
# ---- part1_filtered: First index = 8022, Last index = 8032
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8997, Last index = 9033
# ---- part1_filtered: First index = 9034, Last index = 9044
# ----- Saving 5
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2070_v2_part1.csv
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7858, Last index = 7889
# ---- part1_filtered: First index = 7890, Last index = 7906
# ----- Saving 5
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 4932, Last index = 4973
# ---- part1_filtered: First index = 4974, Last index = 4979
# ----- Saving 5
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2079_v2_part1.csv
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2062_v2_part1.csv
# Found pair: 12hrs_2078_v2_part0.csv, 12hrs_2078_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2078_v2_part1.csv
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2065_v2_part1.csv
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9056, Last index = 9072
# ---- part1_filtered: First index = 9073, Last index = 9103
# ----- Saving 6
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2077_v2_part1.csv
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9688, Last index = 9730
# ---- part1_filtered: First index = 9731, Last index = 9735
# ----- Saving 6
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8159, Last index = 8190
# ---- part1_filtered: First index = 8191, Last index = 8206
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7027, Last index = 7066
# ---- part1_filtered: First index = 7067, Last index = 7074
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2063_v2_part1.csv
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9434, Last index = 9471
# ---- part1_filtered: First index = 9472, Last index = 9481
# ----- Saving 8
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11595, Last index = 11616
# ---- part1_filtered: First index = 11617, Last index = 11650
# ----- Saving 8
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 12789, Last index = 12827
# ---- part1_filtered: First index = 12828, Last index = 12836
# ----- Saving 8
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11995, Last index = 12038
# ---- part1_filtered: First index = 12039, Last index = 12042
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 12hrs_2073_v2_part0.csv, 12hrs_2073_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8075, Last index = 8095
# ---- part1_filtered: First index = 8096, Last index = 8098
# ----- Saving 8
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8089, Last index = 8108
# ---- part1_filtered: First index = 8109, Last index = 8151
# ----- Saving 8
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10442, Last index = 10456
# ---- part1_filtered: First index = 10457, Last index = 10489
# ----- Saving 10
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11561, Last index = 11602
# ---- part1_filtered: First index = 11603, Last index = 11608
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 15515, Last index = 15569
# ---- part1_filtered: First index = 15570, Last index = 15574
# ----- Saving 10
# Found pair: 6hrs_2066_v2_part0.csv, 6hrs_2066_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9667, Last index = 9677
# ---- part1_filtered: First index = 9678, Last index = 9678
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 12hrs_2065_v2_part0.csv, 12hrs_2065_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2065_v2_part1.csv
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11560, Last index = 11602
# ---- part1_filtered: First index = 11603, Last index = 11607
# ----- Saving 11
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 15515, Last index = 15571
# ---- part1_filtered: First index = 15572, Last index = 15572
# ----- Saving 11
# Found pair: 12hrs_2062_v2_part0.csv, 12hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 6680, Last index = 6697
# ---- part1_filtered: First index = 6698, Last index = 6703
# ----- Saving 12
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 6690, Last index = 6708
# ---- part1_filtered: First index = 6709, Last index = 6737
# ----- Saving 12
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 15750, Last index = 15790
# ---- part1_filtered: First index = 15791, Last index = 15797
# ----- Saving 12
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11562, Last index = 11601
# ---- part1_filtered: First index = 11602, Last index = 11609
# ----- Saving 12
# Found pair: 12hrs_2067_v2_part0.csv, 12hrs_2067_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8481, Last index = 8514
# ---- part1_filtered: First index = 8515, Last index = 8516
# ----- Saving 12
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8468, Last index = 8514
# ---- part1_filtered: First index = 8515, Last index = 8516
# ----- Saving 12
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2061_v2_part1.csv
# Found pair: 12hrs_2062_v2_part0.csv, 12hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8463, Last index = 8481
# ---- part1_filtered: First index = 8482, Last index = 8486
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8470, Last index = 8489
# ---- part1_filtered: First index = 8490, Last index = 8517
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 14557, Last index = 14595
# ---- part1_filtered: First index = 14596, Last index = 14604
# ----- Saving 13
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13815, Last index = 13850
# ---- part1_filtered: First index = 13851, Last index = 13863
# ----- Saving 13
# Found pair: 12hrs_2064_v2_part0.csv, 12hrs_2064_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2064_v2_part1.csv
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2064_v2_part1.csv
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 16178, Last index = 16203
# ---- part1_filtered: First index = 16204, Last index = 16237
# ----- Saving 13
# Found pair: 6hrs_2068_v2_part0.csv, 6hrs_2068_v2_part1.csv
# -- All values are overlapping. Deleting 6hrs_2068_v2_part1.csv
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8933, Last index = 8981
# ---- part1_filtered: First index = 8982, Last index = 8982
# ----- Saving 13
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10114, Last index = 10124
# ---- part1_filtered: First index = 10125, Last index = 10161
# ----- Saving 13
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11213, Last index = 11256
# ---- part1_filtered: First index = 11257, Last index = 11260
# ----- Saving 14
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9626, Last index = 9649
# ---- part1_filtered: First index = 9650, Last index = 9673
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2077_v2_part1.csv
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8086, Last index = 8107
# ---- part1_filtered: First index = 8108, Last index = 8152
# ----- Saving 14
# Found pair: 12hrs_2062_v2_part0.csv, 12hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10337, Last index = 10353
# ---- part1_filtered: First index = 10354, Last index = 10360
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7238, Last index = 7247
# ---- part1_filtered: First index = 7248, Last index = 7286
# ----- Saving 15
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9060, Last index = 9069
# ---- part1_filtered: First index = 9070, Last index = 9107
# ----- Saving 15
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2075_v2_part1.csv
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 6527, Last index = 6542
# ---- part1_filtered: First index = 6543, Last index = 6583
# ----- Saving 16
# Found pair: 6hrs_2078_v2_part0.csv, 6hrs_2078_v2_part1.csv
# -- All values are overlapping. Deleting 6hrs_2078_v2_part1.csv
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9725, Last index = 9742
# ---- part1_filtered: First index = 9743, Last index = 9773
# ----- Saving 16
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11558, Last index = 11602
# ---- part1_filtered: First index = 11603, Last index = 11605
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 16689, Last index = 16729
# ---- part1_filtered: First index = 16730, Last index = 16754
# ----- Saving 16
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 12794, Last index = 12827
# ---- part1_filtered: First index = 12828, Last index = 12841
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10119, Last index = 10162
# ---- part1_filtered: First index = 10163, Last index = 10166
# ----- Saving 17
# Found pair: 12hrs_2063_v2_part0.csv, 12hrs_2063_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13649, Last index = 13672
# ---- part1_filtered: First index = 13673, Last index = 13673
# ----- Saving 17
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2065_v2_part1.csv
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2075_v2_part1.csv
# Found pair: 12hrs_2079_v2_part0.csv, 12hrs_2079_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 6798, Last index = 6820
# ---- part1_filtered: First index = 6821, Last index = 6821
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13771, Last index = 13817
# ---- part1_filtered: First index = 13818, Last index = 13818
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 12hrs_2063_v2_part0.csv, 12hrs_2063_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2063_v2_part1.csv
# Found pair: 12hrs_2078_v2_part0.csv, 12hrs_2078_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9844, Last index = 9866
# ---- part1_filtered: First index = 9867, Last index = 9867
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 12hrs_2078_v2_part0.csv, 12hrs_2078_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2078_v2_part1.csv
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9914, Last index = 9927
# ---- part1_filtered: First index = 9928, Last index = 9962
# ----- Saving 19
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 364, Last index = 380
# ---- part1_filtered: First index = 381, Last index = 418
# ----- Saving 19
# Found pair: 12hrs_2066_v2_part0.csv, 12hrs_2066_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2066_v2_part1.csv
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9243, Last index = 9262
# ---- part1_filtered: First index = 9263, Last index = 9302
# ----- Saving 19
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8854, Last index = 8875
# ---- part1_filtered: First index = 8876, Last index = 8906
# ----- Saving 19
# Found pair: 12hrs_2063_v2_part0.csv, 12hrs_2063_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2063_v2_part1.csv
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13652, Last index = 13681
# ---- part1_filtered: First index = 13682, Last index = 13699
# ----- Saving 20
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 350, Last index = 419
# ---- part1_filtered: First index = 420, Last index = 420
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 16178, Last index = 16234
# ---- part1_filtered: First index = 16235, Last index = 16236
# ----- Saving 21
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2062_v2_part1.csv
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 386, Last index = 429
# ---- part1_filtered: First index = 430, Last index = 434
# ----- Saving 22
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11960, Last index = 12006
# ---- part1_filtered: First index = 12007, Last index = 12007
# ----- Saving 22
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 1859, Last index = 1900
# ---- part1_filtered: First index = 1901, Last index = 1906
# ----- Saving 23
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 16696, Last index = 16731
# ---- part1_filtered: First index = 16732, Last index = 16755
# ----- Saving 23
# Found pair: 12hrs_2073_v2_part0.csv, 12hrs_2073_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2073_v2_part1.csv
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9540, Last index = 9578
# ---- part1_filtered: First index = 9579, Last index = 9609
# ----- Saving 23
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 378, Last index = 419
# ---- part1_filtered: First index = 420, Last index = 425
# ----- Saving 24
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2065_v2_part1.csv
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7704, Last index = 7736
# ---- part1_filtered: First index = 7737, Last index = 7751
# ----- Saving 25
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11940, Last index = 11995
# ---- part1_filtered: First index = 11996, Last index = 12007
# ----- Saving 25
# Found pair: 12hrs_2076_v2_part0.csv, 12hrs_2076_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2076_v2_part1.csv
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10819, Last index = 10835
# ---- part1_filtered: First index = 10836, Last index = 10866
# ----- Saving 26
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9448, Last index = 9461
# ---- part1_filtered: First index = 9462, Last index = 9495
# ----- Saving 26
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2073_v2_part1.csv
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13606, Last index = 13631
# ---- part1_filtered: First index = 13632, Last index = 13669
# ----- Saving 26
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10793, Last index = 10830
# ---- part1_filtered: First index = 10831, Last index = 10840
# ----- Saving 27
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13606, Last index = 13634
# ---- part1_filtered: First index = 13635, Last index = 13669
# ----- Saving 27
# Found pair: 12hrs_2076_v2_part0.csv, 12hrs_2076_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2076_v2_part1.csv
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 16258, Last index = 16293
# ---- part1_filtered: First index = 16294, Last index = 16305
# ----- Saving 28
# Found pair: 12hrs_2075_v2_part0.csv, 12hrs_2075_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2075_v2_part1.csv
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13606, Last index = 13634
# ---- part1_filtered: First index = 13635, Last index = 13669
# ----- Saving 28
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2061_v2_part1.csv
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9703, Last index = 9731
# ---- part1_filtered: First index = 9732, Last index = 9750
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 12hrs_2075_v2_part0.csv, 12hrs_2075_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2075_v2_part1.csv
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13604, Last index = 13634
# ---- part1_filtered: First index = 13635, Last index = 13670
# ----- Saving 29
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11209, Last index = 11254
# ---- part1_filtered: First index = 11255, Last index = 11256
# ----- Saving 30
# Found pair: 12hrs_2076_v2_part0.csv, 12hrs_2076_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2076_v2_part1.csv
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10819, Last index = 10867
# ---- part1_filtered: First index = 10868, Last index = 10868
# ----- Saving 30
# Found pair: 12hrs_2077_v2_part0.csv, 12hrs_2077_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9995, Last index = 10010
# ---- part1_filtered: First index = 10011, Last index = 10018
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9985, Last index = 10010
# ---- part1_filtered: First index = 10011, Last index = 10032
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 6889, Last index = 6935
# ---- part1_filtered: First index = 6936, Last index = 6936
# ----- Saving 30
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13657, Last index = 13681
# ---- part1_filtered: First index = 13682, Last index = 13712
# ----- Saving 31
# Found pair: 12hrs_2078_v2_part0.csv, 12hrs_2078_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9843, Last index = 9864
# ---- part1_filtered: First index = 9865, Last index = 9866
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 391, Last index = 430
# ---- part1_filtered: First index = 431, Last index = 439
# ----- Saving 31
# Found pair: 12hrs_2079_v2_part0.csv, 12hrs_2079_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9291, Last index = 9305
# ---- part1_filtered: First index = 9306, Last index = 9314
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9245, Last index = 9258
# ---- part1_filtered: First index = 9259, Last index = 9295
# ----- Saving 31
# Found pair: 12hrs_2074_v2_part0.csv, 12hrs_2074_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10383, Last index = 10405
# ---- part1_filtered: First index = 10406, Last index = 10406
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7368, Last index = 7381
# ---- part1_filtered: First index = 7382, Last index = 7423
# ----- Saving 32
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11201, Last index = 11213
# ---- part1_filtered: First index = 11214, Last index = 11257
# ----- Saving 32
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2071_v2_part1.csv
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2068_v2_part1.csv
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13605, Last index = 13631
# ---- part1_filtered: First index = 13632, Last index = 13668
# ----- Saving 32
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 901, Last index = 936
# ---- part1_filtered: First index = 937, Last index = 953
# ----- Saving 33
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2065_v2_part1.csv
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2075_v2_part1.csv
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2069_v2_part1.csv
# Found pair: 12hrs_2074_v2_part0.csv, 12hrs_2074_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10337, Last index = 10357
# ---- part1_filtered: First index = 10358, Last index = 10360
# ----- Saving 34
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9677, Last index = 9690
# ---- part1_filtered: First index = 9691, Last index = 9726
# ----- Saving 34
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9914, Last index = 9931
# ---- part1_filtered: First index = 9932, Last index = 9961
# ----- Saving 34
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 15694, Last index = 15739
# ---- part1_filtered: First index = 15740, Last index = 15741
# ----- Saving 34
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7245, Last index = 7277
# ---- part1_filtered: First index = 7278, Last index = 7293
# ----- Saving 34
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 14327, Last index = 14375
# ---- part1_filtered: First index = 14376, Last index = 14376
# ----- Saving 34
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13602, Last index = 13633
# ---- part1_filtered: First index = 13634, Last index = 13669
# ----- Saving 34
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10437, Last index = 10450
# ---- part1_filtered: First index = 10451, Last index = 10484
# ----- Saving 35
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 15701, Last index = 15741
# ---- part1_filtered: First index = 15742, Last index = 15748
# ----- Saving 35
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2067_v2_part1.csv
# Found pair: 12hrs_2068_v2_part0.csv, 12hrs_2068_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2068_v2_part1.csv
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13606, Last index = 13632
# ---- part1_filtered: First index = 13633, Last index = 13669
# ----- Saving 35
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11213, Last index = 11250
# ---- part1_filtered: First index = 11251, Last index = 11260
# ----- Saving 36
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10335, Last index = 10359
# ---- part1_filtered: First index = 10360, Last index = 10382
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 12hrs_2078_v2_part0.csv, 12hrs_2078_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2078_v2_part1.csv
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11314, Last index = 11325
# ---- part1_filtered: First index = 11326, Last index = 11361
# ----- Saving 36
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7579, Last index = 7606
# ---- part1_filtered: First index = 7607, Last index = 7640
# ----- Saving 36
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 14265, Last index = 14301
# ---- part1_filtered: First index = 14302, Last index = 14312
# ----- Saving 36
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2079_v2_part1.csv
# Found pair: 12hrs_2077_v2_part0.csv, 12hrs_2077_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9995, Last index = 10006
# ---- part1_filtered: First index = 10007, Last index = 10018
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13659, Last index = 13681
# ---- part1_filtered: First index = 13682, Last index = 13716
# ----- Saving 37
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2065_v2_part1.csv
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 371, Last index = 382
# ---- part1_filtered: First index = 383, Last index = 418
# ----- Saving 37
# Found pair: 12hrs_2063_v2_part0.csv, 12hrs_2063_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13649, Last index = 13671
# ---- part1_filtered: First index = 13672, Last index = 13672
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13659, Last index = 13681
# ---- part1_filtered: First index = 13682, Last index = 13716
# ----- Saving 38
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2074_v2_part1.csv
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2065_v2_part1.csv
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9695, Last index = 9736
# ---- part1_filtered: First index = 9737, Last index = 9742
# ----- Saving 38
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9912, Last index = 9931
# ---- part1_filtered: First index = 9932, Last index = 9959
# ----- Saving 39
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9211, Last index = 9248
# ---- part1_filtered: First index = 9249, Last index = 9258
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2069_v2_part1.csv
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9285, Last index = 9308
# ---- part1_filtered: First index = 9309, Last index = 9340
# ----- Saving 41
# Found pair: 12hrs_2066_v2_part0.csv, 12hrs_2066_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9213, Last index = 9232
# ---- part1_filtered: First index = 9233, Last index = 9247
# ----- Saving 41
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8241, Last index = 8256
# ---- part1_filtered: First index = 8257, Last index = 8288
# ----- Saving 41
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 1685, Last index = 1724
# ---- part1_filtered: First index = 1725, Last index = 1732
# ----- Saving 42
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 16805, Last index = 16832
# ---- part1_filtered: First index = 16833, Last index = 16852
# ----- Saving 42
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11828, Last index = 11870
# ---- part1_filtered: First index = 11871, Last index = 11875
# ----- Saving 42
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 15828, Last index = 15867
# ---- part1_filtered: First index = 15868, Last index = 15875
# ----- Saving 42
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2071_v2_part1.csv
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2069_v2_part1.csv
# Found pair: 12hrs_2076_v2_part0.csv, 12hrs_2076_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10711, Last index = 10733
# ---- part1_filtered: First index = 10734, Last index = 10734
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10731, Last index = 10745
# ---- part1_filtered: First index = 10746, Last index = 10780
# ----- Saving 44
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9444, Last index = 9487
# ---- part1_filtered: First index = 9488, Last index = 9491
# ----- Saving 44
# Found pair: 12hrs_2064_v2_part0.csv, 12hrs_2064_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7890, Last index = 7912
# ---- part1_filtered: First index = 7913, Last index = 7913
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7856, Last index = 7876
# ---- part1_filtered: First index = 7877, Last index = 7903
# ----- Saving 44
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 14247, Last index = 14302
# ---- part1_filtered: First index = 14303, Last index = 14306
# ----- Saving 44
# Found pair: 12hrs_2068_v2_part0.csv, 12hrs_2068_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2068_v2_part1.csv
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8479, Last index = 8522
# ---- part1_filtered: First index = 8523, Last index = 8526
# ----- Saving 45
# Found pair: 12hrs_2074_v2_part0.csv, 12hrs_2074_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10329, Last index = 10352
# ---- part1_filtered: First index = 10353, Last index = 10353
# ----- Saving 45
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10331, Last index = 10352
# ---- part1_filtered: First index = 10353, Last index = 10378
# ----- Saving 45
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2062_v2_part1.csv
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9916, Last index = 9935
# ---- part1_filtered: First index = 9936, Last index = 9963
# ----- Saving 46
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 15233, Last index = 15289
# ---- part1_filtered: First index = 15290, Last index = 15292
# ----- Saving 46
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2064_v2_part1.csv
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2069_v2_part1.csv
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 6694, Last index = 6742
# ---- part1_filtered: First index = 6743, Last index = 6743
# ----- Saving 47
# Found pair: 12hrs_2067_v2_part0.csv, 12hrs_2067_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8488, Last index = 8519
# ---- part1_filtered: First index = 8520, Last index = 8521
# ----- Saving 47
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8486, Last index = 8519
# ---- part1_filtered: First index = 8520, Last index = 8533
# ----- Saving 47
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2075_v2_part1.csv
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2069_v2_part1.csv
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2065_v2_part1.csv
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 17160, Last index = 17207
# ---- part1_filtered: First index = 17208, Last index = 17208
# ----- Saving 48
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 6318, Last index = 6361
# ---- part1_filtered: First index = 6362, Last index = 6365
# ----- Saving 48
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11427, Last index = 11441
# ---- part1_filtered: First index = 11442, Last index = 11474
# ----- Saving 49
# Found pair: 12hrs_2065_v2_part0.csv, 12hrs_2065_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2065_v2_part1.csv
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8096, Last index = 8150
# ---- part1_filtered: First index = 8151, Last index = 8153
# ----- Saving 49
# Found pair: 12hrs_2061_v2_part0.csv, 12hrs_2061_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11445, Last index = 11467
# ---- part1_filtered: First index = 11468, Last index = 11468
# ----- Saving 50
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11427, Last index = 11443
# ---- part1_filtered: First index = 11444, Last index = 11474
# ----- Saving 50
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2074_v2_part1.csv
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9956, Last index = 9976
# ---- part1_filtered: First index = 9977, Last index = 10010
# ----- Saving 50
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 200, Last index = 245
# ---- part1_filtered: First index = 246, Last index = 248
# ----- Saving 50
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 15960, Last index = 16021
# ---- part1_filtered: First index = 16022, Last index = 16022
# ----- Saving 51
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8482, Last index = 8521
# ---- part1_filtered: First index = 8522, Last index = 8529
# ----- Saving 51
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2072_v2_part1.csv
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10452, Last index = 10468
# ---- part1_filtered: First index = 10469, Last index = 10499
# ----- Saving 52
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 14030, Last index = 14056
# ---- part1_filtered: First index = 14057, Last index = 14090
# ----- Saving 52
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11301, Last index = 11331
# ---- part1_filtered: First index = 11332, Last index = 11351
# ----- Saving 52
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2071_v2_part1.csv
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 14897, Last index = 14938
# ---- part1_filtered: First index = 14939, Last index = 14944
# ----- Saving 53
# Found pair: 12hrs_2076_v2_part0.csv, 12hrs_2076_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2076_v2_part1.csv
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 15695, Last index = 15741
# ---- part1_filtered: First index = 15742, Last index = 15742
# ----- Saving 53
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 16389, Last index = 16433
# ---- part1_filtered: First index = 16434, Last index = 16436
# ----- Saving 53
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 14248, Last index = 14271
# ---- part1_filtered: First index = 14272, Last index = 14307
# ----- Saving 53
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2077_v2_part1.csv
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11943, Last index = 11976
# ---- part1_filtered: First index = 11977, Last index = 12000
# ----- Saving 53
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2072_v2_part1.csv
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10343, Last index = 10388
# ---- part1_filtered: First index = 10389, Last index = 10390
# ----- Saving 54
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# ...
# ---- part0: First index = 10303, Last index = 10321
# ---- part1_filtered: First index = 10322, Last index = 10356
# ----- Saving 1276
# Found pair: 12hrs_2075_v2_part0.csv, 12hrs_2075_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2075_v2_part1.csv
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10765, Last index = 10778
# ---- part1_filtered: First index = 10779, Last index = 10813
# ----- Saving 1276
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11768, Last index = 11805
# ---- part1_filtered: First index = 11806, Last index = 11815
# ----- Saving 1276
# Found pair: 12hrs_2072_v2_part0.csv, 12hrs_2072_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2072_v2_part1.csv
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13383, Last index = 13413
# ---- part1_filtered: First index = 13414, Last index = 13439
# ----- Saving 1277
# Found pair: 12hrs_2078_v2_part0.csv, 12hrs_2078_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2078_v2_part1.csv
# Found pair: 12hrs_2076_v2_part0.csv, 12hrs_2076_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10828, Last index = 10839
# ---- part1_filtered: First index = 10840, Last index = 10851
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10825, Last index = 10839
# ---- part1_filtered: First index = 10840, Last index = 10872
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7629, Last index = 7646
# ---- part1_filtered: First index = 7647, Last index = 7679
# ----- Saving 1278
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 14333, Last index = 14378
# ---- part1_filtered: First index = 14379, Last index = 14380
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 24, Last index = 68
# ---- part1_filtered: First index = 69, Last index = 71
# ----- Saving 1278
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 15409, Last index = 15456
# ---- part1_filtered: First index = 15457, Last index = 15457
# ----- Saving 1278
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7629, Last index = 7645
# ---- part1_filtered: First index = 7646, Last index = 7681
# ----- Saving 1279
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 23, Last index = 68
# ---- part1_filtered: First index = 69, Last index = 70
# ----- Saving 1279
# Found pair: 6hrs_2073_v2_part0.csv, 6hrs_2073_v2_part1.csv
# -- All values are overlapping. Deleting 6hrs_2073_v2_part1.csv
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 15409, Last index = 15451
# ---- part1_filtered: First index = 15452, Last index = 15457
# ----- Saving 1279
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2062_v2_part1.csv
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13648, Last index = 13679
# ---- part1_filtered: First index = 13680, Last index = 13695
# ----- Saving 1280
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2066_v2_part1.csv
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13158, Last index = 13169
# ---- part1_filtered: First index = 13170, Last index = 13206
# ----- Saving 1280
# Found pair: 12hrs_2072_v2_part0.csv, 12hrs_2072_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2072_v2_part1.csv
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7628, Last index = 7642
# ---- part1_filtered: First index = 7643, Last index = 7679
# ----- Saving 1281
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 578, Last index = 625
# ---- part1_filtered: First index = 626, Last index = 626
# ----- Saving 1281
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2065_v2_part1.csv
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10295, Last index = 10327
# ---- part1_filtered: First index = 10328, Last index = 10342
# ----- Saving 1281
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10532, Last index = 10551
# ---- part1_filtered: First index = 10552, Last index = 10583
# ----- Saving 1281
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- All values are overlapping. Deleting 24hrs_2062_v2_part1.csv
# Found pair: 12hrs_2065_v2_part0.csv, 12hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11669, Last index = 11692
# ---- part1_filtered: First index = 11693, Last index = 11693
# ----- Saving 1282
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11645, Last index = 11665
# ---- part1_filtered: First index = 11666, Last index = 11693
# ----- Saving 1282
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13623, Last index = 13668
# ---- part1_filtered: First index = 13669, Last index = 13670
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9929, Last index = 9973
# ---- part1_filtered: First index = 9974, Last index = 9976
# ----- Saving 1282
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7629, Last index = 7644
# ---- part1_filtered: First index = 7645, Last index = 7681
# ----- Saving 1283
# Found pair: 12hrs_2067_v2_part0.csv, 12hrs_2067_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10375, Last index = 10397
# ---- part1_filtered: First index = 10398, Last index = 10398
# ----- Saving 1283
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10387, Last index = 10408
# ---- part1_filtered: First index = 10409, Last index = 10434
# ----- Saving 1283
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9929, Last index = 9971
# ---- part1_filtered: First index = 9972, Last index = 9976
# ----- Saving 1283
# Found pair: 12hrs_2061_v2_part0.csv, 12hrs_2061_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10176, Last index = 10189
# ---- part1_filtered: First index = 10190, Last index = 10206
# ----- Saving 1284
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9955, Last index = 9973
# ---- part1_filtered: First index = 9974, Last index = 10002
# ----- Saving 1284
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9978, Last index = 10024
# ---- part1_filtered: First index = 10025, Last index = 10025
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10745, Last index = 10782
# ---- part1_filtered: First index = 10783, Last index = 10792
# ----- Saving 1285
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13147, Last index = 13176
# ---- part1_filtered: First index = 13177, Last index = 13194
# ----- Saving 1285
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9576, Last index = 9610
# ---- part1_filtered: First index = 9611, Last index = 9623
# ----- Saving 1286
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7636, Last index = 7655
# ---- part1_filtered: First index = 7656, Last index = 7687
# ----- Saving 1286
# Found pair: 12hrs_2078_v2_part0.csv, 12hrs_2078_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9902, Last index = 9914
# ---- part1_filtered: First index = 9915, Last index = 9925
# ----- Saving 1286
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9909, Last index = 9921
# ---- part1_filtered: First index = 9922, Last index = 9967
# ----- Saving 1286
# Found pair: 12hrs_2076_v2_part0.csv, 12hrs_2076_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10665, Last index = 10687
# ---- part1_filtered: First index = 10688, Last index = 10688
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10668, Last index = 10687
# ---- part1_filtered: First index = 10688, Last index = 10715
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 8764, Last index = 8782
# ---- part1_filtered: First index = 8783, Last index = 8816
# ----- Saving 1286
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7624, Last index = 7666
# ---- part1_filtered: First index = 7667, Last index = 7671
# ----- Saving 1287
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10607, Last index = 10653
# ---- part1_filtered: First index = 10654, Last index = 10654
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11461, Last index = 11502
# ---- part1_filtered: First index = 11503, Last index = 11508
# ----- Saving 1287
# Found pair: 12hrs_2061_v2_part0.csv, 12hrs_2061_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13684, Last index = 13706
# ---- part1_filtered: First index = 13707, Last index = 13707
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13684, Last index = 13706
# ---- part1_filtered: First index = 13707, Last index = 13731
# ----- Saving 1288
# Found pair: 12hrs_2063_v2_part0.csv, 12hrs_2063_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2063_v2_part1.csv
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 14217, Last index = 14232
# ---- part1_filtered: First index = 14233, Last index = 14265
# ----- Saving 1288
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 4137, Last index = 4159
# ---- part1_filtered: First index = 4160, Last index = 4200
# ----- Saving 1288
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 1406, Last index = 1432
# ---- part1_filtered: First index = 1433, Last index = 1455
# ----- Saving 1288
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 13604, Last index = 13623
# ---- part1_filtered: First index = 13624, Last index = 13653
# ----- Saving 1288
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 9636, Last index = 9648
# ---- part1_filtered: First index = 9649, Last index = 9683
# ----- Saving 1289
# Found pair: 12hrs_2062_v2_part0.csv, 12hrs_2062_v2_part1.csv
# -- All values are overlapping. Deleting 12hrs_2062_v2_part1.csv
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 7623, Last index = 7653
# ---- part1_filtered: First index = 7654, Last index = 7677
# ----- Saving 1289
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 17226, Last index = 17267
# ---- part1_filtered: First index = 17268, Last index = 17273
# ----- Saving 1289
# Found pair: 12hrs_2065_v2_part0.csv, 12hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11681, Last index = 11698
# ---- part1_filtered: First index = 11699, Last index = 11704
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 11679, Last index = 11698
# ---- part1_filtered: First index = 11699, Last index = 11726
# ----- All 0 values, deleting sorted_files[1]
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 6954, Last index = 6973
# ---- part1_filtered: First index = 6974, Last index = 7004
# ----- Saving 1289
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 16286, Last index = 16321
# ---- part1_filtered: First index = 16322, Last index = 16335
# ----- Saving 1289
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 14455, Last index = 14493
# ---- part1_filtered: First index = 14494, Last index = 14505
# ----- Saving 1290
# Found pair: 12hrs_2061_v2_part0.csv, 12hrs_2061_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 15301, Last index = 15323
# ---- part1_filtered: First index = 15324, Last index = 15324
# ----- Saving 1291
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10380, Last index = 10426
# ---- part1_filtered: First index = 10427, Last index = 10428
# ----- Saving 1291
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 5134, Last index = 5180
# ---- part1_filtered: First index = 5181, Last index = 5181
# ----- Saving 1291
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# -- Non-overlapping values exist; after filtering:
# ---- part0: First index = 10668, Last index = 10693
# ---- part1_filtered: First index = 10694, Last index = 10715
# ----- Saving 1293
