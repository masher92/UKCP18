# %%
import os
from collections import defaultdict
import pandas as pd

# %%
em = 'bb198'
time_period = 'Future'

# %%
home_dir = '/nfs/a319/gy17m2a/PhD/'
home_dir2 = '/nfs/a161/gy17m2a/PhD/'

# %%
ems_present = ['bc005', 'bc006', 'bc007', 'bc009', 'bc010', 'bc011', 'bc012', 'bc013', 'bc015', 'bc016', 'bc017', 'bc018']

# %%
for em in [em]:
    for gauge_num in range(0,1294):
        if gauge_num not in [444, 827, 888]:
            # Directory containing the files
            directory_path = home_dir2 + f'ProcessedData/IndependentEvents/UKCP18_30mins/{em}/{gauge_num}/WholeYear/EventSet/'

            # Dictionary to group files with similar names (excluding the 'part' identifier)
            file_groups = defaultdict(list)

            # Loop through all the files in the directory
            for filename in os.listdir(directory_path):
                if filename.endswith('.csv'):
                    # Remove the part of the filename that specifies 'partX'
                    base_name = filename.rsplit('_part', 1)[0]

                    # Add the file to its corresponding group in the dictionary
                    file_groups[base_name].append(filename)

            # Extract and check pairs where we have both part0 and part1
            for base_name, files in file_groups.items():
                
                if len(files) == 2 and any('part0' in f for f in files) and any('part1' in f for f in files):
                    # Sort files so that 'part0' comes first, 'part1' comes second
                    sorted_files = sorted(files, key=lambda x: 'part0' not in x) # 'part0' comes first
                    # print(sorted_files)
                    
                    # Print sorted files to confirm the order
                    print(f"Found pair: {sorted_files[0]}, {sorted_files[1]}")

                    part0 = pd.read_csv(directory_path + sorted_files[0])
                    part1 = pd.read_csv(directory_path + sorted_files[1])

                    col_part0 = part0['Unnamed: 0']
                    col_part1 = part1['Unnamed: 0']
                    
                    if 'part0' in sorted_files[1]:
                        print("'part0' is in the second file")
                        break
                        
                    # Find the overlapping values between the two columns
                    overlapping_values = set(col_part0).intersection(set(col_part1))
                    if len(overlapping_values) == 0:
                        print(f"No values are overlapping {gauge_num}")
                        
                    else:
                        # Check if part1 contains only overlapping values
                        if set(col_part1).issubset(overlapping_values):
                            print(f"-- All values are overlapping. Deleting {sorted_files[1]}")
                            os.remove(directory_path + sorted_files[1])
                        else:
                            print(f"-- Non-overlapping values exist; after filtering:")
                            # Filter part1 to exclude overlapping rows
                            part1_filtered = part1[~part1['Unnamed: 0'].isin(overlapping_values)]
                            # print(f"Filtered part1 (non-overlapping rows):\n{part1_filtered}")

                            # Print the first and last index of part0 and part1_filtered for verification
                            print(f"---- part0: First index = {part0['Unnamed: 0'].iloc[0]}, Last index = {part0['Unnamed: 0'].iloc[-1]}")
                            print(f"---- part1_filtered: First index = {part1_filtered['Unnamed: 0'].iloc[0]}, Last index = {part1_filtered['Unnamed: 0'].iloc[-1]}")

                            ## Check if filtered still has any non zero values
                            count_over_005 = part1_filtered[part1_filtered['precipitation (mm)'] > 0.05].shape[0]
                            if count_over_005 >0:
                                print(f"----- Saving {gauge_num}")
                                part1_filtered.to_csv(directory_path + sorted_files[1], index=False)
                            else:
                                print("----- All 0 values, deleting sorted_files[1]")
                                os.remove(directory_path + sorted_files[1])
# Out:
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 0
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 0
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# No values are overlapping 0
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 1
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 1
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 2
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 2
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 2
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 2
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 2
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 2
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 3
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 3
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 4
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 4
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 5
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 5
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 5
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 5
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 6
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 6
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 6
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 7
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 7
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 7
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 8
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 8
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 8
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 8
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 9
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 9
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 9
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 10
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 10
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 10
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 10
# Found pair: 12hrs_2072_v2_part0.csv, 12hrs_2072_v2_part1.csv
# No values are overlapping 10
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 10
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 11
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 11
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 11
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 12
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 12
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 12
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 13
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 13
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 13
# Found pair: 12hrs_2076_v2_part0.csv, 12hrs_2076_v2_part1.csv
# No values are overlapping 13
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 13
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 13
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# No values are overlapping 13
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 14
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 14
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 14
# Found pair: 12hrs_2071_v2_part0.csv, 12hrs_2071_v2_part1.csv
# No values are overlapping 14
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 14
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 14
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 15
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 15
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 16
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 16
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 16
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 16
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 16
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# No values are overlapping 16
# Found pair: 12hrs_2068_v2_part0.csv, 12hrs_2068_v2_part1.csv
# No values are overlapping 17
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 17
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 17
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 17
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 17
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 18
# Found pair: 12hrs_2070_v2_part0.csv, 12hrs_2070_v2_part1.csv
# No values are overlapping 18
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 18
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 19
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 19
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 19
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 19
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 19
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 20
# Found pair: 12hrs_2079_v2_part0.csv, 12hrs_2079_v2_part1.csv
# No values are overlapping 20
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 20
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 21
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 21
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 22
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 22
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 22
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 23
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 23
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 24
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 24
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 25
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 25
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 25
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 25
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 25
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 25
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 26
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 26
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 27
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 27
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 28
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 28
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 28
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 29
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 29
# Found pair: 12hrs_2063_v2_part0.csv, 12hrs_2063_v2_part1.csv
# No values are overlapping 29
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 29
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 30
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 30
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 30
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 31
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 31
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 31
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 32
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 32
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 32
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 32
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 33
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 34
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 34
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 34
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 35
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 35
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 35
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 36
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 36
# Found pair: 12hrs_2072_v2_part0.csv, 12hrs_2072_v2_part1.csv
# No values are overlapping 36
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 36
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 36
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 36
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 38
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 39
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 40
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# No values are overlapping 41
# Found pair: 12hrs_2061_v2_part0.csv, 12hrs_2061_v2_part1.csv
# No values are overlapping 42
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 42
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 42
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 42
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 42
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 42
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 43
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 44
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 44
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 44
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 45
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 45
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 45
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 45
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 46
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 46
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 47
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 47
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 47
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 48
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 48
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 48
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 49
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 49
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 49
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 49
# Found pair: 12hrs_2064_v2_part0.csv, 12hrs_2064_v2_part1.csv
# No values are overlapping 50
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 50
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 50
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 50
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 50
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 51
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 51
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 51
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 51
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 52
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 52
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 53
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 53
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 53
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 53
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 54
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 54
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 55
# Found pair: 12hrs_2068_v2_part0.csv, 12hrs_2068_v2_part1.csv
# No values are overlapping 55
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 55
# Found pair: 12hrs_2073_v2_part0.csv, 12hrs_2073_v2_part1.csv
# No values are overlapping 55
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 55
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 56
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 56
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 56
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 56
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 57
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 57
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# No values are overlapping 57
# Found pair: 12hrs_2070_v2_part0.csv, 12hrs_2070_v2_part1.csv
# No values are overlapping 58
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 58
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 58
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 60
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 61
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 62
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 63
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 63
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 64
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 64
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 64
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 65
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 65
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 65
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 65
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 65
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 67
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 68
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 68
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 68
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 68
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 69
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 69
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 70
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 70
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 70
# Found pair: 12hrs_2072_v2_part0.csv, 12hrs_2072_v2_part1.csv
# No values are overlapping 70
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 70
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 70
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 71
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 71
# Found pair: 12hrs_2067_v2_part0.csv, 12hrs_2067_v2_part1.csv
# No values are overlapping 71
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 71
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 71
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 71
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 72
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 72
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 72
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 72
# Found pair: 12hrs_2079_v2_part0.csv, 12hrs_2079_v2_part1.csv
# No values are overlapping 72
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 72
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 73
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 73
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 74
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# No values are overlapping 74
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 75
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 75
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 75
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 75
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 75
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 76
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 77
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 77
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 77
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 79
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 80
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 82
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# No values are overlapping 82
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 83
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 83
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 83
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 83
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 83
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 83
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 83
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 83
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 84
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 84
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 84
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# No values are overlapping 84
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 85
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 85
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 85
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 85
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 86
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 86
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 86
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# No values are overlapping 86
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 87
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 87
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 88
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 88
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 88
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 88
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 89
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 89
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 90
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 90
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 90
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 90
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 91
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 95
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 95
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 95
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 95
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 96
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 96
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 97
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 97
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 97
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 98
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 98
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 99
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 100
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 100
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 100
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 100
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 101
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 101
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 102
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 102
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 103
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 103
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 103
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 104
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 104
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 104
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 105
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 106
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 106
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 106
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 107
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 108
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 108
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 110
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 110
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 112
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 112
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 114
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 114
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 115
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 115
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 116
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 117
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 117
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 120
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 122
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 123
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 125
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 127
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 127
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 128
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 132
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 133
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 134
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 135
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 136
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 137
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 137
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 137
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 138
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 138
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 138
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 141
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 142
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 142
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 142
# Found pair: 12hrs_2079_v2_part0.csv, 12hrs_2079_v2_part1.csv
# No values are overlapping 142
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 143
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 143
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 144
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 144
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 144
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 145
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 146
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 146
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 147
# Found pair: 12hrs_2067_v2_part0.csv, 12hrs_2067_v2_part1.csv
# No values are overlapping 148
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 151
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 153
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 153
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 154
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 155
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 155
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 155
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 155
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 156
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 156
# Found pair: 12hrs_2067_v2_part0.csv, 12hrs_2067_v2_part1.csv
# No values are overlapping 156
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 156
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 156
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 156
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 157
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 159
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 160
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 160
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 160
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 161
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 161
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 161
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 161
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 163
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 163
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 163
# Found pair: 12hrs_2077_v2_part0.csv, 12hrs_2077_v2_part1.csv
# No values are overlapping 163
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 163
# Found pair: 12hrs_2079_v2_part0.csv, 12hrs_2079_v2_part1.csv
# No values are overlapping 163
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 163
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 164
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 165
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 165
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 167
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 168
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 170
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 170
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 171
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 171
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 171
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 171
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 171
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 171
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 173
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 173
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 176
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# No values are overlapping 176
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 177
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 177
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 177
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 178
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 178
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 178
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 178
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 178
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 179
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 179
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 179
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 182
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 182
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 182
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 183
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 184
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 185
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 186
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 187
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 187
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 188
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 188
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 188
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 189
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 189
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 190
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 190
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 191
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 192
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 192
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 193
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 194
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 194
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 194
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# No values are overlapping 194
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 195
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 195
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 195
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 198
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 198
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 199
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 200
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 200
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 200
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 201
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 201
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 201
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 203
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 204
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 204
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 206
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 207
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 208
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 209
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 209
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 210
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 210
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 211
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 213
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 213
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 214
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# No values are overlapping 214
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 215
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 215
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 216
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 216
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 217
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# No values are overlapping 217
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 218
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 218
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 220
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 221
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 221
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 221
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 222
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# No values are overlapping 222
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 223
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 223
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 223
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 224
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 225
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 225
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 225
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 225
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 226
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 227
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 228
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 228
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 228
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 228
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 228
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 228
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 228
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 229
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 229
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 229
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 229
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 229
# Found pair: 12hrs_2074_v2_part0.csv, 12hrs_2074_v2_part1.csv
# No values are overlapping 229
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# No values are overlapping 229
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 230
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 230
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 231
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 232
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 233
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 234
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 234
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 234
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# No values are overlapping 234
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 235
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 235
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 235
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# No values are overlapping 235
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 235
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 236
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 236
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 236
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 236
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# No values are overlapping 236
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 237
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 237
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 237
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# No values are overlapping 237
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 238
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 238
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 238
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 239
# ...
# No values are overlapping 1236
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1238
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 1238
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 1238
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 1239
# Found pair: 12hrs_2070_v2_part0.csv, 12hrs_2070_v2_part1.csv
# No values are overlapping 1239
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 1239
# Found pair: 12hrs_2073_v2_part0.csv, 12hrs_2073_v2_part1.csv
# No values are overlapping 1239
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 1239
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 1239
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 1240
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 1240
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 1240
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 1240
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 1240
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 1240
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1241
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 1241
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 1242
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 1242
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 1243
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 1243
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 1243
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 1244
# Found pair: 12hrs_2063_v2_part0.csv, 12hrs_2063_v2_part1.csv
# No values are overlapping 1245
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 1245
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 1246
# Found pair: 12hrs_2066_v2_part0.csv, 12hrs_2066_v2_part1.csv
# No values are overlapping 1246
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 1246
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 1247
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 1248
# Found pair: 12hrs_2069_v2_part0.csv, 12hrs_2069_v2_part1.csv
# No values are overlapping 1248
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 1248
# Found pair: 12hrs_2070_v2_part0.csv, 12hrs_2070_v2_part1.csv
# No values are overlapping 1248
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 1248
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 1248
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 1248
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 1248
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 1249
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1249
# Found pair: 12hrs_2063_v2_part0.csv, 12hrs_2063_v2_part1.csv
# No values are overlapping 1249
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 1249
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 1249
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 1249
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 1249
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# No values are overlapping 1249
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 1249
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1250
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 1250
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 1250
# Found pair: 12hrs_2067_v2_part0.csv, 12hrs_2067_v2_part1.csv
# No values are overlapping 1250
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 1250
# Found pair: 6hrs_2072_v2_part0.csv, 6hrs_2072_v2_part1.csv
# No values are overlapping 1250
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 1250
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 1250
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 1251
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1251
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 1252
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1252
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 1252
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# No values are overlapping 1252
# Found pair: 12hrs_2076_v2_part0.csv, 12hrs_2076_v2_part1.csv
# No values are overlapping 1253
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 1253
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 1253
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 1253
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 1255
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 1255
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 1255
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 1255
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 1255
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 1255
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1256
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 1256
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 1256
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1258
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 1258
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 1258
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 1258
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 1259
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 1259
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 1260
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1260
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 1260
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 1260
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 1260
# Found pair: 12hrs_2073_v2_part0.csv, 12hrs_2073_v2_part1.csv
# No values are overlapping 1260
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# No values are overlapping 1260
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 1260
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1261
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 1261
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 1261
# Found pair: 12hrs_2068_v2_part0.csv, 12hrs_2068_v2_part1.csv
# No values are overlapping 1261
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 1261
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# No values are overlapping 1261
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 1262
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 1262
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 1263
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 1263
# Found pair: 12hrs_2078_v2_part0.csv, 12hrs_2078_v2_part1.csv
# No values are overlapping 1263
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 1263
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 1264
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 1264
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 1265
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 1266
# Found pair: 12hrs_2070_v2_part0.csv, 12hrs_2070_v2_part1.csv
# No values are overlapping 1267
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 1267
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 1267
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 1268
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 1268
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 1268
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 1268
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 1269
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 1269
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1270
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 1270
# Found pair: 12hrs_2070_v2_part0.csv, 12hrs_2070_v2_part1.csv
# No values are overlapping 1270
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 1270
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 1270
# Found pair: 12hrs_2064_v2_part0.csv, 12hrs_2064_v2_part1.csv
# No values are overlapping 1271
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 1271
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 1271
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 1271
# Found pair: 6hrs_2071_v2_part0.csv, 6hrs_2071_v2_part1.csv
# No values are overlapping 1271
# Found pair: 12hrs_2071_v2_part0.csv, 12hrs_2071_v2_part1.csv
# No values are overlapping 1271
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 1271
# Found pair: 12hrs_2073_v2_part0.csv, 12hrs_2073_v2_part1.csv
# No values are overlapping 1271
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 1271
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 1272
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 1272
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 1275
# Found pair: 24hrs_2063_v2_part0.csv, 24hrs_2063_v2_part1.csv
# No values are overlapping 1276
# Found pair: 12hrs_2076_v2_part0.csv, 12hrs_2076_v2_part1.csv
# No values are overlapping 1276
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 1276
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 1276
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 1277
# Found pair: 12hrs_2072_v2_part0.csv, 12hrs_2072_v2_part1.csv
# No values are overlapping 1277
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 1277
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 1278
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 1279
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 1280
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1281
# Found pair: 12hrs_2070_v2_part0.csv, 12hrs_2070_v2_part1.csv
# No values are overlapping 1281
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 1281
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 1282
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 1283
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 1284
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1284
# Found pair: 24hrs_2072_v2_part0.csv, 24hrs_2072_v2_part1.csv
# No values are overlapping 1284
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1285
# Found pair: 24hrs_2075_v2_part0.csv, 24hrs_2075_v2_part1.csv
# No values are overlapping 1285
# Found pair: 12hrs_2073_v2_part0.csv, 12hrs_2073_v2_part1.csv
# No values are overlapping 1285
# Found pair: 24hrs_2073_v2_part0.csv, 24hrs_2073_v2_part1.csv
# No values are overlapping 1285
# Found pair: 24hrs_2064_v2_part0.csv, 24hrs_2064_v2_part1.csv
# No values are overlapping 1286
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 1286
# Found pair: 12hrs_2075_v2_part0.csv, 12hrs_2075_v2_part1.csv
# No values are overlapping 1287
# Found pair: 24hrs_2067_v2_part0.csv, 24hrs_2067_v2_part1.csv
# No values are overlapping 1287
# Found pair: 24hrs_2071_v2_part0.csv, 24hrs_2071_v2_part1.csv
# No values are overlapping 1287
# Found pair: 24hrs_2061_v2_part0.csv, 24hrs_2061_v2_part1.csv
# No values are overlapping 1288
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1288
# Found pair: 24hrs_2070_v2_part0.csv, 24hrs_2070_v2_part1.csv
# No values are overlapping 1288
# Found pair: 24hrs_2078_v2_part0.csv, 24hrs_2078_v2_part1.csv
# No values are overlapping 1288
# Found pair: 24hrs_2079_v2_part0.csv, 24hrs_2079_v2_part1.csv
# No values are overlapping 1288
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1289
# Found pair: 12hrs_2073_v2_part0.csv, 12hrs_2073_v2_part1.csv
# No values are overlapping 1289
# Found pair: 24hrs_2077_v2_part0.csv, 24hrs_2077_v2_part1.csv
# No values are overlapping 1289
# Found pair: 24hrs_2062_v2_part0.csv, 24hrs_2062_v2_part1.csv
# No values are overlapping 1290
# Found pair: 24hrs_2068_v2_part0.csv, 24hrs_2068_v2_part1.csv
# No values are overlapping 1290
# Found pair: 12hrs_2071_v2_part0.csv, 12hrs_2071_v2_part1.csv
# No values are overlapping 1290
# Found pair: 24hrs_2074_v2_part0.csv, 24hrs_2074_v2_part1.csv
# No values are overlapping 1290
# Found pair: 24hrs_2069_v2_part0.csv, 24hrs_2069_v2_part1.csv
# No values are overlapping 1291
# Found pair: 24hrs_2066_v2_part0.csv, 24hrs_2066_v2_part1.csv
# No values are overlapping 1291
# Found pair: 12hrs_2061_v2_part0.csv, 12hrs_2061_v2_part1.csv
# No values are overlapping 1292
# Found pair: 24hrs_2065_v2_part0.csv, 24hrs_2065_v2_part1.csv
# No values are overlapping 1292
# Found pair: 24hrs_2076_v2_part0.csv, 24hrs_2076_v2_part1.csv
# No values are overlapping 1292

# %% [markdown]
# ### NIMROD

# %%
for gauge_num in range(0,1294):
    if gauge_num not in [444, 827, 888]:
        # Directory containing the files
        directory_path = home_dir2 + f'ProcessedData/IndependentEvents/NIMROD_30mins/NIMROD_2.2km_filtered_100/{gauge_num}/WholeYear/EventSet/'
        
        # Dictionary to group files with similar names (excluding the 'part' identifier)
        file_groups = defaultdict(list)

        # Loop through all the files in the directory
        for filename in os.listdir(directory_path):
            if filename.endswith('.csv'):
                # Remove the part of the filename that specifies 'partX'
                base_name = filename.rsplit('_part', 1)[0]

                # Add the file to its corresponding group in the dictionary
                file_groups[base_name].append(filename)

        # Extract and check pairs where we have both part0 and part1
        for base_name, files in file_groups.items():

            if len(files) == 2 and any('part0' in f for f in files) and any('part1' in f for f in files):
                # Sort files so that 'part0' comes first, 'part1' comes second
                sorted_files = sorted(files, key=lambda x: 'part0' not in x) # 'part0' comes first
                # print(sorted_files)

                # Print sorted files to confirm the order
                print(f"Found pair: {sorted_files[0]}, {sorted_files[1]}")

                part0 = pd.read_csv(directory_path + sorted_files[0])
                part1 = pd.read_csv(directory_path + sorted_files[1])

                col_part0 = part0['Unnamed: 0']
                col_part1 = part1['Unnamed: 0']

                if 'part0' in sorted_files[1]:
                    print("'part0' is in the second file")
                    break

                # Find the overlapping values between the two columns
                overlapping_values = set(col_part0).intersection(set(col_part1))
                if len(overlapping_values) == 0:
                    print(f"No values are overlapping {gauge_num}")

                else:
                    # Check if part1 contains only overlapping values
                    if set(col_part1).issubset(overlapping_values):
                        print(f"-- All values are overlapping. Deleting {sorted_files[1]}")
                        os.remove(directory_path + sorted_files[1])
                    else:
                        print(f"-- Non-overlapping values exist; after filtering:")
                        # Filter part1 to exclude overlapping rows
                        part1_filtered = part1[~part1['Unnamed: 0'].isin(overlapping_values)]
                        # print(f"Filtered part1 (non-overlapping rows):\n{part1_filtered}")

                        # Print the first and last index of part0 and part1_filtered for verification
                        print(f"---- part0: First index = {part0['Unnamed: 0'].iloc[0]}, Last index = {part0['Unnamed: 0'].iloc[-1]}")
                        print(f"---- part1_filtered: First index = {part1_filtered['Unnamed: 0'].iloc[0]}, Last index = {part1_filtered['Unnamed: 0'].iloc[-1]}")

                        ## Check if filtered still has any non zero values
                        count_over_005 = part1_filtered[part1_filtered['precipitation (mm)'] > 0.05].shape[0]
                        if count_over_005 >0:
                            print(f"----- Saving {gauge_num}")
                            part1_filtered.to_csv(directory_path + sorted_files[1], index=False)
                        else:
                            print("----- All 0 values, deleting sorted_files[1]")
                            os.remove(directory_path + sorted_files[1])
