# %%
import pandas as pd
import iris
import glob
import sys
import os
import time
import warnings
import pickle
from collections import OrderedDict

from Identify_Events_Functions import *
from Prepare_Data_Functions import *

pd.set_option('display.float_format', '{:.3f}'.format)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning, message=".*'+init=<authority>:<code>' syntax is deprecated.*")

######################################################
### Define which rainfall data we are looking for events in
######################################################
dataset_name = 'filtered_100'
dataset_path_pattern = '/nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/{year}/*'

######################################################
### Define data for finding the indepedent events at each gauge
######################################################

# Get Tb0 values at each gauge
tbo_vals = pd.read_csv('/nfs/a319/gy17m2a/PhD/datadir/RainGauge/interarrival_thresholds_CDD_noMissing.txt')
# Read in a sample cube for finding the location of gauge in grid
yr=2006
sample_cube = iris.load(f'/nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/{yr}/metoffice-c-band-rain-radar_uk_{yr}0602.nc')[0][1,:,:]

######################################################
### Get all the 5 minute data for one year, into one cube
# (if it already exists in a pickle file, then load it from there)
######################################################
general_filename = dataset_path_pattern.format(year=yr)
pickle_file_filepath = f"/nfs/a319/gy17m2a/PhD/datadir/cache/nimrod_5mins/unfiltered/WholeYear/cube_{yr}.pkl"

if os.path.exists(pickle_file_filepath):
    print("Pickle file exists, so loading that")
    full_year_cube = load_cube_from_picklefile(pickle_file_filepath)
else:
    print("Pickle file doesnt exist, so creating and then saving that")
    
    ### Get the data filepaths
    print(f"Loading data for year {yr}")
    
    # Create cube list
    cubes = load_files_to_cubelist(yr, general_filename)
    
    # Clean cubes of things which are problematic for concatenation
    cubes = clean_cubes(cubes)
    
    # Join them into one (with error handling to deal with times which are wrong)
    try:
        full_year_cube = cubes.concatenate_cube()
        print("Concatenation successful!")
    except Exception as e:
        print(f"Initial concatenation failed: {str(e)}")

        # If initial concatenation fails, remove problematic cubes and try again
        try:
            full_year_cube = remove_problematic_cubes(cubes)
            print("Concatenation successful after removing problematic cubes!")
        except RuntimeError as e:
            print(f"Concatenation failed after removing problematic cubes: {str(e)}")               
    save_cube_as_pickle_file(full_year_cube, pickle_file_filepath)

######################################################
# Find events at each gauge
######################################################
failed_gauges = []
for yr in range(2006,2020):
    print(yr)
    gauge_nums = range(250,300)
    # Function to process each gauge
    for gauge_num in gauge_nums:
        if not gauge_num in [423, 444, 827, 888]:
                print(f"gauge num is {gauge_num}")

                ######################################################
                ## Check if any files are missing, across the 3 filtering options
                # If there are: code will continue to run
                # If not: code will move to next gauge
                ######################################################
                for dataset_name in ['unfiltered', 'filtered_100', 'filtered_300']:
                    # Create a flag to record whether we are missing any of the files we need
                    missing_files = False
                    # Define directory filepath which will store results
                    base_dir = f"/nfs/a161/gy17m2a/PhD/ProcessedData/IndependentEvents/NIMROD_5mins/NIMROD_1km_{dataset_name}/{gauge_num}/WholeYear"
                    # Create the directory if it doesnt exist
                    if not os.path.isdir(base_dir):
                        os.makedirs(base_dir)
                    # Check if we are missing any of the files, and if so, change the flag to True
                    if not any(os.path.exists(f"{base_dir}/{duration}hrs_{yr}_v2_part0.csv") for duration in [0.5, 1, 2, 3, 6, 12, 24]):
                        missing_files = True

                # If we are missing some files then get the data for the grid cell, 
                if missing_files:
                    # Find the Tb0 and index of this gauge
                    Tb0, idx_2d = find_gauge_Tb0_and_location_in_grid(tbo_vals, gauge_num, sample_cube)

                    # Extract data for the specified indices
                    start= time.time()
                    one_location_cube = full_year_cube[:, idx_2d[0], idx_2d[1]]
                    data = one_location_cube.data
                    end=time.time()
                    print(f"Time to load data is {round(end-start,2)} seconds")

                    ##### Filter cube according to different options
                    # Find events with filtered cubes
                    filtering_dict = {1000000:'unfiltered', 300:'filtered_300',100:'filtered_100'}
                    for filtering_key, dataset_name in filtering_dict.items():
                        print(f"running for {dataset_name}")
                        # Create cube with filterings applied
                        cube = filtered_cube(one_location_cube,  filter_above=filtering_key)
                        print("reloading data")
                        data = cube.data
                        print(f"max value is {np.nanmax(cube.data)}")
                        # Convert to dataframe
                        df = create_df_with_gaps_filled_in(cube, data, time_resolution = 5)
                        # Search dataframe for events corresponding to durations
                        for duration in [0.5, 1, 2, 3, 6, 12, 24]:
                            base_dir = f"/nfs/a161/gy17m2a/PhD/ProcessedData/IndependentEvents/NIMROD_5mins/NIMROD_1km_{dataset_name}/{gauge_num}/WholeYear"

                            filename =  f"{base_dir}/{duration}hrs_{yr}_v2_part0.csv"
                            if not os.path.exists(filename):
                                print(f"Finding the AMAX for {duration}hr events for gauge {gauge_num} in year {yr} for {dataset_name}")
                                # Find events
                                events_v2 = search_for_valid_events(df, duration=duration, Tb0=Tb0)

                                # Save events to CSV
                                for num, event in enumerate(events_v2):
                                    if len(event) > 1:
                                            event.to_csv(f"{base_dir}/{duration}hrs_{yr}_v2_part{num}.csv")
                                            if event['precipitation (mm/hr)'].isna().any():
                                                print("NANs in this event")
                            else:
                                print(f"already exists{filename}")
                                pass   

    print(f"failed gauges are: {failed_gauges}")
# Out:
# Pickle file exists, so loading that
# 2006
# gauge num is 250
# gauge num is 251
# gauge num is 252
# gauge num is 253
# gauge num is 254
# gauge num is 255
# gauge num is 256
# gauge num is 257
# gauge num is 258
# gauge num is 259
# gauge num is 260
# gauge num is 261
# gauge num is 262
# gauge num is 263
# gauge num is 264
# gauge num is 265
# gauge num is 266
# gauge num is 267
# gauge num is 268
# gauge num is 269
# gauge num is 270
# gauge num is 271
# gauge num is 272
# gauge num is 273
# gauge num is 274
# gauge num is 275
# gauge num is 276
# gauge num is 277
# gauge num is 278
# gauge num is 279
# gauge num is 280
# gauge num is 281
# gauge num is 282
# gauge num is 283
# gauge num is 284
# gauge num is 285
# gauge num is 286
# gauge num is 287
# gauge num is 288
# gauge num is 289
# gauge num is 290
# gauge num is 291
# gauge num is 292
# gauge num is 293
# gauge num is 294
# gauge num is 295
# gauge num is 296
# gauge num is 297
# gauge num is 298
# gauge num is 299
# failed gauges are: []
# 2007
# gauge num is 250
# gauge num is 251
# gauge num is 252
# gauge num is 253
# gauge num is 254
# gauge num is 255
# gauge num is 256
# gauge num is 257
# gauge num is 258
# gauge num is 259
# gauge num is 260
# gauge num is 261
# gauge num is 262
# gauge num is 263
# gauge num is 264
# gauge num is 265
# gauge num is 266
# gauge num is 267
# gauge num is 268
# gauge num is 269
# gauge num is 270
# gauge num is 271
# gauge num is 272
# gauge num is 273
# gauge num is 274
# gauge num is 275
# gauge num is 276
# gauge num is 277
# gauge num is 278
# gauge num is 279
# gauge num is 280
# gauge num is 281
# gauge num is 282
# gauge num is 283
# gauge num is 284
# gauge num is 285
# gauge num is 286
# gauge num is 287
# gauge num is 288
# gauge num is 289
# gauge num is 290
# gauge num is 291
# gauge num is 292
# gauge num is 293
# gauge num is 294
# gauge num is 295
# gauge num is 296
# gauge num is 297
# gauge num is 298
# gauge num is 299
# failed gauges are: []
# 2008
# gauge num is 250
# gauge num is 251
# gauge num is 252
# gauge num is 253
# gauge num is 254
# gauge num is 255
# gauge num is 256
# gauge num is 257
# gauge num is 258
# gauge num is 259
# gauge num is 260
# gauge num is 261
# gauge num is 262
# gauge num is 263
# gauge num is 264
# gauge num is 265
# gauge num is 266
# gauge num is 267
# gauge num is 268
# gauge num is 269
# gauge num is 270
# gauge num is 271
# (824, 827)
# Time to load data is 556.06 seconds
# running for unfiltered
# reloading data
# max value is 35.75
# Finding the AMAX for 0.5hr events for gauge 271 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 11.486978530883789
# Finding the AMAX for 1hr events for gauge 271 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 11.486978530883789
# Finding the AMAX for 2hr events for gauge 271 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 10.453125
# Finding the AMAX for 3hr events for gauge 271 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 10.473958015441895
# Finding the AMAX for 6hr events for gauge 271 in year 2008 for unfiltered
# Event contains NAN, total event precip is 16.01822853088379
# Event contains NAN, total event precip is 11.8984375
# Event doesnt contain NAN, total event precip is 10.473958015441895
# Finding the AMAX for 12hr events for gauge 271 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 11.486978530883789
# Finding the AMAX for 24hr events for gauge 271 in year 2008 for unfiltered
# Event contains NAN, total event precip is 12.5625
# Event doesnt contain NAN, total event precip is 11.692708969116211
# running for filtered_300
# reloading data
# max value is 35.75
# Finding the AMAX for 0.5hr events for gauge 271 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 11.486978530883789
# Finding the AMAX for 1hr events for gauge 271 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 11.486978530883789
# Finding the AMAX for 2hr events for gauge 271 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 10.453125
# Finding the AMAX for 3hr events for gauge 271 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 10.473958015441895
# Finding the AMAX for 6hr events for gauge 271 in year 2008 for filtered_300
# Event contains NAN, total event precip is 16.01822853088379
# Event contains NAN, total event precip is 11.8984375
# Event doesnt contain NAN, total event precip is 10.473958015441895
# Finding the AMAX for 12hr events for gauge 271 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 11.486978530883789
# Finding the AMAX for 24hr events for gauge 271 in year 2008 for filtered_300
# Event contains NAN, total event precip is 12.5625
# Event doesnt contain NAN, total event precip is 11.692708969116211
# running for filtered_100
# reloading data
# max value is 35.75
# Finding the AMAX for 0.5hr events for gauge 271 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 11.486978530883789
# Finding the AMAX for 1hr events for gauge 271 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 11.486978530883789
# Finding the AMAX for 2hr events for gauge 271 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 10.453125
# Finding the AMAX for 3hr events for gauge 271 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 10.473958015441895
# Finding the AMAX for 6hr events for gauge 271 in year 2008 for filtered_100
# Event contains NAN, total event precip is 16.01822853088379
# Event contains NAN, total event precip is 11.8984375
# Event doesnt contain NAN, total event precip is 10.473958015441895
# Finding the AMAX for 12hr events for gauge 271 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 11.486978530883789
# Finding the AMAX for 24hr events for gauge 271 in year 2008 for filtered_100
# Event contains NAN, total event precip is 12.5625
# Event doesnt contain NAN, total event precip is 11.692708969116211
# gauge num is 272
# (839, 814)
# Time to load data is 543.45 seconds
# running for unfiltered
# reloading data
# max value is 33.5625
# Finding the AMAX for 0.5hr events for gauge 272 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 5.3932294845581055
# Finding the AMAX for 1hr events for gauge 272 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 5.3932294845581055
# Finding the AMAX for 2hr events for gauge 272 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 5.3932294845581055
# Finding the AMAX for 3hr events for gauge 272 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 5.3932294845581055
# Finding the AMAX for 6hr events for gauge 272 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 8.848958015441895
# Finding the AMAX for 12hr events for gauge 272 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 11.7578125
# Finding the AMAX for 24hr events for gauge 272 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 12.0546875
# running for filtered_300
# reloading data
# max value is 33.5625
# Finding the AMAX for 0.5hr events for gauge 272 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 5.3932294845581055
# Finding the AMAX for 1hr events for gauge 272 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 5.3932294845581055
# Finding the AMAX for 2hr events for gauge 272 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 5.3932294845581055
# Finding the AMAX for 3hr events for gauge 272 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 5.3932294845581055
# Finding the AMAX for 6hr events for gauge 272 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 8.848958015441895
# Finding the AMAX for 12hr events for gauge 272 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 11.7578125
# Finding the AMAX for 24hr events for gauge 272 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 12.0546875
# running for filtered_100
# reloading data
# max value is 33.5625
# Finding the AMAX for 0.5hr events for gauge 272 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 5.3932294845581055
# Finding the AMAX for 1hr events for gauge 272 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 5.3932294845581055
# Finding the AMAX for 2hr events for gauge 272 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 5.3932294845581055
# Finding the AMAX for 3hr events for gauge 272 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 5.3932294845581055
# Finding the AMAX for 6hr events for gauge 272 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 8.848958015441895
# Finding the AMAX for 12hr events for gauge 272 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 11.7578125
# Finding the AMAX for 24hr events for gauge 272 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 12.0546875
# gauge num is 273
# (845, 823)
# Time to load data is 510.38 seconds
# running for unfiltered
# reloading data
# max value is 55.3125
# Finding the AMAX for 0.5hr events for gauge 273 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 12.559896469116211
# Finding the AMAX for 1hr events for gauge 273 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 12.559896469116211
# Finding the AMAX for 2hr events for gauge 273 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 12.619792938232422
# Finding the AMAX for 3hr events for gauge 273 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 12.619792938232422
# Finding the AMAX for 6hr events for gauge 273 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 12.619792938232422
# Finding the AMAX for 12hr events for gauge 273 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 12.651041984558105
# Finding the AMAX for 24hr events for gauge 273 in year 2008 for unfiltered
# Event contains NAN, total event precip is 12.828125
# Event doesnt contain NAN, total event precip is 12.179686546325684
# running for filtered_300
# reloading data
# max value is 55.3125
# Finding the AMAX for 0.5hr events for gauge 273 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 12.559896469116211
# Finding the AMAX for 1hr events for gauge 273 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 12.559896469116211
# Finding the AMAX for 2hr events for gauge 273 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 12.619792938232422
# Finding the AMAX for 3hr events for gauge 273 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 12.619792938232422
# Finding the AMAX for 6hr events for gauge 273 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 12.619792938232422
# Finding the AMAX for 12hr events for gauge 273 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 12.651041984558105
# Finding the AMAX for 24hr events for gauge 273 in year 2008 for filtered_300
# Event contains NAN, total event precip is 12.828125
# Event doesnt contain NAN, total event precip is 12.179686546325684
# running for filtered_100
# reloading data
# max value is 55.3125
# Finding the AMAX for 0.5hr events for gauge 273 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 12.559896469116211
# Finding the AMAX for 1hr events for gauge 273 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 12.559896469116211
# Finding the AMAX for 2hr events for gauge 273 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 12.619792938232422
# Finding the AMAX for 3hr events for gauge 273 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 12.619792938232422
# Finding the AMAX for 6hr events for gauge 273 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 12.619792938232422
# Finding the AMAX for 12hr events for gauge 273 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 12.651041984558105
# Finding the AMAX for 24hr events for gauge 273 in year 2008 for filtered_100
# Event contains NAN, total event precip is 12.828125
# Event doesnt contain NAN, total event precip is 12.179686546325684
# gauge num is 274
# (835, 835)
# Time to load data is 754.44 seconds
# running for unfiltered
# reloading data
# max value is 83.5
# Finding the AMAX for 0.5hr events for gauge 274 in year 2008 for unfiltered
# Event contains NAN, total event precip is 27.869792938232422
# Event doesnt contain NAN, total event precip is 5.9453125
# Finding the AMAX for 1hr events for gauge 274 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 5.9453125
# Finding the AMAX for 2hr events for gauge 274 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 5.950520992279053
# Finding the AMAX for 3hr events for gauge 274 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 5.950520992279053
# Finding the AMAX for 6hr events for gauge 274 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 11.963542938232422
# Finding the AMAX for 12hr events for gauge 274 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 13.583333969116211
# Finding the AMAX for 24hr events for gauge 274 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 13.677083015441895
# running for filtered_300
# reloading data
# max value is 83.5
# Finding the AMAX for 0.5hr events for gauge 274 in year 2008 for filtered_300
# Event contains NAN, total event precip is 27.869792938232422
# Event doesnt contain NAN, total event precip is 5.9453125
# Finding the AMAX for 1hr events for gauge 274 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 5.9453125
# Finding the AMAX for 2hr events for gauge 274 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 5.950520992279053
# Finding the AMAX for 3hr events for gauge 274 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 5.950520992279053
# Finding the AMAX for 6hr events for gauge 274 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 11.963542938232422
# Finding the AMAX for 12hr events for gauge 274 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 13.583333969116211
# Finding the AMAX for 24hr events for gauge 274 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 13.677083015441895
# running for filtered_100
# reloading data
# max value is 83.5
# Finding the AMAX for 0.5hr events for gauge 274 in year 2008 for filtered_100
# Event contains NAN, total event precip is 27.869792938232422
# Event doesnt contain NAN, total event precip is 5.9453125
# Finding the AMAX for 1hr events for gauge 274 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 5.9453125
# Finding the AMAX for 2hr events for gauge 274 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 5.950520992279053
# Finding the AMAX for 3hr events for gauge 274 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 5.950520992279053
# Finding the AMAX for 6hr events for gauge 274 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 11.963542938232422
# Finding the AMAX for 12hr events for gauge 274 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 13.583333969116211
# Finding the AMAX for 24hr events for gauge 274 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 13.677083015441895
# gauge num is 275
# (833, 849)
# Time to load data is 573.43 seconds
# running for unfiltered
# reloading data
# max value is 88.65625
# Finding the AMAX for 0.5hr events for gauge 275 in year 2008 for unfiltered
# Event contains NAN, total event precip is 31.263023376464844
# Event doesnt contain NAN, total event precip is 16.523439407348633
# Finding the AMAX for 1hr events for gauge 275 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 16.523439407348633
# Finding the AMAX for 2hr events for gauge 275 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 16.54947853088379
# Finding the AMAX for 3hr events for gauge 275 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 16.523439407348633
# Finding the AMAX for 6hr events for gauge 275 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 16.734375
# Finding the AMAX for 12hr events for gauge 275 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 16.734375
# Finding the AMAX for 24hr events for gauge 275 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 17.77083396911621
# running for filtered_300
# reloading data
# max value is 88.65625
# Finding the AMAX for 0.5hr events for gauge 275 in year 2008 for filtered_300
# Event contains NAN, total event precip is 31.263023376464844
# Event doesnt contain NAN, total event precip is 16.523439407348633
# Finding the AMAX for 1hr events for gauge 275 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 16.523439407348633
# Finding the AMAX for 2hr events for gauge 275 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 16.54947853088379
# Finding the AMAX for 3hr events for gauge 275 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 16.523439407348633
# Finding the AMAX for 6hr events for gauge 275 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 16.734375
# Finding the AMAX for 12hr events for gauge 275 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 16.734375
# Finding the AMAX for 24hr events for gauge 275 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 17.77083396911621
# running for filtered_100
# reloading data
# max value is 88.65625
# Finding the AMAX for 0.5hr events for gauge 275 in year 2008 for filtered_100
# Event contains NAN, total event precip is 31.263023376464844
# Event doesnt contain NAN, total event precip is 16.523439407348633
# Finding the AMAX for 1hr events for gauge 275 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 16.523439407348633
# Finding the AMAX for 2hr events for gauge 275 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 16.54947853088379
# Finding the AMAX for 3hr events for gauge 275 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 16.523439407348633
# Finding the AMAX for 6hr events for gauge 275 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 16.734375
# Finding the AMAX for 12hr events for gauge 275 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 16.734375
# Finding the AMAX for 24hr events for gauge 275 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 17.77083396911621
# gauge num is 276
# (851, 834)
# Time to load data is 402.0 seconds
# running for unfiltered
# reloading data
# max value is 32.0
# Finding the AMAX for 0.5hr events for gauge 276 in year 2008 for unfiltered
# Event contains NAN, total event precip is 10.648438453674316
# Event doesnt contain NAN, total event precip is 3.304687261581421
# Finding the AMAX for 1hr events for gauge 276 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 3.5963542461395264
# Finding the AMAX for 2hr events for gauge 276 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 7.067708492279053
# Finding the AMAX for 3hr events for gauge 276 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 7.067708492279053
# Finding the AMAX for 6hr events for gauge 276 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 11.822916030883789
# Finding the AMAX for 12hr events for gauge 276 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 11.822916030883789
# Finding the AMAX for 24hr events for gauge 276 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 11.903646469116211
# running for filtered_300
# reloading data
# max value is 32.0
# Finding the AMAX for 0.5hr events for gauge 276 in year 2008 for filtered_300
# Event contains NAN, total event precip is 10.648438453674316
# Event doesnt contain NAN, total event precip is 3.304687261581421
# Finding the AMAX for 1hr events for gauge 276 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 3.5963542461395264
# Finding the AMAX for 2hr events for gauge 276 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 7.067708492279053
# Finding the AMAX for 3hr events for gauge 276 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 7.067708492279053
# Finding the AMAX for 6hr events for gauge 276 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 11.822916030883789
# Finding the AMAX for 12hr events for gauge 276 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 11.822916030883789
# Finding the AMAX for 24hr events for gauge 276 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 11.903646469116211
# running for filtered_100
# reloading data
# max value is 32.0
# Finding the AMAX for 0.5hr events for gauge 276 in year 2008 for filtered_100
# Event contains NAN, total event precip is 10.648438453674316
# Event doesnt contain NAN, total event precip is 3.304687261581421
# Finding the AMAX for 1hr events for gauge 276 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 3.5963542461395264
# Finding the AMAX for 2hr events for gauge 276 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 7.067708492279053
# Finding the AMAX for 3hr events for gauge 276 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 7.067708492279053
# Finding the AMAX for 6hr events for gauge 276 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 11.822916030883789
# Finding the AMAX for 12hr events for gauge 276 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 11.822916030883789
# Finding the AMAX for 24hr events for gauge 276 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 11.903646469116211
# gauge num is 277
# (830, 855)
# Time to load data is 437.2 seconds
# running for unfiltered
# reloading data
# max value is 34.375
# Finding the AMAX for 0.5hr events for gauge 277 in year 2008 for unfiltered
# Event contains NAN, total event precip is 12.627604484558105
# Event doesnt contain NAN, total event precip is 5.9739580154418945
# Finding the AMAX for 1hr events for gauge 277 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 4.950520992279053
# Finding the AMAX for 2hr events for gauge 277 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 4.34375
# Finding the AMAX for 3hr events for gauge 277 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 15.463541030883789
# Finding the AMAX for 6hr events for gauge 277 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 15.463541030883789
# Finding the AMAX for 12hr events for gauge 277 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 16.135417938232422
# Finding the AMAX for 24hr events for gauge 277 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 16.135417938232422
# running for filtered_300
# reloading data
# max value is 34.375
# Finding the AMAX for 0.5hr events for gauge 277 in year 2008 for filtered_300
# Event contains NAN, total event precip is 12.627604484558105
# Event doesnt contain NAN, total event precip is 5.9739580154418945
# Finding the AMAX for 1hr events for gauge 277 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 4.950520992279053
# Finding the AMAX for 2hr events for gauge 277 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 4.34375
# Finding the AMAX for 3hr events for gauge 277 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 15.463541030883789
# Finding the AMAX for 6hr events for gauge 277 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 15.463541030883789
# Finding the AMAX for 12hr events for gauge 277 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 16.135417938232422
# Finding the AMAX for 24hr events for gauge 277 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 16.135417938232422
# running for filtered_100
# reloading data
# max value is 34.375
# Finding the AMAX for 0.5hr events for gauge 277 in year 2008 for filtered_100
# Event contains NAN, total event precip is 12.627604484558105
# Event doesnt contain NAN, total event precip is 5.9739580154418945
# Finding the AMAX for 1hr events for gauge 277 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 4.950520992279053
# Finding the AMAX for 2hr events for gauge 277 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 4.34375
# Finding the AMAX for 3hr events for gauge 277 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 15.463541030883789
# Finding the AMAX for 6hr events for gauge 277 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 15.463541030883789
# Finding the AMAX for 12hr events for gauge 277 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 16.135417938232422
# Finding the AMAX for 24hr events for gauge 277 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 16.135417938232422
# gauge num is 278
# (879, 861)
# Time to load data is 562.84 seconds
# running for unfiltered
# reloading data
# max value is 68.5625
# Finding the AMAX for 0.5hr events for gauge 278 in year 2008 for unfiltered
# Event contains NAN, total event precip is 13.924479484558105
# Event doesnt contain NAN, total event precip is 12.450521469116211
# Finding the AMAX for 1hr events for gauge 278 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 12.450521469116211
# Finding the AMAX for 2hr events for gauge 278 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 12.450521469116211
# Finding the AMAX for 3hr events for gauge 278 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 12.450521469116211
# Finding the AMAX for 6hr events for gauge 278 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 18.9609375
# Finding the AMAX for 12hr events for gauge 278 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 18.99479103088379
# Finding the AMAX for 24hr events for gauge 278 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 19.07291603088379
# running for filtered_300
# reloading data
# max value is 68.5625
# Finding the AMAX for 0.5hr events for gauge 278 in year 2008 for filtered_300
# Event contains NAN, total event precip is 13.924479484558105
# Event doesnt contain NAN, total event precip is 12.450521469116211
# Finding the AMAX for 1hr events for gauge 278 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 12.450521469116211
# Finding the AMAX for 2hr events for gauge 278 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 12.450521469116211
# Finding the AMAX for 3hr events for gauge 278 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 12.450521469116211
# Finding the AMAX for 6hr events for gauge 278 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 18.9609375
# Finding the AMAX for 12hr events for gauge 278 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 18.99479103088379
# Finding the AMAX for 24hr events for gauge 278 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 19.07291603088379
# running for filtered_100
# reloading data
# max value is 68.5625
# Finding the AMAX for 0.5hr events for gauge 278 in year 2008 for filtered_100
# Event contains NAN, total event precip is 13.924479484558105
# Event doesnt contain NAN, total event precip is 12.450521469116211
# Finding the AMAX for 1hr events for gauge 278 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 12.450521469116211
# Finding the AMAX for 2hr events for gauge 278 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 12.450521469116211
# Finding the AMAX for 3hr events for gauge 278 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 12.450521469116211
# Finding the AMAX for 6hr events for gauge 278 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 18.9609375
# Finding the AMAX for 12hr events for gauge 278 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 18.99479103088379
# Finding the AMAX for 24hr events for gauge 278 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 19.07291603088379
# gauge num is 279
# (877, 857)
# Time to load data is 368.69 seconds
# running for unfiltered
# reloading data
# max value is 55.25
# Finding the AMAX for 0.5hr events for gauge 279 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 16.895832061767578
# Finding the AMAX for 1hr events for gauge 279 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 16.895832061767578
# Finding the AMAX for 2hr events for gauge 279 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 23.200523376464844
# Finding the AMAX for 3hr events for gauge 279 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 23.200523376464844
# Finding the AMAX for 6hr events for gauge 279 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 23.200523376464844
# Finding the AMAX for 12hr events for gauge 279 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 23.200523376464844
# Finding the AMAX for 24hr events for gauge 279 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 23.3515625
# running for filtered_300
# reloading data
# max value is 55.25
# Finding the AMAX for 0.5hr events for gauge 279 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 16.895832061767578
# Finding the AMAX for 1hr events for gauge 279 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 16.895832061767578
# Finding the AMAX for 2hr events for gauge 279 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 23.200523376464844
# Finding the AMAX for 3hr events for gauge 279 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 23.200523376464844
# Finding the AMAX for 6hr events for gauge 279 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 23.200523376464844
# Finding the AMAX for 12hr events for gauge 279 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 23.200523376464844
# Finding the AMAX for 24hr events for gauge 279 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 23.3515625
# running for filtered_100
# reloading data
# max value is 55.25
# Finding the AMAX for 0.5hr events for gauge 279 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 16.895832061767578
# Finding the AMAX for 1hr events for gauge 279 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 16.895832061767578
# Finding the AMAX for 2hr events for gauge 279 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 23.200523376464844
# Finding the AMAX for 3hr events for gauge 279 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 23.200523376464844
# Finding the AMAX for 6hr events for gauge 279 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 23.200523376464844
# Finding the AMAX for 12hr events for gauge 279 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 23.200523376464844
# Finding the AMAX for 24hr events for gauge 279 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 23.3515625
# gauge num is 280
# (866, 850)
# Time to load data is 522.02 seconds
# running for unfiltered
# reloading data
# max value is 66.03125
# Finding the AMAX for 0.5hr events for gauge 280 in year 2008 for unfiltered
# Event contains NAN, total event precip is 15.098958969116211
# Event doesnt contain NAN, total event precip is 31.4921875
# Finding the AMAX for 1hr events for gauge 280 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 31.4921875
# Finding the AMAX for 2hr events for gauge 280 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 31.4921875
# Finding the AMAX for 3hr events for gauge 280 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 31.4921875
# Finding the AMAX for 6hr events for gauge 280 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 31.4921875
# Finding the AMAX for 12hr events for gauge 280 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 31.4921875
# Finding the AMAX for 24hr events for gauge 280 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 31.69270896911621
# running for filtered_300
# reloading data
# max value is 66.03125
# Finding the AMAX for 0.5hr events for gauge 280 in year 2008 for filtered_300
# Event contains NAN, total event precip is 15.098958969116211
# Event doesnt contain NAN, total event precip is 31.4921875
# Finding the AMAX for 1hr events for gauge 280 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 31.4921875
# Finding the AMAX for 2hr events for gauge 280 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 31.4921875
# Finding the AMAX for 3hr events for gauge 280 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 31.4921875
# Finding the AMAX for 6hr events for gauge 280 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 31.4921875
# Finding the AMAX for 12hr events for gauge 280 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 31.4921875
# Finding the AMAX for 24hr events for gauge 280 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 31.69270896911621
# running for filtered_100
# reloading data
# max value is 66.03125
# already exists/nfs/a161/gy17m2a/PhD/ProcessedData/IndependentEvents/NIMROD_5mins/NIMROD_1km_filtered_100/280/WholeYear/0.5hrs_2008_v2_part0.csv
# already exists/nfs/a161/gy17m2a/PhD/ProcessedData/IndependentEvents/NIMROD_5mins/NIMROD_1km_filtered_100/280/WholeYear/1hrs_2008_v2_part0.csv
# already exists/nfs/a161/gy17m2a/PhD/ProcessedData/IndependentEvents/NIMROD_5mins/NIMROD_1km_filtered_100/280/WholeYear/2hrs_2008_v2_part0.csv
# already exists/nfs/a161/gy17m2a/PhD/ProcessedData/IndependentEvents/NIMROD_5mins/NIMROD_1km_filtered_100/280/WholeYear/3hrs_2008_v2_part0.csv
# already exists/nfs/a161/gy17m2a/PhD/ProcessedData/IndependentEvents/NIMROD_5mins/NIMROD_1km_filtered_100/280/WholeYear/6hrs_2008_v2_part0.csv
# already exists/nfs/a161/gy17m2a/PhD/ProcessedData/IndependentEvents/NIMROD_5mins/NIMROD_1km_filtered_100/280/WholeYear/12hrs_2008_v2_part0.csv
# already exists/nfs/a161/gy17m2a/PhD/ProcessedData/IndependentEvents/NIMROD_5mins/NIMROD_1km_filtered_100/280/WholeYear/24hrs_2008_v2_part0.csv
# gauge num is 281
# (846, 862)
# Time to load data is 483.03 seconds
# running for unfiltered
# reloading data
# max value is 98.375
# Finding the AMAX for 0.5hr events for gauge 281 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 30.304689407348633
# Finding the AMAX for 1hr events for gauge 281 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 30.304689407348633
# Finding the AMAX for 2hr events for gauge 281 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 30.304689407348633
# Finding the AMAX for 3hr events for gauge 281 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 30.304689407348633
# Finding the AMAX for 6hr events for gauge 281 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 34.47395706176758
# Finding the AMAX for 12hr events for gauge 281 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 34.47395706176758
# Finding the AMAX for 24hr events for gauge 281 in year 2008 for unfiltered
# Event contains NAN, total event precip is 37.192710876464844
# Event doesnt contain NAN, total event precip is 31.622394561767578
# running for filtered_300
# reloading data
# max value is 98.375
# Finding the AMAX for 0.5hr events for gauge 281 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 30.304689407348633
# Finding the AMAX for 1hr events for gauge 281 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 30.304689407348633
# Finding the AMAX for 2hr events for gauge 281 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 30.304689407348633
# Finding the AMAX for 3hr events for gauge 281 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 30.304689407348633
# Finding the AMAX for 6hr events for gauge 281 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 34.47395706176758
# Finding the AMAX for 12hr events for gauge 281 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 34.47395706176758
# Finding the AMAX for 24hr events for gauge 281 in year 2008 for filtered_300
# Event contains NAN, total event precip is 37.192710876464844
# Event doesnt contain NAN, total event precip is 31.622394561767578
# running for filtered_100
# reloading data
# max value is 98.375
# Finding the AMAX for 0.5hr events for gauge 281 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 30.304689407348633
# Finding the AMAX for 1hr events for gauge 281 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 30.304689407348633
# Finding the AMAX for 2hr events for gauge 281 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 30.304689407348633
# Finding the AMAX for 3hr events for gauge 281 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 30.304689407348633
# Finding the AMAX for 6hr events for gauge 281 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 34.47395706176758
# Finding the AMAX for 12hr events for gauge 281 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 34.47395706176758
# Finding the AMAX for 24hr events for gauge 281 in year 2008 for filtered_100
# Event contains NAN, total event precip is 37.192710876464844
# Event doesnt contain NAN, total event precip is 31.622394561767578
# gauge num is 282
# (817, 839)
# Time to load data is 712.5 seconds
# running for unfiltered
# reloading data
# max value is 31.875
# Finding the AMAX for 0.5hr events for gauge 282 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 4.239583492279053
# Finding the AMAX for 1hr events for gauge 282 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 12.122395515441895
# Finding the AMAX for 2hr events for gauge 282 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 12.122395515441895
# Finding the AMAX for 3hr events for gauge 282 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 12.122395515441895
# Finding the AMAX for 6hr events for gauge 282 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 12.122395515441895
# Finding the AMAX for 12hr events for gauge 282 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 12.127603530883789
# Finding the AMAX for 24hr events for gauge 282 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 10.8828125
# running for filtered_300
# reloading data
# max value is 31.875
# Finding the AMAX for 0.5hr events for gauge 282 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 4.239583492279053
# Finding the AMAX for 1hr events for gauge 282 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 12.122395515441895
# Finding the AMAX for 2hr events for gauge 282 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 12.122395515441895
# Finding the AMAX for 3hr events for gauge 282 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 12.122395515441895
# Finding the AMAX for 6hr events for gauge 282 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 12.122395515441895
# Finding the AMAX for 12hr events for gauge 282 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 12.127603530883789
# Finding the AMAX for 24hr events for gauge 282 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 10.8828125
# running for filtered_100
# reloading data
# max value is 31.875
# Finding the AMAX for 0.5hr events for gauge 282 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 4.239583492279053
# Finding the AMAX for 1hr events for gauge 282 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 12.122395515441895
# Finding the AMAX for 2hr events for gauge 282 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 12.122395515441895
# Finding the AMAX for 3hr events for gauge 282 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 12.122395515441895
# Finding the AMAX for 6hr events for gauge 282 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 12.122395515441895
# Finding the AMAX for 12hr events for gauge 282 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 12.127603530883789
# Finding the AMAX for 24hr events for gauge 282 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 10.8828125
# gauge num is 283
# (820, 854)
# Time to load data is 585.69 seconds
# running for unfiltered
# reloading data
# max value is 30.5
# Finding the AMAX for 0.5hr events for gauge 283 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 10.484375953674316
# Finding the AMAX for 1hr events for gauge 283 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 10.484375953674316
# Finding the AMAX for 2hr events for gauge 283 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 10.484375953674316
# Finding the AMAX for 3hr events for gauge 283 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 10.567708969116211
# Finding the AMAX for 6hr events for gauge 283 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 10.700521469116211
# Finding the AMAX for 12hr events for gauge 283 in year 2008 for unfiltered
# Event contains NAN, total event precip is 12.4296875
# Event contains NAN, total event precip is 15.450521469116211
# Event doesnt contain NAN, total event precip is 15.65625
# Finding the AMAX for 24hr events for gauge 283 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 15.65625
# running for filtered_300
# reloading data
# max value is 30.5
# Finding the AMAX for 0.5hr events for gauge 283 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 10.484375953674316
# Finding the AMAX for 1hr events for gauge 283 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 10.484375953674316
# Finding the AMAX for 2hr events for gauge 283 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 10.484375953674316
# Finding the AMAX for 3hr events for gauge 283 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 10.567708969116211
# Finding the AMAX for 6hr events for gauge 283 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 10.700521469116211
# Finding the AMAX for 12hr events for gauge 283 in year 2008 for filtered_300
# Event contains NAN, total event precip is 12.4296875
# Event contains NAN, total event precip is 15.450521469116211
# Event doesnt contain NAN, total event precip is 15.65625
# Finding the AMAX for 24hr events for gauge 283 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 15.65625
# running for filtered_100
# reloading data
# max value is 30.5
# Finding the AMAX for 0.5hr events for gauge 283 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 10.484375953674316
# Finding the AMAX for 1hr events for gauge 283 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 10.484375953674316
# Finding the AMAX for 2hr events for gauge 283 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 10.484375953674316
# Finding the AMAX for 3hr events for gauge 283 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 10.567708969116211
# Finding the AMAX for 6hr events for gauge 283 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 10.700521469116211
# Finding the AMAX for 12hr events for gauge 283 in year 2008 for filtered_100
# Event contains NAN, total event precip is 12.4296875
# Event contains NAN, total event precip is 15.450521469116211
# Event doesnt contain NAN, total event precip is 15.65625
# Finding the AMAX for 24hr events for gauge 283 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 15.65625
# gauge num is 284
# (834, 895)
# Time to load data is 433.33 seconds
# running for unfiltered
# reloading data
# max value is 46.75
# Finding the AMAX for 0.5hr events for gauge 284 in year 2008 for unfiltered
# Event contains NAN, total event precip is 31.221355438232422
# Event doesnt contain NAN, total event precip is 11.453125
# Finding the AMAX for 1hr events for gauge 284 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 14.731770515441895
# Finding the AMAX for 2hr events for gauge 284 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 14.731770515441895
# Finding the AMAX for 3hr events for gauge 284 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 14.731770515441895
# Finding the AMAX for 6hr events for gauge 284 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 14.731770515441895
# Finding the AMAX for 12hr events for gauge 284 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 17.51041603088379
# Finding the AMAX for 24hr events for gauge 284 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 22.020832061767578
# running for filtered_300
# reloading data
# max value is 46.75
# Finding the AMAX for 0.5hr events for gauge 284 in year 2008 for filtered_300
# Event contains NAN, total event precip is 31.221355438232422
# Event doesnt contain NAN, total event precip is 11.453125
# Finding the AMAX for 1hr events for gauge 284 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 14.731770515441895
# Finding the AMAX for 2hr events for gauge 284 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 14.731770515441895
# Finding the AMAX for 3hr events for gauge 284 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 14.731770515441895
# Finding the AMAX for 6hr events for gauge 284 in year 2008 for filtered_300
# ...
# Event doesnt contain NAN, total event precip is 11.3046875
# Finding the AMAX for 24hr events for gauge 295 in year 2008 for filtered_100
# Event contains NAN, total event precip is 15.6015625
# Event doesnt contain NAN, total event precip is 12.1171875
# gauge num is 296
# (761, 901)
# Time to load data is 409.37 seconds
# running for unfiltered
# reloading data
# max value is 46.25
# Finding the AMAX for 0.5hr events for gauge 296 in year 2008 for unfiltered
# Event contains NAN, total event precip is 20.29166603088379
# Event doesnt contain NAN, total event precip is 31.53125
# Finding the AMAX for 1hr events for gauge 296 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 19.299480438232422
# Finding the AMAX for 2hr events for gauge 296 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 19.299480438232422
# Finding the AMAX for 3hr events for gauge 296 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 31.53125
# Finding the AMAX for 6hr events for gauge 296 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 31.53125
# Finding the AMAX for 12hr events for gauge 296 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 31.53125
# Finding the AMAX for 24hr events for gauge 296 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 31.58072853088379
# running for filtered_300
# reloading data
# max value is 46.25
# Finding the AMAX for 0.5hr events for gauge 296 in year 2008 for filtered_300
# Event contains NAN, total event precip is 20.29166603088379
# Event doesnt contain NAN, total event precip is 31.53125
# Finding the AMAX for 1hr events for gauge 296 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 19.299480438232422
# Finding the AMAX for 2hr events for gauge 296 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 19.299480438232422
# Finding the AMAX for 3hr events for gauge 296 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 31.53125
# Finding the AMAX for 6hr events for gauge 296 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 31.53125
# Finding the AMAX for 12hr events for gauge 296 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 31.53125
# Finding the AMAX for 24hr events for gauge 296 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 31.58072853088379
# running for filtered_100
# reloading data
# max value is 46.25
# Finding the AMAX for 0.5hr events for gauge 296 in year 2008 for filtered_100
# Event contains NAN, total event precip is 20.29166603088379
# Event doesnt contain NAN, total event precip is 31.53125
# Finding the AMAX for 1hr events for gauge 296 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 19.299480438232422
# Finding the AMAX for 2hr events for gauge 296 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 19.299480438232422
# Finding the AMAX for 3hr events for gauge 296 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 31.53125
# Finding the AMAX for 6hr events for gauge 296 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 31.53125
# Finding the AMAX for 12hr events for gauge 296 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 31.53125
# Finding the AMAX for 24hr events for gauge 296 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 31.58072853088379
# gauge num is 297
# (816, 866)
# Time to load data is 702.15 seconds
# running for unfiltered
# reloading data
# max value is 59.84375
# Finding the AMAX for 0.5hr events for gauge 297 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 8.8125
# Finding the AMAX for 1hr events for gauge 297 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 8.8125
# Finding the AMAX for 2hr events for gauge 297 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 8.8125
# Finding the AMAX for 3hr events for gauge 297 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 8.8125
# Finding the AMAX for 6hr events for gauge 297 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 8.8125
# Finding the AMAX for 12hr events for gauge 297 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 17.25520896911621
# Finding the AMAX for 24hr events for gauge 297 in year 2008 for unfiltered
# Event contains NAN, total event precip is 13.075520515441895
# Event doesnt contain NAN, total event precip is 17.25520896911621
# running for filtered_300
# reloading data
# max value is 59.84375
# Finding the AMAX for 0.5hr events for gauge 297 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 8.8125
# Finding the AMAX for 1hr events for gauge 297 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 8.8125
# Finding the AMAX for 2hr events for gauge 297 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 8.8125
# Finding the AMAX for 3hr events for gauge 297 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 8.8125
# Finding the AMAX for 6hr events for gauge 297 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 8.8125
# Finding the AMAX for 12hr events for gauge 297 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 17.25520896911621
# Finding the AMAX for 24hr events for gauge 297 in year 2008 for filtered_300
# Event contains NAN, total event precip is 13.075520515441895
# Event doesnt contain NAN, total event precip is 17.25520896911621
# running for filtered_100
# reloading data
# max value is 59.84375
# Finding the AMAX for 0.5hr events for gauge 297 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 8.8125
# Finding the AMAX for 1hr events for gauge 297 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 8.8125
# Finding the AMAX for 2hr events for gauge 297 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 8.8125
# Finding the AMAX for 3hr events for gauge 297 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 8.8125
# Finding the AMAX for 6hr events for gauge 297 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 8.8125
# Finding the AMAX for 12hr events for gauge 297 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 17.25520896911621
# Finding the AMAX for 24hr events for gauge 297 in year 2008 for filtered_100
# Event contains NAN, total event precip is 13.075520515441895
# Event doesnt contain NAN, total event precip is 17.25520896911621
# gauge num is 298
# (753, 917)
# Time to load data is 555.43 seconds
# running for unfiltered
# reloading data
# max value is 58.5625
# Finding the AMAX for 0.5hr events for gauge 298 in year 2008 for unfiltered
# Event contains NAN, total event precip is 18.109375
# Event doesnt contain NAN, total event precip is 11.614583969116211
# Finding the AMAX for 1hr events for gauge 298 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 11.614583969116211
# Finding the AMAX for 2hr events for gauge 298 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 13.375000953674316
# Finding the AMAX for 3hr events for gauge 298 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 13.395833969116211
# Finding the AMAX for 6hr events for gauge 298 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 13.395833969116211
# Finding the AMAX for 12hr events for gauge 298 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 14.002604484558105
# Finding the AMAX for 24hr events for gauge 298 in year 2008 for unfiltered
# Event doesnt contain NAN, total event precip is 14.151041984558105
# running for filtered_300
# reloading data
# max value is 58.5625
# Finding the AMAX for 0.5hr events for gauge 298 in year 2008 for filtered_300
# Event contains NAN, total event precip is 18.109375
# Event doesnt contain NAN, total event precip is 11.614583969116211
# Finding the AMAX for 1hr events for gauge 298 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 11.614583969116211
# Finding the AMAX for 2hr events for gauge 298 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 13.375000953674316
# Finding the AMAX for 3hr events for gauge 298 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 13.395833969116211
# Finding the AMAX for 6hr events for gauge 298 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 13.395833969116211
# Finding the AMAX for 12hr events for gauge 298 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 14.002604484558105
# Finding the AMAX for 24hr events for gauge 298 in year 2008 for filtered_300
# Event doesnt contain NAN, total event precip is 14.151041984558105
# running for filtered_100
# reloading data
# max value is 58.5625
# Finding the AMAX for 0.5hr events for gauge 298 in year 2008 for filtered_100
# Event contains NAN, total event precip is 18.109375
# Event doesnt contain NAN, total event precip is 11.614583969116211
# Finding the AMAX for 1hr events for gauge 298 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 11.614583969116211
# Finding the AMAX for 2hr events for gauge 298 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 13.375000953674316
# Finding the AMAX for 3hr events for gauge 298 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 13.395833969116211
# Finding the AMAX for 6hr events for gauge 298 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 13.395833969116211
# Finding the AMAX for 12hr events for gauge 298 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 14.002604484558105
# Finding the AMAX for 24hr events for gauge 298 in year 2008 for filtered_100
# Event doesnt contain NAN, total event precip is 14.151041984558105
# gauge num is 299
# (741, 899)
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /tmp/ipykernel_244793/471018578.py in <module>
#     101                 if missing_files:
#     102                     # Find the Tb0 and index of this gauge
# --> 103                     Tb0, idx_2d = find_gauge_Tb0_and_location_in_grid(tbo_vals, gauge_num, sample_cube)
#     104
#     105                     # Extract data for the specified indices
#
# /nfs/a319/gy17m2a/PhD/Scripts/FindIndependentRainfallEvents/FindingEvents/Identify_Events_Functions.py in find_gauge_Tb0_and_location_in_grid(tbo_vals, gauge_num, sample_cube)
#      62     gauge1 = tbo_vals.iloc[gauge_num]
#      63     Tb0 = int(gauge1['Critical_interarrival_time'])
# ---> 64     closest_point, idx_2d = find_position_obs(sample_cube, gauge1['Lat'], gauge1['Lon'], plot_radius=10, plot=False)
#      65     return Tb0, idx_2d
#      66
#
# /nfs/a319/gy17m2a/PhD/Scripts/FindIndependentRainfallEvents/FindingEvents/Identify_Events_Functions.py in find_position_obs(concat_cube, rain_gauge_lat, rain_gauge_lon, plot_radius, plot)
#     365
#     366     # Check if the selected index is masked and find a nearby valid index if necessary
# --> 367     if np.ma.is_masked(concat_cube[selected_index[0], selected_index[1]].data):
#     368         print("yep its masked")
#     369         found = False
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/iris/cube.py in data(self)
#    2167
#    2168         """
# -> 2169         return self._data_manager.data
#    2170
#    2171     @data.setter
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/iris/_data_manager.py in data(self)
#     204             try:
#     205                 # Realise the lazy data.
# --> 206                 result = as_concrete_data(self._lazy_array)
#     207                 # Assign the realised result.
#     208                 self._real_array = result
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/iris/_lazy_data.py in as_concrete_data(data)
#     250     """
#     251     if is_lazy_data(data):
# --> 252         (data,) = _co_realise_lazy_arrays([data])
#     253
#     254     return data
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/iris/_lazy_data.py in _co_realise_lazy_arrays(arrays)
#     213
#     214     """
# --> 215     computed_arrays = da.compute(*arrays)
#     216     results = []
#     217     for lazy_in, real_out in zip(arrays, computed_arrays):
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/dask/base.py in compute(*args, **kwargs)
#     568         postcomputes.append(x.__dask_postcompute__())
#     569
# --> 570     results = schedule(dsk, keys, **kwargs)
#     571     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     572
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      85         get_id=_thread_get_id,
#      86         pack_exception=pack_exception,
# ---> 87         **kwargs,
#      88     )
#      89
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/dask/local.py in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     505                             _execute_task(task, data)  # Re-execute locally
#     506                         else:
# --> 507                             raise_exception(exc, tb)
#     508                     res, worker_id = loads(res_info)
#     509                     state["cache"][key] = res
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/dask/local.py in reraise(exc, tb)
#     313     if exc.__traceback__ is not tb:
#     314         raise exc.with_traceback(tb)
# --> 315     raise exc
#     316
#     317
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/dask/local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     218     try:
#     219         task, data = loads(task_info)
# --> 220         result = _execute_task(task, data)
#     221         id = get_id()
#     222         result = dumps((result, id))
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     117         # temporaries by their reference count and can execute certain
#     118         # operations in-place.
# --> 119         return func(*(_execute_task(a, cache) for a in args))
#     120     elif not ishashable(arg):
#     121         return arg
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/dask/array/core.py in getter(a, b, asarray, lock)
#     100         lock.acquire()
#     101     try:
# --> 102         c = a[b]
#     103         # Below we special-case `np.matrix` to force a conversion to
#     104         # `np.ndarray` and preserve original Dask behavior for `getter`,
#
# /nfs/a321/gy17m2a/anaconda_install/anaconda3/envs/ukcp18/lib/python3.7/site-packages/iris/fileformats/netcdf.py in __getitem__(self, keys)
#     411
#     412     def __getitem__(self, keys):
# --> 413         dataset = netCDF4.Dataset(self.path)
#     414         try:
#     415             variable = dataset.variables[self.variable_name]
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# PermissionError: [Errno 13] Permission denied: b'/nfs/a161/gy17m2a/PhD/datadir/NIMROD/5mins/OriginalFormat_1km/2006/metoffice-c-band-rain-radar_uk_20060602.nc'
