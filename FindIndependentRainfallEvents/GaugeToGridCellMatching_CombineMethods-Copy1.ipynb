# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from warnings import simplefilter
warnings.filterwarnings("ignore", category =UserWarning,)

from pyproj import Transformer
import numpy as np
import pandas as pd
import iris
import glob
import sys
import os
import cartopy.crs as ccrs
import itertools
from scipy import spatial
import numpy.ma as ma
import tilemapbase
import iris.plot as iplt
from math import cos, radians
import geopandas as gpd
from shapely.geometry import Polygon
import matplotlib.pyplot as plt

from Identify_Events_Functions import *

pd.set_option('display.float_format', '{:.3f}'.format)

# %%
def find_amax_indy_events_v1 (df, duration, Tb0):
    
    rainfall_events = find_independent_events(df, Tb0)
    max_val, max_df = find_max_for_this_duration(rainfall_events, duration = duration)
    return max_df

def find_amax_indy_events_v2 (df, duration, Tb0):
    
    rainfall_cores = find_rainfall_core(df, duration=duration, Tb0= Tb0)
    rainfall_events_expanded= []

    for rainfall_core in rainfall_cores:
        rainfall_core_after_search1 = search1(df, rainfall_core)
        rainfall_core_after_search2 = search2(df, rainfall_core_after_search1)
        rainfall_core_after_search3 = search3(df, rainfall_core_after_search2, Tb0= Tb0)
        if len(rainfall_core_after_search3[rainfall_core_after_search3['precipitation (mm/hr)']>0.1]) > 0:
            rainfall_events_expanded.append(rainfall_core_after_search3)
    
    return rainfall_events_expanded

def find_gauge_Tb0_and_location_in_grid (gauge_num, sample_cube):
    # Get data just for this gauge
    gauge1 = tbo_vals.iloc[gauge_num]
    # Find the interevent arrival time (Tb0)
    Tb0 = int(gauge1['Critical_interarrival_time'])
    # Find the coordinates of the cell containing this gauge
    closest_point, idx_2d = find_position_obs(sample_cube,gauge1['Lat'], gauge1['Lon'], plot=False)
    
    return Tb0, idx_2d

def read_model_data(em, yr, idx_2d):
    filename = f'/nfs/a319/gy17m2a/PhD/ProcessedData/TimeSeries/UKCP18_every30mins/2.2km/2002_2020/{em}_wholeyear/{yr}_maskedcube.nc'
    cube = iris.load(filename)[0]
    # This gauge
    data = cube[:,idx_2d[0],idx_2d[1]].data
    # Data as dataframe
    df= pd.DataFrame({'precipitation (mm/hr)':data})
    df['times'] = cube[:,idx_2d[0],idx_2d[1]].coord('time').units.num2date(cube.coord('time').points)
    # New precipitation accumulation column
    df['precipitation (mm)'] = df['precipitation (mm/hr)']/2            
    return df

# %%
## Needed for finding location of gauge in grid
sample_cube = iris.load(f'/nfs/a319/gy17m2a/PhD/datadir/UKCP18_every30mins/2.2km_bng/bc005/2002_2020/bng_bc005a.pr200508*')[0][1,:,:]

# %%
# Get tb0 values at each gauge
tbo_vals = pd.read_csv('/nfs/a319/gy17m2a/PhD/datadir/RainGauge/interarrival_thresholds_CDD_noMissing.txt')

# %% [markdown]
# ### Get Tb0 values from gauge data

# %% [markdown]
# ### Get model data: 30 mins data for one ensemble member 2001-2019
#
# For 5 hour duration events: Find all independent AMAX producing events at grid cells containing a rain gauge

# %%
def is_sequential(numbers):
    return all(numbers[i] - numbers[i - 1] == 1 for i in range(1, len(numbers)))

# %%
# # Loop through gauges
# for gauge_num in [36]:
    
#     # Find the Tb0 and index of this gauge
#     Tb0, idx_2d = find_gauge_Tb0_and_location_in_grid(gauge_num, sample_cube)
    
#     for em in ['bc005']:
#         directory = f"../../ProcessedData/IndependentEvents/{em}/Gauge{gauge_num}/Option2"
#         files = [f for f in os.listdir(directory) if f.endswith('.csv')]
#         files = np.sort(files)
#         for file in files:
#             test = pd.read_csv(directory+ '/'+ file)
#             if test['Unnamed: 0'].is_monotonic_increasing ==False:
#                 print(f"not monotonic: {file}")
#             if not is_sequential(test['Unnamed: 0']):
#                 print(f"not sequential {file}")

# %%
# gauge_num=37
# Tb0, idx_2d = find_gauge_Tb0_and_location_in_grid(gauge_num, sample_cube)
# yr=2001
# duration=12
# em='bc005'
# df =read_model_data(em, yr, idx_2d)
# events_v2 = find_amax_indy_events_v2(df, duration =duration, Tb0=Tb0)
events_v2
# Out:
# []

# %%
# Loop through gauges
for gauge_num in [37]:
    
    # Find the Tb0 and index of this gauge
    Tb0, idx_2d = find_gauge_Tb0_and_location_in_grid(gauge_num, sample_cube)
    
    for em in ['bc005']:
        
        # Make directory to store outputs
        if not os.path.isdir(f"../../ProcessedData/IndependentEvents/{em}/Gauge{gauge_num}/Option1"):
            os.makedirs(f"../../ProcessedData/IndependentEvents/{em}/Gauge{gauge_num}/Option1")
        if not os.path.isdir(f"../../ProcessedData/IndependentEvents/{em}/Gauge{gauge_num}/Option2"):
            os.makedirs(f"../../ProcessedData/IndependentEvents/{em}/Gauge{gauge_num}/Option2")
        
        for yr in range(2001,2020):
            
            if not all(os.path.exists(f"../../ProcessedData/IndependentEvents/{em}/Gauge{gauge_num}/{option}/{duration}hrs_{yr}_v1.csv") for option in ['Option1', 'Option2'] for duration in [0.5, 1, 2, 3, 6, 12, 24]):

                # Get data for this ensemble member and year, at the grid cell containing this gauge
                df =read_model_data(em, yr, idx_2d)

                # Loop through duration
                for duration in [0.5, 1, 2, 3, 6, 12, 24]:    
                    print(f"Finding the AMAX for {duration}hr events in em {em} for the year {yr}")
                    
                    if os.path.isfile(f"../../ProcessedData/IndependentEvents/{em}/Gauge{gauge_num}/Option1/{duration}hrs_{yr}_v1.csv"):
                        print("Option 1 already exists")
                    else:
                        event_v1 = find_amax_indy_events_v1(df, duration =duration, Tb0=Tb0)
                        if len(event_v1)>1:
                            event_v1.to_csv(f"../../ProcessedData/IndependentEvents/{em}/Gauge{gauge_num}/Option1/{duration}hrs_{yr}_v1.csv")
                            print(f"Option 1: length with my method {len(event_v1)/2}, from {event_v1.index[0]}  to {event_v1.index[-1]} ")
                    
                    if os.path.isfile(f"../../ProcessedData/IndependentEvents/{em}/Gauge{gauge_num}/Option2/{duration}hrs_{yr}_v2_part0.csv"):
                        print("Option 2 already exists")
                    else:
                        events_v2 = find_amax_indy_events_v2(df, duration =duration, Tb0=Tb0)
                        for num, event in enumerate(events_v2):
                            if len(event)>1:
                                if event.index.is_monotonic_increasing ==False:
                                    print(f"monotonic: {duration}, {yr}")
                                if not is_sequential(event.index):
                                    print(f"not sequential {file}")
                                event.to_csv(f"../../ProcessedData/IndependentEvents/{em}/Gauge{gauge_num}/Option2/{duration}hrs_{yr}_v2_part{num}.csv")
                                print(f"Option 2: length with RVH method {len(events_v2[num])/2}, from {events_v2[num].index[0]}  to {events_v2[num].index[-1]} ")
                        
            else:
                print(f"all files already exist for {yr}")
# Out:
# Finding the AMAX for 0.5hr events in em bc005 for the year 2001
# Option 1 already exists
# Option 2: length with RVH method 51.0, from 9860  to 9961
# Finding the AMAX for 1hr events in em bc005 for the year 2001
# Option 1 already exists
# Option 2: length with RVH method 34.0, from 9562  to 9629
# Finding the AMAX for 2hr events in em bc005 for the year 2001
# Option 1 already exists
# Option 2: length with RVH method 34.0, from 9562  to 9629
# Finding the AMAX for 3hr events in em bc005 for the year 2001
# Option 1 already exists
# Option 2: length with RVH method 34.0, from 9562  to 9629
# Finding the AMAX for 6hr events in em bc005 for the year 2001
# Option 1 already exists
# Option 2: length with RVH method 36.5, from 9562  to 9634
# Finding the AMAX for 12hr events in em bc005 for the year 2001
# Option 1 already exists
# Option 2: length with RVH method 216.0, from 0  to 431
# Finding the AMAX for 24hr events in em bc005 for the year 2001
# Option 1 already exists
# Option 2: length with RVH method 216.0, from 0  to 431
# Finding the AMAX for 0.5hr events in em bc005 for the year 2002
# Option 1 already exists
# Option 2: length with RVH method 142.5, from 9943  to 10227
# Finding the AMAX for 1hr events in em bc005 for the year 2002
# Option 1 already exists
# Option 2: length with RVH method 142.5, from 9943  to 10227
# Finding the AMAX for 2hr events in em bc005 for the year 2002
# Option 1 already exists
# Option 2: length with RVH method 142.5, from 9943  to 10227
# Finding the AMAX for 3hr events in em bc005 for the year 2002
# Option 1 already exists
# Option 2: length with RVH method 142.5, from 9943  to 10227
# Finding the AMAX for 6hr events in em bc005 for the year 2002
# Option 1 already exists
# Option 2: length with RVH method 142.5, from 9943  to 10227
# Finding the AMAX for 12hr events in em bc005 for the year 2002
# Option 1 already exists
# Option 2: length with RVH method 142.5, from 9943  to 10227
# Finding the AMAX for 24hr events in em bc005 for the year 2002
# Option 1 already exists
# Option 2: length with RVH method 146.5, from 9943  to 10235
# Finding the AMAX for 0.5hr events in em bc005 for the year 2003
# Option 1 already exists
# Option 2: length with RVH method 130.5, from 9316  to 9576
# Finding the AMAX for 1hr events in em bc005 for the year 2003
# Option 1 already exists
# Option 2: length with RVH method 130.5, from 9316  to 9576
# Finding the AMAX for 2hr events in em bc005 for the year 2003
# Option 1 already exists
# Option 2: length with RVH method 130.5, from 9316  to 9576
# Finding the AMAX for 3hr events in em bc005 for the year 2003
# Option 1 already exists
# Option 2: length with RVH method 90.5, from 11237  to 11417
# Finding the AMAX for 6hr events in em bc005 for the year 2003
# Option 1 already exists
# Option 2: length with RVH method 90.5, from 11237  to 11417
# Finding the AMAX for 12hr events in em bc005 for the year 2003
# Option 1 already exists
# Option 2: length with RVH method 104.5, from 968  to 1176
# Finding the AMAX for 24hr events in em bc005 for the year 2003
# Option 1 already exists
# Option 2: length with RVH method 30.0, from 12375  to 12434
# Finding the AMAX for 0.5hr events in em bc005 for the year 2004
# Option 1 already exists
# Option 2: length with RVH method 145.5, from 9622  to 9912
# Finding the AMAX for 1hr events in em bc005 for the year 2004
# Option 1 already exists
# Option 2: length with RVH method 145.5, from 9622  to 9912
# Finding the AMAX for 2hr events in em bc005 for the year 2004
# Option 1 already exists
# Option 2: length with RVH method 145.5, from 9622  to 9912
# Finding the AMAX for 3hr events in em bc005 for the year 2004
# Option 1 already exists
# Option 2: length with RVH method 146.5, from 9622  to 9914
# Finding the AMAX for 6hr events in em bc005 for the year 2004
# Option 1 already exists
# 2 events
# Option 2: length with RVH method 145.5, from 9622  to 9912
# Option 2: length with RVH method 145.5, from 9622  to 9912
# Finding the AMAX for 12hr events in em bc005 for the year 2004
# Option 1 already exists
# 2 events
# Option 2: length with RVH method 139.5, from 9622  to 9900
# Option 2: length with RVH method 147.0, from 9622  to 9915
# Finding the AMAX for 24hr events in em bc005 for the year 2004
# Option 1 already exists
# 2 events
# Option 2: length with RVH method 150.0, from 9622  to 9921
# Option 2: length with RVH method 167.5, from 9622  to 9956
# Finding the AMAX for 0.5hr events in em bc005 for the year 2005
# Option 1 already exists
# Option 2: length with RVH method 117.5, from 6433  to 6667
# Finding the AMAX for 1hr events in em bc005 for the year 2005
# Option 1 already exists
# Option 2: length with RVH method 117.5, from 6433  to 6667
# Finding the AMAX for 2hr events in em bc005 for the year 2005
# Option 1 already exists
# Option 2: length with RVH method 46.0, from 12043  to 12134
# Finding the AMAX for 3hr events in em bc005 for the year 2005
# Option 1 already exists
# Option 2: length with RVH method 46.0, from 12043  to 12134
# Finding the AMAX for 6hr events in em bc005 for the year 2005
# Option 1 already exists
# Option 2: length with RVH method 46.0, from 12043  to 12134
# Finding the AMAX for 12hr events in em bc005 for the year 2005
# Option 1 already exists
# Option 2: length with RVH method 164.5, from 10485  to 10813
# Finding the AMAX for 24hr events in em bc005 for the year 2005
# Option 1 already exists
# Option 2: length with RVH method 164.5, from 10485  to 10813
# Finding the AMAX for 0.5hr events in em bc005 for the year 2006
# Option 1 already exists
# Option 2: length with RVH method 27.0, from 9336  to 9389
# Finding the AMAX for 1hr events in em bc005 for the year 2006
# Option 1 already exists
# Option 2: length with RVH method 26.0, from 11813  to 11864
# Finding the AMAX for 2hr events in em bc005 for the year 2006
# Option 1 already exists
# Option 2: length with RVH method 26.0, from 11813  to 11864
# Finding the AMAX for 3hr events in em bc005 for the year 2006
# Option 1 already exists
# Option 2: length with RVH method 26.0, from 11813  to 11864
# Finding the AMAX for 6hr events in em bc005 for the year 2006
# Option 1 already exists
# Option 2: length with RVH method 26.0, from 11813  to 11864
# Finding the AMAX for 12hr events in em bc005 for the year 2006
# Option 1 already exists
# Option 2: length with RVH method 27.5, from 15744  to 15798
# Finding the AMAX for 24hr events in em bc005 for the year 2006
# Option 1 already exists
# Option 2: length with RVH method 32.5, from 15744  to 15808
# Finding the AMAX for 0.5hr events in em bc005 for the year 2007
# Option 1 already exists
# Option 2: length with RVH method 24.5, from 8198  to 8246
# Finding the AMAX for 1hr events in em bc005 for the year 2007
# Option 1 already exists
# Option 2: length with RVH method 24.5, from 8198  to 8246
# Finding the AMAX for 2hr events in em bc005 for the year 2007
# Option 1 already exists
# Option 2: length with RVH method 24.5, from 8198  to 8246
# Finding the AMAX for 3hr events in em bc005 for the year 2007
# Option 1 already exists
# Option 2: length with RVH method 24.5, from 8198  to 8246
# Finding the AMAX for 6hr events in em bc005 for the year 2007
# Option 1 already exists
# Option 2: length with RVH method 24.5, from 8198  to 8246
# Finding the AMAX for 12hr events in em bc005 for the year 2007
# Option 1 already exists
# Option 2: length with RVH method 50.5, from 15471  to 15571
# Finding the AMAX for 24hr events in em bc005 for the year 2007
# Option 1 already exists
# Option 2: length with RVH method 31.0, from 16668  to 16729
# Finding the AMAX for 0.5hr events in em bc005 for the year 2008
# Option 1 already exists
# Option 2: length with RVH method 86.5, from 7873  to 8045
# Finding the AMAX for 1hr events in em bc005 for the year 2008
# Option 1 already exists
# Option 2: length with RVH method 86.5, from 7873  to 8045
# Finding the AMAX for 2hr events in em bc005 for the year 2008
# Option 1 already exists
# Option 2: length with RVH method 86.5, from 7873  to 8045
# Finding the AMAX for 3hr events in em bc005 for the year 2008
# Option 1 already exists
# Option 2: length with RVH method 86.5, from 7873  to 8045
# Finding the AMAX for 6hr events in em bc005 for the year 2008
# Option 1 already exists
# Option 2: length with RVH method 88.5, from 7873  to 8049
# Finding the AMAX for 12hr events in em bc005 for the year 2008
# Option 1 already exists
# 2 events
# Option 2: length with RVH method 86.5, from 7873  to 8045
# Option 2: length with RVH method 88.0, from 7873  to 8048
# Finding the AMAX for 24hr events in em bc005 for the year 2008
# Option 1 already exists
# 2 events
# Option 2: length with RVH method 72.5, from 7873  to 8017
# Option 2: length with RVH method 92.0, from 7873  to 8056
# Finding the AMAX for 0.5hr events in em bc005 for the year 2009
# Option 1 already exists
# Option 2: length with RVH method 32.0, from 8128  to 8191
# Finding the AMAX for 1hr events in em bc005 for the year 2009
# Option 1 already exists
# Option 2: length with RVH method 32.0, from 8128  to 8191
# Finding the AMAX for 2hr events in em bc005 for the year 2009
# Option 1 already exists
# Option 2: length with RVH method 32.0, from 8128  to 8191
# Finding the AMAX for 3hr events in em bc005 for the year 2009
# Option 1 already exists
# Option 2: length with RVH method 32.0, from 8128  to 8191
# Finding the AMAX for 6hr events in em bc005 for the year 2009
# Option 1 already exists
# Option 2: length with RVH method 32.0, from 8128  to 8191
# Finding the AMAX for 12hr events in em bc005 for the year 2009
# Option 1 already exists
# 2 events
# Option 2: length with RVH method 32.0, from 8128  to 8191
# Option 2: length with RVH method 35.0, from 8128  to 8197
# Finding the AMAX for 24hr events in em bc005 for the year 2009
# Option 1 already exists
# Option 2: length with RVH method 93.5, from 16633  to 16819
# Finding the AMAX for 0.5hr events in em bc005 for the year 2010
# Option 1 already exists
# Option 2: length with RVH method 80.0, from 9262  to 9421
# Finding the AMAX for 1hr events in em bc005 for the year 2010
# Option 1 already exists
# Option 2: length with RVH method 80.0, from 9262  to 9421
# Finding the AMAX for 2hr events in em bc005 for the year 2010
# Option 1 already exists
# Option 2: length with RVH method 331.5, from 7147  to 7809
# Finding the AMAX for 3hr events in em bc005 for the year 2010
# Option 1 already exists
# Option 2: length with RVH method 205.5, from 14844  to 15254
# Finding the AMAX for 6hr events in em bc005 for the year 2010
# Option 1 already exists
# Option 2: length with RVH method 331.5, from 7147  to 7809
# Finding the AMAX for 12hr events in em bc005 for the year 2010
# Option 1 already exists
# Option 2: length with RVH method 331.5, from 7147  to 7809
# Finding the AMAX for 24hr events in em bc005 for the year 2010
# Option 1 already exists
# 2 events
# Option 2: length with RVH method 339.5, from 7147  to 7825
# Option 2: length with RVH method 340.0, from 7147  to 7826
# Finding the AMAX for 0.5hr events in em bc005 for the year 2011
# Option 1 already exists
# Option 2: length with RVH method 109.5, from 6677  to 6895
# Finding the AMAX for 1hr events in em bc005 for the year 2011
# Option 1 already exists
# Option 2: length with RVH method 109.5, from 6677  to 6895
# Finding the AMAX for 2hr events in em bc005 for the year 2011
# Option 1 already exists
# Option 2: length with RVH method 109.5, from 6677  to 6895
# Finding the AMAX for 3hr events in em bc005 for the year 2011
# Option 1 already exists
# Option 2: length with RVH method 109.0, from 6677  to 6894
# Finding the AMAX for 6hr events in em bc005 for the year 2011
# Option 1 already exists
# Option 2: length with RVH method 19.0, from 11378  to 11415
# Finding the AMAX for 12hr events in em bc005 for the year 2011
# Option 1 already exists
# Option 2: length with RVH method 19.0, from 11378  to 11415
# Finding the AMAX for 24hr events in em bc005 for the year 2011
# Option 1 already exists
# 2 events
# Option 2: length with RVH method 23.5, from 11378  to 11424
# Option 2: length with RVH method 29.0, from 11378  to 11435
# Finding the AMAX for 0.5hr events in em bc005 for the year 2012
# Option 1 already exists
# Option 2: length with RVH method 72.0, from 9783  to 9926
# Finding the AMAX for 1hr events in em bc005 for the year 2012
# Option 1 already exists
# Option 2: length with RVH method 71.5, from 9783  to 9925
# Finding the AMAX for 2hr events in em bc005 for the year 2012
# Option 1 already exists
# Option 2: length with RVH method 71.5, from 9783  to 9925
# Finding the AMAX for 3hr events in em bc005 for the year 2012
# Option 1 already exists
# Option 2: length with RVH method 71.5, from 9783  to 9925
# Finding the AMAX for 6hr events in em bc005 for the year 2012
# Option 1 already exists
# Option 2: length with RVH method 71.5, from 9783  to 9925
# Finding the AMAX for 12hr events in em bc005 for the year 2012
# Option 1 already exists
# Option 2: length with RVH method 72.0, from 9783  to 9926
# Finding the AMAX for 24hr events in em bc005 for the year 2012
# Option 1 already exists
# Option 2: length with RVH method 78.5, from 9783  to 9939
# Finding the AMAX for 0.5hr events in em bc005 for the year 2013
# Option 1 already exists
# Option 2: length with RVH method 3.0, from 6847  to 6852
# Finding the AMAX for 1hr events in em bc005 for the year 2013
# Option 1 already exists
# Option 2: length with RVH method 9.5, from 6902  to 6920
# Finding the AMAX for 2hr events in em bc005 for the year 2013
# Option 1 already exists
# Option 2: length with RVH method 9.5, from 6902  to 6920
# Finding the AMAX for 3hr events in em bc005 for the year 2013
# Option 1 already exists
# Option 2: length with RVH method 9.5, from 6902  to 6920
# Finding the AMAX for 6hr events in em bc005 for the year 2013
# Option 1 already exists
# Option 2: length with RVH method 11.0, from 6902  to 6923
# Finding the AMAX for 12hr events in em bc005 for the year 2013
# Option 1 already exists
# Option 2: length with RVH method 142.5, from 10178  to 10462
# Finding the AMAX for 24hr events in em bc005 for the year 2013
# Option 1 already exists
# Option 2: length with RVH method 44.5, from 3319  to 3407
# Finding the AMAX for 0.5hr events in em bc005 for the year 2014
# Option 1 already exists
# Option 2: length with RVH method 36.5, from 7829  to 7901
# Finding the AMAX for 1hr events in em bc005 for the year 2014
# Option 1 already exists
# Option 2: length with RVH method 83.5, from 12711  to 12877
# Finding the AMAX for 2hr events in em bc005 for the year 2014
# Option 1 already exists
# Option 2: length with RVH method 83.5, from 12711  to 12877
# Finding the AMAX for 3hr events in em bc005 for the year 2014
# Option 1 already exists
# Option 2: length with RVH method 83.5, from 12711  to 12877
# Finding the AMAX for 6hr events in em bc005 for the year 2014
# Option 1 already exists
# Option 2: length with RVH method 83.5, from 12711  to 12877
# Finding the AMAX for 12hr events in em bc005 for the year 2014
# Option 1 already exists
# Option 2: length with RVH method 128.5, from 11512  to 11768
# Finding the AMAX for 24hr events in em bc005 for the year 2014
# Option 1 already exists
# 2 events
# Option 2: length with RVH method 142.0, from 11512  to 11795
# Option 2: length with RVH method 142.0, from 11512  to 11795
# Finding the AMAX for 0.5hr events in em bc005 for the year 2015
# Option 1 already exists
# Option 2: length with RVH method 23.0, from 8732  to 8777
# Finding the AMAX for 1hr events in em bc005 for the year 2015
# Option 1 already exists
# Option 2: length with RVH method 23.0, from 8732  to 8777
# Finding the AMAX for 2hr events in em bc005 for the year 2015
# Option 1 already exists
# Option 2: length with RVH method 48.5, from 12323  to 12419
# Finding the AMAX for 3hr events in em bc005 for the year 2015
# Option 1 already exists
# Option 2: length with RVH method 48.5, from 12323  to 12419
# Finding the AMAX for 6hr events in em bc005 for the year 2015
# Option 1 already exists
# Option 2: length with RVH method 48.5, from 12323  to 12419
# Finding the AMAX for 12hr events in em bc005 for the year 2015
# Option 1 already exists
# Option 2: length with RVH method 48.5, from 12323  to 12419
# Finding the AMAX for 24hr events in em bc005 for the year 2015
# Option 1 already exists
# 2 events
# Option 2: length with RVH method 31.0, from 12323  to 12384
# Option 2: length with RVH method 48.5, from 12323  to 12419
# Finding the AMAX for 0.5hr events in em bc005 for the year 2016
# Option 1 already exists
# Option 2: length with RVH method 87.0, from 11903  to 12076
# Finding the AMAX for 1hr events in em bc005 for the year 2016
# Option 1 already exists
# Option 2: length with RVH method 76.5, from 11320  to 11472
# Finding the AMAX for 2hr events in em bc005 for the year 2016
# Option 1 already exists
# Option 2: length with RVH method 76.5, from 11320  to 11472
# Finding the AMAX for 3hr events in em bc005 for the year 2016
# Option 1 already exists
# Option 2: length with RVH method 46.0, from 13048  to 13139
# Finding the AMAX for 6hr events in em bc005 for the year 2016
# Option 1 already exists
# Option 2: length with RVH method 46.0, from 13048  to 13139
# Finding the AMAX for 12hr events in em bc005 for the year 2016
# Option 1 already exists
# Option 2: length with RVH method 46.5, from 13048  to 13140
# Finding the AMAX for 24hr events in em bc005 for the year 2016
# Option 1 already exists
# Option 2: length with RVH method 187.5, from 14418  to 14792
# Finding the AMAX for 0.5hr events in em bc005 for the year 2017
# Option 1 already exists
# Option 2: length with RVH method 121.0, from 9980  to 10221
# Finding the AMAX for 1hr events in em bc005 for the year 2017
# Option 1 already exists
# Option 2: length with RVH method 121.0, from 9980  to 10221
# Finding the AMAX for 2hr events in em bc005 for the year 2017
# Option 1 already exists
# Option 2: length with RVH method 121.0, from 9980  to 10221
# Finding the AMAX for 3hr events in em bc005 for the year 2017
# Option 1 already exists
# Option 2: length with RVH method 121.0, from 9980  to 10221
# Finding the AMAX for 6hr events in em bc005 for the year 2017
# Option 1 already exists
# Option 2: length with RVH method 121.0, from 9980  to 10221
# Finding the AMAX for 12hr events in em bc005 for the year 2017
# Option 1 already exists
# Option 2: length with RVH method 312.5, from 11586  to 12210
# Finding the AMAX for 24hr events in em bc005 for the year 2017
# Option 1 already exists
# Option 2: length with RVH method 312.5, from 11586  to 12210
# Finding the AMAX for 0.5hr events in em bc005 for the year 2018
# Option 1 already exists
# Option 2: length with RVH method 14.0, from 8405  to 8432
# Finding the AMAX for 1hr events in em bc005 for the year 2018
# Option 1 already exists
# Option 2: length with RVH method 14.0, from 8405  to 8432
# Finding the AMAX for 2hr events in em bc005 for the year 2018
# Option 1 already exists
# Option 2: length with RVH method 14.0, from 8405  to 8432
# Finding the AMAX for 3hr events in em bc005 for the year 2018
# Option 1 already exists
# Option 2: length with RVH method 14.0, from 8405  to 8432
# Finding the AMAX for 6hr events in em bc005 for the year 2018
# Option 1 already exists
# Option 2: length with RVH method 15.5, from 8405  to 8435
# Finding the AMAX for 12hr events in em bc005 for the year 2018
# Option 1 already exists
# 2 events
# Option 2: length with RVH method 18.5, from 8405  to 8441
# Option 2: length with RVH method 22.0, from 8405  to 8448
# Finding the AMAX for 24hr events in em bc005 for the year 2018
# Option 1 already exists
# Option 2: length with RVH method 280.0, from 192  to 751
# Finding the AMAX for 0.5hr events in em bc005 for the year 2019
# Option 1 already exists
# Option 2: length with RVH method 129.5, from 9195  to 9453
# Finding the AMAX for 1hr events in em bc005 for the year 2019
# Option 1 already exists
# Option 2: length with RVH method 129.5, from 9195  to 9453
# Finding the AMAX for 2hr events in em bc005 for the year 2019
# Option 1 already exists
# Option 2: length with RVH method 129.5, from 9195  to 9453
# Finding the AMAX for 3hr events in em bc005 for the year 2019
# Option 1 already exists
# Option 2: length with RVH method 27.5, from 13300  to 13354
# Finding the AMAX for 6hr events in em bc005 for the year 2019
# Option 1 already exists
# Option 2: length with RVH method 26.0, from 2057  to 2108
# Finding the AMAX for 12hr events in em bc005 for the year 2019
# Option 1 already exists
# Option 2: length with RVH method 71.0, from 5022  to 5163
# Finding the AMAX for 24hr events in em bc005 for the year 2019
# Option 1 already exists
# Option 2: length with RVH method 76.0, from 5022  to 5173

# %%
# # Extract 'dataframe' items for dictionaries with 'year' == 2005
# dataframes_2h = [event['Event'] for event in events_v1_ls if event['Duration'] ==2]

# %% [markdown]
# ## Summary statistic

# %%
def calculate_normalized_com(times, intensities):
    """
    Calculate the normalized center of mass for a rainfall event.
    
    Parameters:
        times (np.array): Array of time points (scaled to the duration of the event, e.g., as fractions of the total duration)
        intensities (np.array): Array of rainfall intensities at the corresponding times
    
    Returns:
        float: The normalized center of mass of the rainfall event.
    """
    intensities = intensities.astype(float)
    
    # Normalize time values to a scale of 0 to 1 (assuming times are already normalized if not multiply by (times - times.min()) / (times.max() - times.min()))
    normalized_times = (times - times.min()) / (times.max() - times.min())
    
    # Calculate the weighted average of normalized time points
    center_of_mass = np.sum(normalized_times * intensities) / np.sum(intensities)
    
    return center_of_mass

# Example usage:
times = np.array([1, 2, 3, 4, 5])  # e.g., time points of the event
intensities = np.array([5, 15, 25, 15, 5])  # rainfall intensities

com = calculate_normalized_com(times, intensities)
print("Normalized Center of Mass of the rainfall event:", com)

# %%
def calculate_p_dry(rainfall_amounts, total_duration):
    """
    Calculate the proportion of dry periods in a rainfall event.

    Parameters:
        rainfall_amounts (np.array): Array of rainfall amounts at consistent time intervals.
        total_duration (float): Total duration of the rainfall event in the same units as the time intervals.

    Returns:
        float: The proportion of the total duration that was dry (no rainfall).
    """
    # Calculate the number of dry periods (intervals with zero rainfall)
    dry_periods = np.sum(rainfall_amounts < 0.1)
    
    # Assuming the time interval between rainfall measurements is constant and the sum of intervals equals total_duration
    p_dry = dry_periods / len(rainfall_amounts)

    return p_dry

# Example usage:
rainfall_amounts = np.array([0, 0, 5, 0, 2, 0, 0, 0, 3, 0])  # rainfall amounts, where 0 indicates a dry period
total_duration = 10  # total number of intervals, which could be in hours, minutes, etc.

p_dry = calculate_p_dry(rainfall_amounts, total_duration)
print("Proportion of Dry Period (Pdry):", p_dry)
# Out:
# Proportion of Dry Period (Pdry): 0.7

# %%
def calculate_effective_intensity(rainfall_amounts, total_duration):
    """
    Calculate the effective rainstorm intensity, ignoring dry periods.

    Parameters:
        rainfall_amounts (np.array): Array of rainfall amounts at consistent time intervals.
        total_duration (float): Total duration of the rainfall event in the same units as the time intervals.

    Returns:
        float: Effective rainstorm intensity.
    """
    # Total Rainstorm Volume (sum of all rainfall amounts)
    total_volume = np.sum(rainfall_amounts)

    # Effective Rainstorm Duration (count of non-dry intervals)
    effective_duration = np.sum(rainfall_amounts > 0.1)  # Assuming time intervals are uniform

    # Calculate effective intensity
    if effective_duration > 0:
        effective_intensity = total_volume / effective_duration
    else:
        effective_intensity = 0

    return effective_intensity

# Example usage:
rainfall_amounts = np.array([0, 0, 5, 0, 2, 0, 0, 0, 3, 0])  # rainfall amounts, where 0 indicates a dry period
total_duration = 10  # total number of intervals, which could be in hours, minutes, etc.

effective_intensity = calculate_effective_intensity(rainfall_amounts, total_duration)
print("Effective Rainstorm Intensity (Ie):", effective_intensity)
# Out:
# Effective Rainstorm Intensity (Ie): 3.3333333333333335

# %%
intensities = event_v2['precipitation (mm)']
times = np.array(range(0,len(intensities)))
com = calculate_normalized_com(times, intensities)
print("Center of Mass of the rainfall event:", com)

# %%
p_dry = calculate_p_dry(np.array(intensities), len(intensities))
print("Proportion of Dry Period (Pdry):", p_dry)
# Out:
# Proportion of Dry Period (Pdry): 0.85

# %%
effective_intensity = calculate_effective_intensity(np.array(intensities), len(intensities))
print("Effective Rainstorm Intensity (Ie):", effective_intensity)
# Out:
# Effective Rainstorm Intensity (Ie): 4.5476226806640625

# %% [markdown]
# ## Plotting

# %%
# Assuming each event's DataFrame is stored in 'dataframe' key of dictionaries in the list
# Example event data retrieval
events_dataframes = [event['Event'] for event in events_v1_ls if event['Duration'] ==2]

# Plotting hyetographs
plt.figure(figsize=(10, 6))
for i, event_df in enumerate(events_dataframes):
    event_df.reset_index(inplace=True, drop=True)
    plt.plot(event_df.index, event_df['precipitation (mm/hr)'], label=f'Event {i+1}')
    plt.xlabel('Time')
    plt.ylabel('Precipitation (mm/hr)')
    plt.title(f'Hyetograph for Event {i+1}')
    plt.legend()
plt.show()

# %%
# Assuming each event's DataFrame is stored in 'dataframe' key of dictionaries in the list
# Example event data retrieval
events_dataframes = [event['Event'] for event in events_v2_ls if event['Duration'] ==2]

# Plotting hyetographs
plt.figure(figsize=(10, 6))
for i, event_df in enumerate(events_dataframes):
    event_df.reset_index(inplace=True, drop=True)
    plt.plot(event_df.index, event_df['precipitation (mm/hr)'], label=f'Event {i+1}')
    plt.xlabel('Time')
    plt.ylabel('Precipitation (mm/hr)')
    plt.title(f'Hyetograph for Event {i+1}')
    plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming each event's DataFrame is stored in 'dataframe' key of dictionaries in the list
# Example event data retrieval
events_dataframes = [event['Event'] for event in events_v2_ls if event['Duration'] ==6]

# Plotting hyetographs
plt.figure(figsize=(10, 6))
for i, event_df in enumerate(events_dataframes):
    event_df.reset_index(inplace=True, drop=True)
    plt.plot(event_df.index, event_df['precipitation (mm/hr)'], label=f'Event {i+1}')
    plt.xlabel('Time')
    plt.ylabel('Precipitation (mm/hr)')
    plt.title(f'Hyetograph for Event {i+1}')
    plt.legend()
plt.show()

# %% [markdown]
# ### Trying to work out why results for year 2002 and duration 2hr and em BC005 are so different

# %%
df =read_model_data(em, yr, idx_2d)

# %%
# SO in the set of independent events algorithm identifies there is an event from 1578-1627
# The event identified by algorithm v1 was 1594-1599
# The event identified by algorithm v1 was 1591-1609

# WHy does V1 trim it like it does?

# %%
rainfall_events = find_independent_events(df, Tb0)
rainfall_events
# Out:
# [{'start_index': 221,
#   'end_index': 247,
#   'event_data':      precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   221                  0.227               0.114   False              221
#   222                  2.191               1.096   False                0
#   223                  0.983               0.492   False                0
#   224                  0.309               0.155   False                0
#   225                  0.449               0.225   False                0
#   226                  0.287               0.143   False                0
#   227                  0.002               0.001    True                0
#   228                  0.152               0.076    True                1
#   229                  0.265               0.133   False                2
#
#        starts_after_dry_period
#   221                     True
#   222                    False
#   223                    False
#   224                    False
#   225                    False
#   226                    False
#   227                    False
#   228                    False
#   229                    False  },
#  {'start_index': 506,
#   'end_index': 538,
#   'event_data':      precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   506                  0.279               0.139   False              276
#   507                  0.000               0.000    True                0
#   508                  0.000               0.000    True                1
#   509                  0.000               0.000    True                2
#   510                  0.000               0.000    True                3
#   511                  0.000               0.000    True                4
#   512                  0.000               0.000    True                5
#   513                  0.000               0.000    True                6
#   514                  0.000               0.000    True                7
#   515                  0.000               0.000    True                8
#   516                  0.000               0.000    True                9
#   517                  0.000               0.000    True               10
#   518                  0.000               0.000    True               11
#   519                  0.000               0.000    True               12
#   520                  0.499               0.249   False               13
#
#        starts_after_dry_period
#   506                     True
#   507                    False
#   508                    False
#   509                    False
#   510                    False
#   511                    False
#   512                    False
#   513                    False
#   514                    False
#   515                    False
#   516                    False
#   517                    False
#   518                    False
#   519                    False
#   520                    False  },
#  {'start_index': 545,
#   'end_index': 563,
#   'event_data':      precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   545                  0.513               0.256   False               24
#
#        starts_after_dry_period
#   545                     True  },
#  {'start_index': 606,
#   'end_index': 625,
#   'event_data':      precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   606                  0.417               0.208   False               60
#   607                  0.206               0.103   False                0
#
#        starts_after_dry_period
#   606                     True
#   607                    False  },
#  {'start_index': 647,
#   'end_index': 666,
#   'event_data':      precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   647                  3.984               1.992   False               39
#   648                  8.460               4.230   False                0
#
#        starts_after_dry_period
#   647                     True
#   648                    False  },
#  {'start_index': 703,
#   'end_index': 733,
#   'event_data':      precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   703                  0.578               0.289   False               54
#   704                  0.477               0.239   False                0
#   705                  0.110               0.055    True                0
#   706                  0.140               0.070    True                1
#   707                  0.157               0.078    True                2
#   708                  0.047               0.023    True                3
#   709                  0.168               0.084    True                4
#   710                  0.055               0.028    True                5
#   711                  0.000               0.000    True                6
#   712                  0.000               0.000    True                7
#   713                  0.000               0.000    True                8
#   714                  0.000               0.000    True                9
#   715                  1.700               0.850   False               10
#
#        starts_after_dry_period
#   703                     True
#   704                    False
#   705                    False
#   706                    False
#   707                    False
#   708                    False
#   709                    False
#   710                    False
#   711                    False
#   712                    False
#   713                    False
#   714                    False
#   715                    False  },
#  {'start_index': 1007,
#   'end_index': 1027,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   1007                  0.588               0.294   False              291
#   1008                  3.099               1.550   False                0
#   1009                  0.357               0.179   False                0
#
#         starts_after_dry_period
#   1007                     True
#   1008                    False
#   1009                    False  },
#  {'start_index': 1468,
#   'end_index': 1488,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   1468                  0.422               0.211   False              458
#   1469                  0.870               0.435   False                0
#   1470                  1.182               0.591   False                0
#
#         starts_after_dry_period
#   1468                     True
#   1469                    False
#   1470                    False  },
#  {'start_index': 1545,
#   'end_index': 1563,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   1545                  1.102               0.551   False               74
#
#         starts_after_dry_period
#   1545                     True  },
#  {'start_index': 1578,
#   'end_index': 1627,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   1578                  1.840               0.920   False               32
#   1579                  2.203               1.102   False                0
#   1580                  0.000               0.000    True                0
#   1581                  0.000               0.000    True                1
#   1582                  0.000               0.000    True                2
#   1583                  0.490               0.245   False                3
#   1584                  0.000               0.000    True                0
#   1585                  0.000               0.000    True                1
#   1586                  0.000               0.000    True                2
#   1587                  0.000               0.000    True                3
#   1588                  0.000               0.000    True                4
#   1589                  0.000               0.000    True                5
#   1590                  0.000               0.000    True                6
#   1591                  2.087               1.044   False                7
#   1592                  3.729               1.865   False                0
#   1593                  4.581               2.291   False                0
#   1594                  2.363               1.181   False                0
#   1595                  3.473               1.737   False                0
#   1596                  8.678               4.339   False                0
#   1597                 10.176               5.088   False                0
#   1598                  8.358               4.179   False                0
#   1599                  4.889               2.444   False                0
#   1600                  0.015               0.008    True                0
#   1601                  4.244               2.122   False                1
#   1602                  4.558               2.279   False                0
#   1603                  2.786               1.393   False                0
#   1604                  2.255               1.128   False                0
#   1605                  5.713               2.856   False                0
#   1606                  2.068               1.034   False                0
#   1607                  2.419               1.209   False                0
#   1608                  6.500               3.250   False                0
#   1609                  2.593               1.296   False                0
#
#         starts_after_dry_period
#   1578                     True
#   1579                    False
#   1580                    False
#   1581                    False
#   1582                    False
#   1583                    False
#   1584                    False
#   1585                    False
#   1586                    False
#   1587                    False
#   1588                    False
#   1589                    False
#   1590                    False
#   1591                    False
#   1592                    False
#   1593                    False
#   1594                    False
#   1595                    False
#   1596                    False
#   1597                    False
#   1598                    False
#   1599                    False
#   1600                    False
#   1601                    False
#   1602                    False
#   1603                    False
#   1604                    False
#   1605                    False
#   1606                    False
#   1607                    False
#   1608                    False
#   1609                    False  },
#  {'start_index': 1672,
#   'end_index': 1711,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   1672                  0.745               0.372   False               62
#   1673                  0.470               0.235   False                0
#   1674                  0.000               0.000    True                0
#   1675                  0.019               0.010    True                1
#   1676                  0.000               0.000    True                2
#   1677                  0.000               0.000    True                3
#   1678                  0.000               0.000    True                4
#   1679                  0.000               0.000    True                5
#   1680                  0.000               0.000    True                6
#   1681                  0.000               0.000    True                7
#   1682                  0.000               0.000    True                8
#   1683                  0.000               0.000    True                9
#   1684                  0.000               0.000    True               10
#   1685                  3.106               1.553   False               11
#   1686                  0.011               0.005    True                0
#   1687                  0.000               0.000    True                1
#   1688                  0.000               0.000    True                2
#   1689                  0.000               0.000    True                3
#   1690                  0.779               0.389   False                4
#   1691                  1.312               0.656   False                0
#   1692                  0.382               0.191   False                0
#   1693                  1.406               0.703   False                0
#
#         starts_after_dry_period
#   1672                     True
#   1673                    False
#   1674                    False
#   1675                    False
#   1676                    False
#   1677                    False
#   1678                    False
#   1679                    False
#   1680                    False
#   1681                    False
#   1682                    False
#   1683                    False
#   1684                    False
#   1685                    False
#   1686                    False
#   1687                    False
#   1688                    False
#   1689                    False
#   1690                    False
#   1691                    False
#   1692                    False
#   1693                    False  },
#  {'start_index': 1765,
#   'end_index': 1796,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   1765                 10.248               5.124   False               71
#   1766                  1.679               0.839   False                0
#   1767                  0.566               0.283   False                0
#   1768                  0.000               0.000    True                0
#   1769                  0.000               0.000    True                1
#   1770                  0.000               0.000    True                2
#   1771                  0.000               0.000    True                3
#   1772                  0.000               0.000    True                4
#   1773                  0.000               0.000    True                5
#   1774                  0.002               0.001    True                6
#   1775                  2.559               1.279   False                7
#   1776                  5.512               2.756   False                0
#   1777                  5.892               2.946   False                0
#   1778                  4.248               2.124   False                0
#
#         starts_after_dry_period
#   1765                     True
#   1766                    False
#   1767                    False
#   1768                    False
#   1769                    False
#   1770                    False
#   1771                    False
#   1772                    False
#   1773                    False
#   1774                    False
#   1775                    False
#   1776                    False
#   1777                    False
#   1778                    False  },
#  {'start_index': 2003,
#   'end_index': 2021,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   2003                  2.013               1.007   False              224
#
#         starts_after_dry_period
#   2003                     True  },
#  {'start_index': 2055,
#   'end_index': 2074,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   2055                  4.720               2.360   False               51
#   2056                  1.005               0.503   False                0
#
#         starts_after_dry_period
#   2055                     True
#   2056                    False  },
#  {'start_index': 2081,
#   'end_index': 2106,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   2081                  0.698               0.349   False               24
#   2082                  0.000               0.000    True                0
#   2083                  0.000               0.000    True                1
#   2084                  0.000               0.000    True                2
#   2085                  0.003               0.002    True                3
#   2086                  3.980               1.990   False                4
#   2087                  0.005               0.003    True                0
#   2088                  0.386               0.193   False                1
#
#         starts_after_dry_period
#   2081                     True
#   2082                    False
#   2083                    False
#   2084                    False
#   2085                    False
#   2086                    False
#   2087                    False
#   2088                    False  },
#  {'start_index': 2129,
#   'end_index': 2166,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   2129                  0.448               0.224   False               40
#   2130                  1.095               0.548   False                0
#   2131                  1.303               0.652   False                0
#   2132                  1.679               0.840   False                0
#   2133                  1.784               0.892   False                0
#   2134                  2.291               1.146   False                0
#   2135                  1.029               0.514   False                0
#   2136                  1.194               0.597   False                0
#   2137                  0.778               0.389   False                0
#   2138                  1.639               0.819   False                0
#   2139                  0.722               0.361   False                0
#   2140                  0.938               0.469   False                0
#   2141                  0.789               0.394   False                0
#   2142                  0.658               0.329   False                0
#   2143                  0.526               0.263   False                0
#   2144                  0.191               0.096    True                0
#   2145                  0.002               0.001    True                1
#   2146                  0.000               0.000    True                2
#   2147                  0.000               0.000    True                3
#   2148                  0.527               0.263   False                4
#
#         starts_after_dry_period
#   2129                     True
#   2130                    False
#   2131                    False
#   2132                    False
#   2133                    False
#   2134                    False
#   2135                    False
#   2136                    False
#   2137                    False
#   2138                    False
#   2139                    False
#   2140                    False
#   2141                    False
#   2142                    False
#   2143                    False
#   2144                    False
#   2145                    False
#   2146                    False
#   2147                    False
#   2148                    False  },
#  {'start_index': 2186,
#   'end_index': 2210,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   2186                  0.280               0.140   False               37
#   2187                  1.120               0.560   False                0
#   2188                  0.661               0.330   False                0
#   2189                  0.438               0.219   False                0
#   2190                  0.282               0.141   False                0
#   2191                  0.271               0.135   False                0
#   2192                  0.600               0.300   False                0
#
#         starts_after_dry_period
#   2186                     True
#   2187                    False
#   2188                    False
#   2189                    False
#   2190                    False
#   2191                    False
#   2192                    False  },
#  {'start_index': 2242,
#   'end_index': 2260,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   2242                  1.838               0.919   False               49
#
#         starts_after_dry_period
#   2242                     True  },
#  {'start_index': 2667,
#   'end_index': 2686,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   2667                  1.209               0.605   False              424
#   2668                  0.535               0.268   False                0
#
#         starts_after_dry_period
#   2667                     True
#   2668                    False  },
#  {'start_index': 3050,
#   'end_index': 3072,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   3050                  0.219               0.110   False              381
#   3051                  0.840               0.420   False                0
#   3052                  0.235               0.117   False                0
#   3053                  2.126               1.063   False                0
#   3054                  0.483               0.241   False                0
#
#         starts_after_dry_period
#   3050                     True
#   3051                    False
#   3052                    False
#   3053                    False
#   3054                    False  },
#  {'start_index': 3352,
#   'end_index': 3370,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   3352                  0.560               0.280   False              297
#
#         starts_after_dry_period
#   3352                     True  },
#  {'start_index': 3437,
#   'end_index': 3455,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   3437                  0.677               0.338   False               84
#
#         starts_after_dry_period
#   3437                     True  },
#  {'start_index': 3992,
#   'end_index': 4011,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   3992                  0.305               0.152   False              554
#   3993                  0.509               0.254   False                0
#
#         starts_after_dry_period
#   3992                     True
#   3993                    False  },
#  {'start_index': 4047,
#   'end_index': 4065,
#   'event_data':       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
#   4047                  0.837               0.418   False               53
#
#         starts_after_dry_period
#   4047                     True  }]

# %%
duration = 2
# to account for each being 30mins
window_length = duration *2
one_independent_event_df = rainfall_events[9]['event_data']
one_independent_event_df['Rolling_Sum'] = one_independent_event_df['precipitation (mm)'].rolling(window=window_length).sum()

# Find the index of the maximum total rainfall within a 2-hour window
max_rainfall_end_index = one_independent_event_df['Rolling_Sum'].idxmax()

max_rainfall_end_pos = one_independent_event_df.index.get_loc(max_rainfall_end_index)

# Calculate the start position of the 2-hour window with the most rainfall
# This accounts for 3 periods before the max index, as the max index is inclusive
max_rainfall_start_pos = max(0, max_rainfall_end_pos - window_length)  # Ensure it doesn't go below the DataFrame's range

# Extract the 2-hour window using iloc
max_rainfall_window = one_independent_event_df.iloc[max_rainfall_start_pos:max_rainfall_end_pos]
max_rainfall_window
# Out:
#       precipitation (mm/hr)  precipitation (mm)  is_dry  consecutive_dry  \
# 1595                  3.473               1.737   False                0
# 1596                  8.678               4.339   False                0
# 1597                 10.176               5.088   False                0
# 1598                  8.358               4.179   False                0
#
#       starts_after_dry_period  Rolling_Sum
# 1595                    False        7.073
# 1596                    False        9.548
# 1597                    False       12.345
# 1598                    False       15.342

# %%
duration = 2
# to account for each being 30mins
window_length = duration *2

# to store the outcomes
max_val = 0
max_idx = 'PlaceHolder'
max_df = pd.DataFrame({})

# Search each of the independent rainfall events for a maximum value at this duration
for idx in range(1,len(rainfall_events)):

    # Get this independent event
    one_independent_event_df = rainfall_events[idx]['event_data']

    # Filter out events shorter than this duration
    if len(one_independent_event_df)>window_length:

        # Calculate the rolling sum of precipitation for each 2-hour window
        one_independent_event_df['Rolling_Sum'] = one_independent_event_df['precipitation (mm)'].rolling(window=window_length).sum()

        # Find the index of the maximum total rainfall within a 2-hour window
        max_rainfall_end_index = one_independent_event_df['Rolling_Sum'].idxmax()

        # Find the position of max_rainfall_end_index in the DataFrame's index
        max_rainfall_end_pos = one_independent_event_df.index.get_loc(max_rainfall_end_index)

        # Calculate the start position of the 2-hour window with the most rainfall
        # This accounts for 3 periods before the max index, as the max index is inclusive
        max_rainfall_start_pos = max(0, max_rainfall_end_pos - window_length-1)  # Ensure it doesn't go below the DataFrame's range

        # Extract the 2-hour window using iloc
        max_rainfall_window = one_independent_event_df.iloc[max_rainfall_start_pos:max_rainfall_end_pos + 1]

        # Display the results
        # print(f"The 2-hour window with the most rainfall ends at {max_rainfall_end_index} and includes:")

        # If the maximum value for this duration in this independent event, is bigger than the biggest one that came before
        # then save these results
        if one_independent_event_df['Rolling_Sum'].max() > max_val:
            max_val = one_independent_event_df['Rolling_Sum'].max()
            max_df = max_rainfall_window
            max_idx = idx
        else:
            pass

# %%
def find_amax_indy_events_v1 (df, duration, Tb0):
    
    rainfall_events = find_independent_events(df, Tb0)
    max_val, max_df, max_idx = find_max_for_this_duration(rainfall_events, duration = duration)
    return max_df

# %% [markdown]
# ## Create dimensionless profiles

# %%
import pandas as pd
from scipy.interpolate import interp1d
import numpy as np

# Assuming each event is a DataFrame in a list `events_dataframes`
# Each DataFrame has a 'time' column (in any consistent unit) and a 'precipitation' column

# Target number of intervals for the dimensionless representation
target_intervals = 12

dimensionless_events = []

for event_df in events_dataframes:
    # Normalize time scale from 0 to 1 for the event
    normalized_time = np.linspace(0, 1, num=len(event_df))
    
    # Target time scale with uniform length
    target_time_scale = np.linspace(0, 1, num=target_intervals)
    
    # Interpolation function for precipitation
    interp_func = interp1d(normalized_time, event_df['precipitation (mm/hr)'], kind='linear')
    
    # Interpolated precipitation values at the target time scale
    interpolated_precip = interp_func(target_time_scale)
    
    # Create a new DataFrame for the dimensionless event
    dimensionless_event_df = pd.DataFrame({
        'time': target_time_scale,
        'precipitation (mm/hr)': interpolated_precip
    })
    
    dimensionless_events.append(dimensionless_event_df)

# %%
# Plotting hyetographs
plt.figure(figsize=(10, 6))
for i, event_df in enumerate(dimensionless_events):
    event_df.reset_index(inplace=True, drop=True)
    plt.plot(event_df.index, event_df['precipitation (mm/hr)'], label=f'Event {i+1}')
    plt.xlabel('Time')
    plt.ylabel('Precipitation (mm/hr)')
    plt.title(f'Hyetograph for Event {i+1}')
    plt.legend()
plt.show()
